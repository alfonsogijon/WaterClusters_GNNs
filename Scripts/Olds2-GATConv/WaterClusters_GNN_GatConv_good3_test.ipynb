# %%
"""
This example shows how to perform regression of molecular properties with a
database of the atomic geometry of water clusters with an associated energy, 
using a simple GNN in disjoint mode.
"""

import numpy as np
import scipy.sparse as sp
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.losses import MeanAbsoluteError
from tensorflow.keras.losses import MeanAbsolutePercentageError
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_absolute_error, mean_squared_error
from mendeleev import H, O

# Install matplotlib inside the virtual env
#import pip
#pip.main(["install","matplotlib"])
import matplotlib.pyplot as plt

from spektral.data import Dataset, DisjointLoader, Graph
from spektral.datasets import QM9
from spektral.layers import GCSConv, ECCConv, GlobalSumPool, MessagePassing, GATConv, CrystalConv

#from spektral.utils import normalized_adjacency
# Out:
# 2023-01-26 18:19:39.698088: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-26 18:19:39.916766: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-01-26 18:19:40.710032: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-01-26 18:19:40.710115: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-01-26 18:19:40.710123: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
################################################################################
# Config
################################################################################
learning_rate = 1e-3  # Learning rate
#learning_rate = 1e-4  # Learning rate
#epochs = 200  # Number of training epochs
epochs = 150  # Number of training epochs
batch_size = 2  # Batch size

#initial_learning_rate = 1e-3
#learning_rate = tf.keras.optimizers.schedules.InverseTimeDecay(initial_learning_rate=initial_learning_rate, decay_steps=epochs/10, decay_rate=0.8)
#learning_rate = tf.keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=initial_learning_rate,
#                decay_steps=epochs/10, decay_rate=0.98)

"""
learning_rate = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=learning_rate_initial,
    decay_steps=epochs,
    decay_rate=0.98)
"""
# Out:
# '\nlearning_rate = tf.keras.optimizers.schedules.ExponentialDecay(\n    initial_learning_rate=learning_rate_initial,\n    decay_steps=epochs,\n    decay_rate=0.98)\n'

# %%
################################################################################
# Load data and make graphs
################################################################################
class MyDataset(Dataset):
    """
    A dataset of graphs obtained from the atomic positions of water
    clusters with size between 20 and 237 water molecules, each of them
    associated to an energy value.
    """

    def __init__(self, r2_cutoff, n_dim = 3, **kwargs):

        self.r2_cutoff = r2_cutoff
        self.n_dim = n_dim

        # path of the atomic geometry files
        self.geometry_paths = []
        data_dir = "../dataset_WaterClusters_big/"
        #data_dir = "../dataset_WaterClusters/"
        #for N in [20,32,47,76,100,139,190,237]:
            #for temp in [100,150,200]:
                #for MDstep in ["0500.dat","1000.dat","1500.dat","2000.dat"]:
                    #geometry_path = data_dir+"N"+str(N)+"-T"+str(temp)+"/"+str(MDstep)
                    #self.geometry_paths.append(geometry_path)
        for folder in os.listdir(data_dir): 
            dir_name = os.path.join(data_dir,folder)
            for file_name in os.listdir(dir_name):
                geometry_path = os.path.join(dir_name,file_name)
                self.geometry_paths.append(geometry_path)

        self.n_samples = len(self.geometry_paths)

        self.Epm_avrg = 0.0
        self.Epm_dev = 0.0
        self.E_avrg = 0.0
        self.E_dev = 0.0
        self.xmax = 22.0
        self.Emax = 0
        self.Emin = 0

        self.num_node_features = 0
        self.num_edge_features = 0
        self.num_labels = 0
        
        super().__init__(**kwargs)

    def read(self):

        def compute_Eavrg():

            # Compute the average energy per molecule among all the clusters

            Epm_avrg = 0.0
            E_avrg = 0.0
            Emax = 0.0
            Emin = 1E6
            
            for ii in range(self.n_samples):
            
                geom_path = self.geometry_paths[ii]
                gfile = open(geom_path,'r')
                line = gfile.readline()
                n_molecules = int(gfile.readline())
                line = gfile.readline()
                line = gfile.readline()
                line = gfile.readline()
                columns = line.split()
                energy = float(columns[0])
                gfile.close()

                Epm_avrg = Epm_avrg + energy / float(n_molecules)
                E_avrg = E_avrg + energy
                if(energy>Emax): Emax = energy
                if(energy<Emin): Emin = energy

            Epm_avrg = Epm_avrg / float(self.n_samples)
            E_avrg = E_avrg / float(self.n_samples)

            self.Epm_avrg = Epm_avrg
            self.E_avrg = E_avrg
            self.Emax = Emax
            self.Emin = Emin

            print("E_avrg: "+str(E_avrg))

        def compute_Edev():

            # Compute standard deviation from Epm_avrg

            Epm_dev = 0.0
            E_dev = 0.0

            for ii in range(self.n_samples):
            
                geom_path = self.geometry_paths[ii]
                gfile = open(geom_path,'r')
                line = gfile.readline()
                n_molecules = int(gfile.readline())
                line = gfile.readline()
                line = gfile.readline()
                line = gfile.readline()
                columns = line.split()
                energy = float(columns[0])
                gfile.close()

                Epm_dev = Epm_dev + ( energy / float(n_molecules) - self.Epm_avrg )**2
                E_dev = E_dev + ( energy - self.E_avrg )**2

            Epm_dev = np.sqrt( Epm_dev / float(self.n_samples) )
            E_dev = np.sqrt( E_dev / float(self.n_samples) )

            self.Epm_dev = Epm_dev
            self.E_dev = E_dev

            print("E_dev: "+str(E_dev))
            
        def make_graph(isample):

            # Process the header of the geometry file
            geom_path = self.geometry_paths[isample]
            gfile = open(geom_path,'r')
            line = gfile.readline()
            n_molecules = int(gfile.readline())
            line = gfile.readline()
            line = gfile.readline()
            line = gfile.readline()
            columns = line.split()
            energy = float(columns[0])
            line = gfile.readline()
            line = gfile.readline()            

            # Node features (atom type and position [x,y,z])            
            n_nodes = 3*n_molecules
            #num_node_features = 1 + self.n_dim
            num_physical_features = 4
            num_abstract_features = 0
            num_node_features = num_physical_features + num_abstract_features
            self.num_node_features = num_node_features
            x = np.zeros((n_nodes, num_node_features))
            pos = np.zeros((n_nodes, 3))
            for inode in range(n_nodes):
                line = gfile.readline()
                columns = line.split()
                if (inode%3==0):
                    #x[inode,0] = 1.0    # oxygen atom
                    x[inode,0] = O.atomic_number/O.atomic_number    # oxygen atom
                    #x[inode,0] = O.atomic_number
                    #x[inode,1] = O.atomic_radius
                    #x[inode,2] = O.covalent_radius
                    #x[inode,3] = O.vdw_radius
                    #x[inode,4] = O.dipole_polarizability
                    #x[inode,5] = O.electron_affinity
                    #x[inode,6] = O.en_pauling
                    
                else:
                    #x[inode,0] = 0.0    # hydrogen atom
                    x[inode,0] = H.atomic_number/O.atomic_number    # hydrogen atom
                    #x[inode,0] = H.atomic_number
                    #x[inode,1] = H.atomic_radius
                    #x[inode,2] = H.covalent_radius
                    #x[inode,3] = H.vdw_radius
                    #x[inode,4] = H.dipole_polarizability
                    #x[inode,5] = H.electron_affinity
                    #x[inode,6] = H.en_pauling
                pos[inode,0:] = columns[1:]
                x[inode,1:] = pos[inode,0:]/float(self.xmax)
                #x[inode,1:] = x[inode,1:] / float(self.xmax)
                #x[inode,1:] = np.random.random(num_abstract_features)
            gfile.close()                

            # Binary Adjacency matrix (two nodes/atoms are connected if rij2 < r2_cutoff)
            a = np.zeros((n_nodes,n_nodes))
            n_edges = 0
            for iatom in range(3*n_molecules):
                for jatom in range(iatom+1,3*n_molecules):
                    rij = pos[iatom,0:] - pos[jatom,0:]
                    r2 = np.dot(rij,rij)
                    if (r2 <= self.r2_cutoff):
                        #print(iatom,jatom,r2)                        
                        #a[iatom,jatom] = np.sqrt(r2)
                        a[iatom,jatom] = 1
                        n_edges = n_edges + 1            
            a = np.maximum(a, a.T)#.astype(int) # Adjacency matrix is symetric in this case
            a = sp.csr_matrix(a)
            #a = normalized_adjacency(a, symmetric=True)

            """ # Edge features (type of bonding: O-O, H-O, H-H)
            n_edges = n_edges*2
            num_abstract_features = 0
            num_edge_features = 1 + num_abstract_features
            self.num_edge_features = num_edge_features
            e = np.zeros((n_edges,num_edge_features))
            id_edge = 0
            for iatom in range(3*n_molecules):
                for jatom in range(3*n_molecules):
                    if(iatom!=jatom):
                        rij = pos[iatom,0:] - pos[jatom,0:]
                        r2 = np.dot(rij,rij)
                        if (r2 <= self.r2_cutoff):
                            #print(iatom,jatom,r2)                        
                            e[id_edge,0] = np.sqrt(r2)
                            #e[id_edge,1:] = np.random.random(num_abstract_features)
                            id_edge = id_edge + 1 """
            
            # Labels
            num_labels = 1
            self.num_labels = num_labels
            y = np.zeros(num_labels,)
            #y[0,] = energy
            #y[0,] = ( energy / float(n_molecules) - self.Epm_avrg ) / self.Epm_avrg
            #y[0,] = ( energy / float(n_molecules) - self.Epm_avrg ) / self.Epm_dev
            #y[0,] = ( energy - self.E_avrg ) / self.E_dev
            #y[0,] = energy - self.E_avrg
            #y[0,] = ( energy - self.E_avrg ) / self.E_dev * 100
            #y[0,] = energy * 100
            
            # Put energies into [0,1]
            ca = 1.0/(self.Emax-self.Emin)
            cb = 1.0 - ca * self.Emax
            y[0,] = ca*energy + cb

            # Put energies into [-1,1]
            #ca = 2.0/(self.Emax-self.Emin)
            #cb = 1.0 - ca * self.Emax
            #y[0,] = ca*energy + cb

            print(str(geom_path)+"    Energy "+str(y[0,]))
            
            return Graph(x=x, a=a, y=y)
            #return Graph(x=x, a=a, e=e, y=y)

        # Compute average of the energy per molecule
        compute_Eavrg()
        compute_Edev()
        # We must return a list of Graph objects
        return [make_graph(isample) for isample in range(self.n_samples)]        

# Generate dataset from atomic geometry files
#d2_cutoff = 20.0
d_cutoff = 6.0
d2_cutoff = d_cutoff * d_cutoff
dataset = MyDataset( d2_cutoff )

# Parameters
F = dataset.num_node_features  # Dimension of node features
S = dataset.num_edge_features  # Dimension of edge features
n_out = dataset.num_labels  # Dimension of the target

# Train/test split
idxs = np.random.permutation(len(dataset))
split = int(0.8 * len(dataset))
idx_tr, idx_te = np.split(idxs, [split])
dataset_tr, dataset_te = dataset[idx_tr], dataset[idx_te]

loader_tr = DisjointLoader(dataset_tr, batch_size=batch_size, epochs=epochs)
#loader_tr = DisjointLoader(dataset_tr, batch_size=batch_size)
loader_te = DisjointLoader(dataset_te, batch_size=batch_size, epochs=1)
#loader_te = DisjointLoader(dataset_te, batch_size=batch_size)
# we set epochs=epochs within loader_te to check loss on test set
#loader_te = DisjointLoader(dataset_te, batch_size=batch_size, epochs=epochs+1)
# Out:
# E_avrg: -1.678857124507812
# E_dev: 1.2688447356520496
# ../dataset_WaterClusters_big/N20-T150/0350.dat    Energy 0.9435111830385654
# ../dataset_WaterClusters_big/N20-T150/1700.dat    Energy 0.9402770134052554
# ../dataset_WaterClusters_big/N20-T150/0100.dat    Energy 0.943036170706861
# ../dataset_WaterClusters_big/N20-T150/1550.dat    Energy 0.9402757351471521
# ../dataset_WaterClusters_big/N20-T150/1850.dat    Energy 0.9378043997365022
# ../dataset_WaterClusters_big/N20-T150/1100.dat    Energy 0.9421674618516651
# ../dataset_WaterClusters_big/N20-T150/0450.dat    Energy 0.9412985972813913
# ../dataset_WaterClusters_big/N20-T150/0500.dat    Energy 0.9396770315890579
# ../dataset_WaterClusters_big/N20-T150/1350.dat    Energy 0.9437441769533131
# ../dataset_WaterClusters_big/N20-T150/0850.dat    Energy 0.9386008684160179
# ../dataset_WaterClusters_big/N20-T150/1900.dat    Energy 0.9407225212158308
# ../dataset_WaterClusters_big/N20-T150/1650.dat    Energy 0.9418776900360757
# ../dataset_WaterClusters_big/N20-T150/0250.dat    Energy 0.9397171572729726
# ../dataset_WaterClusters_big/N20-T150/0950.dat    Energy 0.9404371256911658
# ../dataset_WaterClusters_big/N20-T150/2000.dat    Energy 0.9404953305928719
# ../dataset_WaterClusters_big/N20-T150/1950.dat    Energy 0.9396371197228625
# ../dataset_WaterClusters_big/N20-T150/1500.dat    Energy 0.9416494280004157
# ../dataset_WaterClusters_big/N20-T150/1250.dat    Energy 0.9422609978073457
# ../dataset_WaterClusters_big/N20-T150/0800.dat    Energy 0.9413121630860255
# ../dataset_WaterClusters_big/N20-T150/0900.dat    Energy 0.9394855183118143
# ../dataset_WaterClusters_big/N20-T150/0700.dat    Energy 0.9438720306529083
# ../dataset_WaterClusters_big/N20-T150/0550.dat    Energy 0.9403178804788699
# ../dataset_WaterClusters_big/N20-T150/1750.dat    Energy 0.9428704712709864
# ../dataset_WaterClusters_big/N20-T150/1300.dat    Energy 0.9412709590170929
# ../dataset_WaterClusters_big/N20-T150/0600.dat    Energy 0.9396543901518906
# ../dataset_WaterClusters_big/N20-T150/0650.dat    Energy 0.9421204335739929
# ../dataset_WaterClusters_big/N20-T150/1600.dat    Energy 0.9421188555062617
# ../dataset_WaterClusters_big/N20-T150/1050.dat    Energy 0.9425488824491537
# ../dataset_WaterClusters_big/N20-T150/0300.dat    Energy 0.9416774450939338
# ../dataset_WaterClusters_big/N20-T150/1400.dat    Energy 0.9400084258125957
# ../dataset_WaterClusters_big/N20-T150/1450.dat    Energy 0.9418760538657035
# ../dataset_WaterClusters_big/N20-T150/1200.dat    Energy 0.9424141284799066
# ../dataset_WaterClusters_big/N20-T150/0150.dat    Energy 0.9417494365903102
# ../dataset_WaterClusters_big/N20-T150/1150.dat    Energy 0.9419624803822243
# ../dataset_WaterClusters_big/N20-T150/0400.dat    Energy 0.9395879114340977
# ../dataset_WaterClusters_big/N20-T150/0050.dat    Energy 0.9425179044450472
# ../dataset_WaterClusters_big/N20-T150/0750.dat    Energy 0.939302618170081
# ../dataset_WaterClusters_big/N20-T150/1000.dat    Energy 0.9420946406495745
# ../dataset_WaterClusters_big/N20-T150/1800.dat    Energy 0.941022619032789
# ../dataset_WaterClusters_big/N20-T150/0200.dat    Energy 0.9415626900537389
# ../dataset_WaterClusters_big/N32-T150/0350.dat    Energy 0.9055186446262122
# ../dataset_WaterClusters_big/N32-T150/1700.dat    Energy 0.9099351541988315
# ../dataset_WaterClusters_big/N32-T150/0100.dat    Energy 0.9081889560173233
# ../dataset_WaterClusters_big/N32-T150/1550.dat    Energy 0.9046926644532505
# ../dataset_WaterClusters_big/N32-T150/1850.dat    Energy 0.91011867022856
# ../dataset_WaterClusters_big/N32-T150/1100.dat    Energy 0.9064155169935816
# ../dataset_WaterClusters_big/N32-T150/0450.dat    Energy 0.9051374727080275
# ../dataset_WaterClusters_big/N32-T150/0500.dat    Energy 0.9060596755027923
# ../dataset_WaterClusters_big/N32-T150/1350.dat    Energy 0.9072561483285125
# ../dataset_WaterClusters_big/N32-T150/0850.dat    Energy 0.9103286578215544
# ../dataset_WaterClusters_big/N32-T150/1900.dat    Energy 0.9074762411328398
# ../dataset_WaterClusters_big/N32-T150/1650.dat    Energy 0.9084585615682544
# ../dataset_WaterClusters_big/N32-T150/0250.dat    Energy 0.9099840092235386
# ../dataset_WaterClusters_big/N32-T150/0950.dat    Energy 0.9072606524452473
# ../dataset_WaterClusters_big/N32-T150/2000.dat    Energy 0.9099642566496846
# ../dataset_WaterClusters_big/N32-T150/1950.dat    Energy 0.908337961402369
# ../dataset_WaterClusters_big/N32-T150/1500.dat    Energy 0.9040812991676169
# ../dataset_WaterClusters_big/N32-T150/1250.dat    Energy 0.9015633352254652
# ../dataset_WaterClusters_big/N32-T150/0800.dat    Energy 0.9121363750794147
# ../dataset_WaterClusters_big/N32-T150/0900.dat    Energy 0.9091836709081285
# ../dataset_WaterClusters_big/N32-T150/0700.dat    Energy 0.9051380885960226
# ../dataset_WaterClusters_big/N32-T150/0550.dat    Energy 0.9054910970020339
# ../dataset_WaterClusters_big/N32-T150/1750.dat    Energy 0.9066314450005978
# ../dataset_WaterClusters_big/N32-T150/1300.dat    Energy 0.9080022885003438
# ../dataset_WaterClusters_big/N32-T150/0600.dat    Energy 0.9115850925728463
# ../dataset_WaterClusters_big/N32-T150/0650.dat    Energy 0.9086735808499644
# ../dataset_WaterClusters_big/N32-T150/1600.dat    Energy 0.9076488733758452
# ../dataset_WaterClusters_big/N32-T150/1050.dat    Energy 0.9056471142138025
# ../dataset_WaterClusters_big/N32-T150/0300.dat    Energy 0.908371781787676
# ../dataset_WaterClusters_big/N32-T150/1400.dat    Energy 0.9083726742442426
# ../dataset_WaterClusters_big/N32-T150/1450.dat    Energy 0.9065332375925761
# ../dataset_WaterClusters_big/N139-T50/1050.dat    Energy 0.4314527119802811
# ../dataset_WaterClusters_big/N139-T50/0300.dat    Energy 0.4325012671023961
# ../dataset_WaterClusters_big/N139-T50/1400.dat    Energy 0.43125181628855935
# ../dataset_WaterClusters_big/N139-T50/1450.dat    Energy 0.43052282336815706
# ../dataset_WaterClusters_big/N139-T50/1200.dat    Energy 0.4305376441898381
# ../dataset_WaterClusters_big/N139-T50/0150.dat    Energy 0.4312086018682463
# ../dataset_WaterClusters_big/N139-T50/1150.dat    Energy 0.4310007849899218
# ../dataset_WaterClusters_big/N139-T50/0400.dat    Energy 0.43729382161615327
# ../dataset_WaterClusters_big/N139-T50/0050.dat    Energy 0.4344018649181459
# ../dataset_WaterClusters_big/N139-T50/0750.dat    Energy 0.43008743936175964
# ../dataset_WaterClusters_big/N139-T50/1000.dat    Energy 0.42962708051612986
# ../dataset_WaterClusters_big/N139-T50/1800.dat    Energy 0.4299227067538324
# ../dataset_WaterClusters_big/N139-T50/0200.dat    Energy 0.4319436049258396
# ../dataset_WaterClusters_big/N237-T200/0350.dat    Energy 0.14809451923829564
# ../dataset_WaterClusters_big/N237-T200/1700.dat    Energy 0.1338621169478802
# ../dataset_WaterClusters_big/N237-T200/0100.dat    Energy 0.14147234741921078
# ../dataset_WaterClusters_big/N237-T200/1550.dat    Energy 0.14677319313336468
# ../dataset_WaterClusters_big/N237-T200/1850.dat    Energy 0.14048580175973835
# ../dataset_WaterClusters_big/N237-T200/1100.dat    Energy 0.14977262577269534
# ../dataset_WaterClusters_big/N237-T200/0450.dat    Energy 0.14258182432252775
# ../dataset_WaterClusters_big/N237-T200/0500.dat    Energy 0.13929863232890438
# ../dataset_WaterClusters_big/N237-T200/1350.dat    Energy 0.13814172972585026
# ../dataset_WaterClusters_big/N237-T200/0850.dat    Energy 0.14364963698399502
# ../dataset_WaterClusters_big/N237-T200/1900.dat    Energy 0.13437164922069011
# ../dataset_WaterClusters_big/N237-T200/1650.dat    Energy 0.13291444892759252
# ../dataset_WaterClusters_big/N237-T200/0250.dat    Energy 0.14492154098244214
# ../dataset_WaterClusters_big/N237-T200/0950.dat    Energy 0.15007797142019397
# ../dataset_WaterClusters_big/N237-T200/2000.dat    Energy 0.13929710306739174
# ../dataset_WaterClusters_big/N237-T200/1950.dat    Energy 0.13750796471003612
# ../dataset_WaterClusters_big/N237-T200/1500.dat    Energy 0.1423685597405776
# ../dataset_WaterClusters_big/N237-T200/1250.dat    Energy 0.14772691312474506
# ../dataset_WaterClusters_big/N237-T200/0800.dat    Energy 0.14466855278685364
# ../dataset_WaterClusters_big/N237-T200/0900.dat    Energy 0.15903270630202626
# ../dataset_WaterClusters_big/N237-T200/0700.dat    Energy 0.1483414113047844
# ../dataset_WaterClusters_big/N237-T200/0550.dat    Energy 0.15182427186235048
# ../dataset_WaterClusters_big/N237-T200/1750.dat    Energy 0.13193187516466276
# ../dataset_WaterClusters_big/N237-T200/1300.dat    Energy 0.13216104824973463
# ../dataset_WaterClusters_big/N237-T200/0600.dat    Energy 0.1553804230913468
# ../dataset_WaterClusters_big/N237-T200/0650.dat    Energy 0.14676804059115578
# ../dataset_WaterClusters_big/N237-T200/1600.dat    Energy 0.1402883620131068
# ../dataset_WaterClusters_big/N237-T200/1050.dat    Energy 0.13674270644519115
# ../dataset_WaterClusters_big/N237-T200/0300.dat    Energy 0.14680591421670286
# ../dataset_WaterClusters_big/N237-T200/1400.dat    Energy 0.13059908889480953
# ../dataset_WaterClusters_big/N237-T200/1450.dat    Energy 0.14076641892320274
# ../dataset_WaterClusters_big/N237-T200/1200.dat    Energy 0.14205545855255064
# ../dataset_WaterClusters_big/N237-T200/0150.dat    Energy 0.14780575608455504
# ../dataset_WaterClusters_big/N237-T200/1150.dat    Energy 0.15198893009889713
# ../dataset_WaterClusters_big/N237-T200/0400.dat    Energy 0.14968871858669086
# ../dataset_WaterClusters_big/N237-T200/0050.dat    Energy 0.1526604757760328
# ../dataset_WaterClusters_big/N237-T200/0750.dat    Energy 0.14220314849380278
# ../dataset_WaterClusters_big/N237-T200/1000.dat    Energy 0.14263721240819538
# ../dataset_WaterClusters_big/N237-T200/1800.dat    Energy 0.14326846738991583
# ../dataset_WaterClusters_big/N237-T200/0200.dat    Energy 0.14757882111321674
# ../dataset_WaterClusters_big/N237-T150/0350.dat    Energy 0.10548674860037699
# ../dataset_WaterClusters_big/N237-T150/1700.dat    Energy 0.0927511470390987
# ../dataset_WaterClusters_big/N237-T150/0100.dat    Energy 0.09791909109620245
# ../dataset_WaterClusters_big/N237-T150/1550.dat    Energy 0.0956499970344411
# ../dataset_WaterClusters_big/N237-T150/1850.dat    Energy 0.09587621385713585
# ../dataset_WaterClusters_big/N237-T150/1100.dat    Energy 0.10909579182558116
# ../dataset_WaterClusters_big/N237-T150/0450.dat    Energy 0.09627318272137142
# ../dataset_WaterClusters_big/N237-T150/0500.dat    Energy 0.09252115122062954
# ../dataset_WaterClusters_big/N237-T150/1350.dat    Energy 0.09808659868626668
# ../dataset_WaterClusters_big/N237-T150/0850.dat    Energy 0.09946168135470435
# ../dataset_WaterClusters_big/N237-T150/1900.dat    Energy 0.09158334205647645
# ../dataset_WaterClusters_big/N237-T150/1650.dat    Energy 0.09078312459455973
# ../dataset_WaterClusters_big/N237-T150/0250.dat    Energy 0.09790959712465364
# ../dataset_WaterClusters_big/N237-T150/0950.dat    Energy 0.1036125293836676
# ../dataset_WaterClusters_big/N237-T150/2000.dat    Energy 0.0953055785228839
# ../dataset_WaterClusters_big/N237-T150/1950.dat    Energy 0.09382597849960561
# ../dataset_WaterClusters_big/N237-T150/1500.dat    Energy 0.09629586366833487
# ../dataset_WaterClusters_big/N237-T150/1250.dat    Energy 0.10080960917281734
# ../dataset_WaterClusters_big/N237-T150/0800.dat    Energy 0.09993700046835363
# ../dataset_WaterClusters_big/N237-T150/0900.dat    Energy 0.10824035593770864
# ../dataset_WaterClusters_big/N237-T150/0700.dat    Energy 0.10411579354356004
# ../dataset_WaterClusters_big/N237-T150/0550.dat    Energy 0.10181214235500313
# ../dataset_WaterClusters_big/N237-T150/1750.dat    Energy 0.09607945224734493
# ../dataset_WaterClusters_big/N32-T100/1250.dat    Energy 0.8969814329989162
# ../dataset_WaterClusters_big/N32-T100/0800.dat    Energy 0.9009602321353901
# ../dataset_WaterClusters_big/N32-T100/0900.dat    Energy 0.9015156469017905
# ../dataset_WaterClusters_big/N32-T100/0700.dat    Energy 0.9000965154591141
# ../dataset_WaterClusters_big/N32-T100/0550.dat    Energy 0.8999146634890255
# ../dataset_WaterClusters_big/N32-T100/1750.dat    Energy 0.8993792732168392
# ../dataset_WaterClusters_big/N32-T100/1300.dat    Energy 0.8982406125189717
# ../dataset_WaterClusters_big/N32-T100/0600.dat    Energy 0.9029480280707338
# ../dataset_WaterClusters_big/N32-T100/0650.dat    Energy 0.9009653196026411
# ../dataset_WaterClusters_big/N32-T100/1600.dat    Energy 0.9004576373179226
# ../dataset_WaterClusters_big/N32-T100/1050.dat    Energy 0.8992901228485057
# ../dataset_WaterClusters_big/N32-T100/0300.dat    Energy 0.9011385421684798
# ../dataset_WaterClusters_big/N32-T100/1400.dat    Energy 0.901304594868412
# ../dataset_WaterClusters_big/N32-T100/1450.dat    Energy 0.9017596012987474
# ../dataset_WaterClusters_big/N32-T100/1200.dat    Energy 0.8984408899985925
# ../dataset_WaterClusters_big/N32-T100/0150.dat    Energy 0.9013890551915593
# ../dataset_WaterClusters_big/N32-T100/1150.dat    Energy 0.8977633829904843
# ../dataset_WaterClusters_big/N32-T100/0400.dat    Energy 0.901330831697008
# ../dataset_WaterClusters_big/N32-T100/0050.dat    Energy 0.9044054677467126
# ../dataset_WaterClusters_big/N32-T100/0750.dat    Energy 0.9000961993807467
# ../dataset_WaterClusters_big/N32-T100/1000.dat    Energy 0.9040910975970049
# ../dataset_WaterClusters_big/N32-T100/1800.dat    Energy 0.8986854719040728
# ../dataset_WaterClusters_big/N32-T100/0200.dat    Energy 0.9031986317339334
# ../dataset_WaterClusters_big/N237-T50/0350.dat    Energy 0.009268537949763234
# ../dataset_WaterClusters_big/N237-T50/1700.dat    Energy 0.0013971198381380612
# ../dataset_WaterClusters_big/N237-T50/0100.dat    Energy 0.007890708188456275
# ../dataset_WaterClusters_big/N237-T50/1550.dat    Energy 0.0030917019574359106
# ../dataset_WaterClusters_big/N237-T50/1850.dat    Energy 0.0006822760728860677
# ../dataset_WaterClusters_big/N237-T50/1100.dat    Energy 0.008617855768978555
# ../dataset_WaterClusters_big/N237-T50/0450.dat    Energy 0.00540975562865853
# ../dataset_WaterClusters_big/N237-T50/0500.dat    Energy 0.005474595851973407
# ../dataset_WaterClusters_big/N237-T50/1350.dat    Energy 0.004224998619481113
# ../dataset_WaterClusters_big/N237-T50/0850.dat    Energy 0.007853301708143134
# ../dataset_WaterClusters_big/N237-T50/1900.dat    Energy 0.001528792043303362
# ../dataset_WaterClusters_big/N237-T50/1650.dat    Energy 0.0
# ../dataset_WaterClusters_big/N237-T50/0250.dat    Energy 0.00954222230609636
# ../dataset_WaterClusters_big/N237-T50/0950.dat    Energy 0.00926492861370054
# ../dataset_WaterClusters_big/N237-T50/2000.dat    Energy 0.0025108893645763297
# ../dataset_WaterClusters_big/N237-T50/1950.dat    Energy 0.0010290024213461813
# ../dataset_WaterClusters_big/N237-T50/1500.dat    Energy 0.0029791594658126197
# ../dataset_WaterClusters_big/N237-T50/1250.dat    Energy 0.004679345003814284
# ../dataset_WaterClusters_big/N237-T50/0800.dat    Energy 0.008383490631901913
# ../dataset_WaterClusters_big/N237-T50/0900.dat    Energy 0.011412934447391776
# ../dataset_WaterClusters_big/N237-T50/0700.dat    Energy 0.009265653734661039
# ../dataset_WaterClusters_big/N237-T50/0550.dat    Energy 0.008329696882704796
# ../dataset_WaterClusters_big/N237-T50/1750.dat    Energy 0.0014762021808291115
# ../dataset_WaterClusters_big/N237-T50/1300.dat    Energy 0.0020044435040594832
# ../dataset_WaterClusters_big/N237-T50/0600.dat    Energy 0.009087371590839055
# ../dataset_WaterClusters_big/N237-T50/0650.dat    Energy 0.008585048693731556
# ../dataset_WaterClusters_big/N237-T50/1600.dat    Energy 0.004264196985244384
# ../dataset_WaterClusters_big/N237-T50/1050.dat    Energy 0.005527311216152353
# ../dataset_WaterClusters_big/N237-T50/0300.dat    Energy 0.007548023459708064
# ../dataset_WaterClusters_big/N237-T50/1400.dat    Energy 0.0032082930410883836
# ../dataset_WaterClusters_big/N237-T50/1450.dat    Energy 0.0024217389962427616
# ../dataset_WaterClusters_big/N237-T50/1200.dat    Energy 0.006110255013886068
# ../dataset_WaterClusters_big/N237-T50/0150.dat    Energy 0.008084615294511543
# ../dataset_WaterClusters_big/N237-T50/1150.dat    Energy 0.009665713659400832
# ../dataset_WaterClusters_big/N237-T50/0400.dat    Energy 0.008174602340876302
# ../dataset_WaterClusters_big/N237-T50/0050.dat    Energy 0.007948736458133543
# ../dataset_WaterClusters_big/N237-T50/0750.dat    Energy 0.00633412448988202
# ../dataset_WaterClusters_big/N237-T50/1000.dat    Energy 0.008853271401805474
# ../dataset_WaterClusters_big/N237-T50/1800.dat    Energy 0.0040529357823579915
# ../dataset_WaterClusters_big/N237-T50/0200.dat    Energy 0.008216766265439102
# ../dataset_WaterClusters_big/N47-T50/0350.dat    Energy 0.8380834318599185
# ../dataset_WaterClusters_big/N47-T50/1700.dat    Energy 0.837145306617398
# ../dataset_WaterClusters_big/N47-T50/0100.dat    Energy 0.8411349593272216
# ../dataset_WaterClusters_big/N47-T50/1550.dat    Energy 0.8385593738338799
# ../dataset_WaterClusters_big/N47-T50/1850.dat    Energy 0.8382135167009301
# ../dataset_WaterClusters_big/N47-T50/1100.dat    Energy 0.8386073968287671
# ../dataset_WaterClusters_big/N47-T50/0450.dat    Energy 0.8384526323099397
# ../dataset_WaterClusters_big/N47-T50/0500.dat    Energy 0.8387820835811605
# ../dataset_WaterClusters_big/N47-T50/1350.dat    Energy 0.8395998480406767
# ../dataset_WaterClusters_big/N47-T50/0850.dat    Energy 0.8366060908673246
# ../dataset_WaterClusters_big/N47-T50/1900.dat    Energy 0.8382992738750259
# ../dataset_WaterClusters_big/N47-T50/1650.dat    Energy 0.8394875821176246
# ../dataset_WaterClusters_big/N47-T50/0250.dat    Energy 0.8386942161191414
# ../dataset_WaterClusters_big/N20-T50/1650.dat    Energy 0.9339658045970066
# ../dataset_WaterClusters_big/N20-T50/0250.dat    Energy 0.9362687910913498
# ../dataset_WaterClusters_big/N20-T50/0950.dat    Energy 0.9338232927631255
# ../dataset_WaterClusters_big/N20-T50/2000.dat    Energy 0.9335615543097936
# ../dataset_WaterClusters_big/N20-T50/1950.dat    Energy 0.9333113387722364
# ../dataset_WaterClusters_big/N20-T50/1500.dat    Energy 0.9351740420454882
# ../dataset_WaterClusters_big/N20-T50/1250.dat    Energy 0.9351154978243582
# ../dataset_WaterClusters_big/N20-T50/0800.dat    Energy 0.9348969249851211
# ../dataset_WaterClusters_big/N20-T50/0900.dat    Energy 0.9339135377852166
# ../dataset_WaterClusters_big/N20-T50/0700.dat    Energy 0.9343127447631857
# ../dataset_WaterClusters_big/N20-T50/0550.dat    Energy 0.9345043765698171
# ../dataset_WaterClusters_big/N20-T50/1750.dat    Energy 0.934327349443042
# ../dataset_WaterClusters_big/N20-T50/1300.dat    Energy 0.933803835350688
# ../dataset_WaterClusters_big/N20-T50/0600.dat    Energy 0.9344119933705352
# ../dataset_WaterClusters_big/N20-T50/0650.dat    Energy 0.9335930808028317
# ../dataset_WaterClusters_big/N20-T50/1600.dat    Energy 0.9326210793964688
# ../dataset_WaterClusters_big/N20-T50/1050.dat    Energy 0.9336269802077304
# ../dataset_WaterClusters_big/N20-T50/0300.dat    Energy 0.9348086322117695
# ../dataset_WaterClusters_big/N20-T50/1400.dat    Energy 0.9333759884188886
# ../dataset_WaterClusters_big/N20-T50/1450.dat    Energy 0.9330433600952549
# ../dataset_WaterClusters_big/N20-T50/1200.dat    Energy 0.9355312965925079
# ../dataset_WaterClusters_big/N20-T50/0150.dat    Energy 0.9348225396599331
# ../dataset_WaterClusters_big/N20-T50/1150.dat    Energy 0.9343510111625865
# ../dataset_WaterClusters_big/N20-T50/0400.dat    Energy 0.933028337076383
# ../dataset_WaterClusters_big/N20-T50/0050.dat    Energy 0.9349787590688926
# ../dataset_WaterClusters_big/N20-T50/0750.dat    Energy 0.9341370261078872
# ../dataset_WaterClusters_big/N20-T50/1000.dat    Energy 0.9331823927429894
# ../dataset_WaterClusters_big/N20-T50/1800.dat    Energy 0.9337295127763524
# ../dataset_WaterClusters_big/N20-T50/0200.dat    Energy 0.9353802738837645
# ../dataset_WaterClusters_big/N47-T150/0350.dat    Energy 0.8528954730698441
# ../dataset_WaterClusters_big/N47-T150/1700.dat    Energy 0.853981014009151
# ../dataset_WaterClusters_big/N47-T150/0100.dat    Energy 0.8564244136699803
# ../dataset_WaterClusters_big/N47-T150/1550.dat    Energy 0.8541272072263695
# ../dataset_WaterClusters_big/N47-T150/1850.dat    Energy 0.8527639798208133
# ../dataset_WaterClusters_big/N47-T150/1100.dat    Energy 0.8531735453376302
# ../dataset_WaterClusters_big/N47-T150/0450.dat    Energy 0.8509435985113081
# ../dataset_WaterClusters_big/N47-T150/0500.dat    Energy 0.8546529803494078
# ../dataset_WaterClusters_big/N47-T150/1350.dat    Energy 0.8561454257045712
# ../dataset_WaterClusters_big/N32-T200/1100.dat    Energy 0.9120952314372288
# ../dataset_WaterClusters_big/N32-T200/0450.dat    Energy 0.9124795548426645
# ../dataset_WaterClusters_big/N32-T200/0500.dat    Energy 0.9124709951615839
# ../dataset_WaterClusters_big/N32-T200/1350.dat    Energy 0.9133639932448475
# ../dataset_WaterClusters_big/N32-T200/0850.dat    Energy 0.9169893656362945
# ../dataset_WaterClusters_big/N32-T200/1900.dat    Energy 0.9182504974050896
# ../dataset_WaterClusters_big/N32-T200/1650.dat    Energy 0.9113752072405001
# ../dataset_WaterClusters_big/N32-T200/0250.dat    Energy 0.9172232915174049
# ../dataset_WaterClusters_big/N32-T200/0950.dat    Energy 0.9136484149692483
# ../dataset_WaterClusters_big/N32-T200/2000.dat    Energy 0.9198833210651544
# ../dataset_WaterClusters_big/N32-T200/1950.dat    Energy 0.9198628131569666
# ../dataset_WaterClusters_big/N32-T200/1500.dat    Energy 0.9109087150800803
# ../dataset_WaterClusters_big/N32-T200/1250.dat    Energy 0.9072183723154024
# ../dataset_WaterClusters_big/N32-T200/0800.dat    Energy 0.919053575841052
# ../dataset_WaterClusters_big/N32-T200/0900.dat    Energy 0.9171234851247013
# ../dataset_WaterClusters_big/N32-T200/0700.dat    Energy 0.9106482176991615
# ../dataset_WaterClusters_big/N32-T200/0550.dat    Energy 0.9113248531676537
# ../dataset_WaterClusters_big/N32-T200/1750.dat    Energy 0.9141671785896694
# ../dataset_WaterClusters_big/N32-T200/1300.dat    Energy 0.9119759211499749
# ../dataset_WaterClusters_big/N32-T200/0600.dat    Energy 0.9155904004582764
# ../dataset_WaterClusters_big/N32-T200/0650.dat    Energy 0.9137881704138376
# ../dataset_WaterClusters_big/N32-T200/1600.dat    Energy 0.9148951930615964
# ../dataset_WaterClusters_big/N32-T200/1050.dat    Energy 0.9094486003585073
# ../dataset_WaterClusters_big/N32-T200/0300.dat    Energy 0.9119286023590973
# ../dataset_WaterClusters_big/N32-T200/1400.dat    Energy 0.9177427407489904
# ../dataset_WaterClusters_big/N32-T200/1450.dat    Energy 0.9126645559758985
# ../dataset_WaterClusters_big/N32-T200/1200.dat    Energy 0.9130338772794131
# ../dataset_WaterClusters_big/N32-T200/0150.dat    Energy 0.9170743512073171
# ../dataset_WaterClusters_big/N32-T200/1150.dat    Energy 0.9149962242579734
# ../dataset_WaterClusters_big/N32-T200/0400.dat    Energy 0.9136459607136901
# ../dataset_WaterClusters_big/N32-T200/0050.dat    Energy 0.9204790311751813
# ../dataset_WaterClusters_big/N32-T200/0750.dat    Energy 0.913796699881545
# ../dataset_WaterClusters_big/N32-T200/1000.dat    Energy 0.9183948754958015
# ../dataset_WaterClusters_big/N32-T200/1800.dat    Energy 0.9158256673483424
# ../dataset_WaterClusters_big/N32-T200/0200.dat    Energy 0.9135083759837707
# ../dataset_WaterClusters_big/N139-T100/0350.dat    Energy 0.4602719194305085
# ../dataset_WaterClusters_big/N139-T100/1700.dat    Energy 0.45109327556288437
# ../dataset_WaterClusters_big/N139-T100/0100.dat    Energy 0.4585105657561068
# ../dataset_WaterClusters_big/N139-T100/1550.dat    Energy 0.4515072615286331
# ../dataset_WaterClusters_big/N139-T100/1850.dat    Energy 0.4539761496560416
# ../dataset_WaterClusters_big/N139-T100/1100.dat    Energy 0.455651034980021
# ../dataset_WaterClusters_big/N139-T100/0450.dat    Energy 0.45774703197764843
# ../dataset_WaterClusters_big/N139-T100/0500.dat    Energy 0.4588364797385399
# ../dataset_WaterClusters_big/N139-T100/1350.dat    Energy 0.44835431241520496
# ../dataset_WaterClusters_big/N139-T100/0850.dat    Energy 0.4575635275684481
# ../dataset_WaterClusters_big/N139-T100/1900.dat    Energy 0.45216599208725694
# ../dataset_WaterClusters_big/N139-T100/1650.dat    Energy 0.4510375783711663
# ../dataset_WaterClusters_big/N139-T100/0250.dat    Energy 0.4597526538032687
# ../dataset_WaterClusters_big/N139-T100/0950.dat    Energy 0.45844428923550495
# ../dataset_WaterClusters_big/N139-T100/2000.dat    Energy 0.4515714347336286
# ../dataset_WaterClusters_big/N139-T100/1950.dat    Energy 0.44911039743507974
# ../dataset_WaterClusters_big/N139-T100/1500.dat    Energy 0.4542729356224595
# ../dataset_WaterClusters_big/N139-T100/1250.dat    Energy 0.45041355135799355
# ../dataset_WaterClusters_big/N139-T100/0800.dat    Energy 0.45871161483880085
# ../dataset_WaterClusters_big/N139-T100/0900.dat    Energy 0.45491258062554873
# ../dataset_WaterClusters_big/N139-T100/0700.dat    Energy 0.45834840360901996
# ../dataset_WaterClusters_big/N139-T100/0550.dat    Energy 0.4608328748647602
# ../dataset_WaterClusters_big/N139-T100/1750.dat    Energy 0.44893966631048965
# ../dataset_WaterClusters_big/N139-T100/1300.dat    Energy 0.4497100562005929
# ../dataset_WaterClusters_big/N139-T100/0600.dat    Energy 0.4612585464336785
# ../dataset_WaterClusters_big/N139-T100/0650.dat    Energy 0.4604377722573554
# ../dataset_WaterClusters_big/N139-T100/1600.dat    Energy 0.4509828735725575
# ../dataset_WaterClusters_big/N139-T100/1050.dat    Energy 0.45648960948145856
# ...
# ../dataset_WaterClusters_big/N100-T200/1200.dat    Energy 0.6656138088503059
# ../dataset_WaterClusters_big/N100-T200/0150.dat    Energy 0.6741903094834851
# ../dataset_WaterClusters_big/N100-T200/1150.dat    Energy 0.6683975180039168
# ../dataset_WaterClusters_big/N100-T200/0400.dat    Energy 0.671217494826076
# ../dataset_WaterClusters_big/N100-T200/0050.dat    Energy 0.6777080385980028
# ../dataset_WaterClusters_big/N100-T200/0750.dat    Energy 0.6545202739172317
# ../dataset_WaterClusters_big/N100-T200/1000.dat    Energy 0.6621602296997273
# ../dataset_WaterClusters_big/N100-T200/1800.dat    Energy 0.6558585264835556
# ../dataset_WaterClusters_big/N100-T200/0200.dat    Energy 0.6739648921531314
# ../dataset_WaterClusters_big/N47-T200/0350.dat    Energy 0.8504006525716786
# ../dataset_WaterClusters_big/N47-T200/1700.dat    Energy 0.8506666673793923
# ../dataset_WaterClusters_big/N47-T200/0100.dat    Energy 0.8514529471797722
# ../dataset_WaterClusters_big/N47-T200/1550.dat    Energy 0.8489250593065277
# ../dataset_WaterClusters_big/N47-T200/1850.dat    Energy 0.8509089763095545
# ../dataset_WaterClusters_big/N47-T200/1100.dat    Energy 0.8538679764830257
# ../dataset_WaterClusters_big/N47-T200/0450.dat    Energy 0.8513449785280528
# ../dataset_WaterClusters_big/N47-T200/0500.dat    Energy 0.8545111471543744
# ../dataset_WaterClusters_big/N47-T200/1350.dat    Energy 0.8512173037845923
# ../dataset_WaterClusters_big/N47-T200/0850.dat    Energy 0.8553487803930266
# ../dataset_WaterClusters_big/N47-T200/1900.dat    Energy 0.8485167418344407
# ../dataset_WaterClusters_big/N47-T200/1650.dat    Energy 0.8498141714851574
# ../dataset_WaterClusters_big/N47-T200/0250.dat    Energy 0.850134247314217
# ../dataset_WaterClusters_big/N47-T200/0950.dat    Energy 0.8549970734861752
# ../dataset_WaterClusters_big/N47-T200/2000.dat    Energy 0.8515173411748038
# ../dataset_WaterClusters_big/N47-T200/1950.dat    Energy 0.8485565235507202
# ../dataset_WaterClusters_big/N47-T200/1500.dat    Energy 0.8537534747703458
# ../dataset_WaterClusters_big/N47-T200/1250.dat    Energy 0.8550810596917715
# ../dataset_WaterClusters_big/N47-T200/0800.dat    Energy 0.8511441990416132
# ../dataset_WaterClusters_big/N47-T200/0900.dat    Energy 0.8559050318374584
# ../dataset_WaterClusters_big/N47-T200/0700.dat    Energy 0.8512733495921566
# ../dataset_WaterClusters_big/N47-T200/0550.dat    Energy 0.8527199124537294
# ../dataset_WaterClusters_big/N47-T200/1750.dat    Energy 0.8492146777311449
# ../dataset_WaterClusters_big/N47-T200/1300.dat    Energy 0.8517388981656857
# ../dataset_WaterClusters_big/N47-T200/0600.dat    Energy 0.849475212297754
# ../dataset_WaterClusters_big/N47-T200/0650.dat    Energy 0.8481225944344549
# ../dataset_WaterClusters_big/N47-T200/1600.dat    Energy 0.8496395451595108
# ../dataset_WaterClusters_big/N47-T200/1050.dat    Energy 0.8556580886406455
# ../dataset_WaterClusters_big/N47-T200/0300.dat    Energy 0.8536485251318557
# ../dataset_WaterClusters_big/N47-T200/1400.dat    Energy 0.8547441666342841
# ../dataset_WaterClusters_big/N47-T200/1450.dat    Energy 0.8494584252826995
# ../dataset_WaterClusters_big/N47-T200/1200.dat    Energy 0.8519346157500363
# ../dataset_WaterClusters_big/N47-T200/0150.dat    Energy 0.8514327344330009
# ../dataset_WaterClusters_big/N47-T200/1150.dat    Energy 0.853923497042715
# ../dataset_WaterClusters_big/N47-T200/0400.dat    Energy 0.8535324290827052
# ../dataset_WaterClusters_big/N47-T200/0050.dat    Energy 0.8555052252402335
# ../dataset_WaterClusters_big/N47-T200/0750.dat    Energy 0.8536963900875593
# ../dataset_WaterClusters_big/N47-T200/1000.dat    Energy 0.8541499695170304
# ../dataset_WaterClusters_big/N47-T200/1800.dat    Energy 0.8498079033722401
# ../dataset_WaterClusters_big/N47-T200/0200.dat    Energy 0.8540414012460553
# ../dataset_WaterClusters_big/N237-T100/0350.dat    Energy 0.05058964651840592
# ../dataset_WaterClusters_big/N237-T100/1700.dat    Energy 0.041366291506435005
# ../dataset_WaterClusters_big/N237-T100/0100.dat    Energy 0.050805407189815965
# ../dataset_WaterClusters_big/N237-T100/1550.dat    Energy 0.04600479500179688
# ../dataset_WaterClusters_big/N237-T100/1850.dat    Energy 0.042411079253303785
# ../dataset_WaterClusters_big/N237-T100/1100.dat    Energy 0.05016509981661865
# ../dataset_WaterClusters_big/N237-T100/0450.dat    Energy 0.04513523784804174
# ../dataset_WaterClusters_big/N237-T100/0500.dat    Energy 0.042426499694240505
# ../dataset_WaterClusters_big/N237-T100/1350.dat    Energy 0.04519044930168048
# ../dataset_WaterClusters_big/N237-T100/0850.dat    Energy 0.04757089358887079
# ../dataset_WaterClusters_big/N237-T100/1900.dat    Energy 0.04399205211648849
# ../dataset_WaterClusters_big/N237-T100/1650.dat    Energy 0.041495028366174136
# ../dataset_WaterClusters_big/N237-T100/0250.dat    Energy 0.05151448717307483
# ../dataset_WaterClusters_big/N237-T100/0950.dat    Energy 0.05013165593642577
# ../dataset_WaterClusters_big/N237-T100/2000.dat    Energy 0.045013610427462436
# ../dataset_WaterClusters_big/N237-T100/1950.dat    Energy 0.0448008943344439
# ../dataset_WaterClusters_big/N237-T100/1500.dat    Energy 0.045555171200129085
# ../dataset_WaterClusters_big/N237-T100/1250.dat    Energy 0.04705866767762146
# ../dataset_WaterClusters_big/N237-T100/0800.dat    Energy 0.04851184959206356
# ../dataset_WaterClusters_big/N237-T100/0900.dat    Energy 0.05339205775012068
# ../dataset_WaterClusters_big/N237-T100/0700.dat    Energy 0.051820462653202615
# ../dataset_WaterClusters_big/N237-T100/0550.dat    Energy 0.05243187906916025
# ../dataset_WaterClusters_big/N237-T100/1750.dat    Energy 0.04217961227596301
# ../dataset_WaterClusters_big/N237-T100/1300.dat    Energy 0.04149309471027973
# ../dataset_WaterClusters_big/N237-T100/0600.dat    Energy 0.05664706299051414
# ../dataset_WaterClusters_big/N237-T100/0650.dat    Energy 0.04894347087142614
# ../dataset_WaterClusters_big/N237-T100/1600.dat    Energy 0.048696983199319144
# ../dataset_WaterClusters_big/N237-T100/1050.dat    Energy 0.04505881195809991
# ../dataset_WaterClusters_big/N237-T100/0300.dat    Energy 0.047912255901508494
# ../dataset_WaterClusters_big/N237-T100/1400.dat    Energy 0.04468825655448916
# ../dataset_WaterClusters_big/N237-T100/1450.dat    Energy 0.045958789330607264
# ../dataset_WaterClusters_big/N237-T100/1200.dat    Energy 0.04528954684216324
# ../dataset_WaterClusters_big/N237-T100/0150.dat    Energy 0.05017507022982415
# ../dataset_WaterClusters_big/N237-T100/1150.dat    Energy 0.0507679797925521
# ../dataset_WaterClusters_big/N237-T100/0400.dat    Energy 0.05114633489469833
# ../dataset_WaterClusters_big/N237-T100/0050.dat    Energy 0.05104936158677276
# ../dataset_WaterClusters_big/N237-T100/0750.dat    Energy 0.04691065236157954
# ../dataset_WaterClusters_big/N237-T100/1000.dat    Energy 0.046504382426563295
# ../dataset_WaterClusters_big/N237-T100/1800.dat    Energy 0.044794812149977936
# ../dataset_WaterClusters_big/N190-T50/0050.dat    Energy 0.21930246199018177
# ../dataset_WaterClusters_big/N190-T50/0750.dat    Energy 0.21507146020582646
# ../dataset_WaterClusters_big/N190-T50/1000.dat    Energy 0.21325915283932262
# ../dataset_WaterClusters_big/N190-T50/1800.dat    Energy 0.2110621316176351
# ../dataset_WaterClusters_big/N190-T50/0200.dat    Energy 0.21531886822376778
# ../dataset_WaterClusters_big/N76-T200/0350.dat    Energy 0.7668066816363861
# ../dataset_WaterClusters_big/N76-T200/1700.dat    Energy 0.7549259976874219
# ../dataset_WaterClusters_big/N76-T200/0100.dat    Energy 0.7679498789884673
# ../dataset_WaterClusters_big/N76-T200/1550.dat    Energy 0.7637779211079551
# ../dataset_WaterClusters_big/N76-T200/1850.dat    Energy 0.7536050016054922
# ../dataset_WaterClusters_big/N76-T200/1100.dat    Energy 0.7636430276923695
# ../dataset_WaterClusters_big/N76-T200/0450.dat    Energy 0.7635407600717907
# ../dataset_WaterClusters_big/N76-T200/0500.dat    Energy 0.7630438198033509
# ../dataset_WaterClusters_big/N76-T200/1350.dat    Energy 0.7560016635018545
# ../dataset_WaterClusters_big/N76-T200/0850.dat    Energy 0.7680139662015543
# ../dataset_WaterClusters_big/N76-T200/1900.dat    Energy 0.7576874860669867
# ../dataset_WaterClusters_big/N76-T200/1650.dat    Energy 0.7579950372907398
# ../dataset_WaterClusters_big/N76-T200/0250.dat    Energy 0.7665128333394999
# ../dataset_WaterClusters_big/N76-T200/0950.dat    Energy 0.7546832564736103
# ../dataset_WaterClusters_big/N76-T200/2000.dat    Energy 0.7608818716599115
# ../dataset_WaterClusters_big/N76-T200/1950.dat    Energy 0.756278492373122
# ../dataset_WaterClusters_big/N76-T200/1500.dat    Energy 0.7627256032588051
# ../dataset_WaterClusters_big/N76-T200/1250.dat    Energy 0.7589389890661056
# ../dataset_WaterClusters_big/N76-T200/0800.dat    Energy 0.765675671894293
# ../dataset_WaterClusters_big/N76-T200/0900.dat    Energy 0.7598746670253846
# ../dataset_WaterClusters_big/N76-T200/0700.dat    Energy 0.7584210109933915
# ../dataset_WaterClusters_big/N76-T200/0550.dat    Energy 0.7569816203218309
# ../dataset_WaterClusters_big/N76-T200/1750.dat    Energy 0.7536186673466689
# ../dataset_WaterClusters_big/N76-T200/1300.dat    Energy 0.762798410516262
# ../dataset_WaterClusters_big/N76-T200/0600.dat    Energy 0.7587040986811537
# ../dataset_WaterClusters_big/N76-T200/0650.dat    Energy 0.770621642945605
# ../dataset_WaterClusters_big/N76-T200/1600.dat    Energy 0.760675107601443
# ../dataset_WaterClusters_big/N76-T200/1050.dat    Energy 0.7603947251726485
# ../dataset_WaterClusters_big/N76-T200/0300.dat    Energy 0.7703026408533521
# ../dataset_WaterClusters_big/N76-T200/1400.dat    Energy 0.7556285910918332
# ../dataset_WaterClusters_big/N76-T200/1450.dat    Energy 0.7580600285809216
# ../dataset_WaterClusters_big/N76-T200/1200.dat    Energy 0.7613217853482058
# ../dataset_WaterClusters_big/N76-T200/0150.dat    Energy 0.7716736726056552
# ../dataset_WaterClusters_big/N76-T200/1150.dat    Energy 0.7580222734847621
# ../dataset_WaterClusters_big/N76-T200/0400.dat    Energy 0.7661671272734168
# ../dataset_WaterClusters_big/N76-T200/0050.dat    Energy 0.7646183200323218
# ../dataset_WaterClusters_big/N76-T200/0750.dat    Energy 0.7600137019972248
# ../dataset_WaterClusters_big/N76-T200/1000.dat    Energy 0.7562911633970839
# ../dataset_WaterClusters_big/N76-T200/1800.dat    Energy 0.7502310951204378
# ../dataset_WaterClusters_big/N76-T200/0200.dat    Energy 0.7652751099627344

# %%
################################################################################
# Build model
################################################################################
class Net(Model):
    def __init__(self):
        super().__init__()
        #self.conv1 = ECCConv(32, activation="relu")
        #self.conv2 = ECCConv(32, activation="relu")
        #self.conv1 = GCSConv(32, activation="relu")
        #self.conv2 = GCSConv(32, activation="relu")
        #self.conv1 = GCSConv(64, activation="tanh")
        #self.conv2 = GCSConv(64, activation="tanh")
        #self.conv3 = GCSConv(64, activation="tanh")
        #self.conv1 = CrystalConv(aggregate="sum",activation="sigmoid")
        #self.conv2 = CrystalConv(aggregate="sum",activation="sigmoid")
        self.conv1 = GATConv(8,attn_heads=7,dropout_rate=0)
        self.conv2 = GATConv(8,attn_heads=7,dropout_rate=0)
        self.global_pool = GlobalSumPool()
        #self.dense1 = Dense(128,activation="tanh")
        #self.dense2 = Dense(128,activation="tanh")
        self.dense1 = Dense(128)
        self.dense2 = Dense(128)
        #self.dense3 = Dense(128)
        self.dense = Dense(n_out,activation="sigmoid")
        self.dense = Dense(n_out)

    def call(self, inputs):
        #x, a, e, i = inputs
        #x = self.conv1([x, a, e])
        #x = self.conv2([x, a, e])
        x, a, i = inputs
        x = self.conv1([x, a])
        x = self.conv2([x, a])
        #x = self.conv3([x, a])
        output = self.global_pool([x, i])
        output = self.dense1(output)
        output = self.dense2(output)
        #output = self.dense3(output)
        output = self.dense(output)

        return output

model = Net()
optimizer = Adam(learning_rate)
#loss_fn = MeanSquaredError()
loss_fn = MeanAbsoluteError()
#loss_fn = MeanAbsolutePercentageError()
# Out:
# 2023-01-26 18:23:32.276682: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-26 18:23:32.312236: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2023-01-26 18:23:32.312259: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-01-26 18:23:32.312920: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
################################################################################
# Fit model
################################################################################
@tf.function(input_signature=loader_tr.tf_signature(), experimental_relax_shapes=True)
def train_step(inputs, target):
    with tf.GradientTape() as tape:
        predictions = model(inputs, training=True)
        loss = loss_fn(target, predictions) + sum(model.losses)
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    return loss

outfile = open("loss.dat",'w')
nepoch = 1
step = loss = 0
loss_train = []
#loss_test = []
#loss_te = 0
for batch in loader_tr:
    step += 1
    loss += train_step(*batch)
    if step == loader_tr.steps_per_epoch:
        step = 0
        print(str(nepoch)+" Loss: {}".format(loss / loader_tr.steps_per_epoch))
        outfile.write(str(nepoch)+" {}".format(loss / loader_tr.steps_per_epoch)+" \n")
        loss_train.append(loss / loader_tr.steps_per_epoch)

        #if(nepoch==epochs): break
        nepoch = nepoch + 1

        # log the loss into wandb
        #wandb.log({"loss": loss / loader_tr.steps_per_epoch})
        
        loss = 0

        """
        # Loss on test set
        batch_te = next(iter(loader_te))
        inputs, target = batch_te
        predictions = model(inputs, training=False)
        #loss_te += loss_fn(target, predictions)
        loss_te = loss_fn(target, predictions)
        #loss_te /= loader_te.steps_per_epoch
        loss_test.append(loss_te)
        #loss_te = 0
        """

outfile.close()

# Plot Loss Function on Training Set
plt.figure(figsize=(6,4))
plt.scatter(range(1,epochs+1),loss_train)
plt.plot(range(1,epochs+1),loss_train,ls="--")
plt.xlabel("Epochs")
plt.ylabel("Loss (MSE)")
plt.show()

"""
# Plot Loss Function on Test Set
plt.figure(figsize=(6,4))
plt.scatter(range(1,epochs+1),loss_test)
plt.plot(range(1,epochs+1),loss_test,ls="--")
plt.xlabel("Epochs")
plt.ylabel("Loss (MSE)")
plt.show()
"""
# Out:
# /home/alfonso/Work/UGR/Calculations/WaterClusters_GNNs/GNNs_WaterClusters_venv/lib/python3.10/site-packages/spektral/data/utils.py:221: UserWarning: you are shuffling a 'MyDataset' object which is not a subclass of 'Sequence'; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   np.random.shuffle(a)
# /home/alfonso/Work/UGR/Calculations/WaterClusters_GNNs/GNNs_WaterClusters_venv/lib/python3.10/site-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer GlorotUniform is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# 1 Loss: 0.5920391082763672
# 2 Loss: 0.2690213620662689
# 3 Loss: 0.1313968151807785
# 4 Loss: 0.06642317026853561
# 5 Loss: 0.07278252393007278
# 6 Loss: 0.10960955172777176
# 7 Loss: 0.11440746486186981
# 8 Loss: 0.06943445652723312
# 9 Loss: 0.07278783619403839
# 10 Loss: 0.06269345432519913
# 11 Loss: 0.05868881568312645
# 12 Loss: 0.059068650007247925
# 13 Loss: 0.05023910477757454
# 14 Loss: 0.048447463661432266
# 15 Loss: 0.03908733278512955
# 16 Loss: 0.04136796295642853
# 17 Loss: 0.043083980679512024
# 18 Loss: 0.048123788088560104
# 19 Loss: 0.042242735624313354
# 20 Loss: 0.033353064209222794
# 21 Loss: 0.03801438957452774
# 22 Loss: 0.04591298848390579
# 23 Loss: 0.04013809561729431
# 24 Loss: 0.03655770793557167
# 25 Loss: 0.03194916993379593
# 26 Loss: 0.032711803913116455
# 27 Loss: 0.03534085676074028
# 28 Loss: 0.032344091683626175
# 29 Loss: 0.030866343528032303
# 30 Loss: 0.03275034949183464
# 31 Loss: 0.03731819614768028
# 32 Loss: 0.03248100355267525
# 33 Loss: 0.03230255842208862
# 34 Loss: 0.04077291488647461
# 35 Loss: 0.02988108992576599
# 36 Loss: 0.029459411278367043
# 37 Loss: 0.028832875192165375
# 38 Loss: 0.032368674874305725
# 39 Loss: 0.027681853622198105
# 40 Loss: 0.03051820397377014
# 41 Loss: 0.030520236119627953
# 42 Loss: 0.03320444002747536
# 43 Loss: 0.03230772167444229
# 44 Loss: 0.026905672624707222
# 45 Loss: 0.03316931053996086
# 46 Loss: 0.026410823687911034
# 47 Loss: 0.031109174713492393
# 48 Loss: 0.029110964387655258
# 49 Loss: 0.027182143181562424
# 50 Loss: 0.03346531093120575
# 51 Loss: 0.027876298874616623
# 52 Loss: 0.02597908303141594
# 139 Loss: 0.022697219625115395
# 140 Loss: 0.027040330693125725
# 141 Loss: 0.02427680231630802
# 142 Loss: 0.02448926493525505
# 143 Loss: 0.02408006228506565
# 144 Loss: 0.025299223139882088
# 145 Loss: 0.024671515449881554
# 146 Loss: 0.023830462247133255
# 147 Loss: 0.026752255856990814
# 148 Loss: 0.022846218198537827
# 149 Loss: 0.024118028581142426
# 150 Loss: 0.023259388282895088
# '\n# Plot Loss Function on Test Set\nplt.figure(figsize=(6,4))\nplt.scatter(range(1,epochs+1),loss_test)\nplt.plot(range(1,epochs+1),loss_test,ls="--")\nplt.xlabel("Epochs")\nplt.ylabel("Loss (MSE)")\nplt.show()\n'

# %%
# Plot Loss Function on Training Set
plt.figure(figsize=(6,4))
plt.scatter(range(1,epochs+1),loss_train)
plt.plot(range(1,epochs+1),loss_train,ls="--")
plt.xlabel("Epochs")
plt.ylabel("Loss (MSE)")
ymedian = np.median(loss_train)
#plt.xlim(0,200)
plt.ylim(0,ymedian*2)
plt.show()

# %%
################################################################################
# Evaluate model
################################################################################

# Loss on Test Set. Predicted vs Real energies
print("Testing model")
loss = 0
ypred = []
ytrue = []
for batch in loader_te:
    inputs, target = batch
    predictions = model(inputs, training=False)
    loss += loss_fn(target, predictions)
    ypred.append(predictions)
    ytrue.append(target)
    #break
loss /= loader_te.steps_per_epoch
print("Done. Test loss: {}".format(loss))
# Out:
# Testing model
# Done. Test loss: 0.02078327350318432

# %%
# Plot Predicted vs Real on Test Set

y_pred = np.array(ypred).ravel()
y_true = np.array(ytrue).ravel()

# Convert to original units
#y_pred = np.array(ypred).ravel()#/100
#y_true = np.array(ytrue).ravel()#/100

#E_avrg = -0.025591339035879856
#E_dev = 2.0321151163332116
#y_pred = np.array(ypred).ravel()*E_dev + E_avrg
#y_true = np.array(ytrue).ravel()*E_dev + E_avrg

plt.figure(figsize=(6,4))
plt.scatter(y_true,y_pred,label = "GNN model",color="red")
p1 = max(max(y_pred), max(y_true))
p2 = min(min(y_pred), min(y_true))
plt.plot([p1, p2], [p1, p2], 'b-')
#plt.plot(np.linspace(-0.2,0.1,50),np.linspace(-0.2,0.1,50))
plt.xlabel("True Atomic Energy")
plt.ylabel("Pred Atomic Energy")
#plt.xlim(-5,0)
#plt.ylim(-5,0)
plt.title("Test Set")
plt.show()

# mean absolute percentage error (MAPE)
def mape(ytrue, ypred):
    ytrue, ypred = np.array(ytrue), np.array(ypred)
    
    mape_i = np.zeros(len(ytrue))
    mape_i = np.abs((ypred-ytrue)/ytrue)*100
    mape_i = mape_i[ mape_i < 1e3]

    return np.mean(mape_i)

# Compute metrics (MAPE, MAE, MSE)
print("Test MAE:", mean_absolute_error(y_true,y_pred))
print("Test MSE:", mean_squared_error(y_true,y_pred))
print("Test MAPE:", mape(y_true,y_pred))
# Out:
# Test MAE: 0.02078327343738907
# Test MSE: 0.0008037580145930487
# Test MAPE: 17.99735801678492
# /tmp/ipykernel_19414/1774026835.py:33: RuntimeWarning: divide by zero encountered in divide
#   mape_i = np.abs((ypred-ytrue)/ytrue)*100
