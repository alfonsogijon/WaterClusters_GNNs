# %%
"""
This example shows how to perform regression of molecular properties with a
database of the atomic geometry of water clusters with an associated energy, 
using a simple GNN in disjoint mode.
"""

import numpy as np
import scipy.sparse as sp
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.losses import MeanAbsoluteError
from tensorflow.keras.losses import MeanAbsolutePercentageError
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_absolute_error, mean_squared_error
from mendeleev import H, O

# Install matplotlib inside the virtual env
#import pip
#pip.main(["install","matplotlib"])
import matplotlib.pyplot as plt

from spektral.data import Dataset, DisjointLoader, Graph
from spektral.datasets import QM9
from spektral.layers import GCSConv, ECCConv, GlobalSumPool, MessagePassing, GATConv, CrystalConv

#from spektral.utils import normalized_adjacency
# Out:
# 2023-01-30 13:56:14.260344: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-30 13:56:14.492466: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-01-30 13:56:15.208303: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-01-30 13:56:15.208442: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-01-30 13:56:15.208447: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
################################################################################
# Load data and make graphs
################################################################################
class MyDataset(Dataset):
    """
    A dataset of graphs obtained from the atomic positions of water
    clusters with size between 20 and 237 water molecules, each of them
    associated to an energy value.
    """

    def __init__(self, r2_cutoff, n_dim = 3, **kwargs):

        self.r2_cutoff = r2_cutoff
        self.n_dim = n_dim

        # path of the atomic geometry files
        self.geometry_paths = []
        #data_dir = "../dataset_WaterClusters_big/"
        data_dir = "../dataset_WaterClusters_big/"
        #for N in [20,32,47,76,100,139,190,237]:
            #for temp in [100,150,200]:
                #for MDstep in ["0500.dat","1000.dat","1500.dat","2000.dat"]:
                    #geometry_path = data_dir+"N"+str(N)+"-T"+str(temp)+"/"+str(MDstep)
                    #self.geometry_paths.append(geometry_path)
        for folder in os.listdir(data_dir): 
            dir_name = os.path.join(data_dir,folder)
            for file_name in os.listdir(dir_name):
                geometry_path = os.path.join(dir_name,file_name)
                self.geometry_paths.append(geometry_path)

        self.n_samples = len(self.geometry_paths)

        self.Epm_avrg = 0.0
        self.Epm_dev = 0.0
        self.E_avrg = 0.0
        self.E_dev = 0.0
        self.xmax = 22.0
        self.Emax = 0
        self.Emin = 0

        self.num_node_features = 0
        self.num_edge_features = 0
        self.num_labels = 0
        
        super().__init__(**kwargs)

    def read(self):

        def compute_Eavrg():

            # Compute the average energy per molecule among all the clusters

            Epm_avrg = 0.0
            E_avrg = 0.0
            Emax = 0.0
            Emin = 1E6
            
            for ii in range(self.n_samples):
            
                geom_path = self.geometry_paths[ii]
                gfile = open(geom_path,'r')
                line = gfile.readline()
                n_molecules = int(gfile.readline())
                line = gfile.readline()
                line = gfile.readline()
                line = gfile.readline()
                columns = line.split()
                #energy = float(columns[0])
                energy = float(columns[1])  # electron contribution
                gfile.close()

                Epm_avrg = Epm_avrg + energy / float(n_molecules)
                E_avrg = E_avrg + energy
                if(energy>Emax): Emax = energy
                if(energy<Emin): Emin = energy

            Epm_avrg = Epm_avrg / float(self.n_samples)
            E_avrg = E_avrg / float(self.n_samples)

            self.Epm_avrg = Epm_avrg
            self.E_avrg = E_avrg
            self.Emax = Emax
            self.Emin = Emin

            print("E_avrg: "+str(E_avrg))

        def compute_Edev():

            # Compute standard deviation from Epm_avrg

            Epm_dev = 0.0
            E_dev = 0.0

            for ii in range(self.n_samples):
            
                geom_path = self.geometry_paths[ii]
                gfile = open(geom_path,'r')
                line = gfile.readline()
                n_molecules = int(gfile.readline())
                line = gfile.readline()
                line = gfile.readline()
                line = gfile.readline()
                columns = line.split()
                #energy = float(columns[0])
                energy = float(columns[1]) # electron contribution
                gfile.close()

                Epm_dev = Epm_dev + ( energy / float(n_molecules) - self.Epm_avrg )**2
                E_dev = E_dev + ( energy - self.E_avrg )**2

            Epm_dev = np.sqrt( Epm_dev / float(self.n_samples) )
            E_dev = np.sqrt( E_dev / float(self.n_samples) )

            self.Epm_dev = Epm_dev
            self.E_dev = E_dev

            print("E_dev: "+str(E_dev))
            
        def make_graph(isample):

            # Process the header of the geometry file
            geom_path = self.geometry_paths[isample]
            gfile = open(geom_path,'r')
            line = gfile.readline()
            n_molecules = int(gfile.readline())
            line = gfile.readline()
            line = gfile.readline()
            line = gfile.readline()
            columns = line.split()
            #energy = float(columns[0])
            energy = float(columns[1]) # electron contribution
            line = gfile.readline()
            line = gfile.readline()            

            # Node features (atom type and position [x,y,z])            
            n_nodes = 3*n_molecules
            #num_node_features = 1 + self.n_dim
            num_physical_features = 4
            #num_abstract_features = 6
            num_abstract_features = 0
            num_node_features = num_physical_features + num_abstract_features
            self.num_node_features = num_node_features
            x = np.zeros((n_nodes, num_node_features))
            pos = np.zeros((n_nodes, 3))
            for inode in range(n_nodes):
                line = gfile.readline()
                columns = line.split()
                if (inode%3==0):
                    #x[inode,0] = 1.0    # oxygen atom
                    #x[inode,0] = O.atomic_number/O.atomic_number    # oxygen atom
                    x[inode,0] = O.atomic_number
                    #x[inode,1] = O.atomic_radius
                    #x[inode,2] = O.covalent_radius
                    #x[inode,3] = O.vdw_radius
                    #x[inode,4] = O.dipole_polarizability
                    #x[inode,5] = O.electron_affinity
                    #x[inode,6] = O.en_pauling
                    #for l in range(3):
                    #    w = O.atomic_number/O.atomic_number*np.pi/float(l+1)
                    #    x[inode,1+l] = np.sin(w)
                    
                else:
                    #x[inode,0] = 0.0    # hydrogen atom
                    #x[inode,0] = H.atomic_number/O.atomic_number    # hydrogen atom
                    x[inode,0] = H.atomic_number
                    #x[inode,1] = H.atomic_radius
                    #x[inode,2] = H.covalent_radius
                    #x[inode,3] = H.vdw_radius
                    #x[inode,4] = H.dipole_polarizability
                    #x[inode,5] = H.electron_affinity
                    #x[inode,6] = H.en_pauling
                    #for l in range(3):
                    #    w = H.atomic_number/O.atomic_number*np.pi/float(l+1)
                    #    x[inode,1+l] = np.sin(w)
                pos[inode,0:] = columns[1:]
                x[inode,1:] = pos[inode,0:]
                #x[inode,1:] = pos[inode,0:]/float(self.xmax)
                #x[inode,7:] = pos[inode,0:]/float(self.xmax)
                #x[inode,1:] = np.random.random(num_abstract_features)
            gfile.close()                

            # Binary Adjacency matrix (two nodes/atoms are connected if rij2 < r2_cutoff)
            a = np.zeros((n_nodes,n_nodes))
            n_edges = 0
            for iatom in range(3*n_molecules):
                for jatom in range(iatom+1,3*n_molecules):
                    rij = pos[iatom,0:] - pos[jatom,0:]
                    r2 = np.dot(rij,rij)
                    if (r2 <= self.r2_cutoff):
                        #print(iatom,jatom,r2)                        
                        #a[iatom,jatom] = np.sqrt(r2)
                        a[iatom,jatom] = 1
                        n_edges = n_edges + 1            
            a = np.maximum(a, a.T)#.astype(int) # Adjacency matrix is symetric in this case
            a = sp.csr_matrix(a)
            #a = normalized_adjacency(a, symmetric=True)

            """ # Edge features (type of bonding: O-O, H-O, H-H)
            n_edges = n_edges*2
            num_abstract_features = 0
            num_edge_features = 1 + num_abstract_features
            self.num_edge_features = num_edge_features
            e = np.zeros((n_edges,num_edge_features))
            id_edge = 0
            for iatom in range(3*n_molecules):
                for jatom in range(3*n_molecules):
                    if(iatom!=jatom):
                        rij = pos[iatom,0:] - pos[jatom,0:]
                        r2 = np.dot(rij,rij)
                        if (r2 <= self.r2_cutoff):
                            #print(iatom,jatom,r2)                        
                            e[id_edge,0] = np.sqrt(r2)
                            #e[id_edge,1:] = np.random.random(num_abstract_features)
                            id_edge = id_edge + 1 """
            
            # Labels
            num_labels = 1
            self.num_labels = num_labels
            y = np.zeros(num_labels,)
            y[0,] = energy
            #y[0,] = ( energy / float(n_molecules) - self.Epm_avrg ) / self.Epm_avrg
            #y[0,] = ( energy / float(n_molecules) - self.Epm_avrg ) / self.Epm_dev
            #y[0,] = ( energy - self.E_avrg ) / self.E_dev
            #y[0,] = energy - self.E_avrg
            #y[0,] = ( energy - self.E_avrg ) / self.E_dev * 100
            #y[0,] = energy * 100
            
            # Put energies into [0,1]
            #ca = 1.0/(self.Emax-self.Emin)
            #cb = 1.0 - ca * self.Emax
            #y[0,] = ca*energy + cb

            # Put energies into [-1,1]
            #ca = 2.0/(self.Emax-self.Emin)
            #cb = 1.0 - ca * self.Emax
            #y[0,] = ca*energy + cb

            print(str(geom_path)+"    Energy "+str(y[0,]))
            
            return Graph(x=x, a=a, y=y)
            #return Graph(x=x, a=a, e=e, y=y)

        # Compute average of the energy per molecule
        compute_Eavrg()
        compute_Edev()
        # We must return a list of Graph objects
        return [make_graph(isample) for isample in range(self.n_samples)]        

# Generate dataset from atomic geometry files
#d2_cutoff = 20.0
d_cutoff = 6.0
d2_cutoff = d_cutoff * d_cutoff
dataset = MyDataset( d2_cutoff )
# Out:
# E_avrg: -0.082706061609375
# E_dev: 0.032428410162306805
# ../dataset_WaterClusters_big/N20-T150/0350.dat    Energy -0.03364731
# ../dataset_WaterClusters_big/N20-T150/1700.dat    Energy -0.02216927
# ../dataset_WaterClusters_big/N20-T150/0100.dat    Energy -0.0233834
# ../dataset_WaterClusters_big/N20-T150/1550.dat    Energy -0.02285929
# ../dataset_WaterClusters_big/N20-T150/1850.dat    Energy -0.01897021
# ../dataset_WaterClusters_big/N20-T150/1100.dat    Energy -0.03038906
# ../dataset_WaterClusters_big/N20-T150/0450.dat    Energy -0.02811601
# ../dataset_WaterClusters_big/N20-T150/0500.dat    Energy -0.02823979
# ../dataset_WaterClusters_big/N20-T150/1350.dat    Energy -0.02914551
# ../dataset_WaterClusters_big/N20-T150/0850.dat    Energy -0.02615065
# ../dataset_WaterClusters_big/N20-T150/1900.dat    Energy -0.02339293
# ../dataset_WaterClusters_big/N20-T150/1650.dat    Energy -0.02087158
# ../dataset_WaterClusters_big/N20-T150/0250.dat    Energy -0.02243953
# ../dataset_WaterClusters_big/N20-T150/0950.dat    Energy -0.02657709
# ../dataset_WaterClusters_big/N20-T150/2000.dat    Energy -0.02185721
# ../dataset_WaterClusters_big/N20-T150/1950.dat    Energy -0.02639351
# ../dataset_WaterClusters_big/N20-T150/1500.dat    Energy -0.02316882
# ../dataset_WaterClusters_big/N20-T150/1250.dat    Energy -0.02545399
# ../dataset_WaterClusters_big/N20-T150/0800.dat    Energy -0.02825689
# ../dataset_WaterClusters_big/N20-T150/0900.dat    Energy -0.02696438
# ../dataset_WaterClusters_big/N20-T150/0700.dat    Energy -0.0246226
# ../dataset_WaterClusters_big/N20-T150/0550.dat    Energy -0.02406381
# ../dataset_WaterClusters_big/N20-T150/1750.dat    Energy -0.0228342
# ../dataset_WaterClusters_big/N20-T150/1300.dat    Energy -0.02637207
# ../dataset_WaterClusters_big/N20-T150/0600.dat    Energy -0.02748547
# ../dataset_WaterClusters_big/N20-T150/0650.dat    Energy -0.02515037
# ../dataset_WaterClusters_big/N20-T150/1600.dat    Energy -0.02113594
# ../dataset_WaterClusters_big/N20-T150/1050.dat    Energy -0.02744172
# ../dataset_WaterClusters_big/N20-T150/0300.dat    Energy -0.02468853
# ../dataset_WaterClusters_big/N20-T150/1400.dat    Energy -0.02182898
# ../dataset_WaterClusters_big/N20-T150/1450.dat    Energy -0.02834452
# ../dataset_WaterClusters_big/N20-T150/1200.dat    Energy -0.02601531
# ../dataset_WaterClusters_big/N20-T150/0150.dat    Energy -0.02210552
# ../dataset_WaterClusters_big/N20-T150/1150.dat    Energy -0.02551878
# ../dataset_WaterClusters_big/N20-T150/0400.dat    Energy -0.02321578
# ../dataset_WaterClusters_big/N20-T150/0050.dat    Energy -0.02943123
# ../dataset_WaterClusters_big/N20-T150/0750.dat    Energy -0.02486593
# ../dataset_WaterClusters_big/N20-T150/1000.dat    Energy -0.02600227
# ../dataset_WaterClusters_big/N20-T150/1800.dat    Energy -0.02393092
# ../dataset_WaterClusters_big/N20-T150/0200.dat    Energy -0.02701467
# ../dataset_WaterClusters_big/N32-T150/0350.dat    Energy -0.06165227
# ../dataset_WaterClusters_big/N32-T150/1700.dat    Energy -0.06797572
# ../dataset_WaterClusters_big/N32-T150/0100.dat    Energy -0.05785682
# ../dataset_WaterClusters_big/N32-T150/1550.dat    Energy -0.04925045
# ../dataset_WaterClusters_big/N32-T150/1850.dat    Energy -0.06083231
# ../dataset_WaterClusters_big/N32-T150/1100.dat    Energy -0.05039625
# ../dataset_WaterClusters_big/N32-T150/0450.dat    Energy -0.05839666
# ../dataset_WaterClusters_big/N32-T150/0500.dat    Energy -0.05795854
# ../dataset_WaterClusters_big/N32-T150/1350.dat    Energy -0.06315332
# ../dataset_WaterClusters_big/N32-T150/0850.dat    Energy -0.06288092
# ../dataset_WaterClusters_big/N32-T150/1900.dat    Energy -0.05635353
# ../dataset_WaterClusters_big/N32-T150/1650.dat    Energy -0.06584703
# ../dataset_WaterClusters_big/N32-T150/0250.dat    Energy -0.05799836
# ../dataset_WaterClusters_big/N32-T150/0950.dat    Energy -0.06120065
# ../dataset_WaterClusters_big/N32-T150/2000.dat    Energy -0.05883658
# ../dataset_WaterClusters_big/N32-T150/1950.dat    Energy -0.05323079
# ../dataset_WaterClusters_big/N32-T150/1500.dat    Energy -0.04886218
# ../dataset_WaterClusters_big/N32-T150/1250.dat    Energy -0.04301954
# ../dataset_WaterClusters_big/N32-T150/0800.dat    Energy -0.0640524
# ../dataset_WaterClusters_big/N32-T150/0900.dat    Energy -0.05848935
# ../dataset_WaterClusters_big/N32-T150/0700.dat    Energy -0.05195021
# ../dataset_WaterClusters_big/N32-T150/0550.dat    Energy -0.05487263
# ../dataset_WaterClusters_big/N32-T150/1750.dat    Energy -0.05556696
# ../dataset_WaterClusters_big/N32-T150/1300.dat    Energy -0.06281909
# ../dataset_WaterClusters_big/N32-T150/0600.dat    Energy -0.06540097
# ../dataset_WaterClusters_big/N32-T150/0650.dat    Energy -0.06138647
# ../dataset_WaterClusters_big/N32-T150/1600.dat    Energy -0.06076307
# ../dataset_WaterClusters_big/N32-T150/1050.dat    Energy -0.0525779
# ../dataset_WaterClusters_big/N32-T150/0300.dat    Energy -0.06299352
# ../dataset_WaterClusters_big/N32-T150/1400.dat    Energy -0.04941815
# ../dataset_WaterClusters_big/N32-T150/1450.dat    Energy -0.05684809
# ../dataset_WaterClusters_big/N32-T150/1200.dat    Energy -0.05051118
# ../dataset_WaterClusters_big/N32-T150/0150.dat    Energy -0.06046834
# ../dataset_WaterClusters_big/N32-T150/1150.dat    Energy -0.05357056
# ../dataset_WaterClusters_big/N32-T150/0400.dat    Energy -0.05675243
# ../dataset_WaterClusters_big/N32-T150/0050.dat    Energy -0.07983495
# ../dataset_WaterClusters_big/N32-T150/0750.dat    Energy -0.05711831
# ../dataset_WaterClusters_big/N32-T150/1000.dat    Energy -0.06778597
# ../dataset_WaterClusters_big/N32-T150/1800.dat    Energy -0.05889262
# ../dataset_WaterClusters_big/N32-T150/0200.dat    Energy -0.05720895
# ../dataset_WaterClusters_big/N100-T150/0350.dat    Energy -0.11244472
# ../dataset_WaterClusters_big/N100-T150/1700.dat    Energy -0.09103621
# ../dataset_WaterClusters_big/N100-T150/0100.dat    Energy -0.09318868
# ../dataset_WaterClusters_big/N100-T150/1550.dat    Energy -0.09712765
# ../dataset_WaterClusters_big/N100-T150/1850.dat    Energy -0.08794468
# ../dataset_WaterClusters_big/N100-T150/1100.dat    Energy -0.09644454
# ../dataset_WaterClusters_big/N100-T150/0450.dat    Energy -0.0996818
# ../dataset_WaterClusters_big/N100-T150/0500.dat    Energy -0.09323595
# ../dataset_WaterClusters_big/N100-T150/1350.dat    Energy -0.09288623
# ../dataset_WaterClusters_big/N100-T150/0850.dat    Energy -0.09663996
# ../dataset_WaterClusters_big/N100-T150/1900.dat    Energy -0.10768858
# ../dataset_WaterClusters_big/N100-T150/1650.dat    Energy -0.09588466
# ../dataset_WaterClusters_big/N100-T150/0250.dat    Energy -0.0952804
# ../dataset_WaterClusters_big/N100-T150/0950.dat    Energy -0.10305491
# ../dataset_WaterClusters_big/N100-T150/2000.dat    Energy -0.09470207
# ../dataset_WaterClusters_big/N100-T150/1950.dat    Energy -0.10022016
# ../dataset_WaterClusters_big/N100-T150/1500.dat    Energy -0.0980665
# ../dataset_WaterClusters_big/N100-T150/1250.dat    Energy -0.11241436
# ../dataset_WaterClusters_big/N100-T150/0800.dat    Energy -0.09359367
# ../dataset_WaterClusters_big/N100-T150/0900.dat    Energy -0.09486395
# ../dataset_WaterClusters_big/N100-T150/0700.dat    Energy -0.10610328
# ../dataset_WaterClusters_big/N100-T150/0550.dat    Energy -0.09467498
# ../dataset_WaterClusters_big/N100-T150/1750.dat    Energy -0.11250788
# ../dataset_WaterClusters_big/N100-T150/1300.dat    Energy -0.10169668
# ../dataset_WaterClusters_big/N100-T150/0600.dat    Energy -0.10057352
# ../dataset_WaterClusters_big/N100-T150/0650.dat    Energy -0.09411276
# ../dataset_WaterClusters_big/N100-T150/1600.dat    Energy -0.09674707
# ../dataset_WaterClusters_big/N100-T150/1050.dat    Energy -0.10282477
# ../dataset_WaterClusters_big/N100-T150/0300.dat    Energy -0.0994695
# ../dataset_WaterClusters_big/N100-T150/1400.dat    Energy -0.09547704
# ../dataset_WaterClusters_big/N100-T150/1450.dat    Energy -0.08997866
# ../dataset_WaterClusters_big/N100-T150/1200.dat    Energy -0.09501895
# ../dataset_WaterClusters_big/N100-T150/0150.dat    Energy -0.10808709
# ../dataset_WaterClusters_big/N100-T150/1150.dat    Energy -0.10022579
# ../dataset_WaterClusters_big/N100-T150/0400.dat    Energy -0.11210253
# ../dataset_WaterClusters_big/N100-T150/0050.dat    Energy -0.09789992
# ../dataset_WaterClusters_big/N100-T150/0750.dat    Energy -0.09646299
# ../dataset_WaterClusters_big/N100-T150/1000.dat    Energy -0.10403145
# ../dataset_WaterClusters_big/N100-T150/1800.dat    Energy -0.09543811
# ../dataset_WaterClusters_big/N100-T150/0200.dat    Energy -0.09543179
# ../dataset_WaterClusters_big/N139-T50/0350.dat    Energy -0.08770153
# ../dataset_WaterClusters_big/N139-T50/1700.dat    Energy -0.08096587
# ../dataset_WaterClusters_big/N139-T50/0100.dat    Energy -0.07560542
# ../dataset_WaterClusters_big/N139-T50/1550.dat    Energy -0.08097698
# ../dataset_WaterClusters_big/N139-T50/1850.dat    Energy -0.08253051
# ../dataset_WaterClusters_big/N139-T50/1100.dat    Energy -0.08020637
# ../dataset_WaterClusters_big/N139-T50/0450.dat    Energy -0.08111665
# ../dataset_WaterClusters_big/N139-T50/0500.dat    Energy -0.08134213
# ../dataset_WaterClusters_big/N139-T50/1350.dat    Energy -0.08581401
# ../dataset_WaterClusters_big/N139-T50/0850.dat    Energy -0.07308718
# ../dataset_WaterClusters_big/N139-T50/1900.dat    Energy -0.08083964
# ../dataset_WaterClusters_big/N139-T50/1650.dat    Energy -0.08188038
# ../dataset_WaterClusters_big/N139-T50/0250.dat    Energy -0.08423048
# ../dataset_WaterClusters_big/N139-T50/0950.dat    Energy -0.08140019
# ../dataset_WaterClusters_big/N139-T50/2000.dat    Energy -0.08469334
# ../dataset_WaterClusters_big/N139-T50/1950.dat    Energy -0.08253446
# ../dataset_WaterClusters_big/N139-T50/1500.dat    Energy -0.08453706
# ../dataset_WaterClusters_big/N139-T50/1250.dat    Energy -0.07764284
# ../dataset_WaterClusters_big/N139-T50/0800.dat    Energy -0.08173866
# ../dataset_WaterClusters_big/N139-T50/0900.dat    Energy -0.08529295
# ../dataset_WaterClusters_big/N139-T50/0700.dat    Energy -0.07298645
# ../dataset_WaterClusters_big/N139-T50/0550.dat    Energy -0.07746422
# ../dataset_WaterClusters_big/N139-T50/1750.dat    Energy -0.08192187
# ../dataset_WaterClusters_big/N139-T50/1300.dat    Energy -0.07445538
# ../dataset_WaterClusters_big/N139-T50/0600.dat    Energy -0.08311437
# ../dataset_WaterClusters_big/N139-T50/0650.dat    Energy -0.07918296
# ../dataset_WaterClusters_big/N139-T50/1600.dat    Energy -0.08494792
# ../dataset_WaterClusters_big/N139-T50/1050.dat    Energy -0.08105762
# ../dataset_WaterClusters_big/N139-T50/0300.dat    Energy -0.07679068
# ../dataset_WaterClusters_big/N139-T50/1400.dat    Energy -0.08083629
# ../dataset_WaterClusters_big/N139-T50/1450.dat    Energy -0.0781775
# ../dataset_WaterClusters_big/N139-T50/1200.dat    Energy -0.07878064
# ../dataset_WaterClusters_big/N139-T50/0150.dat    Energy -0.07783518
# ../dataset_WaterClusters_big/N139-T50/1150.dat    Energy -0.07807658
# ../dataset_WaterClusters_big/N139-T50/0400.dat    Energy -0.09079424
# ../dataset_WaterClusters_big/N139-T50/0050.dat    Energy -0.07943388
# ../dataset_WaterClusters_big/N139-T50/0750.dat    Energy -0.0751907
# ../dataset_WaterClusters_big/N139-T50/1000.dat    Energy -0.07253687
# ../dataset_WaterClusters_big/N139-T50/1800.dat    Energy -0.08510602
# ../dataset_WaterClusters_big/N139-T50/0200.dat    Energy -0.07843743
# ../dataset_WaterClusters_big/N237-T200/0350.dat    Energy -0.12496193
# ../dataset_WaterClusters_big/N237-T200/1700.dat    Energy -0.12210023
# ../dataset_WaterClusters_big/N237-T200/0100.dat    Energy -0.10795248
# ../dataset_WaterClusters_big/N237-T200/1550.dat    Energy -0.11869104
# ../dataset_WaterClusters_big/N237-T200/1850.dat    Energy -0.10943102
# ../dataset_WaterClusters_big/N237-T200/1100.dat    Energy -0.11720103
# ../dataset_WaterClusters_big/N237-T200/0450.dat    Energy -0.10332863
# ../dataset_WaterClusters_big/N237-T200/0500.dat    Energy -0.11031111
# ../dataset_WaterClusters_big/N237-T200/1350.dat    Energy -0.1141109
# ../dataset_WaterClusters_big/N237-T200/0850.dat    Energy -0.12823917
# ../dataset_WaterClusters_big/N237-T200/1900.dat    Energy -0.11585901
# ../dataset_WaterClusters_big/N237-T200/1650.dat    Energy -0.10625674
# ../dataset_WaterClusters_big/N237-T200/0250.dat    Energy -0.12777542
# ../dataset_WaterClusters_big/N237-T200/0950.dat    Energy -0.12818316
# ../dataset_WaterClusters_big/N237-T200/2000.dat    Energy -0.13022169
# ../dataset_WaterClusters_big/N237-T200/1950.dat    Energy -0.12465461
# ../dataset_WaterClusters_big/N237-T200/1500.dat    Energy -0.11543333
# ../dataset_WaterClusters_big/N237-T200/1250.dat    Energy -0.10622473
# ../dataset_WaterClusters_big/N237-T200/0800.dat    Energy -0.11933081
# ../dataset_WaterClusters_big/N237-T200/0900.dat    Energy -0.12956705
# ../dataset_WaterClusters_big/N237-T200/0700.dat    Energy -0.11884527
# ../dataset_WaterClusters_big/N237-T200/0550.dat    Energy -0.11023838
# ../dataset_WaterClusters_big/N237-T200/1750.dat    Energy -0.11956003
# ../dataset_WaterClusters_big/N237-T200/1300.dat    Energy -0.10675915
# ../dataset_WaterClusters_big/N237-T200/0600.dat    Energy -0.11590195
# ../dataset_WaterClusters_big/N237-T200/0650.dat    Energy -0.12556786
# ../dataset_WaterClusters_big/N237-T200/1600.dat    Energy -0.11543806
# ../dataset_WaterClusters_big/N237-T200/1050.dat    Energy -0.1131287
# ../dataset_WaterClusters_big/N237-T200/0300.dat    Energy -0.11277098
# ../dataset_WaterClusters_big/N237-T200/1400.dat    Energy -0.09977379
# ../dataset_WaterClusters_big/N237-T200/1450.dat    Energy -0.11960058
# ../dataset_WaterClusters_big/N237-T200/1200.dat    Energy -0.1141621
# ../dataset_WaterClusters_big/N237-T200/0150.dat    Energy -0.12552369
# ../dataset_WaterClusters_big/N237-T200/1150.dat    Energy -0.11740198
# ../dataset_WaterClusters_big/N237-T200/0400.dat    Energy -0.11035129
# ../dataset_WaterClusters_big/N237-T200/0050.dat    Energy -0.11186938
# ../dataset_WaterClusters_big/N237-T200/0750.dat    Energy -0.10418703
# ../dataset_WaterClusters_big/N237-T200/1000.dat    Energy -0.13243145
# ../dataset_WaterClusters_big/N237-T200/1800.dat    Energy -0.1175211
# ../dataset_WaterClusters_big/N237-T200/0200.dat    Energy -0.11390901
# ../dataset_WaterClusters_big/N237-T150/0350.dat    Energy -0.11882664
# ../dataset_WaterClusters_big/N237-T150/1700.dat    Energy -0.12687613
# ../dataset_WaterClusters_big/N237-T150/0100.dat    Energy -0.10455118
# ../dataset_WaterClusters_big/N237-T150/1550.dat    Energy -0.12462142
# ../dataset_WaterClusters_big/N237-T150/1850.dat    Energy -0.11520497
# ../dataset_WaterClusters_big/N237-T150/1100.dat    Energy -0.13252854
# ../dataset_WaterClusters_big/N237-T150/0450.dat    Energy -0.1072844
# ../dataset_WaterClusters_big/N237-T150/0500.dat    Energy -0.11823519
# ../dataset_WaterClusters_big/N237-T150/1350.dat    Energy -0.11841368
# ../dataset_WaterClusters_big/N237-T150/0850.dat    Energy -0.13893482
# ../dataset_WaterClusters_big/N237-T150/1900.dat    Energy -0.11517814
# ../dataset_WaterClusters_big/N237-T150/1650.dat    Energy -0.12160192
# ../dataset_WaterClusters_big/N237-T150/0250.dat    Energy -0.11445207
# ../dataset_WaterClusters_big/N237-T150/0950.dat    Energy -0.121533
# ../dataset_WaterClusters_big/N237-T150/2000.dat    Energy -0.12325518
# ../dataset_WaterClusters_big/N237-T150/1950.dat    Energy -0.12684978
# ../dataset_WaterClusters_big/N237-T150/1500.dat    Energy -0.12388467
# ../dataset_WaterClusters_big/N237-T150/1250.dat    Energy -0.11532299
# ../dataset_WaterClusters_big/N237-T150/0800.dat    Energy -0.13845472
# ../dataset_WaterClusters_big/N237-T150/0900.dat    Energy -0.1313844
# ../dataset_WaterClusters_big/N237-T150/0700.dat    Energy -0.12246971
# ../dataset_WaterClusters_big/N237-T150/0550.dat    Energy -0.11753024
# ../dataset_WaterClusters_big/N237-T150/1750.dat    Energy -0.11900224
# ../dataset_WaterClusters_big/N237-T150/1300.dat    Energy -0.11404658
# ../dataset_WaterClusters_big/N237-T150/0600.dat    Energy -0.10988751
# ../dataset_WaterClusters_big/N237-T150/0650.dat    Energy -0.12289922
# ../dataset_WaterClusters_big/N237-T150/1600.dat    Energy -0.13285437
# ../dataset_WaterClusters_big/N237-T150/1050.dat    Energy -0.11959531
# ../dataset_WaterClusters_big/N237-T150/0300.dat    Energy -0.10320357
# ../dataset_WaterClusters_big/N237-T150/1400.dat    Energy -0.12354689
# ../dataset_WaterClusters_big/N237-T150/1450.dat    Energy -0.1166787
# ../dataset_WaterClusters_big/N237-T150/1200.dat    Energy -0.12652647
# ../dataset_WaterClusters_big/N237-T150/0150.dat    Energy -0.1153097
# ../dataset_WaterClusters_big/N237-T150/1150.dat    Energy -0.12886595
# ../dataset_WaterClusters_big/N237-T150/0400.dat    Energy -0.11760231
# ../dataset_WaterClusters_big/N237-T150/0050.dat    Energy -0.10990711
# ../dataset_WaterClusters_big/N237-T150/0750.dat    Energy -0.11399042
# ../dataset_WaterClusters_big/N237-T150/1000.dat    Energy -0.13934704
# ../dataset_WaterClusters_big/N237-T150/1800.dat    Energy -0.12510874
# ../dataset_WaterClusters_big/N237-T150/0200.dat    Energy -0.11642426
# ../dataset_WaterClusters_big/N76-T50/0350.dat    Energy -0.09496385
# ../dataset_WaterClusters_big/N76-T50/1700.dat    Energy -0.09238398
# ../dataset_WaterClusters_big/N76-T50/0100.dat    Energy -0.08850104
# ../dataset_WaterClusters_big/N76-T50/1550.dat    Energy -0.09484152
# ../dataset_WaterClusters_big/N76-T50/1850.dat    Energy -0.08958171
# ../dataset_WaterClusters_big/N76-T50/1100.dat    Energy -0.08897057
# ../dataset_WaterClusters_big/N76-T50/0450.dat    Energy -0.08192467
# ../dataset_WaterClusters_big/N76-T50/0500.dat    Energy -0.08747352
# ../dataset_WaterClusters_big/N76-T50/1350.dat    Energy -0.08620442
# ../dataset_WaterClusters_big/N76-T50/0850.dat    Energy -0.08303664
# ../dataset_WaterClusters_big/N76-T50/1900.dat    Energy -0.08508351
# ../dataset_WaterClusters_big/N76-T50/1650.dat    Energy -0.0944203
# ../dataset_WaterClusters_big/N76-T50/0250.dat    Energy -0.09285043
# ../dataset_WaterClusters_big/N76-T50/0950.dat    Energy -0.08085035
# ../dataset_WaterClusters_big/N76-T50/2000.dat    Energy -0.09768065
# ../dataset_WaterClusters_big/N76-T50/1950.dat    Energy -0.08482702
# ../dataset_WaterClusters_big/N76-T50/1500.dat    Energy -0.09317082
# ../dataset_WaterClusters_big/N76-T50/1250.dat    Energy -0.09021605
# ../dataset_WaterClusters_big/N76-T50/0800.dat    Energy -0.08993827
# ../dataset_WaterClusters_big/N76-T50/0900.dat    Energy -0.08498999
# ../dataset_WaterClusters_big/N76-T50/0700.dat    Energy -0.08657166
# ../dataset_WaterClusters_big/N76-T50/0550.dat    Energy -0.08950773
# ../dataset_WaterClusters_big/N76-T50/1750.dat    Energy -0.08814797
# ../dataset_WaterClusters_big/N76-T50/1300.dat    Energy -0.08983875
# ../dataset_WaterClusters_big/N76-T50/0600.dat    Energy -0.08528756
# ../dataset_WaterClusters_big/N76-T50/0650.dat    Energy -0.08715199
# ../dataset_WaterClusters_big/N76-T50/1600.dat    Energy -0.09510387
# ../dataset_WaterClusters_big/N76-T50/1050.dat    Energy -0.08207722
# ../dataset_WaterClusters_big/N76-T50/0300.dat    Energy -0.09619512
# ../dataset_WaterClusters_big/N76-T50/1400.dat    Energy -0.08169038
# ../dataset_WaterClusters_big/N76-T50/1450.dat    Energy -0.09174095
# ../dataset_WaterClusters_big/N76-T50/1200.dat    Energy -0.08629467
# ../dataset_WaterClusters_big/N76-T50/0150.dat    Energy -0.08685156
# ../dataset_WaterClusters_big/N76-T50/1150.dat    Energy -0.08296299
# ../dataset_WaterClusters_big/N76-T50/0400.dat    Energy -0.09188774
# ../dataset_WaterClusters_big/N76-T50/0050.dat    Energy -0.08895911
# ../dataset_WaterClusters_big/N76-T50/0750.dat    Energy -0.08210621
# ../dataset_WaterClusters_big/N76-T50/1000.dat    Energy -0.08377159
# ../dataset_WaterClusters_big/N76-T50/1800.dat    Energy -0.08877954
# ../dataset_WaterClusters_big/N76-T50/0200.dat    Energy -0.09221044
# ../dataset_WaterClusters_big/N100-T50/0350.dat    Energy -0.1190075
# ../dataset_WaterClusters_big/N100-T50/1700.dat    Energy -0.1070788
# ../dataset_WaterClusters_big/N100-T50/0100.dat    Energy -0.1097416
# ../dataset_WaterClusters_big/N100-T50/1550.dat    Energy -0.11220749
# ../dataset_WaterClusters_big/N100-T50/1850.dat    Energy -0.11692292
# ../dataset_WaterClusters_big/N100-T50/1100.dat    Energy -0.10999798
# ../dataset_WaterClusters_big/N100-T50/0450.dat    Energy -0.11609098
# ../dataset_WaterClusters_big/N100-T50/0500.dat    Energy -0.11220287
# ../dataset_WaterClusters_big/N100-T50/1350.dat    Energy -0.11274269
# ../dataset_WaterClusters_big/N100-T50/0850.dat    Energy -0.1172224
# ../dataset_WaterClusters_big/N100-T50/1900.dat    Energy -0.13280087
# ../dataset_WaterClusters_big/N100-T50/1650.dat    Energy -0.11427883
# ../dataset_WaterClusters_big/N100-T50/0250.dat    Energy -0.1099611
# ../dataset_WaterClusters_big/N100-T50/0950.dat    Energy -0.12018595
# ../dataset_WaterClusters_big/N100-T50/2000.dat    Energy -0.11368312
# ../dataset_WaterClusters_big/N100-T50/1950.dat    Energy -0.11535345
# ../dataset_WaterClusters_big/N100-T50/1500.dat    Energy -0.11634395
# ../dataset_WaterClusters_big/N100-T50/1250.dat    Energy -0.12182443
# ../dataset_WaterClusters_big/N100-T50/0800.dat    Energy -0.11498764
# ../dataset_WaterClusters_big/N100-T50/0900.dat    Energy -0.10560462
# ../dataset_WaterClusters_big/N100-T50/0700.dat    Energy -0.11571835
# ../dataset_WaterClusters_big/N100-T50/0550.dat    Energy -0.11460768
# ../dataset_WaterClusters_big/N100-T50/1750.dat    Energy -0.11661513
# ../dataset_WaterClusters_big/N100-T50/1300.dat    Energy -0.11372413
# ../dataset_WaterClusters_big/N100-T50/0600.dat    Energy -0.11342325
# ../dataset_WaterClusters_big/N100-T50/0650.dat    Energy -0.11546384
# ../dataset_WaterClusters_big/N100-T50/1600.dat    Energy -0.11310437
# ../dataset_WaterClusters_big/N100-T50/1050.dat    Energy -0.11466049
# ../dataset_WaterClusters_big/N100-T50/0300.dat    Energy -0.11393789
# ../dataset_WaterClusters_big/N100-T50/1400.dat    Energy -0.10815774
# ../dataset_WaterClusters_big/N100-T50/1450.dat    Energy -0.10589301
# ../dataset_WaterClusters_big/N100-T50/1200.dat    Energy -0.11345366
# ../dataset_WaterClusters_big/N100-T50/0150.dat    Energy -0.11339469
# ../dataset_WaterClusters_big/N100-T50/1150.dat    Energy -0.11294594
# ../dataset_WaterClusters_big/N100-T50/0400.dat    Energy -0.1202528
# ../dataset_WaterClusters_big/N100-T50/0050.dat    Energy -0.11124898
# ../dataset_WaterClusters_big/N100-T50/0750.dat    Energy -0.11084873
# ../dataset_WaterClusters_big/N100-T50/1000.dat    Energy -0.11226988
# ../dataset_WaterClusters_big/N100-T50/1800.dat    Energy -0.11504932
# ../dataset_WaterClusters_big/N100-T50/0200.dat    Energy -0.11192941
# ../dataset_WaterClusters_big/N32-T100/0350.dat    Energy -0.05519208
# ../dataset_WaterClusters_big/N32-T100/1700.dat    Energy -0.06989186
# ../dataset_WaterClusters_big/N32-T100/0100.dat    Energy -0.05142878
# ../dataset_WaterClusters_big/N32-T100/1550.dat    Energy -0.0638777
# ../dataset_WaterClusters_big/N32-T100/1850.dat    Energy -0.06292485
# ../dataset_WaterClusters_big/N32-T100/1100.dat    Energy -0.04702563
# ../dataset_WaterClusters_big/N32-T100/0450.dat    Energy -0.05504031
# ../dataset_WaterClusters_big/N32-T100/0500.dat    Energy -0.057696
# ../dataset_WaterClusters_big/N32-T100/1350.dat    Energy -0.05216456
# ../dataset_WaterClusters_big/N32-T100/0850.dat    Energy -0.04839762
# ../dataset_WaterClusters_big/N32-T100/1900.dat    Energy -0.06268633
# ../dataset_WaterClusters_big/N32-T100/1650.dat    Energy -0.05588081
# ../dataset_WaterClusters_big/N32-T100/0250.dat    Energy -0.04783875
# ../dataset_WaterClusters_big/N32-T100/0950.dat    Energy -0.05967431
# ../dataset_WaterClusters_big/N32-T100/2000.dat    Energy -0.06751899
# ../dataset_WaterClusters_big/N32-T100/1950.dat    Energy -0.06886814
# ../dataset_WaterClusters_big/N32-T100/1500.dat    Energy -0.06024307
# ../dataset_WaterClusters_big/N32-T100/1250.dat    Energy -0.04992793
# ../dataset_WaterClusters_big/N32-T100/0800.dat    Energy -0.05437882
# ../dataset_WaterClusters_big/N32-T100/0900.dat    Energy -0.06013694
# ../dataset_WaterClusters_big/N32-T100/0700.dat    Energy -0.05423018
# ../dataset_WaterClusters_big/N32-T100/0550.dat    Energy -0.05817665
# ../dataset_WaterClusters_big/N32-T100/1750.dat    Energy -0.05976347
# ../dataset_WaterClusters_big/N32-T100/1300.dat    Energy -0.05532348
# ../dataset_WaterClusters_big/N32-T100/0600.dat    Energy -0.06200353
# ../dataset_WaterClusters_big/N32-T100/0650.dat    Energy -0.05824562
# ../dataset_WaterClusters_big/N32-T100/1600.dat    Energy -0.05861518
# ../dataset_WaterClusters_big/N32-T100/1050.dat    Energy -0.0555005
# ../dataset_WaterClusters_big/N32-T100/0300.dat    Energy -0.05248726
# ../dataset_WaterClusters_big/N32-T100/1400.dat    Energy -0.06498477
# ../dataset_WaterClusters_big/N32-T100/1450.dat    Energy -0.06771935
# ../dataset_WaterClusters_big/N32-T100/1200.dat    Energy -0.04921261
# ../dataset_WaterClusters_big/N32-T100/0150.dat    Energy -0.0526696
# ../dataset_WaterClusters_big/N32-T100/1150.dat    Energy -0.04562539
# ../dataset_WaterClusters_big/N32-T100/0400.dat    Energy -0.05323233
# ../dataset_WaterClusters_big/N32-T100/0050.dat    Energy -0.06853966
# ../dataset_WaterClusters_big/N32-T100/0750.dat    Energy -0.0514234
# ../dataset_WaterClusters_big/N32-T100/1000.dat    Energy -0.06685138
# ../dataset_WaterClusters_big/N32-T100/1800.dat    Energy -0.05849019
# ../dataset_WaterClusters_big/N32-T100/0200.dat    Energy -0.05374332
# ../dataset_WaterClusters_big/N237-T50/0350.dat    Energy -0.11258943
# ../dataset_WaterClusters_big/N237-T50/1700.dat    Energy -0.1131202
# ../dataset_WaterClusters_big/N237-T50/0100.dat    Energy -0.10230905
# ../dataset_WaterClusters_big/N237-T50/1550.dat    Energy -0.11304284
# ../dataset_WaterClusters_big/N237-T50/1850.dat    Energy -0.11080214
# ../dataset_WaterClusters_big/N237-T50/1100.dat    Energy -0.11426294
# ../dataset_WaterClusters_big/N237-T50/0450.dat    Energy -0.10838183
# ../dataset_WaterClusters_big/N237-T50/0500.dat    Energy -0.10651957
# ../dataset_WaterClusters_big/N237-T50/1350.dat    Energy -0.11269768
# ../dataset_WaterClusters_big/N237-T50/0850.dat    Energy -0.11435852
# ../dataset_WaterClusters_big/N237-T50/1900.dat    Energy -0.1099301
# ../dataset_WaterClusters_big/N237-T50/1650.dat    Energy -0.1097658
# ../dataset_WaterClusters_big/N237-T50/0250.dat    Energy -0.1100521
# ../dataset_WaterClusters_big/N237-T50/0950.dat    Energy -0.11893671
# ../dataset_WaterClusters_big/N237-T50/2000.dat    Energy -0.11402472
# ../dataset_WaterClusters_big/N237-T50/1950.dat    Energy -0.11472033
# ../dataset_WaterClusters_big/N237-T50/1500.dat    Energy -0.11841397
# ../dataset_WaterClusters_big/N237-T50/1250.dat    Energy -0.1049854
# ../dataset_WaterClusters_big/N237-T50/0800.dat    Energy -0.11927363
# ../dataset_WaterClusters_big/N237-T50/0900.dat    Energy -0.11833751
# ../dataset_WaterClusters_big/N237-T50/0700.dat    Energy -0.11010483
# ../dataset_WaterClusters_big/N237-T50/0550.dat    Energy -0.10854713
# ../dataset_WaterClusters_big/N237-T50/1750.dat    Energy -0.1143099
# ../dataset_WaterClusters_big/N237-T50/1300.dat    Energy -0.10678932
# ../dataset_WaterClusters_big/N237-T50/0600.dat    Energy -0.10225797
# ../dataset_WaterClusters_big/N237-T50/0650.dat    Energy -0.11022434
# ../dataset_WaterClusters_big/N237-T50/1600.dat    Energy -0.12137871
# ../dataset_WaterClusters_big/N237-T50/1050.dat    Energy -0.10890763
# ../dataset_WaterClusters_big/N237-T50/0300.dat    Energy -0.10473394
# ../dataset_WaterClusters_big/N237-T50/1400.dat    Energy -0.11438341
# ../dataset_WaterClusters_big/N237-T50/1450.dat    Energy -0.1158133
# ../dataset_WaterClusters_big/N237-T50/1200.dat    Energy -0.1184624
# ../dataset_WaterClusters_big/N237-T50/0150.dat    Energy -0.10832979
# ../dataset_WaterClusters_big/N237-T50/1150.dat    Energy -0.11261651
# ../dataset_WaterClusters_big/N237-T50/0400.dat    Energy -0.10416358
# ../dataset_WaterClusters_big/N237-T50/0050.dat    Energy -0.0960048
# ../dataset_WaterClusters_big/N237-T50/0750.dat    Energy -0.10412536
# ../dataset_WaterClusters_big/N237-T50/1000.dat    Energy -0.11968237
# ../dataset_WaterClusters_big/N237-T50/1800.dat    Energy -0.11469831
# ../dataset_WaterClusters_big/N237-T50/0200.dat    Energy -0.10424534
# ../dataset_WaterClusters_big/N47-T50/0350.dat    Energy -0.0821376
# ../dataset_WaterClusters_big/N47-T50/1700.dat    Energy -0.08386674
# ../dataset_WaterClusters_big/N47-T50/0100.dat    Energy -0.0880009
# ../dataset_WaterClusters_big/N47-T50/1550.dat    Energy -0.08849045
# ../dataset_WaterClusters_big/N47-T50/1850.dat    Energy -0.08701578
# ../dataset_WaterClusters_big/N47-T50/1100.dat    Energy -0.08587007
# ../dataset_WaterClusters_big/N47-T50/0450.dat    Energy -0.08020559
# ../dataset_WaterClusters_big/N47-T50/0500.dat    Energy -0.0808543
# ../dataset_WaterClusters_big/N47-T50/1350.dat    Energy -0.08943997
# ../dataset_WaterClusters_big/N47-T50/0850.dat    Energy -0.07983524
# ../dataset_WaterClusters_big/N47-T50/1900.dat    Energy -0.08969843
# ../dataset_WaterClusters_big/N47-T50/1650.dat    Energy -0.09061173
# ../dataset_WaterClusters_big/N47-T50/0250.dat    Energy -0.08263689
# ../dataset_WaterClusters_big/N47-T50/0950.dat    Energy -0.08445057
# ../dataset_WaterClusters_big/N47-T50/2000.dat    Energy -0.08597671
# ../dataset_WaterClusters_big/N47-T50/1950.dat    Energy -0.08906274
# ../dataset_WaterClusters_big/N47-T50/1500.dat    Energy -0.08994362
# ../dataset_WaterClusters_big/N47-T50/1250.dat    Energy -0.08208229
# ../dataset_WaterClusters_big/N47-T50/0800.dat    Energy -0.07992162
# ../dataset_WaterClusters_big/N47-T50/0900.dat    Energy -0.07622111
# ../dataset_WaterClusters_big/N47-T50/0700.dat    Energy -0.08368552
# ../dataset_WaterClusters_big/N47-T50/0550.dat    Energy -0.08277979
# ../dataset_WaterClusters_big/N47-T50/1750.dat    Energy -0.09075844
# ../dataset_WaterClusters_big/N47-T50/1300.dat    Energy -0.07944734
# ../dataset_WaterClusters_big/N47-T50/0600.dat    Energy -0.08167367
# ../dataset_WaterClusters_big/N47-T50/0650.dat    Energy -0.0780235
# ../dataset_WaterClusters_big/N47-T50/1600.dat    Energy -0.08083014
# ../dataset_WaterClusters_big/N47-T50/1050.dat    Energy -0.08546377
# ../dataset_WaterClusters_big/N47-T50/0300.dat    Energy -0.08514895
# ../dataset_WaterClusters_big/N47-T50/1400.dat    Energy -0.08490272
# ../dataset_WaterClusters_big/N47-T50/1450.dat    Energy -0.08061853
# ../dataset_WaterClusters_big/N47-T50/1200.dat    Energy -0.09059873
# ../dataset_WaterClusters_big/N47-T50/0150.dat    Energy -0.08589252
# ../dataset_WaterClusters_big/N47-T50/1150.dat    Energy -0.08055807
# ../dataset_WaterClusters_big/N47-T50/0400.dat    Energy -0.08604332
# ../dataset_WaterClusters_big/N47-T50/0050.dat    Energy -0.07937535
# ../dataset_WaterClusters_big/N47-T50/0750.dat    Energy -0.08211182
# ../dataset_WaterClusters_big/N47-T50/1000.dat    Energy -0.08125722
# ../dataset_WaterClusters_big/N47-T50/1800.dat    Energy -0.08872474
# ../dataset_WaterClusters_big/N47-T50/0200.dat    Energy -0.07951267
# ../dataset_WaterClusters_big/N20-T50/0350.dat    Energy -0.02641588
# ../dataset_WaterClusters_big/N20-T50/1700.dat    Energy -0.02458119
# ../dataset_WaterClusters_big/N20-T50/0100.dat    Energy -0.02723965
# ../dataset_WaterClusters_big/N20-T50/1550.dat    Energy -0.02118512
# ../dataset_WaterClusters_big/N20-T50/1850.dat    Energy -0.02583042
# ../dataset_WaterClusters_big/N20-T50/1100.dat    Energy -0.02067701
# ../dataset_WaterClusters_big/N20-T50/0450.dat    Energy -0.02270354
# ../dataset_WaterClusters_big/N20-T50/0500.dat    Energy -0.02440138
# ../dataset_WaterClusters_big/N20-T50/1350.dat    Energy -0.0246412
# ../dataset_WaterClusters_big/N20-T50/0850.dat    Energy -0.02163022
# ../dataset_WaterClusters_big/N20-T50/1900.dat    Energy -0.02333381
# ../dataset_WaterClusters_big/N20-T50/1650.dat    Energy -0.02522169
# ../dataset_WaterClusters_big/N20-T50/0250.dat    Energy -0.02959565
# ../dataset_WaterClusters_big/N20-T50/0950.dat    Energy -0.02346458
# ../dataset_WaterClusters_big/N20-T50/2000.dat    Energy -0.02546309
# ../dataset_WaterClusters_big/N20-T50/1950.dat    Energy -0.02662178
# ../dataset_WaterClusters_big/N20-T50/1500.dat    Energy -0.02671401
# ../dataset_WaterClusters_big/N20-T50/1250.dat    Energy -0.02932448
# ../dataset_WaterClusters_big/N20-T50/0800.dat    Energy -0.02760769
# ../dataset_WaterClusters_big/N20-T50/0900.dat    Energy -0.02325899
# ../dataset_WaterClusters_big/N20-T50/0700.dat    Energy -0.02088636
# ../dataset_WaterClusters_big/N20-T50/0550.dat    Energy -0.02557297
# ../dataset_WaterClusters_big/N20-T50/1750.dat    Energy -0.02431938
# ../dataset_WaterClusters_big/N20-T50/1300.dat    Energy -0.02576242
# ../dataset_WaterClusters_big/N20-T50/0600.dat    Energy -0.02377154
# ../dataset_WaterClusters_big/N20-T50/0650.dat    Energy -0.02097901
# ../dataset_WaterClusters_big/N20-T50/1600.dat    Energy -0.02148099
# ../dataset_WaterClusters_big/N20-T50/1050.dat    Energy -0.02266808
# ../dataset_WaterClusters_big/N20-T50/0300.dat    Energy -0.02652356
# ../dataset_WaterClusters_big/N20-T50/1400.dat    Energy -0.02694834
# ../dataset_WaterClusters_big/N20-T50/1450.dat    Energy -0.02359818
# ../dataset_WaterClusters_big/N20-T50/1200.dat    Energy -0.03176353
# ../dataset_WaterClusters_big/N20-T50/0150.dat    Energy -0.02098033
# ../dataset_WaterClusters_big/N20-T50/1150.dat    Energy -0.02531223
# ../dataset_WaterClusters_big/N20-T50/0400.dat    Energy -0.01885584
# ../dataset_WaterClusters_big/N20-T50/0050.dat    Energy -0.02359588
# ../dataset_WaterClusters_big/N20-T50/0750.dat    Energy -0.02443643
# ../dataset_WaterClusters_big/N20-T50/1000.dat    Energy -0.0203736
# ../dataset_WaterClusters_big/N20-T50/1800.dat    Energy -0.02657192
# ../dataset_WaterClusters_big/N20-T50/0200.dat    Energy -0.02573067
# ../dataset_WaterClusters_big/N47-T150/0350.dat    Energy -0.07147062
# ../dataset_WaterClusters_big/N47-T150/1700.dat    Energy -0.0811144
# ../dataset_WaterClusters_big/N47-T150/0100.dat    Energy -0.08117061
# ../dataset_WaterClusters_big/N47-T150/1550.dat    Energy -0.08120394
# ../dataset_WaterClusters_big/N47-T150/1850.dat    Energy -0.07278619
# ../dataset_WaterClusters_big/N47-T150/1100.dat    Energy -0.07138923
# ../dataset_WaterClusters_big/N47-T150/0450.dat    Energy -0.06458024
# ../dataset_WaterClusters_big/N47-T150/0500.dat    Energy -0.07463892
# ../dataset_WaterClusters_big/N47-T150/1350.dat    Energy -0.08014091
# ../dataset_WaterClusters_big/N47-T150/0850.dat    Energy -0.06745094
# ../dataset_WaterClusters_big/N47-T150/1900.dat    Energy -0.07979683
# ../dataset_WaterClusters_big/N47-T150/1650.dat    Energy -0.08674511
# ../dataset_WaterClusters_big/N47-T150/0250.dat    Energy -0.06244138
# ../dataset_WaterClusters_big/N47-T150/0950.dat    Energy -0.05828977
# ../dataset_WaterClusters_big/N47-T150/2000.dat    Energy -0.07197125
# ../dataset_WaterClusters_big/N47-T150/1950.dat    Energy -0.07402952
# ../dataset_WaterClusters_big/N47-T150/1500.dat    Energy -0.077165
# ../dataset_WaterClusters_big/N47-T150/1250.dat    Energy -0.07258249
# ../dataset_WaterClusters_big/N47-T150/0800.dat    Energy -0.05863208
# ../dataset_WaterClusters_big/N47-T150/0900.dat    Energy -0.05611209
# ../dataset_WaterClusters_big/N47-T150/0700.dat    Energy -0.06323576
# ../dataset_WaterClusters_big/N47-T150/0550.dat    Energy -0.05620185
# ../dataset_WaterClusters_big/N47-T150/1750.dat    Energy -0.08498338
# ../dataset_WaterClusters_big/N47-T150/1300.dat    Energy -0.0613274
# ../dataset_WaterClusters_big/N47-T150/0600.dat    Energy -0.04747335
# ../dataset_WaterClusters_big/N47-T150/0650.dat    Energy -0.0492265
# ../dataset_WaterClusters_big/N47-T150/1600.dat    Energy -0.06804313
# ../dataset_WaterClusters_big/N47-T150/1050.dat    Energy -0.06344702
# ../dataset_WaterClusters_big/N47-T150/0300.dat    Energy -0.06881758
# ../dataset_WaterClusters_big/N47-T150/1400.dat    Energy -0.07776901
# ../dataset_WaterClusters_big/N47-T150/1450.dat    Energy -0.05803659
# ../dataset_WaterClusters_big/N47-T150/1200.dat    Energy -0.08151885
# ../dataset_WaterClusters_big/N47-T150/0150.dat    Energy -0.06831052
# ../dataset_WaterClusters_big/N47-T150/1150.dat    Energy -0.06413361
# ../dataset_WaterClusters_big/N47-T150/0400.dat    Energy -0.06930084
# ../dataset_WaterClusters_big/N47-T150/0050.dat    Energy -0.06811811
# ../dataset_WaterClusters_big/N47-T150/0750.dat    Energy -0.06195088
# ../dataset_WaterClusters_big/N47-T150/1000.dat    Energy -0.05536631
# ../dataset_WaterClusters_big/N47-T150/1800.dat    Energy -0.08249919
# ../dataset_WaterClusters_big/N47-T150/0200.dat    Energy -0.06069256
# ../dataset_WaterClusters_big/N190-T100/0350.dat    Energy -0.11984273
# ../dataset_WaterClusters_big/N190-T100/1700.dat    Energy -0.11915451
# ../dataset_WaterClusters_big/N190-T100/0100.dat    Energy -0.11484438
# ../dataset_WaterClusters_big/N190-T100/1550.dat    Energy -0.11781128
# ../dataset_WaterClusters_big/N190-T100/1850.dat    Energy -0.11382514
# ../dataset_WaterClusters_big/N190-T100/1100.dat    Energy -0.11505513
# ../dataset_WaterClusters_big/N190-T100/0450.dat    Energy -0.11252964
# ../dataset_WaterClusters_big/N190-T100/0500.dat    Energy -0.12220232
# ../dataset_WaterClusters_big/N190-T100/1350.dat    Energy -0.12775196
# ../dataset_WaterClusters_big/N190-T100/0850.dat    Energy -0.12455266
# ../dataset_WaterClusters_big/N190-T100/1900.dat    Energy -0.11739553
# ../dataset_WaterClusters_big/N190-T100/1650.dat    Energy -0.12847297
# ../dataset_WaterClusters_big/N190-T100/0250.dat    Energy -0.12129098
# ../dataset_WaterClusters_big/N190-T100/0950.dat    Energy -0.12585665
# ../dataset_WaterClusters_big/N190-T100/2000.dat    Energy -0.1275973
# ../dataset_WaterClusters_big/N190-T100/1950.dat    Energy -0.11402714
# ../dataset_WaterClusters_big/N190-T100/1500.dat    Energy -0.12344874
# ../dataset_WaterClusters_big/N190-T100/1250.dat    Energy -0.1274141
# ../dataset_WaterClusters_big/N190-T100/0800.dat    Energy -0.11388511
# ../dataset_WaterClusters_big/N190-T100/0900.dat    Energy -0.13066433
# ../dataset_WaterClusters_big/N190-T100/0700.dat    Energy -0.10594817
# ../dataset_WaterClusters_big/N190-T100/0550.dat    Energy -0.11628478
# ../dataset_WaterClusters_big/N190-T100/1750.dat    Energy -0.12022395
# ../dataset_WaterClusters_big/N190-T100/1300.dat    Energy -0.11357796
# ../dataset_WaterClusters_big/N190-T100/0600.dat    Energy -0.11015298
# ../dataset_WaterClusters_big/N190-T100/0650.dat    Energy -0.12685883
# ../dataset_WaterClusters_big/N190-T100/1600.dat    Energy -0.11980672
# ../dataset_WaterClusters_big/N190-T100/1050.dat    Energy -0.11991007
# ../dataset_WaterClusters_big/N190-T100/0300.dat    Energy -0.11289681
# ../dataset_WaterClusters_big/N190-T100/1400.dat    Energy -0.11609534
# ../dataset_WaterClusters_big/N190-T100/1450.dat    Energy -0.11732417
# ../dataset_WaterClusters_big/N190-T100/1200.dat    Energy -0.11879523
# ../dataset_WaterClusters_big/N190-T100/0150.dat    Energy -0.11605205
# ../dataset_WaterClusters_big/N190-T100/1150.dat    Energy -0.11776391
# ../dataset_WaterClusters_big/N190-T100/0400.dat    Energy -0.12629336
# ../dataset_WaterClusters_big/N190-T100/0050.dat    Energy -0.12716212
# ../dataset_WaterClusters_big/N190-T100/0750.dat    Energy -0.11524925
# ../dataset_WaterClusters_big/N190-T100/1000.dat    Energy -0.11802351
# ../dataset_WaterClusters_big/N190-T100/1800.dat    Energy -0.11734082
# ../dataset_WaterClusters_big/N190-T100/0200.dat    Energy -0.11101055
# ../dataset_WaterClusters_big/N32-T200/0350.dat    Energy -0.04265379
# ../dataset_WaterClusters_big/N32-T200/1700.dat    Energy -0.0693168
# ../dataset_WaterClusters_big/N32-T200/0100.dat    Energy -0.04244097
# ../dataset_WaterClusters_big/N32-T200/1550.dat    Energy -0.04927624
# ../dataset_WaterClusters_big/N32-T200/1850.dat    Energy -0.05748093
# ../dataset_WaterClusters_big/N32-T200/1100.dat    Energy -0.04866902
# ../dataset_WaterClusters_big/N32-T200/0450.dat    Energy -0.05746147
# ../dataset_WaterClusters_big/N32-T200/0500.dat    Energy -0.04886702
# ../dataset_WaterClusters_big/N32-T200/1350.dat    Energy -0.05816576
# ../dataset_WaterClusters_big/N32-T200/0850.dat    Energy -0.04657623
# ../dataset_WaterClusters_big/N32-T200/1900.dat    Energy -0.06897773
# ../dataset_WaterClusters_big/N32-T200/1650.dat    Energy -0.05243321
# ../dataset_WaterClusters_big/N32-T200/0250.dat    Energy -0.04737637
# ../dataset_WaterClusters_big/N32-T200/0950.dat    Energy -0.05260037
# ../dataset_WaterClusters_big/N32-T200/2000.dat    Energy -0.07229406
# ../dataset_WaterClusters_big/N32-T200/1950.dat    Energy -0.07144848
# ../dataset_WaterClusters_big/N32-T200/1500.dat    Energy -0.04665297
# ../dataset_WaterClusters_big/N32-T200/1250.dat    Energy -0.03431285
# ../dataset_WaterClusters_big/N32-T200/0800.dat    Energy -0.05269976
# ../dataset_WaterClusters_big/N32-T200/0900.dat    Energy -0.05228609
# ../dataset_WaterClusters_big/N32-T200/0700.dat    Energy -0.04361513
# ../dataset_WaterClusters_big/N32-T200/0550.dat    Energy -0.04515526
# ../dataset_WaterClusters_big/N32-T200/1750.dat    Energy -0.0628559
# ../dataset_WaterClusters_big/N32-T200/1300.dat    Energy -0.0504363
# ../dataset_WaterClusters_big/N32-T200/0600.dat    Energy -0.04269325
# ../dataset_WaterClusters_big/N32-T200/0650.dat    Energy -0.05099967
# ../dataset_WaterClusters_big/N32-T200/1600.dat    Energy -0.06016087
# ../dataset_WaterClusters_big/N32-T200/1050.dat    Energy -0.04437061
# ../dataset_WaterClusters_big/N32-T200/0300.dat    Energy -0.04993135
# ../dataset_WaterClusters_big/N32-T200/1400.dat    Energy -0.06055754
# ../dataset_WaterClusters_big/N32-T200/1450.dat    Energy -0.05374287
# ../dataset_WaterClusters_big/N32-T200/1200.dat    Energy -0.04493851
# ../dataset_WaterClusters_big/N32-T200/0150.dat    Energy -0.05613088
# ../dataset_WaterClusters_big/N32-T200/1150.dat    Energy -0.04301448
# ../dataset_WaterClusters_big/N32-T200/0400.dat    Energy -0.05208837
# ../dataset_WaterClusters_big/N32-T200/0050.dat    Energy -0.06192355
# ../dataset_WaterClusters_big/N32-T200/0750.dat    Energy -0.05126973
# ../dataset_WaterClusters_big/N32-T200/1000.dat    Energy -0.05920335
# ../dataset_WaterClusters_big/N32-T200/1800.dat    Energy -0.06710143
# ../dataset_WaterClusters_big/N32-T200/0200.dat    Energy -0.03597818
# ../dataset_WaterClusters_big/N139-T100/0350.dat    Energy -0.09504667
# ../dataset_WaterClusters_big/N139-T100/1700.dat    Energy -0.08151482
# ../dataset_WaterClusters_big/N139-T100/0100.dat    Energy -0.08888388
# ../dataset_WaterClusters_big/N139-T100/1550.dat    Energy -0.07928228
# ../dataset_WaterClusters_big/N139-T100/1850.dat    Energy -0.08915649
# ../dataset_WaterClusters_big/N139-T100/1100.dat    Energy -0.09101865
# ../dataset_WaterClusters_big/N139-T100/0450.dat    Energy -0.08975192
# ../dataset_WaterClusters_big/N139-T100/0500.dat    Energy -0.09767834
# ../dataset_WaterClusters_big/N139-T100/1350.dat    Energy -0.09302547
# ../dataset_WaterClusters_big/N139-T100/0850.dat    Energy -0.08188455
# ../dataset_WaterClusters_big/N139-T100/1900.dat    Energy -0.08475828
# ../dataset_WaterClusters_big/N139-T100/1650.dat    Energy -0.08668341
# ../dataset_WaterClusters_big/N139-T100/0250.dat    Energy -0.09309792
# ../dataset_WaterClusters_big/N139-T100/0950.dat    Energy -0.09351213
# ../dataset_WaterClusters_big/N139-T100/2000.dat    Energy -0.09471576
# ../dataset_WaterClusters_big/N139-T100/1950.dat    Energy -0.08748125
# ../dataset_WaterClusters_big/N139-T100/1500.dat    Energy -0.09283853
# ../dataset_WaterClusters_big/N139-T100/1250.dat    Energy -0.09755085
# ../dataset_WaterClusters_big/N139-T100/0800.dat    Energy -0.09010447
# ../dataset_WaterClusters_big/N139-T100/0900.dat    Energy -0.08537189
# ../dataset_WaterClusters_big/N139-T100/0700.dat    Energy -0.09339484
# ../dataset_WaterClusters_big/N139-T100/0550.dat    Energy -0.09378108
# ../dataset_WaterClusters_big/N139-T100/1750.dat    Energy -0.08301645
# ../dataset_WaterClusters_big/N139-T100/1300.dat    Energy -0.08133448
# ../dataset_WaterClusters_big/N139-T100/0600.dat    Energy -0.09340015
# ../dataset_WaterClusters_big/N139-T100/0650.dat    Energy -0.09218346
# ../dataset_WaterClusters_big/N139-T100/1600.dat    Energy -0.0830869
# ../dataset_WaterClusters_big/N139-T100/1050.dat    Energy -0.09227391
# ../dataset_WaterClusters_big/N139-T100/0300.dat    Energy -0.09131625
# ../dataset_WaterClusters_big/N139-T100/1400.dat    Energy -0.0898237
# ../dataset_WaterClusters_big/N139-T100/1450.dat    Energy -0.08498221
# ../dataset_WaterClusters_big/N139-T100/1200.dat    Energy -0.08784072
# ../dataset_WaterClusters_big/N139-T100/0150.dat    Energy -0.087178
# ../dataset_WaterClusters_big/N139-T100/1150.dat    Energy -0.08940799
# ../dataset_WaterClusters_big/N139-T100/0400.dat    Energy -0.10229322
# ../dataset_WaterClusters_big/N139-T100/0050.dat    Energy -0.10014787
# ../dataset_WaterClusters_big/N139-T100/0750.dat    Energy -0.0821682
# ../dataset_WaterClusters_big/N139-T100/1000.dat    Energy -0.09652332
# ../dataset_WaterClusters_big/N139-T100/1800.dat    Energy -0.0968724
# ../dataset_WaterClusters_big/N139-T100/0200.dat    Energy -0.08675638
# ../dataset_WaterClusters_big/N139-T150/0350.dat    Energy -0.10035432
# ../dataset_WaterClusters_big/N139-T150/1700.dat    Energy -0.09943447
# ../dataset_WaterClusters_big/N139-T150/0100.dat    Energy -0.09656295
# ../dataset_WaterClusters_big/N139-T150/1550.dat    Energy -0.10126972
# ../dataset_WaterClusters_big/N139-T150/1850.dat    Energy -0.10189427
# ../dataset_WaterClusters_big/N139-T150/1100.dat    Energy -0.10185115
# ../dataset_WaterClusters_big/N139-T150/0450.dat    Energy -0.0926394
# ../dataset_WaterClusters_big/N139-T150/0500.dat    Energy -0.08985304
# ../dataset_WaterClusters_big/N139-T150/1350.dat    Energy -0.10706147
# ../dataset_WaterClusters_big/N139-T150/0850.dat    Energy -0.09466573
# ../dataset_WaterClusters_big/N139-T150/1900.dat    Energy -0.10107582
# ../dataset_WaterClusters_big/N139-T150/1650.dat    Energy -0.10542619
# ../dataset_WaterClusters_big/N139-T150/0250.dat    Energy -0.11057037
# ../dataset_WaterClusters_big/N139-T150/0950.dat    Energy -0.10957217
# ../dataset_WaterClusters_big/N139-T150/2000.dat    Energy -0.10455465
# ../dataset_WaterClusters_big/N139-T150/1950.dat    Energy -0.10008954
# ../dataset_WaterClusters_big/N139-T150/1500.dat    Energy -0.10528569
# ../dataset_WaterClusters_big/N139-T150/1250.dat    Energy -0.10939781
# ../dataset_WaterClusters_big/N139-T150/0800.dat    Energy -0.10288675
# ../dataset_WaterClusters_big/N139-T150/0900.dat    Energy -0.1007414
# ../dataset_WaterClusters_big/N139-T150/0700.dat    Energy -0.10296542
# ../dataset_WaterClusters_big/N139-T150/0550.dat    Energy -0.09077016
# ../dataset_WaterClusters_big/N139-T150/1750.dat    Energy -0.09898851
# ../dataset_WaterClusters_big/N139-T150/1300.dat    Energy -0.09639968
# ../dataset_WaterClusters_big/N139-T150/0600.dat    Energy -0.09994636
# ../dataset_WaterClusters_big/N139-T150/0650.dat    Energy -0.09936762
# ../dataset_WaterClusters_big/N139-T150/1600.dat    Energy -0.09908684
# ../dataset_WaterClusters_big/N139-T150/1050.dat    Energy -0.09979329
# ../dataset_WaterClusters_big/N139-T150/0300.dat    Energy -0.09448438
# ../dataset_WaterClusters_big/N139-T150/1400.dat    Energy -0.103254
# ../dataset_WaterClusters_big/N139-T150/1450.dat    Energy -0.09843145
# ../dataset_WaterClusters_big/N139-T150/1200.dat    Energy -0.09857862
# ../dataset_WaterClusters_big/N139-T150/0150.dat    Energy -0.08680633
# ../dataset_WaterClusters_big/N139-T150/1150.dat    Energy -0.09760443
# ../dataset_WaterClusters_big/N139-T150/0400.dat    Energy -0.10814335
# ../dataset_WaterClusters_big/N139-T150/0050.dat    Energy -0.10514825
# ../dataset_WaterClusters_big/N139-T150/0750.dat    Energy -0.10307355
# ../dataset_WaterClusters_big/N139-T150/1000.dat    Energy -0.10139809
# ../dataset_WaterClusters_big/N139-T150/1800.dat    Energy -0.11092837
# ../dataset_WaterClusters_big/N139-T150/0200.dat    Energy -0.09740813
# ../dataset_WaterClusters_big/N32-T50/0350.dat    Energy -0.04880272
# ../dataset_WaterClusters_big/N32-T50/1700.dat    Energy -0.05909482
# ../dataset_WaterClusters_big/N32-T50/0100.dat    Energy -0.04310936
# ../dataset_WaterClusters_big/N32-T50/1550.dat    Energy -0.05253459
# ../dataset_WaterClusters_big/N32-T50/1850.dat    Energy -0.05820477
# ../dataset_WaterClusters_big/N32-T50/1100.dat    Energy -0.04958434
# ../dataset_WaterClusters_big/N32-T50/0450.dat    Energy -0.04632412
# ../dataset_WaterClusters_big/N32-T50/0500.dat    Energy -0.0513651
# ../dataset_WaterClusters_big/N32-T50/1350.dat    Energy -0.0531496
# ../dataset_WaterClusters_big/N32-T50/0850.dat    Energy -0.04882848
# ../dataset_WaterClusters_big/N32-T50/1900.dat    Energy -0.05376861
# ../dataset_WaterClusters_big/N32-T50/1650.dat    Energy -0.05589757
# ../dataset_WaterClusters_big/N32-T50/0250.dat    Energy -0.04311704
# ../dataset_WaterClusters_big/N32-T50/0950.dat    Energy -0.05204854
# ...
# ../dataset_WaterClusters_big/N100-T200/0850.dat    Energy -0.10004072
# ../dataset_WaterClusters_big/N100-T200/1900.dat    Energy -0.11472067
# ../dataset_WaterClusters_big/N100-T200/1650.dat    Energy -0.103885
# ../dataset_WaterClusters_big/N100-T200/0250.dat    Energy -0.08995256
# ../dataset_WaterClusters_big/N100-T200/0950.dat    Energy -0.11819922
# ../dataset_WaterClusters_big/N100-T200/2000.dat    Energy -0.10056489
# ../dataset_WaterClusters_big/N100-T200/1950.dat    Energy -0.10441945
# ../dataset_WaterClusters_big/N100-T200/1500.dat    Energy -0.10466267
# ../dataset_WaterClusters_big/N100-T200/1250.dat    Energy -0.12171043
# ../dataset_WaterClusters_big/N100-T200/0800.dat    Energy -0.09796039
# ../dataset_WaterClusters_big/N100-T200/0900.dat    Energy -0.10053206
# ../dataset_WaterClusters_big/N100-T200/0700.dat    Energy -0.10736621
# ../dataset_WaterClusters_big/N100-T200/0550.dat    Energy -0.09934692
# ../dataset_WaterClusters_big/N100-T200/1750.dat    Energy -0.10635126
# ../dataset_WaterClusters_big/N100-T200/1300.dat    Energy -0.1063379
# ../dataset_WaterClusters_big/N100-T200/0600.dat    Energy -0.09874333
# ../dataset_WaterClusters_big/N100-T200/0650.dat    Energy -0.10039629
# ../dataset_WaterClusters_big/N100-T200/1600.dat    Energy -0.09557083
# ../dataset_WaterClusters_big/N100-T200/1050.dat    Energy -0.10908827
# ../dataset_WaterClusters_big/N100-T200/0300.dat    Energy -0.10087613
# ../dataset_WaterClusters_big/N100-T200/1400.dat    Energy -0.10242006
# ../dataset_WaterClusters_big/N100-T200/1450.dat    Energy -0.09202624
# ../dataset_WaterClusters_big/N100-T200/1200.dat    Energy -0.10678295
# ../dataset_WaterClusters_big/N100-T200/0150.dat    Energy -0.10565656
# ../dataset_WaterClusters_big/N100-T200/1150.dat    Energy -0.11039229
# ../dataset_WaterClusters_big/N100-T200/0400.dat    Energy -0.10831754
# ../dataset_WaterClusters_big/N100-T200/0050.dat    Energy -0.09900152
# ../dataset_WaterClusters_big/N100-T200/0750.dat    Energy -0.09268586
# ../dataset_WaterClusters_big/N100-T200/1000.dat    Energy -0.10387157
# ../dataset_WaterClusters_big/N100-T200/1800.dat    Energy -0.09642878
# ../dataset_WaterClusters_big/N100-T200/0200.dat    Energy -0.09588148
# ../dataset_WaterClusters_big/N47-T200/0350.dat    Energy -0.03805771
# ../dataset_WaterClusters_big/N47-T200/1700.dat    Energy -0.04203447
# ../dataset_WaterClusters_big/N47-T200/0100.dat    Energy -0.0326926
# ../dataset_WaterClusters_big/N47-T200/1550.dat    Energy -0.03931918
# ../dataset_WaterClusters_big/N47-T200/1850.dat    Energy -0.03812659
# ../dataset_WaterClusters_big/N47-T200/1100.dat    Energy -0.03443783
# ../dataset_WaterClusters_big/N47-T200/0450.dat    Energy -0.03725581
# ../dataset_WaterClusters_big/N47-T200/0500.dat    Energy -0.04618698
# ../dataset_WaterClusters_big/N47-T200/1350.dat    Energy -0.03639008
# ../dataset_WaterClusters_big/N47-T200/0850.dat    Energy -0.03026144
# ../dataset_WaterClusters_big/N47-T200/1900.dat    Energy -0.04164096
# ../dataset_WaterClusters_big/N47-T200/1650.dat    Energy -0.0397602
# ../dataset_WaterClusters_big/N47-T200/0250.dat    Energy -0.02856087
# ../dataset_WaterClusters_big/N47-T200/0950.dat    Energy -0.03834759
# ../dataset_WaterClusters_big/N47-T200/2000.dat    Energy -0.04641283
# ../dataset_WaterClusters_big/N47-T200/1950.dat    Energy -0.04062296
# ../dataset_WaterClusters_big/N47-T200/1500.dat    Energy -0.04589572
# ../dataset_WaterClusters_big/N47-T200/1250.dat    Energy -0.03862983
# ../dataset_WaterClusters_big/N47-T200/0800.dat    Energy -0.03622931
# ../dataset_WaterClusters_big/N47-T200/0900.dat    Energy -0.03397123
# ../dataset_WaterClusters_big/N47-T200/0700.dat    Energy -0.03116199
# ../dataset_WaterClusters_big/N47-T200/0550.dat    Energy -0.03956558
# ../dataset_WaterClusters_big/N47-T200/1750.dat    Energy -0.04612528
# ../dataset_WaterClusters_big/N47-T200/1300.dat    Energy -0.04224068
# ../dataset_WaterClusters_big/N47-T200/0600.dat    Energy -0.03901663
# ../dataset_WaterClusters_big/N47-T200/0650.dat    Energy -0.0383917
# ../dataset_WaterClusters_big/N47-T200/1600.dat    Energy -0.03573567
# ../dataset_WaterClusters_big/N47-T200/1050.dat    Energy -0.03577897
# ../dataset_WaterClusters_big/N47-T200/0300.dat    Energy -0.03899048
# ../dataset_WaterClusters_big/N47-T200/1400.dat    Energy -0.04630099
# ../dataset_WaterClusters_big/N47-T200/1450.dat    Energy -0.03816929
# ../dataset_WaterClusters_big/N47-T200/1200.dat    Energy -0.03545088
# ../dataset_WaterClusters_big/N47-T200/0150.dat    Energy -0.04027602
# ../dataset_WaterClusters_big/N47-T200/1150.dat    Energy -0.03773229
# ../dataset_WaterClusters_big/N47-T200/0400.dat    Energy -0.03962728
# ../dataset_WaterClusters_big/N47-T200/0050.dat    Energy -0.0401599
# ../dataset_WaterClusters_big/N47-T200/0750.dat    Energy -0.03168988
# ../dataset_WaterClusters_big/N47-T200/1000.dat    Energy -0.03611241
# ../dataset_WaterClusters_big/N47-T200/1800.dat    Energy -0.04358669
# ../dataset_WaterClusters_big/N47-T200/0200.dat    Energy -0.04227732
# ../dataset_WaterClusters_big/N237-T100/0350.dat    Energy -0.1193639
# ../dataset_WaterClusters_big/N237-T100/1700.dat    Energy -0.11952963
# ../dataset_WaterClusters_big/N237-T100/0100.dat    Energy -0.10759507
# ../dataset_WaterClusters_big/N237-T100/1550.dat    Energy -0.12099289
# ../dataset_WaterClusters_big/N237-T100/1850.dat    Energy -0.11243814
# ../dataset_WaterClusters_big/N237-T100/1100.dat    Energy -0.11179566
# ../dataset_WaterClusters_big/N237-T100/0450.dat    Energy -0.11154949
# ../dataset_WaterClusters_big/N237-T100/0500.dat    Energy -0.10961672
# ../dataset_WaterClusters_big/N237-T100/1350.dat    Energy -0.11166599
# ../dataset_WaterClusters_big/N237-T100/0850.dat    Energy -0.11600527
# ../dataset_WaterClusters_big/N237-T100/1900.dat    Energy -0.11296531
# ../dataset_WaterClusters_big/N237-T100/1650.dat    Energy -0.11235578
# ../dataset_WaterClusters_big/N237-T100/0250.dat    Energy -0.11098785
# ../dataset_WaterClusters_big/N237-T100/0950.dat    Energy -0.11739959
# ../dataset_WaterClusters_big/N237-T100/2000.dat    Energy -0.12554002
# ../dataset_WaterClusters_big/N237-T100/1950.dat    Energy -0.1201154
# ../dataset_WaterClusters_big/N237-T100/1500.dat    Energy -0.11970657
# ../dataset_WaterClusters_big/N237-T100/1250.dat    Energy -0.10351142
# ../dataset_WaterClusters_big/N237-T100/0800.dat    Energy -0.12784249
# ../dataset_WaterClusters_big/N237-T100/0900.dat    Energy -0.11394034
# ../dataset_WaterClusters_big/N237-T100/0700.dat    Energy -0.11216221
# ../dataset_WaterClusters_big/N237-T100/0550.dat    Energy -0.11068599
# ../dataset_WaterClusters_big/N237-T100/1750.dat    Energy -0.11192986
# ../dataset_WaterClusters_big/N237-T100/1300.dat    Energy -0.10530258
# ../dataset_WaterClusters_big/N237-T100/0600.dat    Energy -0.10419914
# ../dataset_WaterClusters_big/N237-T100/0650.dat    Energy -0.11131797
# ../dataset_WaterClusters_big/N237-T100/1600.dat    Energy -0.12493474
# ../dataset_WaterClusters_big/N237-T100/1050.dat    Energy -0.11248932
# ../dataset_WaterClusters_big/N237-T100/0300.dat    Energy -0.10707237
# ../dataset_WaterClusters_big/N237-T100/1400.dat    Energy -0.11451781
# ../dataset_WaterClusters_big/N237-T100/1450.dat    Energy -0.11786765
# ../dataset_WaterClusters_big/N237-T100/1200.dat    Energy -0.11301169
# ../dataset_WaterClusters_big/N237-T100/0150.dat    Energy -0.11100919
# ../dataset_WaterClusters_big/N237-T100/1150.dat    Energy -0.1138472
# ../dataset_WaterClusters_big/N237-T100/0400.dat    Energy -0.11920597
# ../dataset_WaterClusters_big/N237-T100/0050.dat    Energy -0.10409547
# ../dataset_WaterClusters_big/N237-T100/0750.dat    Energy -0.10397005
# ../dataset_WaterClusters_big/N237-T100/1000.dat    Energy -0.12332995
# ../dataset_WaterClusters_big/N237-T100/1800.dat    Energy -0.11681707
# ../dataset_WaterClusters_big/N237-T100/0200.dat    Energy -0.10488183
# ../dataset_WaterClusters_big/N76-T150/0350.dat    Energy -0.09054172
# ../dataset_WaterClusters_big/N76-T150/1700.dat    Energy -0.09962783
# ../dataset_WaterClusters_big/N76-T150/0100.dat    Energy -0.07637572
# ../dataset_WaterClusters_big/N76-T150/1550.dat    Energy -0.10167566
# ../dataset_WaterClusters_big/N76-T150/1850.dat    Energy -0.09079786
# ../dataset_WaterClusters_big/N76-T150/1100.dat    Energy -0.07770461
# ../dataset_WaterClusters_big/N76-T150/0450.dat    Energy -0.06807107
# ../dataset_WaterClusters_big/N76-T150/0500.dat    Energy -0.07964724
# ../dataset_WaterClusters_big/N76-T150/1350.dat    Energy -0.07489679
# ../dataset_WaterClusters_big/N76-T150/0850.dat    Energy -0.07050291
# ../dataset_WaterClusters_big/N76-T150/1900.dat    Energy -0.08332761
# ../dataset_WaterClusters_big/N76-T150/1650.dat    Energy -0.10369168
# ../dataset_WaterClusters_big/N76-T150/0250.dat    Energy -0.08970495
# ../dataset_WaterClusters_big/N76-T150/0950.dat    Energy -0.0669348
# ../dataset_WaterClusters_big/N76-T150/2000.dat    Energy -0.10431362
# ../dataset_WaterClusters_big/N76-T150/1950.dat    Energy -0.08901213
# ../dataset_WaterClusters_big/N76-T150/1500.dat    Energy -0.09325202
# ../dataset_WaterClusters_big/N76-T150/1250.dat    Energy -0.08263511
# ../dataset_WaterClusters_big/N76-T150/0800.dat    Energy -0.07565252
# ../dataset_WaterClusters_big/N76-T150/0900.dat    Energy -0.07758138
# ../dataset_WaterClusters_big/N76-T150/0700.dat    Energy -0.07254645
# ../dataset_WaterClusters_big/N76-T150/0550.dat    Energy -0.08673701
# ../dataset_WaterClusters_big/N76-T150/1750.dat    Energy -0.08892985
# ../dataset_WaterClusters_big/N76-T150/1300.dat    Energy -0.08215783
# ../dataset_WaterClusters_big/N76-T150/0600.dat    Energy -0.08262322
# ../dataset_WaterClusters_big/N76-T150/0650.dat    Energy -0.07421185
# ../dataset_WaterClusters_big/N76-T150/1600.dat    Energy -0.10165792
# ../dataset_WaterClusters_big/N76-T150/1050.dat    Energy -0.07586055
# ../dataset_WaterClusters_big/N76-T150/0300.dat    Energy -0.09206967
# ../dataset_WaterClusters_big/N76-T150/1400.dat    Energy -0.07348388
# ../dataset_WaterClusters_big/N76-T150/1450.dat    Energy -0.09328627
# ../dataset_WaterClusters_big/N76-T150/1200.dat    Energy -0.07947403
# ../dataset_WaterClusters_big/N76-T150/0150.dat    Energy -0.08525149
# ../dataset_WaterClusters_big/N76-T150/1150.dat    Energy -0.06834113
# ../dataset_WaterClusters_big/N76-T150/0400.dat    Energy -0.08848823
# ../dataset_WaterClusters_big/N76-T150/0050.dat    Energy -0.07796819
# ../dataset_WaterClusters_big/N76-T150/0750.dat    Energy -0.06636913
# ../dataset_WaterClusters_big/N76-T150/1000.dat    Energy -0.07059366
# ../dataset_WaterClusters_big/N76-T150/1800.dat    Energy -0.09057442
# ../dataset_WaterClusters_big/N76-T150/0200.dat    Energy -0.08941799
# ../dataset_WaterClusters_big/N190-T50/0350.dat    Energy -0.10879492
# ../dataset_WaterClusters_big/N190-T50/1700.dat    Energy -0.10460655
# ../dataset_WaterClusters_big/N190-T50/0100.dat    Energy -0.09992483
# ../dataset_WaterClusters_big/N190-T50/1550.dat    Energy -0.1048511
# ../dataset_WaterClusters_big/N190-T50/1850.dat    Energy -0.10030567
# ../dataset_WaterClusters_big/N190-T50/1100.dat    Energy -0.10176564
# ../dataset_WaterClusters_big/N190-T50/0450.dat    Energy -0.10733864
# ../dataset_WaterClusters_big/N190-T50/0500.dat    Energy -0.10990538
# ../dataset_WaterClusters_big/N190-T50/1350.dat    Energy -0.11354627
# ../dataset_WaterClusters_big/N190-T50/0850.dat    Energy -0.11195806
# ../dataset_WaterClusters_big/N190-T50/1900.dat    Energy -0.09797667
# ../dataset_WaterClusters_big/N190-T50/1650.dat    Energy -0.10917333
# ../dataset_WaterClusters_big/N190-T50/0250.dat    Energy -0.11051498
# ../dataset_WaterClusters_big/N190-T50/0950.dat    Energy -0.11289119
# ../dataset_WaterClusters_big/N190-T50/2000.dat    Energy -0.1089001
# ../dataset_WaterClusters_big/N190-T50/1950.dat    Energy -0.10496781
# ../dataset_WaterClusters_big/N190-T50/1500.dat    Energy -0.10473966
# ../dataset_WaterClusters_big/N190-T50/1250.dat    Energy -0.11297853
# ../dataset_WaterClusters_big/N190-T50/0800.dat    Energy -0.1031603
# ../dataset_WaterClusters_big/N190-T50/0900.dat    Energy -0.10930842
# ../dataset_WaterClusters_big/N190-T50/0700.dat    Energy -0.09916259
# ../dataset_WaterClusters_big/N190-T50/0550.dat    Energy -0.10021061
# ../dataset_WaterClusters_big/N190-T50/1750.dat    Energy -0.10653339
# ../dataset_WaterClusters_big/N190-T50/1300.dat    Energy -0.09962818
# ../dataset_WaterClusters_big/N190-T50/0600.dat    Energy -0.10392061
# ../dataset_WaterClusters_big/N190-T50/0650.dat    Energy -0.1112468
# ../dataset_WaterClusters_big/N190-T50/1600.dat    Energy -0.10596378
# ../dataset_WaterClusters_big/N190-T50/1050.dat    Energy -0.09834534
# ../dataset_WaterClusters_big/N190-T50/0300.dat    Energy -0.10500076
# ../dataset_WaterClusters_big/N190-T50/1400.dat    Energy -0.10228516
# ../dataset_WaterClusters_big/N190-T50/1450.dat    Energy -0.1010683
# ../dataset_WaterClusters_big/N190-T50/1200.dat    Energy -0.10227955
# ../dataset_WaterClusters_big/N190-T50/0150.dat    Energy -0.10085714
# ../dataset_WaterClusters_big/N190-T50/1150.dat    Energy -0.10146108
# ../dataset_WaterClusters_big/N190-T50/0400.dat    Energy -0.10945086
# ../dataset_WaterClusters_big/N190-T50/0050.dat    Energy -0.10718652
# ../dataset_WaterClusters_big/N190-T50/0750.dat    Energy -0.10495698
# ../dataset_WaterClusters_big/N190-T50/1000.dat    Energy -0.10485621
# ../dataset_WaterClusters_big/N190-T50/1800.dat    Energy -0.10715663
# ../dataset_WaterClusters_big/N190-T50/0200.dat    Energy -0.10342863
# ../dataset_WaterClusters_big/N76-T200/0350.dat    Energy -0.09407459
# ../dataset_WaterClusters_big/N76-T200/1700.dat    Energy -0.08177313
# ../dataset_WaterClusters_big/N76-T200/0100.dat    Energy -0.09872622
# ../dataset_WaterClusters_big/N76-T200/1550.dat    Energy -0.10927731
# ../dataset_WaterClusters_big/N76-T200/1850.dat    Energy -0.09405904
# ../dataset_WaterClusters_big/N76-T200/1100.dat    Energy -0.09520426
# ../dataset_WaterClusters_big/N76-T200/0450.dat    Energy -0.10147518
# ../dataset_WaterClusters_big/N76-T200/0500.dat    Energy -0.08771732
# ../dataset_WaterClusters_big/N76-T200/1350.dat    Energy -0.08250409
# ../dataset_WaterClusters_big/N76-T200/0850.dat    Energy -0.11243525
# ../dataset_WaterClusters_big/N76-T200/1900.dat    Energy -0.09412437
# ../dataset_WaterClusters_big/N76-T200/1650.dat    Energy -0.09684618
# ../dataset_WaterClusters_big/N76-T200/0250.dat    Energy -0.09500018
# ../dataset_WaterClusters_big/N76-T200/0950.dat    Energy -0.08395723
# ../dataset_WaterClusters_big/N76-T200/2000.dat    Energy -0.10932095
# ../dataset_WaterClusters_big/N76-T200/1950.dat    Energy -0.08296353
# ../dataset_WaterClusters_big/N76-T200/1500.dat    Energy -0.09930307
# ../dataset_WaterClusters_big/N76-T200/1250.dat    Energy -0.08331138
# ../dataset_WaterClusters_big/N76-T200/0800.dat    Energy -0.10693558
# ../dataset_WaterClusters_big/N76-T200/0900.dat    Energy -0.08633359
# ../dataset_WaterClusters_big/N76-T200/0700.dat    Energy -0.10362758
# ../dataset_WaterClusters_big/N76-T200/0550.dat    Energy -0.09884742
# ../dataset_WaterClusters_big/N76-T200/1750.dat    Energy -0.08726395
# ../dataset_WaterClusters_big/N76-T200/1300.dat    Energy -0.09328465
# ../dataset_WaterClusters_big/N76-T200/0600.dat    Energy -0.10229402
# ../dataset_WaterClusters_big/N76-T200/0650.dat    Energy -0.10079884
# ../dataset_WaterClusters_big/N76-T200/1600.dat    Energy -0.08970034
# ../dataset_WaterClusters_big/N76-T200/1050.dat    Energy -0.09016903
# ../dataset_WaterClusters_big/N76-T200/0300.dat    Energy -0.10053328
# ../dataset_WaterClusters_big/N76-T200/1400.dat    Energy -0.09157938
# ../dataset_WaterClusters_big/N76-T200/1450.dat    Energy -0.08744976
# ../dataset_WaterClusters_big/N76-T200/1200.dat    Energy -0.0947403
# ../dataset_WaterClusters_big/N76-T200/0150.dat    Energy -0.11334985
# ../dataset_WaterClusters_big/N76-T200/1150.dat    Energy -0.09216746
# ../dataset_WaterClusters_big/N76-T200/0400.dat    Energy -0.10506889
# ../dataset_WaterClusters_big/N76-T200/0050.dat    Energy -0.09419894
# ../dataset_WaterClusters_big/N76-T200/0750.dat    Energy -0.10519409
# ../dataset_WaterClusters_big/N76-T200/1000.dat    Energy -0.08986178
# ../dataset_WaterClusters_big/N76-T200/1800.dat    Energy -0.08574932
# ../dataset_WaterClusters_big/N76-T200/0200.dat    Energy -0.10520845

# %%
################################################################################
# Config
################################################################################
learning_rate = 1e-3  # Learning rate
#learning_rate = 1e-4  # Learning rate
#epochs = 200  # Number of training epochs
#epochs = 400  # Number of training epochs
epochs = 150  # Number of training epochs
batch_size = 4  # Batch size

initial_learning_rate = 1e-3
#learning_rate = tf.keras.optimizers.schedules.InverseTimeDecay(initial_learning_rate=initial_learning_rate, decay_steps=epochs/10, decay_rate=0.8)
learning_rate = tf.keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=initial_learning_rate,
#                decay_steps=10, decay_rate=0.98)
                decay_steps=epochs/5, decay_rate=0.99)

"""
learning_rate = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=learning_rate_initial,
    decay_steps=epochs,
    decay_rate=0.98)
"""

# Parameters
F = dataset.num_node_features  # Dimension of node features
S = dataset.num_edge_features  # Dimension of edge features
n_out = dataset.num_labels  # Dimension of the target

# Train/test split
idxs = np.random.permutation(len(dataset))
split = int(0.8 * len(dataset))
idx_tr, idx_te = np.split(idxs, [split])
dataset_tr, dataset_te = dataset[idx_tr], dataset[idx_te]

loader_tr = DisjointLoader(dataset_tr, batch_size=batch_size, epochs=epochs)
#loader_tr = DisjointLoader(dataset_tr, batch_size=batch_size)
loader_te = DisjointLoader(dataset_te, batch_size=batch_size, epochs=1)
#loader_te = DisjointLoader(dataset_te, batch_size=batch_size)
# we set epochs=epochs within loader_te to check loss on test set
#loader_te = DisjointLoader(dataset_te, batch_size=batch_size, epochs=epochs+1)

# %%
################################################################################
# Build model
################################################################################
class Net(Model):
    def __init__(self):
        super().__init__()
        #self.conv1 = ECCConv(32, activation="relu")
        #self.conv2 = ECCConv(32, activation="relu")
        #self.conv1 = GCSConv(32, activation="relu")
        #self.conv2 = GCSConv(32, activation="relu")
        #self.conv1 = GCSConv(64, activation="tanh")
        #self.conv2 = GCSConv(64, activation="tanh")
        #self.conv3 = GCSConv(64, activation="tanh")
        #self.conv1 = CrystalConv(aggregate="sum",activation="sigmoid")
        #self.conv2 = CrystalConv(aggregate="sum",activation="sigmoid")
        self.conv1 = GATConv(8,attn_heads=7,dropout_rate=0,activation="relu")
        self.conv2 = GATConv(8,attn_heads=7,dropout_rate=0,activation="relu")
        #self.conv1 = GATConv(16,attn_heads=8,dropout_rate=0)
        #self.conv2 = GATConv(16,attn_heads=8,dropout_rate=0)
        #self.conv3 = GATConv(16,attn_heads=8,dropout_rate=0)
        self.global_pool = GlobalSumPool()
        self.dense1 = Dense(128,activation="relu")
        self.dense2 = Dense(128,activation="relu")
        #self.dense1 = Dense(128)
        #self.dense2 = Dense(128)
        #self.dense3 = Dense(128)
        #self.dense = Dense(n_out,activation="sigmoid")
        self.dense = Dense(n_out)

    def call(self, inputs):
        #x, a, e, i = inputs
        #x = self.conv1([x, a, e])
        #x = self.conv2([x, a, e])
        x, a, i = inputs
        x = self.conv1([x, a])
        x = self.conv2([x, a])
        #x = self.conv3([x, a])
        #x = self.conv3([x, a])
        output = self.global_pool([x, i])
        output = self.dense1(output)
        output = self.dense2(output)
        #output = self.dense3(output)
        output = self.dense(output)

        return output

model = Net()
optimizer = Adam(learning_rate)
#loss_fn = MeanSquaredError()
loss_fn = MeanAbsoluteError()
#loss_fn = MeanAbsolutePercentageError()
# Out:
# 2023-01-30 13:58:59.442904: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-30 13:58:59.485528: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2023-01-30 13:58:59.485550: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-01-30 13:58:59.486871: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
################################################################################
# Fit model
################################################################################
@tf.function(input_signature=loader_tr.tf_signature(), experimental_relax_shapes=True)
def train_step(inputs, target):
    with tf.GradientTape() as tape:
        predictions = model(inputs, training=True)
        loss = loss_fn(target, predictions) + sum(model.losses)
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    return loss

outfile = open("loss.dat",'w')
nepoch = 1
step = loss = 0
loss_train = []
#loss_test = []
#loss_te = 0
for batch in loader_tr:
    step += 1
    loss += train_step(*batch)
    if step == loader_tr.steps_per_epoch:
        step = 0
        print(str(nepoch)+" Loss: {}".format(loss / loader_tr.steps_per_epoch))
        outfile.write(str(nepoch)+" {}".format(loss / loader_tr.steps_per_epoch)+" \n")
        loss_train.append(loss / loader_tr.steps_per_epoch)

        #if(nepoch==epochs): break
        nepoch = nepoch + 1

        # log the loss into wandb
        #wandb.log({"loss": loss / loader_tr.steps_per_epoch})
        
        loss = 0

        """
        # Loss on test set
        batch_te = next(iter(loader_te))
        inputs, target = batch_te
        predictions = model(inputs, training=False)
        #loss_te += loss_fn(target, predictions)
        loss_te = loss_fn(target, predictions)
        #loss_te /= loader_te.steps_per_epoch
        loss_test.append(loss_te)
        #loss_te = 0
        """

outfile.close()

# Plot Loss Function on Training Set
plt.figure(figsize=(6,4))
plt.scatter(range(1,epochs+1),loss_train)
plt.plot(range(1,epochs+1),loss_train,ls="--")
plt.xlabel("Epochs")
plt.ylabel("Loss (MSE)")
plt.show()

"""
# Plot Loss Function on Test Set
plt.figure(figsize=(6,4))
plt.scatter(range(1,epochs+1),loss_test)
plt.plot(range(1,epochs+1),loss_test,ls="--")
plt.xlabel("Epochs")
plt.ylabel("Loss (MSE)")
plt.show()
"""
# Out:
# /home/alfonso/Work/UGR/Calculations/WaterClusters_GNNs/GNNs_WaterClusters_venv/lib/python3.10/site-packages/spektral/data/utils.py:221: UserWarning: you are shuffling a 'MyDataset' object which is not a subclass of 'Sequence'; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   np.random.shuffle(a)
# /home/alfonso/Work/UGR/Calculations/WaterClusters_GNNs/GNNs_WaterClusters_venv/lib/python3.10/site-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer GlorotUniform is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# 1 Loss: 3.923780679702759
# 2 Loss: 0.5518450736999512
# 3 Loss: 0.22477281093597412
# 4 Loss: 0.12126284092664719
# 5 Loss: 0.05581317096948624
# 6 Loss: 0.04068292677402496
# 7 Loss: 0.024270029738545418
# 8 Loss: 0.018872423097491264
# 9 Loss: 0.01720084808766842
# 10 Loss: 0.01677493192255497
# 11 Loss: 0.01312846876680851
# 12 Loss: 0.012656740844249725
# 13 Loss: 0.012067568488419056
# 14 Loss: 0.010915376245975494
# 15 Loss: 0.009968706406652927
# 16 Loss: 0.008460828103125095
# 17 Loss: 0.00854596309363842
# 18 Loss: 0.008077152073383331
# 19 Loss: 0.008077220059931278
# 20 Loss: 0.007773774676024914
# 21 Loss: 0.007832905277609825
# 22 Loss: 0.007247223053127527
# 23 Loss: 0.007369043305516243
# 24 Loss: 0.007946806028485298
# 25 Loss: 0.007645932026207447
# 26 Loss: 0.007016973569989204
# 27 Loss: 0.007339271251112223
# 28 Loss: 0.0069221858866512775
# 29 Loss: 0.006506294012069702
# 30 Loss: 0.006686211563646793
# 31 Loss: 0.00700783496722579
# 32 Loss: 0.006451369728893042
# 33 Loss: 0.006035462021827698
# 34 Loss: 0.006333282217383385
# 35 Loss: 0.006197300739586353
# 36 Loss: 0.005880990996956825
# 37 Loss: 0.0058647943660616875
# 38 Loss: 0.005714000668376684
# 39 Loss: 0.005833758506923914
# 40 Loss: 0.005693123675882816
# 41 Loss: 0.005594021640717983
# 42 Loss: 0.00580329867079854
# 43 Loss: 0.005582762416452169
# 44 Loss: 0.005173177924007177
# 45 Loss: 0.005308581981807947
# 46 Loss: 0.005137593951076269
# 47 Loss: 0.005193246994167566
# 48 Loss: 0.005148013588041067
# 49 Loss: 0.005117589142173529
# 50 Loss: 0.005030495580285788
# 51 Loss: 0.004896286875009537
# 52 Loss: 0.004881283268332481
# 53 Loss: 0.004916907288134098
# 54 Loss: 0.005029244814068079
# 55 Loss: 0.004811864346265793
# 56 Loss: 0.00468221353366971
# 57 Loss: 0.004717608913779259
# 58 Loss: 0.004673467483371496
# 59 Loss: 0.00465345149859786
# 60 Loss: 0.004614030010998249
# 61 Loss: 0.004540238529443741
# 62 Loss: 0.00459809647873044
# 63 Loss: 0.0045664492063224316
# 64 Loss: 0.00449306471273303
# 65 Loss: 0.0044790576212108135
# 66 Loss: 0.004494198597967625
# 67 Loss: 0.004456421826034784
# 68 Loss: 0.0044346759095788
# 69 Loss: 0.00441444618627429
# 70 Loss: 0.00439539086073637
# 71 Loss: 0.004376314114779234
# 72 Loss: 0.0043429601937532425
# 73 Loss: 0.004342477302998304
# 74 Loss: 0.004328971263021231
# 75 Loss: 0.00432326877489686
# 76 Loss: 0.004302525892853737
# 77 Loss: 0.004327488597482443
# 78 Loss: 0.004292539786547422
# 79 Loss: 0.004291481338441372
# 80 Loss: 0.004307842347770929
# 81 Loss: 0.004281559959053993
# 82 Loss: 0.004273821134120226
# 83 Loss: 0.0042726509273052216
# 84 Loss: 0.0042554051615297794
# 85 Loss: 0.004259245004504919
# 86 Loss: 0.004253322724252939
# 87 Loss: 0.00425433786585927
# 88 Loss: 0.004250695928931236
# 89 Loss: 0.004237797576934099
# 90 Loss: 0.004256101790815592
# 91 Loss: 0.004246678669005632
# 92 Loss: 0.004241335671395063
# 93 Loss: 0.004236777778714895
# 94 Loss: 0.0042356871999800205
# 95 Loss: 0.004230455495417118
# 96 Loss: 0.0042261178605258465
# 97 Loss: 0.004231462255120277
# 98 Loss: 0.004224393982440233
# 99 Loss: 0.00422637676820159
# 100 Loss: 0.004220479167997837
# 101 Loss: 0.004224271979182959
# 102 Loss: 0.004220771603286266
# 103 Loss: 0.004222634714096785
# 104 Loss: 0.004219020251184702
# 105 Loss: 0.004218715708702803
# 106 Loss: 0.004216339439153671
# 107 Loss: 0.004215538501739502
# 108 Loss: 0.004215143620967865
# 109 Loss: 0.004213568288832903
# 110 Loss: 0.004214612301439047
# 111 Loss: 0.0042145103216171265
# 112 Loss: 0.004213128704577684
# 113 Loss: 0.004210130777209997
# 114 Loss: 0.0042135147377848625
# 115 Loss: 0.004211153835058212
# 116 Loss: 0.004211300052702427
# 117 Loss: 0.00421107467263937
# 118 Loss: 0.004210521932691336
# 119 Loss: 0.004210013896226883
# 120 Loss: 0.004209964536130428
# 121 Loss: 0.004209764767438173
# 122 Loss: 0.004209435544908047
# 123 Loss: 0.004208873491734266
# 124 Loss: 0.0042086411267519
# 125 Loss: 0.004209427163004875
# 126 Loss: 0.004208687227219343
# 127 Loss: 0.004208904691040516
# 128 Loss: 0.004208463244140148
# 129 Loss: 0.004208248108625412
# 130 Loss: 0.004208022262901068
# 131 Loss: 0.004207809455692768
# 132 Loss: 0.004208076745271683
# 133 Loss: 0.004207541234791279
# 134 Loss: 0.004207703750580549
# 135 Loss: 0.004207475110888481
# 136 Loss: 0.004207444842904806
# 137 Loss: 0.004207422491163015
# 138 Loss: 0.004207268822938204
# 139 Loss: 0.004207267891615629
# 140 Loss: 0.004207220394164324
# 141 Loss: 0.004207170568406582
# 142 Loss: 0.004207235295325518
# 143 Loss: 0.004207149147987366
# 144 Loss: 0.004207103978842497
# 145 Loss: 0.0042070853523910046
# 146 Loss: 0.004207042045891285
# 147 Loss: 0.004207048565149307
# 148 Loss: 0.004207044839859009
# 149 Loss: 0.00420699967071414
# 150 Loss: 0.004206995479762554
# '\n# Plot Loss Function on Test Set\nplt.figure(figsize=(6,4))\nplt.scatter(range(1,epochs+1),loss_test)\nplt.plot(range(1,epochs+1),loss_test,ls="--")\nplt.xlabel("Epochs")\nplt.ylabel("Loss (MSE)")\nplt.show()\n'

# %%
# Plot Loss Function on Training Set
plt.figure(figsize=(6,4))
plt.scatter(range(1,epochs+1),loss_train)
plt.plot(range(1,epochs+1),loss_train,ls="--")
plt.xlabel("Epochs")
plt.ylabel("Loss (MSE)")
ymedian = np.median(loss_train)
#plt.xlim(0,200)
plt.ylim(0,ymedian*2)
plt.show()

# %%
################################################################################
# Evaluate model
################################################################################

# Loss on Test Set. Predicted vs Real energies
print("Testing model")
loss = 0
ypred = []
ytrue = []
for batch in loader_te:
    inputs, target = batch
    predictions = model(inputs, training=False)
    loss += loss_fn(target, predictions)
    ypred.append(predictions)
    ytrue.append(target)
    #break
loss /= loader_te.steps_per_epoch
print("Done. Test loss: {}".format(loss))
# Out:
# Testing model
# Done. Test loss: 0.005265004467219114

# %%
# Plot Predicted vs Real on Test Set

y_pred = np.array(ypred).ravel()
y_true = np.array(ytrue).ravel()

# Convert to original units
#y_pred = np.array(ypred).ravel()#/100
#y_true = np.array(ytrue).ravel()#/100

#E_avrg = -0.025591339035879856
#E_dev = 2.0321151163332116
#y_pred = np.array(ypred).ravel()*E_dev + E_avrg
#y_true = np.array(ytrue).ravel()*E_dev + E_avrg

plt.figure(figsize=(6,4))
plt.scatter(y_true,y_pred,label = "GNN model",color="red")
p1 = max(max(y_pred), max(y_true))
p2 = min(min(y_pred), min(y_true))
plt.plot([p1, p2], [p1, p2], 'b-',label = "Exact")
#plt.plot(np.linspace(-0.2,0.1,50),np.linspace(-0.2,0.1,50))
plt.xlabel("True",fontsize=15)
plt.ylabel("Predicted",fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#plt.xlim(-5,0)
#plt.ylim(-5,0)
plt.title("Electronic Energy",fontsize=18)
plt.legend(loc="lower right",fontsize=12)
#plt.legend(loc="upper left",fontsize=12)
plt.text(-0.132,-0.025,"(b)",fontsize=20,color='black')
plt.show()

# mean absolute percentage error (MAPE)
def mape(ytrue, ypred):
    ytrue, ypred = np.array(ytrue), np.array(ypred)
    
    mape_i = np.zeros(len(ytrue))
    mape_i = np.abs((ypred-ytrue)/ytrue)*100
    mape_i = mape_i[ mape_i < 1e3]

    return np.mean(mape_i)

# Compute metrics (MAPE, MAE, MSE)
print("Test MAE:", mean_absolute_error(y_true,y_pred))
print("Test MSE:", mean_squared_error(y_true,y_pred))
print("Test MAPE:", mape(y_true,y_pred))
# Out:
# Test MAE: 0.005265004771561102
# Test MSE: 5.043457103315945e-05
# Test MAPE: 7.510203578601875

# %%
################################################################################
# Load data and make graphs to measure time
################################################################################
class MyDataset_time(Dataset):
    """
    A dataset of graphs obtained from the atomic positions of water
    clusters with size between 20 and 237 water molecules, each of them
    associated to an energy value.
    """

    def __init__(self, r2_cutoff, n_dim = 3, n_size=20, **kwargs):

        self.r2_cutoff = r2_cutoff
        self.n_dim = n_dim
        self.n_size = n_size

        # path of the atomic geometry files
        self.geometry_paths = []
        #data_dir = "../dataset_WaterClusters_big/"
        data_dir = "../dataset_WaterClusters_big/"
        #for N in [20,32,47,76,100,139,190,237]:
        N = self.n_size
        for temp in [50,100,150,200]:
            dir_name = data_dir+"N"+str(N)+"-T"+str(temp)
            #for MDstep in ["0500.dat","1000.dat","1500.dat","2000.dat"]:
            for file_name in os.listdir(dir_name):
                #geometry_path = data_dir+"N"+str(N)+"-T"+str(temp)+"/"+str(MDstep)
                geometry_path = os.path.join(dir_name,file_name)
                self.geometry_paths.append(geometry_path)
        #for folder in os.listdir(data_dir): 
        #    dir_name = os.path.join(data_dir,folder)
        #    for file_name in os.listdir(dir_name):
        #        geometry_path = os.path.join(dir_name,file_name)
        #        self.geometry_paths.append(geometry_path)

        self.n_samples = len(self.geometry_paths)

        self.Epm_avrg = 0.0
        self.Epm_dev = 0.0
        self.E_avrg = 0.0
        self.E_dev = 0.0
        self.xmax = 22.0
        self.Emax = 0
        self.Emin = 0

        self.num_node_features = 0
        self.num_edge_features = 0
        self.num_labels = 0
        
        super().__init__(**kwargs)

    def read(self):
            
        def make_graph(isample):

            # Process the header of the geometry file
            geom_path = self.geometry_paths[isample]
            gfile = open(geom_path,'r')
            line = gfile.readline()
            n_molecules = int(gfile.readline())
            line = gfile.readline()
            line = gfile.readline()
            line = gfile.readline()
            columns = line.split()
            #energy = float(columns[0])
            energy = float(columns[1]) # electron contribution
            line = gfile.readline()
            line = gfile.readline()            

            # Node features (atom type and position [x,y,z])            
            n_nodes = 3*n_molecules
            #num_node_features = 1 + self.n_dim
            num_physical_features = 4
            #num_abstract_features = 6
            num_abstract_features = 0
            num_node_features = num_physical_features + num_abstract_features
            self.num_node_features = num_node_features
            x = np.zeros((n_nodes, num_node_features))
            pos = np.zeros((n_nodes, 3))
            for inode in range(n_nodes):
                line = gfile.readline()
                columns = line.split()
                if (inode%3==0):
                    #x[inode,0] = 1.0    # oxygen atom
                    #x[inode,0] = O.atomic_number/O.atomic_number    # oxygen atom
                    x[inode,0] = O.atomic_number
                    #x[inode,1] = O.atomic_radius
                    #x[inode,2] = O.covalent_radius
                    #x[inode,3] = O.vdw_radius
                    #x[inode,4] = O.dipole_polarizability
                    #x[inode,5] = O.electron_affinity
                    #x[inode,6] = O.en_pauling
                    #for l in range(3):
                    #    w = O.atomic_number/O.atomic_number*np.pi/float(l+1)
                    #    x[inode,1+l] = np.sin(w)
                    
                else:
                    #x[inode,0] = 0.0    # hydrogen atom
                    #x[inode,0] = H.atomic_number/O.atomic_number    # hydrogen atom
                    x[inode,0] = H.atomic_number
                    #x[inode,1] = H.atomic_radius
                    #x[inode,2] = H.covalent_radius
                    #x[inode,3] = H.vdw_radius
                    #x[inode,4] = H.dipole_polarizability
                    #x[inode,5] = H.electron_affinity
                    #x[inode,6] = H.en_pauling
                    #for l in range(3):
                    #    w = H.atomic_number/O.atomic_number*np.pi/float(l+1)
                    #    x[inode,1+l] = np.sin(w)
                pos[inode,0:] = columns[1:]
                x[inode,1:] = pos[inode,0:]
                #x[inode,1:] = pos[inode,0:]/float(self.xmax)
                #x[inode,7:] = pos[inode,0:]/float(self.xmax)
                #x[inode,1:] = np.random.random(num_abstract_features)
            gfile.close()                

            # Binary Adjacency matrix (two nodes/atoms are connected if rij2 < r2_cutoff)
            a = np.zeros((n_nodes,n_nodes))
            n_edges = 0
            for iatom in range(3*n_molecules):
                for jatom in range(iatom+1,3*n_molecules):
                    rij = pos[iatom,0:] - pos[jatom,0:]
                    r2 = np.dot(rij,rij)
                    if (r2 <= self.r2_cutoff):
                        #print(iatom,jatom,r2)                        
                        #a[iatom,jatom] = np.sqrt(r2)
                        a[iatom,jatom] = 1
                        n_edges = n_edges + 1            
            a = np.maximum(a, a.T)#.astype(int) # Adjacency matrix is symetric in this case
            a = sp.csr_matrix(a)
            #a = normalized_adjacency(a, symmetric=True)

            """ # Edge features (type of bonding: O-O, H-O, H-H)
            n_edges = n_edges*2
            num_abstract_features = 0
            num_edge_features = 1 + num_abstract_features
            self.num_edge_features = num_edge_features
            e = np.zeros((n_edges,num_edge_features))
            id_edge = 0
            for iatom in range(3*n_molecules):
                for jatom in range(3*n_molecules):
                    if(iatom!=jatom):
                        rij = pos[iatom,0:] - pos[jatom,0:]
                        r2 = np.dot(rij,rij)
                        if (r2 <= self.r2_cutoff):
                            #print(iatom,jatom,r2)                        
                            e[id_edge,0] = np.sqrt(r2)
                            #e[id_edge,1:] = np.random.random(num_abstract_features)
                            id_edge = id_edge + 1 """
            
            # Labels
            num_labels = 1
            self.num_labels = num_labels
            y = np.zeros(num_labels,)
            y[0,] = energy
            #y[0,] = ( energy / float(n_molecules) - self.Epm_avrg ) / self.Epm_avrg
            #y[0,] = ( energy / float(n_molecules) - self.Epm_avrg ) / self.Epm_dev
            #y[0,] = ( energy - self.E_avrg ) / self.E_dev
            #y[0,] = energy - self.E_avrg
            #y[0,] = ( energy - self.E_avrg ) / self.E_dev * 100
            #y[0,] = energy * 100
            
            # Put energies into [0,1]
            #ca = 1.0/(self.Emax-self.Emin)
            #cb = 1.0 - ca * self.Emax
            #y[0,] = ca*energy + cb

            # Put energies into [-1,1]
            #ca = 2.0/(self.Emax-self.Emin)
            #cb = 1.0 - ca * self.Emax
            #y[0,] = ca*energy + cb

            #print(str(geom_path)+"    Energy "+str(y[0,]))
            
            return Graph(x=x, a=a, y=y)
            #return Graph(x=x, a=a, e=e, y=y)

        # Compute average of the energy per molecule

        # We must return a list of Graph objects
        return [make_graph(isample) for isample in range(self.n_samples)]

# %%
################################################################################
# Measure evaluation time for an specific cluster size
################################################################################
import time 

#cluster_size = 20 

time_evaluation = 0.0
time_electron = []
for N in [20,32,47,76,100,139,190,237]:

    # Generate dataset from atomic geometry files
    #d2_cutoff = 20.0
    d_cutoff = 6.0
    d2_cutoff = d_cutoff * d_cutoff
    #dataset_time = MyDataset_time( d2_cutoff, int(N) )
    dataset_time = MyDataset_time( r2_cutoff=d2_cutoff,n_size=int(N) )

    n_clusters = len(dataset_time)
    loader_time = DisjointLoader(dataset_time, batch_size=n_clusters, epochs=1) 

    time_evaluation = 0
    for batch in loader_time :
        inputs, target = batch
        t_init = time.time()
        predictions = model(inputs, training=False)
        t_end = time.time()
        time_evaluation+= (t_end-t_init)

    time_evaluation = time_evaluation/n_clusters
    time_electron.append(time_evaluation)
    print("cluster_size: "+str(N)+", n_clusters: "+str(n_clusters)+", time_evaluation: "+str(time_evaluation))
# Out:
# cluster_size: 20, n_clusters: 160, time_evaluation: 0.0003378003835678101
# cluster_size: 32, n_clusters: 160, time_evaluation: 0.0005262777209281922
# cluster_size: 47, n_clusters: 160, time_evaluation: 0.0007659897208213806
# cluster_size: 76, n_clusters: 160, time_evaluation: 0.0012963429093360902
# cluster_size: 100, n_clusters: 160, time_evaluation: 0.0017568498849868774
# cluster_size: 139, n_clusters: 160, time_evaluation: 0.002617451548576355
# cluster_size: 190, n_clusters: 160, time_evaluation: 0.003850002586841583
# cluster_size: 237, n_clusters: 160, time_evaluation: 0.005050760507583618

# %%
#############################
# Plot Time vs N
#############################

time_Schrodinger = [1.52, 1.78, 1.83, 2.64, 3.29, 4.11, 8.67, 12.39]
#time_electron = [0.0003378003835678101, 0.0005262777209281922, 0.0007659897208213806, 0.0012963429093360902, 0.0017568498849868774, 0.002617451548576355, 0.003850002586841583, 0.005050760507583618]
N = [20, 32, 47, 76, 100, 139, 190, 237]

time_Schrodinger = np.array(time_Schrodinger)
time_electron = np.array(time_electron)
N = np.array(N)

# quadratical fit for the numerical method
x_data = np.linspace(0,250,100)
model = np.poly1d(np.polyfit(N,time_Schrodinger,2))
y_fit = model(x_data)

plt.figure(figsize=(6,4))
plt.scatter(N, time_Schrodinger, color='green',label = "Data",s=75.0)
#plt.plot(N, time_Schrodinger, 'b--')
plt.plot(x_data, model(x_data), 'k--', label="Quadratic fit",)
plt.xlabel("Cluster Size (# of water molecules)",fontsize=15)
plt.ylabel("Time (s)",fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(loc="lower right",fontsize=12)
plt.title("Numerical Method",fontsize=18)
plt.text(10,12,"(a)",fontsize=20,color='black')
plt.xlim([0,250])
plt.show()

# linear fit for the numerical method
x_data = np.linspace(0,250,100)
model = np.poly1d(np.polyfit(N,time_electron,1))
y_fit = model(x_data)

plt.figure(figsize=(6,4))
plt.scatter(N, time_electron*1000, color='green',label='Data',s=75.0)
#plt.plot(N, time_electron*1000, 'k--',label="Linear fit")
plt.plot(x_data, model(x_data)*1000, 'k--',label="Linear fit")
plt.xlabel("Cluster Size (# of water molecules)",fontsize=15)
plt.ylabel("Time (ms)",fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(loc="lower right",fontsize=12)
plt.title("GNN",fontsize=18)
plt.xlim([0,250])
plt.text(10,4.5,"(b)",fontsize=20,color='black')
plt.show()
