# %%
"""
This example shows how to perform regression of molecular properties with a
database of the atomic geometry of water clusters with an associated energy, 
using a simple GNN in disjoint mode.
"""

import numpy as np
import scipy.sparse as sp
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.losses import MeanAbsoluteError
from tensorflow.keras.losses import MeanAbsolutePercentageError
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Install matplotlib inside the virtual env
#import pip
#pip.main(["install","matplotlib"])
import matplotlib.pyplot as plt

from spektral.data import Dataset, DisjointLoader, Graph
from spektral.datasets import QM9
from spektral.layers import GCSConv, ECCConv, GlobalSumPool, MessagePassing, GATConv, CrystalConv

#from spektral.utils import normalized_adjacency

# %%
################################################################################
# Config
################################################################################
learning_rate = 1e-3  # Learning rate
#learning_rate = 1e-4  # Learning rate
epochs = 200  # Number of training epochs
batch_size = 1  # Batch size

initial_learning_rate = 1e-3
#learning_rate = tf.keras.optimizers.schedules.InverseTimeDecay(initial_learning_rate=initial_learning_rate, decay_steps=epochs/10, decay_rate=0.8)
learning_rate = tf.keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=initial_learning_rate,
                decay_steps=epochs/10, decay_rate=0.8)

"""
learning_rate = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=learning_rate_initial,
    decay_steps=epochs,
    decay_rate=0.98)
"""
# Out:
# '\nlearning_rate = tf.keras.optimizers.schedules.ExponentialDecay(\n    initial_learning_rate=learning_rate_initial,\n    decay_steps=epochs,\n    decay_rate=0.98)\n'

# %%
################################################################################
# Load data and make graphs
################################################################################
class MyDataset(Dataset):
    """
    A dataset of graphs obtained from the atomic positions of water
    clusters with size between 20 and 237 water molecules, each of them
    associated to an energy value.
    """

    def __init__(self, r2_cutoff, n_dim = 3, **kwargs):

        self.r2_cutoff = r2_cutoff
        self.n_dim = n_dim

        # path of the atomic geometry files
        self.geometry_paths = []
        data_dir = "../dataset_WaterClusters_big/"
        #data_dir = "../dataset_WaterClusters/"
        #for N in [20,32,47,76,100,139,190,237]:
            #for temp in [100,150,200]:
                #for MDstep in ["0500.dat","1000.dat","1500.dat","2000.dat"]:
                    #geometry_path = data_dir+"N"+str(N)+"-T"+str(temp)+"/"+str(MDstep)
                    #self.geometry_paths.append(geometry_path)
        for folder in os.listdir(data_dir): 
            dir_name = os.path.join(data_dir,folder)
            for file_name in os.listdir(dir_name):
                geometry_path = os.path.join(dir_name,file_name)
                self.geometry_paths.append(geometry_path)

        self.n_samples = len(self.geometry_paths)

        self.Epm_avrg = 0.0
        self.Epm_dev = 0.0
        self.E_avrg = 0.0
        self.E_dev = 0.0
        self.xmax = 22.0

        self.num_node_features = 0
        self.num_edge_features = 0
        self.num_labels = 0
        
        super().__init__(**kwargs)

    def read(self):

        def compute_Eavrg():

            # Compute the average energy per molecule among all the clusters

            Epm_avrg = 0.0
            E_avrg = 0.0
            
            for ii in range(self.n_samples):
            
                geom_path = self.geometry_paths[ii]
                gfile = open(geom_path,'r')
                line = gfile.readline()
                n_molecules = int(gfile.readline())
                line = gfile.readline()
                line = gfile.readline()
                line = gfile.readline()
                columns = line.split()
                energy = float(columns[1])
                gfile.close()

                Epm_avrg = Epm_avrg + energy / float(n_molecules)
                E_avrg = E_avrg + energy

            Epm_avrg = Epm_avrg / float(self.n_samples)
            E_avrg = E_avrg / float(self.n_samples)

            self.Epm_avrg = Epm_avrg
            self.E_avrg = E_avrg

            print("E_avrg: "+str(E_avrg))

        def compute_Edev():

            # Compute standard deviation from Epm_avrg

            Epm_dev = 0.0
            E_dev = 0.0

            for ii in range(self.n_samples):
            
                geom_path = self.geometry_paths[ii]
                gfile = open(geom_path,'r')
                line = gfile.readline()
                n_molecules = int(gfile.readline())
                line = gfile.readline()
                line = gfile.readline()
                line = gfile.readline()
                columns = line.split()
                energy = float(columns[1])
                gfile.close()

                Epm_dev = Epm_dev + ( energy / float(n_molecules) - self.Epm_avrg )**2
                E_dev = E_dev + ( energy - self.E_avrg )**2

            Epm_dev = np.sqrt( Epm_dev / float(self.n_samples) )
            E_dev = np.sqrt( E_dev / float(self.n_samples) )

            self.Epm_dev = Epm_dev
            self.E_dev = E_dev

            print("E_dev: "+str(E_dev))
            
        def make_graph(isample):

            # Process the header of the geometry file
            geom_path = self.geometry_paths[isample]
            gfile = open(geom_path,'r')
            line = gfile.readline()
            n_molecules = int(gfile.readline())
            line = gfile.readline()
            line = gfile.readline()
            line = gfile.readline()
            columns = line.split()
            energy = float(columns[1])
            line = gfile.readline()
            line = gfile.readline()            

            # Node features (atom type and position [x,y,z])            
            n_nodes = 3*n_molecules
            #num_node_features = 1 + self.n_dim
            num_node_features = 1
            self.num_node_features = num_node_features
            x = np.zeros((n_nodes, num_node_features))
            pos = np.zeros((n_nodes, 3))
            for inode in range(n_nodes):
                line = gfile.readline()
                columns = line.split()
                if (inode%3==0):
                    x[inode,0] = 1.0    # oxygen atom
                else:
                    x[inode,0] = 0.0    # hydrogen atom
                pos[inode,0:] = columns[1:]
                #x[inode,1:] = pos[inode,0:]
                #x[inode,1:] = x[inode,1:] / float(self.xmax)
            gfile.close()                

            # Binary Adjacency matrix (two nodes/atoms are connected if rij2 < r2_cutoff)
            a = np.zeros((n_nodes,n_nodes))
            n_edges = 0
            for iatom in range(3*n_molecules):
                for jatom in range(iatom+1,3*n_molecules):
                    rij = pos[iatom,0:] - pos[jatom,0:]
                    r2 = np.dot(rij,rij)
                    if (r2 <= self.r2_cutoff):
                        #print(iatom,jatom,r2)                        
                        #a[iatom,jatom] = np.sqrt(r2)
                        a[iatom,jatom] = 1
                        n_edges = n_edges + 1            
            a = np.maximum(a, a.T)#.astype(int) # Adjacency matrix is symetric in this case
            a = sp.csr_matrix(a)
            #a = normalized_adjacency(a, symmetric=True)

            # Edge features (type of bonding: O-O, H-O, H-H)
            n_edges = n_edges*2
            num_edge_features = 1
            self.num_edge_features = num_edge_features
            e = np.zeros((n_edges,num_edge_features))
            id_edge = 0
            for iatom in range(3*n_molecules):
                for jatom in range(3*n_molecules):
                    if(iatom!=jatom):
                        rij = pos[iatom,0:] - pos[jatom,0:]
                        r2 = np.dot(rij,rij)
                        if (r2 <= self.r2_cutoff):
                            #print(iatom,jatom,r2)                        
                            e[id_edge,0] = np.sqrt(r2)
                            id_edge = id_edge + 1
            
            # Labels
            num_labels = 1
            self.num_labels = num_labels
            y = np.zeros(num_labels,)
            #y[0,] = energy
            #y[0,] = ( energy / float(n_molecules) - self.Epm_avrg ) / self.Epm_avrg
            #y[0,] = ( energy / float(n_molecules) - self.Epm_avrg ) / self.Epm_dev
            #y[0,] = ( energy - self.E_avrg ) / self.E_dev
            #y[0,] = energy - self.E_avrg
            #y[0,] = ( energy - self.E_avrg ) / self.E_dev * 100
            y[0,] = energy * 100

            print(str(geom_path)+"    Energy "+str(y[0,]))
            
            return Graph(x=x, a=a, e=e, y=y)

        # Compute average of the energy per molecule
        compute_Eavrg()
        compute_Edev()
        # We must return a list of Graph objects
        return [make_graph(isample) for isample in range(self.n_samples)]        

# Generate dataset from atomic geometry files
#d2_cutoff = 20.0
d2_cutoff = 10.0            
dataset = MyDataset( d2_cutoff )

# Parameters
F = dataset.num_node_features  # Dimension of node features
S = dataset.num_edge_features  # Dimension of edge features
n_out = dataset.num_labels  # Dimension of the target

# Train/test split
idxs = np.random.permutation(len(dataset))
split = int(0.8 * len(dataset))
idx_tr, idx_te = np.split(idxs, [split])
dataset_tr, dataset_te = dataset[idx_tr], dataset[idx_te]

loader_tr = DisjointLoader(dataset_tr, batch_size=batch_size, epochs=epochs)
loader_te = DisjointLoader(dataset_te, batch_size=batch_size, epochs=1)
# we set epochs=epochs within loader_te to check loss on test set
#loader_te = DisjointLoader(dataset_te, batch_size=batch_size, epochs=epochs+1)
# Out:
# E_avrg: -0.082706061609375
# E_dev: 0.032428410162306805
# ../dataset_WaterClusters_big/N20-T150/0350.dat    Energy -3.364731
# ../dataset_WaterClusters_big/N20-T150/1700.dat    Energy -2.216927
# ../dataset_WaterClusters_big/N20-T150/0100.dat    Energy -2.3383399999999996
# ../dataset_WaterClusters_big/N20-T150/1550.dat    Energy -2.285929
# ../dataset_WaterClusters_big/N20-T150/1850.dat    Energy -1.897021
# ../dataset_WaterClusters_big/N20-T150/1100.dat    Energy -3.038906
# ../dataset_WaterClusters_big/N20-T150/0450.dat    Energy -2.811601
# ../dataset_WaterClusters_big/N20-T150/0500.dat    Energy -2.823979
# ../dataset_WaterClusters_big/N20-T150/1350.dat    Energy -2.914551
# ../dataset_WaterClusters_big/N20-T150/0850.dat    Energy -2.615065
# ../dataset_WaterClusters_big/N20-T150/1900.dat    Energy -2.339293
# ../dataset_WaterClusters_big/N20-T150/1650.dat    Energy -2.087158
# ../dataset_WaterClusters_big/N20-T150/0250.dat    Energy -2.243953
# ../dataset_WaterClusters_big/N20-T150/0950.dat    Energy -2.657709
# ../dataset_WaterClusters_big/N20-T150/2000.dat    Energy -2.185721
# ../dataset_WaterClusters_big/N20-T150/1950.dat    Energy -2.639351
# ../dataset_WaterClusters_big/N20-T150/1500.dat    Energy -2.316882
# ../dataset_WaterClusters_big/N20-T150/1250.dat    Energy -2.5453989999999997
# ../dataset_WaterClusters_big/N20-T150/0800.dat    Energy -2.825689
# ../dataset_WaterClusters_big/N20-T150/0900.dat    Energy -2.696438
# ../dataset_WaterClusters_big/N20-T150/0700.dat    Energy -2.46226
# ../dataset_WaterClusters_big/N20-T150/0550.dat    Energy -2.406381
# ../dataset_WaterClusters_big/N20-T150/1750.dat    Energy -2.28342
# ../dataset_WaterClusters_big/N20-T150/1300.dat    Energy -2.637207
# ../dataset_WaterClusters_big/N20-T150/0600.dat    Energy -2.7485470000000003
# ../dataset_WaterClusters_big/N20-T150/0650.dat    Energy -2.515037
# ../dataset_WaterClusters_big/N20-T150/1600.dat    Energy -2.113594
# ../dataset_WaterClusters_big/N20-T150/1050.dat    Energy -2.744172
# ../dataset_WaterClusters_big/N20-T150/0300.dat    Energy -2.468853
# ../dataset_WaterClusters_big/N20-T150/1400.dat    Energy -2.1828980000000002
# ../dataset_WaterClusters_big/N20-T150/1450.dat    Energy -2.834452
# ../dataset_WaterClusters_big/N20-T150/1200.dat    Energy -2.601531
# ../dataset_WaterClusters_big/N20-T150/0150.dat    Energy -2.210552
# ../dataset_WaterClusters_big/N20-T150/1150.dat    Energy -2.5518780000000003
# ../dataset_WaterClusters_big/N20-T150/0400.dat    Energy -2.3215779999999997
# ../dataset_WaterClusters_big/N20-T150/0050.dat    Energy -2.943123
# ../dataset_WaterClusters_big/N20-T150/0750.dat    Energy -2.486593
# ../dataset_WaterClusters_big/N20-T150/1000.dat    Energy -2.6002270000000003
# ../dataset_WaterClusters_big/N20-T150/1800.dat    Energy -2.393092
# ../dataset_WaterClusters_big/N20-T150/0200.dat    Energy -2.701467
# ../dataset_WaterClusters_big/N32-T150/0350.dat    Energy -6.165227
# ../dataset_WaterClusters_big/N32-T150/1700.dat    Energy -6.797572000000001
# ../dataset_WaterClusters_big/N32-T150/0100.dat    Energy -5.785682
# ../dataset_WaterClusters_big/N32-T150/1550.dat    Energy -4.925045
# ../dataset_WaterClusters_big/N32-T150/1850.dat    Energy -6.083231
# ../dataset_WaterClusters_big/N32-T150/1100.dat    Energy -5.039625
# ../dataset_WaterClusters_big/N32-T150/0450.dat    Energy -5.839666
# ../dataset_WaterClusters_big/N32-T150/0500.dat    Energy -5.795854
# ../dataset_WaterClusters_big/N32-T150/1350.dat    Energy -6.315332
# ../dataset_WaterClusters_big/N32-T150/0850.dat    Energy -6.288092000000001
# ../dataset_WaterClusters_big/N32-T150/1900.dat    Energy -5.635353
# ../dataset_WaterClusters_big/N32-T150/1650.dat    Energy -6.584703
# ../dataset_WaterClusters_big/N32-T150/0250.dat    Energy -5.799836
# ../dataset_WaterClusters_big/N32-T150/0950.dat    Energy -6.120065
# ../dataset_WaterClusters_big/N32-T150/2000.dat    Energy -5.883658
# ../dataset_WaterClusters_big/N32-T150/1950.dat    Energy -5.323079
# ../dataset_WaterClusters_big/N32-T150/1500.dat    Energy -4.8862179999999995
# ../dataset_WaterClusters_big/N32-T150/1250.dat    Energy -4.301954
# ../dataset_WaterClusters_big/N32-T150/0800.dat    Energy -6.405239999999999
# ../dataset_WaterClusters_big/N32-T150/0900.dat    Energy -5.848935
# ../dataset_WaterClusters_big/N32-T150/0700.dat    Energy -5.195021
# ../dataset_WaterClusters_big/N32-T150/0550.dat    Energy -5.487263
# ../dataset_WaterClusters_big/N32-T150/1750.dat    Energy -5.556696
# ../dataset_WaterClusters_big/N32-T150/1300.dat    Energy -6.281909
# ../dataset_WaterClusters_big/N32-T150/0600.dat    Energy -6.540097
# ../dataset_WaterClusters_big/N32-T150/0650.dat    Energy -6.138647
# ../dataset_WaterClusters_big/N32-T150/1600.dat    Energy -6.076307
# ../dataset_WaterClusters_big/N32-T150/1050.dat    Energy -5.25779
# ../dataset_WaterClusters_big/N32-T150/0300.dat    Energy -6.299352
# ../dataset_WaterClusters_big/N32-T150/1400.dat    Energy -4.941815
# ../dataset_WaterClusters_big/N32-T150/1450.dat    Energy -5.684809
# ../dataset_WaterClusters_big/N32-T150/1200.dat    Energy -5.051118000000001
# ../dataset_WaterClusters_big/N32-T150/0150.dat    Energy -6.0468340000000005
# ../dataset_WaterClusters_big/N32-T150/1150.dat    Energy -5.357056
# ../dataset_WaterClusters_big/N32-T150/0400.dat    Energy -5.675243
# ../dataset_WaterClusters_big/N32-T150/0050.dat    Energy -7.9834950000000005
# ../dataset_WaterClusters_big/N32-T150/0750.dat    Energy -5.711831
# ../dataset_WaterClusters_big/N32-T150/1000.dat    Energy -6.778597
# ../dataset_WaterClusters_big/N32-T150/1800.dat    Energy -5.8892619999999996
# ../dataset_WaterClusters_big/N32-T150/0200.dat    Energy -5.7208950000000005
# ../dataset_WaterClusters_big/N100-T150/0350.dat    Energy -11.244472
# ../dataset_WaterClusters_big/N100-T150/1700.dat    Energy -9.103621
# ../dataset_WaterClusters_big/N100-T150/0100.dat    Energy -9.318868
# ../dataset_WaterClusters_big/N100-T150/1550.dat    Energy -9.712765
# ../dataset_WaterClusters_big/N100-T150/1850.dat    Energy -8.794468
# ../dataset_WaterClusters_big/N100-T150/1100.dat    Energy -9.644454
# ../dataset_WaterClusters_big/N100-T150/0450.dat    Energy -9.96818
# ../dataset_WaterClusters_big/N100-T150/0500.dat    Energy -9.323595
# ../dataset_WaterClusters_big/N100-T150/1350.dat    Energy -9.288623
# ../dataset_WaterClusters_big/N100-T150/0850.dat    Energy -9.663996
# ../dataset_WaterClusters_big/N100-T150/1900.dat    Energy -10.768858
# ../dataset_WaterClusters_big/N100-T150/1650.dat    Energy -9.588466
# ../dataset_WaterClusters_big/N100-T150/0250.dat    Energy -9.52804
# ../dataset_WaterClusters_big/N100-T150/0950.dat    Energy -10.305491
# ../dataset_WaterClusters_big/N100-T150/2000.dat    Energy -9.470207
# ../dataset_WaterClusters_big/N100-T150/1950.dat    Energy -10.022016
# ../dataset_WaterClusters_big/N100-T150/1500.dat    Energy -9.80665
# ../dataset_WaterClusters_big/N100-T150/1250.dat    Energy -11.241436
# ../dataset_WaterClusters_big/N100-T150/0800.dat    Energy -9.359367
# ../dataset_WaterClusters_big/N100-T150/0900.dat    Energy -9.486395
# ../dataset_WaterClusters_big/N100-T150/0700.dat    Energy -10.610327999999999
# ../dataset_WaterClusters_big/N100-T150/0550.dat    Energy -9.467498
# ../dataset_WaterClusters_big/N100-T150/1750.dat    Energy -11.250788
# ../dataset_WaterClusters_big/N100-T150/1300.dat    Energy -10.169668
# ../dataset_WaterClusters_big/N100-T150/0600.dat    Energy -10.057352
# ../dataset_WaterClusters_big/N100-T150/0650.dat    Energy -9.411276
# ../dataset_WaterClusters_big/N100-T150/1600.dat    Energy -9.674707
# ../dataset_WaterClusters_big/N100-T150/1050.dat    Energy -10.282477
# ../dataset_WaterClusters_big/N100-T150/0300.dat    Energy -9.946950000000001
# ../dataset_WaterClusters_big/N100-T150/1400.dat    Energy -9.547704
# ../dataset_WaterClusters_big/N100-T150/1450.dat    Energy -8.997866
# ../dataset_WaterClusters_big/N100-T150/1200.dat    Energy -9.501895000000001
# ../dataset_WaterClusters_big/N100-T150/0150.dat    Energy -10.808709
# ../dataset_WaterClusters_big/N100-T150/1150.dat    Energy -10.022579
# ../dataset_WaterClusters_big/N100-T150/0400.dat    Energy -11.210253
# ../dataset_WaterClusters_big/N100-T150/0050.dat    Energy -9.789992
# ../dataset_WaterClusters_big/N100-T150/0750.dat    Energy -9.646298999999999
# ../dataset_WaterClusters_big/N100-T150/1000.dat    Energy -10.403145
# ../dataset_WaterClusters_big/N100-T150/1800.dat    Energy -9.543811
# ../dataset_WaterClusters_big/N100-T150/0200.dat    Energy -9.543179
# ../dataset_WaterClusters_big/N139-T50/0350.dat    Energy -8.770153
# ../dataset_WaterClusters_big/N139-T50/1700.dat    Energy -8.096587
# ../dataset_WaterClusters_big/N139-T50/0100.dat    Energy -7.560542000000001
# ../dataset_WaterClusters_big/N139-T50/1550.dat    Energy -8.097698000000001
# ../dataset_WaterClusters_big/N139-T50/1850.dat    Energy -8.253051
# ../dataset_WaterClusters_big/N139-T50/1100.dat    Energy -8.020637
# ../dataset_WaterClusters_big/N139-T50/0450.dat    Energy -8.111665
# ../dataset_WaterClusters_big/N139-T50/0500.dat    Energy -8.134212999999999
# ../dataset_WaterClusters_big/N139-T50/1350.dat    Energy -8.581401
# ../dataset_WaterClusters_big/N139-T50/0850.dat    Energy -7.308718
# ../dataset_WaterClusters_big/N139-T50/1900.dat    Energy -8.083964
# ../dataset_WaterClusters_big/N139-T50/1650.dat    Energy -8.188038
# ../dataset_WaterClusters_big/N139-T50/0250.dat    Energy -8.423048
# ../dataset_WaterClusters_big/N139-T50/0950.dat    Energy -8.140019
# ../dataset_WaterClusters_big/N139-T50/2000.dat    Energy -8.469334
# ../dataset_WaterClusters_big/N139-T50/1950.dat    Energy -8.253446
# ../dataset_WaterClusters_big/N139-T50/1500.dat    Energy -8.453706
# ../dataset_WaterClusters_big/N139-T50/1250.dat    Energy -7.764284000000001
# ../dataset_WaterClusters_big/N139-T50/0800.dat    Energy -8.173866
# ../dataset_WaterClusters_big/N139-T50/0900.dat    Energy -8.529295000000001
# ../dataset_WaterClusters_big/N139-T50/0700.dat    Energy -7.298645
# ../dataset_WaterClusters_big/N139-T50/0550.dat    Energy -7.746422
# ../dataset_WaterClusters_big/N139-T50/1750.dat    Energy -8.192186999999999
# ../dataset_WaterClusters_big/N139-T50/1300.dat    Energy -7.445538
# ../dataset_WaterClusters_big/N139-T50/0600.dat    Energy -8.311437000000002
# ../dataset_WaterClusters_big/N139-T50/0650.dat    Energy -7.918296
# ../dataset_WaterClusters_big/N139-T50/1600.dat    Energy -8.494792
# ../dataset_WaterClusters_big/N139-T50/1050.dat    Energy -8.105762
# ../dataset_WaterClusters_big/N139-T50/0300.dat    Energy -7.679068
# ../dataset_WaterClusters_big/N139-T50/1400.dat    Energy -8.083629
# ../dataset_WaterClusters_big/N139-T50/1450.dat    Energy -7.817749999999999
# ../dataset_WaterClusters_big/N139-T50/1200.dat    Energy -7.878064
# ../dataset_WaterClusters_big/N139-T50/0150.dat    Energy -7.783518000000001
# ../dataset_WaterClusters_big/N139-T50/1150.dat    Energy -7.807658000000001
# ../dataset_WaterClusters_big/N139-T50/0400.dat    Energy -9.079424
# ../dataset_WaterClusters_big/N139-T50/0050.dat    Energy -7.943388
# ../dataset_WaterClusters_big/N139-T50/0750.dat    Energy -7.51907
# ../dataset_WaterClusters_big/N139-T50/1000.dat    Energy -7.253687
# ../dataset_WaterClusters_big/N139-T50/1800.dat    Energy -8.510602
# ../dataset_WaterClusters_big/N139-T50/0200.dat    Energy -7.843743
# ../dataset_WaterClusters_big/N237-T200/0350.dat    Energy -12.496193
# ../dataset_WaterClusters_big/N237-T200/1700.dat    Energy -12.210023
# ../dataset_WaterClusters_big/N237-T200/0100.dat    Energy -10.795248
# ../dataset_WaterClusters_big/N237-T200/1550.dat    Energy -11.869104
# ../dataset_WaterClusters_big/N237-T200/1850.dat    Energy -10.943102
# ../dataset_WaterClusters_big/N237-T200/1100.dat    Energy -11.720103
# ../dataset_WaterClusters_big/N237-T200/0450.dat    Energy -10.332863
# ../dataset_WaterClusters_big/N237-T200/0500.dat    Energy -11.031111000000001
# ../dataset_WaterClusters_big/N237-T200/1350.dat    Energy -11.41109
# ../dataset_WaterClusters_big/N237-T200/0850.dat    Energy -12.823917000000002
# ../dataset_WaterClusters_big/N237-T200/1900.dat    Energy -11.585901
# ../dataset_WaterClusters_big/N237-T200/1650.dat    Energy -10.625674
# ../dataset_WaterClusters_big/N237-T200/0250.dat    Energy -12.777542
# ../dataset_WaterClusters_big/N237-T200/0950.dat    Energy -12.818316
# ../dataset_WaterClusters_big/N237-T200/2000.dat    Energy -13.022169
# ../dataset_WaterClusters_big/N237-T200/1950.dat    Energy -12.465461
# ../dataset_WaterClusters_big/N237-T200/1500.dat    Energy -11.543333
# ../dataset_WaterClusters_big/N237-T200/1250.dat    Energy -10.622473000000001
# ../dataset_WaterClusters_big/N237-T200/0800.dat    Energy -11.933081
# ../dataset_WaterClusters_big/N237-T200/0900.dat    Energy -12.956705
# ../dataset_WaterClusters_big/N237-T200/0700.dat    Energy -11.884527
# ../dataset_WaterClusters_big/N237-T200/0550.dat    Energy -11.023838
# ../dataset_WaterClusters_big/N237-T200/1750.dat    Energy -11.956002999999999
# ../dataset_WaterClusters_big/N237-T200/1300.dat    Energy -10.675915
# ../dataset_WaterClusters_big/N237-T200/0600.dat    Energy -11.590195
# ../dataset_WaterClusters_big/N237-T200/0650.dat    Energy -12.556786
# ../dataset_WaterClusters_big/N237-T200/1600.dat    Energy -11.543806
# ../dataset_WaterClusters_big/N237-T200/1050.dat    Energy -11.31287
# ../dataset_WaterClusters_big/N237-T200/0300.dat    Energy -11.277098
# ../dataset_WaterClusters_big/N237-T200/1400.dat    Energy -9.977379
# ../dataset_WaterClusters_big/N237-T200/1450.dat    Energy -11.960058
# ../dataset_WaterClusters_big/N237-T200/1200.dat    Energy -11.41621
# ../dataset_WaterClusters_big/N237-T200/0150.dat    Energy -12.552368999999999
# ../dataset_WaterClusters_big/N237-T200/1150.dat    Energy -11.740198
# ../dataset_WaterClusters_big/N237-T200/0400.dat    Energy -11.035129000000001
# ../dataset_WaterClusters_big/N237-T200/0050.dat    Energy -11.186938
# ../dataset_WaterClusters_big/N237-T200/0750.dat    Energy -10.418703
# ../dataset_WaterClusters_big/N237-T200/1000.dat    Energy -13.243145
# ../dataset_WaterClusters_big/N237-T200/1800.dat    Energy -11.75211
# ../dataset_WaterClusters_big/N237-T200/0200.dat    Energy -11.390901000000001
# ../dataset_WaterClusters_big/N237-T150/0350.dat    Energy -11.882664
# ../dataset_WaterClusters_big/N237-T150/1700.dat    Energy -12.687613
# ../dataset_WaterClusters_big/N237-T150/0100.dat    Energy -10.455117999999999
# ../dataset_WaterClusters_big/N237-T150/1550.dat    Energy -12.462142
# ../dataset_WaterClusters_big/N237-T150/1850.dat    Energy -11.520497
# ../dataset_WaterClusters_big/N237-T150/1100.dat    Energy -13.252854
# ../dataset_WaterClusters_big/N237-T150/0450.dat    Energy -10.72844
# ../dataset_WaterClusters_big/N237-T150/0500.dat    Energy -11.823519000000001
# ../dataset_WaterClusters_big/N237-T150/1350.dat    Energy -11.841368
# ../dataset_WaterClusters_big/N237-T150/0850.dat    Energy -13.893481999999999
# ../dataset_WaterClusters_big/N237-T150/1900.dat    Energy -11.517814
# ../dataset_WaterClusters_big/N237-T150/1650.dat    Energy -12.160192
# ../dataset_WaterClusters_big/N237-T150/0250.dat    Energy -11.445207
# ../dataset_WaterClusters_big/N237-T150/0950.dat    Energy -12.1533
# ../dataset_WaterClusters_big/N237-T150/2000.dat    Energy -12.325518
# ../dataset_WaterClusters_big/N237-T150/1950.dat    Energy -12.684978
# ../dataset_WaterClusters_big/N237-T150/1500.dat    Energy -12.388467
# ../dataset_WaterClusters_big/N237-T150/1250.dat    Energy -11.532299
# ../dataset_WaterClusters_big/N237-T150/0800.dat    Energy -13.845472000000001
# ../dataset_WaterClusters_big/N237-T150/0900.dat    Energy -13.138440000000001
# ../dataset_WaterClusters_big/N237-T150/0700.dat    Energy -12.246971
# ../dataset_WaterClusters_big/N237-T150/0550.dat    Energy -11.753024
# ../dataset_WaterClusters_big/N237-T150/1750.dat    Energy -11.900224
# ../dataset_WaterClusters_big/N237-T150/1300.dat    Energy -11.404658
# ../dataset_WaterClusters_big/N237-T150/0600.dat    Energy -10.988750999999999
# ../dataset_WaterClusters_big/N237-T150/0650.dat    Energy -12.289922
# ../dataset_WaterClusters_big/N237-T150/1600.dat    Energy -13.285437
# ../dataset_WaterClusters_big/N237-T150/1050.dat    Energy -11.959531
# ../dataset_WaterClusters_big/N237-T150/0300.dat    Energy -10.320357
# ../dataset_WaterClusters_big/N237-T150/1400.dat    Energy -12.354689
# ../dataset_WaterClusters_big/N237-T150/1450.dat    Energy -11.667869999999999
# ../dataset_WaterClusters_big/N237-T150/1200.dat    Energy -12.652647
# ../dataset_WaterClusters_big/N237-T150/0150.dat    Energy -11.53097
# ../dataset_WaterClusters_big/N237-T150/1150.dat    Energy -12.886595
# ../dataset_WaterClusters_big/N237-T150/0400.dat    Energy -11.760231000000001
# ../dataset_WaterClusters_big/N237-T150/0050.dat    Energy -10.990711000000001
# ../dataset_WaterClusters_big/N237-T150/0750.dat    Energy -11.399042
# ../dataset_WaterClusters_big/N237-T150/1000.dat    Energy -13.934704
# ../dataset_WaterClusters_big/N237-T150/1800.dat    Energy -12.510874
# ../dataset_WaterClusters_big/N237-T150/0200.dat    Energy -11.642426
# ../dataset_WaterClusters_big/N76-T50/0350.dat    Energy -9.496385
# ../dataset_WaterClusters_big/N76-T50/1700.dat    Energy -9.238398
# ../dataset_WaterClusters_big/N76-T50/0100.dat    Energy -8.850104
# ../dataset_WaterClusters_big/N76-T50/1550.dat    Energy -9.484152
# ../dataset_WaterClusters_big/N76-T50/1850.dat    Energy -8.958171
# ../dataset_WaterClusters_big/N76-T50/1100.dat    Energy -8.897057
# ../dataset_WaterClusters_big/N76-T50/0450.dat    Energy -8.192467
# ../dataset_WaterClusters_big/N76-T50/0500.dat    Energy -8.747352
# ../dataset_WaterClusters_big/N76-T50/1350.dat    Energy -8.620442
# ../dataset_WaterClusters_big/N76-T50/0850.dat    Energy -8.303664
# ../dataset_WaterClusters_big/N76-T50/1900.dat    Energy -8.508351
# ../dataset_WaterClusters_big/N76-T50/1650.dat    Energy -9.442029999999999
# ../dataset_WaterClusters_big/N76-T50/0250.dat    Energy -9.285043
# ../dataset_WaterClusters_big/N76-T50/0950.dat    Energy -8.085035
# ../dataset_WaterClusters_big/N76-T50/2000.dat    Energy -9.768065
# ../dataset_WaterClusters_big/N76-T50/1950.dat    Energy -8.482702
# ../dataset_WaterClusters_big/N76-T50/1500.dat    Energy -9.317082000000001
# ../dataset_WaterClusters_big/N76-T50/1250.dat    Energy -9.021605000000001
# ../dataset_WaterClusters_big/N76-T50/0800.dat    Energy -8.993827
# ../dataset_WaterClusters_big/N76-T50/0900.dat    Energy -8.498999
# ../dataset_WaterClusters_big/N76-T50/0700.dat    Energy -8.657166
# ../dataset_WaterClusters_big/N76-T50/0550.dat    Energy -8.950773
# ../dataset_WaterClusters_big/N76-T50/1750.dat    Energy -8.814797
# ../dataset_WaterClusters_big/N76-T50/1300.dat    Energy -8.983875
# ../dataset_WaterClusters_big/N76-T50/0600.dat    Energy -8.528756
# ../dataset_WaterClusters_big/N76-T50/0650.dat    Energy -8.715199
# ../dataset_WaterClusters_big/N76-T50/1600.dat    Energy -9.510387
# ../dataset_WaterClusters_big/N76-T50/1050.dat    Energy -8.207722
# ../dataset_WaterClusters_big/N76-T50/0300.dat    Energy -9.619512
# ../dataset_WaterClusters_big/N76-T50/1400.dat    Energy -8.169038
# ../dataset_WaterClusters_big/N76-T50/1450.dat    Energy -9.174095
# ../dataset_WaterClusters_big/N76-T50/1200.dat    Energy -8.629467
# ../dataset_WaterClusters_big/N76-T50/0150.dat    Energy -8.685156
# ../dataset_WaterClusters_big/N76-T50/1150.dat    Energy -8.296299
# ../dataset_WaterClusters_big/N76-T50/0400.dat    Energy -9.188773999999999
# ../dataset_WaterClusters_big/N76-T50/0050.dat    Energy -8.895911
# ../dataset_WaterClusters_big/N76-T50/0750.dat    Energy -8.210621
# ../dataset_WaterClusters_big/N76-T50/1000.dat    Energy -8.377159
# ../dataset_WaterClusters_big/N76-T50/1800.dat    Energy -8.877954
# ../dataset_WaterClusters_big/N76-T50/0200.dat    Energy -9.221044000000001
# ../dataset_WaterClusters_big/N100-T50/0350.dat    Energy -11.90075
# ../dataset_WaterClusters_big/N100-T50/1700.dat    Energy -10.70788
# ../dataset_WaterClusters_big/N100-T50/0100.dat    Energy -10.97416
# ../dataset_WaterClusters_big/N100-T50/1550.dat    Energy -11.220749
# ../dataset_WaterClusters_big/N100-T50/1850.dat    Energy -11.692292
# ../dataset_WaterClusters_big/N100-T50/1100.dat    Energy -10.999798
# ../dataset_WaterClusters_big/N100-T50/0450.dat    Energy -11.609098
# ../dataset_WaterClusters_big/N100-T50/0500.dat    Energy -11.220286999999999
# ../dataset_WaterClusters_big/N100-T50/1350.dat    Energy -11.274269
# ../dataset_WaterClusters_big/N100-T50/0850.dat    Energy -11.722240000000001
# ../dataset_WaterClusters_big/N100-T50/1900.dat    Energy -13.280086999999998
# ../dataset_WaterClusters_big/N100-T50/1650.dat    Energy -11.427883
# ../dataset_WaterClusters_big/N100-T50/0250.dat    Energy -10.99611
# ../dataset_WaterClusters_big/N100-T50/0950.dat    Energy -12.018595
# ../dataset_WaterClusters_big/N100-T50/2000.dat    Energy -11.368312
# ../dataset_WaterClusters_big/N100-T50/1950.dat    Energy -11.535345
# ../dataset_WaterClusters_big/N100-T50/1500.dat    Energy -11.634395
# ../dataset_WaterClusters_big/N100-T50/1250.dat    Energy -12.182443
# ../dataset_WaterClusters_big/N100-T50/0800.dat    Energy -11.498764
# ../dataset_WaterClusters_big/N100-T50/0900.dat    Energy -10.560462
# ../dataset_WaterClusters_big/N100-T50/0700.dat    Energy -11.571835
# ../dataset_WaterClusters_big/N100-T50/0550.dat    Energy -11.460768
# ../dataset_WaterClusters_big/N100-T50/1750.dat    Energy -11.661513
# ../dataset_WaterClusters_big/N100-T50/1300.dat    Energy -11.372413
# ../dataset_WaterClusters_big/N100-T50/0600.dat    Energy -11.342325
# ../dataset_WaterClusters_big/N100-T50/0650.dat    Energy -11.546384
# ../dataset_WaterClusters_big/N100-T50/1600.dat    Energy -11.310437
# ../dataset_WaterClusters_big/N100-T50/1050.dat    Energy -11.466049
# ../dataset_WaterClusters_big/N100-T50/0300.dat    Energy -11.393789
# ../dataset_WaterClusters_big/N100-T50/1400.dat    Energy -10.815774000000001
# ../dataset_WaterClusters_big/N100-T50/1450.dat    Energy -10.589300999999999
# ../dataset_WaterClusters_big/N100-T50/1200.dat    Energy -11.345366
# ../dataset_WaterClusters_big/N100-T50/0150.dat    Energy -11.339469000000001
# ../dataset_WaterClusters_big/N100-T50/1150.dat    Energy -11.294594
# ../dataset_WaterClusters_big/N100-T50/0400.dat    Energy -12.02528
# ../dataset_WaterClusters_big/N100-T50/0050.dat    Energy -11.124898
# ../dataset_WaterClusters_big/N100-T50/0750.dat    Energy -11.084873
# ../dataset_WaterClusters_big/N100-T50/1000.dat    Energy -11.226988
# ../dataset_WaterClusters_big/N100-T50/1800.dat    Energy -11.504932
# ../dataset_WaterClusters_big/N100-T50/0200.dat    Energy -11.192941
# ../dataset_WaterClusters_big/N32-T100/0350.dat    Energy -5.519208
# ../dataset_WaterClusters_big/N32-T100/1700.dat    Energy -6.989186
# ../dataset_WaterClusters_big/N32-T100/0100.dat    Energy -5.142878
# ../dataset_WaterClusters_big/N32-T100/1550.dat    Energy -6.38777
# ../dataset_WaterClusters_big/N32-T100/1850.dat    Energy -6.292485
# ../dataset_WaterClusters_big/N32-T100/1100.dat    Energy -4.702563
# ../dataset_WaterClusters_big/N32-T100/0450.dat    Energy -5.504031
# ../dataset_WaterClusters_big/N32-T100/0500.dat    Energy -5.7696
# ../dataset_WaterClusters_big/N32-T100/1350.dat    Energy -5.216456
# ../dataset_WaterClusters_big/N32-T100/0850.dat    Energy -4.839762
# ../dataset_WaterClusters_big/N32-T100/1900.dat    Energy -6.2686329999999995
# ../dataset_WaterClusters_big/N32-T100/1650.dat    Energy -5.588081000000001
# ../dataset_WaterClusters_big/N32-T100/0250.dat    Energy -4.783875
# ../dataset_WaterClusters_big/N32-T100/0950.dat    Energy -5.967431
# ../dataset_WaterClusters_big/N32-T100/2000.dat    Energy -6.751899
# ../dataset_WaterClusters_big/N32-T100/1950.dat    Energy -6.886813999999999
# ../dataset_WaterClusters_big/N32-T100/1500.dat    Energy -6.024307
# ../dataset_WaterClusters_big/N32-T100/1250.dat    Energy -4.992793
# ../dataset_WaterClusters_big/N32-T100/0800.dat    Energy -5.437882
# ../dataset_WaterClusters_big/N32-T100/0900.dat    Energy -6.013694
# ../dataset_WaterClusters_big/N32-T100/0700.dat    Energy -5.423018
# ../dataset_WaterClusters_big/N32-T100/0550.dat    Energy -5.817665000000001
# ../dataset_WaterClusters_big/N32-T100/1750.dat    Energy -5.976347
# ../dataset_WaterClusters_big/N32-T100/1300.dat    Energy -5.532348
# ../dataset_WaterClusters_big/N32-T100/0600.dat    Energy -6.200353
# ../dataset_WaterClusters_big/N32-T100/0650.dat    Energy -5.824562
# ../dataset_WaterClusters_big/N32-T100/1600.dat    Energy -5.861518
# ../dataset_WaterClusters_big/N32-T100/1050.dat    Energy -5.55005
# ../dataset_WaterClusters_big/N32-T100/0300.dat    Energy -5.2487260000000004
# ../dataset_WaterClusters_big/N32-T100/1400.dat    Energy -6.498476999999999
# ../dataset_WaterClusters_big/N32-T100/1450.dat    Energy -6.771935
# ../dataset_WaterClusters_big/N32-T100/1200.dat    Energy -4.921260999999999
# ../dataset_WaterClusters_big/N32-T100/0150.dat    Energy -5.26696
# ../dataset_WaterClusters_big/N32-T100/1150.dat    Energy -4.562539
# ../dataset_WaterClusters_big/N32-T100/0400.dat    Energy -5.323233
# ../dataset_WaterClusters_big/N32-T100/0050.dat    Energy -6.853966
# ../dataset_WaterClusters_big/N32-T100/0750.dat    Energy -5.14234
# ../dataset_WaterClusters_big/N32-T100/1000.dat    Energy -6.685138
# ../dataset_WaterClusters_big/N32-T100/1800.dat    Energy -5.849019
# ../dataset_WaterClusters_big/N32-T100/0200.dat    Energy -5.374332
# ../dataset_WaterClusters_big/N237-T50/0350.dat    Energy -11.258943
# ../dataset_WaterClusters_big/N237-T50/1700.dat    Energy -11.31202
# ../dataset_WaterClusters_big/N237-T50/0100.dat    Energy -10.230905
# ../dataset_WaterClusters_big/N237-T50/1550.dat    Energy -11.304284
# ../dataset_WaterClusters_big/N237-T50/1850.dat    Energy -11.080214
# ../dataset_WaterClusters_big/N237-T50/1100.dat    Energy -11.426293999999999
# ../dataset_WaterClusters_big/N237-T50/0450.dat    Energy -10.838182999999999
# ../dataset_WaterClusters_big/N237-T50/0500.dat    Energy -10.651957
# ../dataset_WaterClusters_big/N237-T50/1350.dat    Energy -11.269768
# ../dataset_WaterClusters_big/N237-T50/0850.dat    Energy -11.435852
# ../dataset_WaterClusters_big/N237-T50/1900.dat    Energy -10.99301
# ../dataset_WaterClusters_big/N237-T50/1650.dat    Energy -10.97658
# ../dataset_WaterClusters_big/N237-T50/0250.dat    Energy -11.00521
# ../dataset_WaterClusters_big/N237-T50/0950.dat    Energy -11.893671
# ../dataset_WaterClusters_big/N237-T50/2000.dat    Energy -11.402472
# ../dataset_WaterClusters_big/N237-T50/1950.dat    Energy -11.472033
# ../dataset_WaterClusters_big/N237-T50/1500.dat    Energy -11.841396999999999
# ../dataset_WaterClusters_big/N237-T50/1250.dat    Energy -10.49854
# ../dataset_WaterClusters_big/N237-T50/0800.dat    Energy -11.927363
# ../dataset_WaterClusters_big/N237-T50/0900.dat    Energy -11.833751000000001
# ../dataset_WaterClusters_big/N237-T50/0700.dat    Energy -11.010483
# ../dataset_WaterClusters_big/N237-T50/0550.dat    Energy -10.854713
# ../dataset_WaterClusters_big/N237-T50/1750.dat    Energy -11.430990000000001
# ../dataset_WaterClusters_big/N237-T50/1300.dat    Energy -10.678932
# ../dataset_WaterClusters_big/N237-T50/0600.dat    Energy -10.225797
# ../dataset_WaterClusters_big/N237-T50/0650.dat    Energy -11.022434
# ../dataset_WaterClusters_big/N237-T50/1600.dat    Energy -12.137871
# ../dataset_WaterClusters_big/N237-T50/1050.dat    Energy -10.890763
# ../dataset_WaterClusters_big/N237-T50/0300.dat    Energy -10.473393999999999
# ../dataset_WaterClusters_big/N237-T50/1400.dat    Energy -11.438341000000001
# ../dataset_WaterClusters_big/N237-T50/1450.dat    Energy -11.58133
# ../dataset_WaterClusters_big/N237-T50/1200.dat    Energy -11.84624
# ../dataset_WaterClusters_big/N237-T50/0150.dat    Energy -10.832979
# ../dataset_WaterClusters_big/N237-T50/1150.dat    Energy -11.261651
# ../dataset_WaterClusters_big/N237-T50/0400.dat    Energy -10.416358
# ../dataset_WaterClusters_big/N237-T50/0050.dat    Energy -9.600480000000001
# ../dataset_WaterClusters_big/N237-T50/0750.dat    Energy -10.412536
# ../dataset_WaterClusters_big/N237-T50/1000.dat    Energy -11.968237
# ../dataset_WaterClusters_big/N237-T50/1800.dat    Energy -11.469831
# ../dataset_WaterClusters_big/N237-T50/0200.dat    Energy -10.424534000000001
# ../dataset_WaterClusters_big/N47-T50/0350.dat    Energy -8.21376
# ../dataset_WaterClusters_big/N47-T50/1700.dat    Energy -8.386674
# ../dataset_WaterClusters_big/N47-T50/0100.dat    Energy -8.80009
# ../dataset_WaterClusters_big/N47-T50/1550.dat    Energy -8.849045
# ../dataset_WaterClusters_big/N47-T50/1850.dat    Energy -8.701578
# ../dataset_WaterClusters_big/N47-T50/1100.dat    Energy -8.587007
# ../dataset_WaterClusters_big/N47-T50/0450.dat    Energy -8.020558999999999
# ../dataset_WaterClusters_big/N47-T50/0500.dat    Energy -8.08543
# ../dataset_WaterClusters_big/N47-T50/1350.dat    Energy -8.943997
# ../dataset_WaterClusters_big/N47-T50/0850.dat    Energy -7.983524
# ../dataset_WaterClusters_big/N47-T50/1900.dat    Energy -8.969843
# ../dataset_WaterClusters_big/N47-T50/1650.dat    Energy -9.061173
# ../dataset_WaterClusters_big/N47-T50/0250.dat    Energy -8.263689000000001
# ../dataset_WaterClusters_big/N47-T50/0950.dat    Energy -8.445057
# ../dataset_WaterClusters_big/N47-T50/2000.dat    Energy -8.597671
# ../dataset_WaterClusters_big/N47-T50/1950.dat    Energy -8.906274
# ../dataset_WaterClusters_big/N47-T50/1500.dat    Energy -8.994362
# ../dataset_WaterClusters_big/N47-T50/1250.dat    Energy -8.208229
# ../dataset_WaterClusters_big/N47-T50/0800.dat    Energy -7.9921619999999995
# ../dataset_WaterClusters_big/N47-T50/0900.dat    Energy -7.622110999999999
# ../dataset_WaterClusters_big/N47-T50/0700.dat    Energy -8.368552
# ../dataset_WaterClusters_big/N47-T50/0550.dat    Energy -8.277979
# ../dataset_WaterClusters_big/N47-T50/1750.dat    Energy -9.075844
# ../dataset_WaterClusters_big/N47-T50/1300.dat    Energy -7.944734
# ../dataset_WaterClusters_big/N47-T50/0600.dat    Energy -8.167367
# ../dataset_WaterClusters_big/N47-T50/0650.dat    Energy -7.80235
# ../dataset_WaterClusters_big/N47-T50/1600.dat    Energy -8.083013999999999
# ../dataset_WaterClusters_big/N47-T50/1050.dat    Energy -8.546377
# ../dataset_WaterClusters_big/N47-T50/0300.dat    Energy -8.514895
# ../dataset_WaterClusters_big/N47-T50/1400.dat    Energy -8.490272000000001
# ../dataset_WaterClusters_big/N47-T50/1450.dat    Energy -8.061853
# ../dataset_WaterClusters_big/N47-T50/1200.dat    Energy -9.059873
# ../dataset_WaterClusters_big/N47-T50/0150.dat    Energy -8.589252
# ../dataset_WaterClusters_big/N47-T50/1150.dat    Energy -8.055807
# ../dataset_WaterClusters_big/N47-T50/0400.dat    Energy -8.604332000000001
# ../dataset_WaterClusters_big/N47-T50/0050.dat    Energy -7.937535
# ../dataset_WaterClusters_big/N47-T50/0750.dat    Energy -8.211182
# ../dataset_WaterClusters_big/N47-T50/1000.dat    Energy -8.125722
# ../dataset_WaterClusters_big/N47-T50/1800.dat    Energy -8.872474
# ../dataset_WaterClusters_big/N47-T50/0200.dat    Energy -7.951267
# ../dataset_WaterClusters_big/N20-T50/0350.dat    Energy -2.641588
# ../dataset_WaterClusters_big/N20-T50/1700.dat    Energy -2.458119
# ../dataset_WaterClusters_big/N20-T50/0100.dat    Energy -2.723965
# ../dataset_WaterClusters_big/N20-T50/1550.dat    Energy -2.118512
# ../dataset_WaterClusters_big/N20-T50/1850.dat    Energy -2.583042
# ../dataset_WaterClusters_big/N20-T50/1100.dat    Energy -2.067701
# ../dataset_WaterClusters_big/N20-T50/0450.dat    Energy -2.270354
# ../dataset_WaterClusters_big/N20-T50/0500.dat    Energy -2.440138
# ../dataset_WaterClusters_big/N20-T50/1350.dat    Energy -2.46412
# ../dataset_WaterClusters_big/N20-T50/0850.dat    Energy -2.163022
# ../dataset_WaterClusters_big/N20-T50/1900.dat    Energy -2.333381
# ../dataset_WaterClusters_big/N20-T50/1650.dat    Energy -2.5221690000000003
# ../dataset_WaterClusters_big/N20-T50/0250.dat    Energy -2.959565
# ../dataset_WaterClusters_big/N20-T50/0950.dat    Energy -2.3464579999999997
# ../dataset_WaterClusters_big/N20-T50/2000.dat    Energy -2.546309
# ../dataset_WaterClusters_big/N20-T50/1950.dat    Energy -2.662178
# ../dataset_WaterClusters_big/N20-T50/1500.dat    Energy -2.671401
# ../dataset_WaterClusters_big/N20-T50/1250.dat    Energy -2.932448
# ../dataset_WaterClusters_big/N20-T50/0800.dat    Energy -2.7607690000000003
# ../dataset_WaterClusters_big/N20-T50/0900.dat    Energy -2.325899
# ../dataset_WaterClusters_big/N20-T50/0700.dat    Energy -2.088636
# ../dataset_WaterClusters_big/N20-T50/0550.dat    Energy -2.557297
# ../dataset_WaterClusters_big/N20-T50/1750.dat    Energy -2.431938
# ../dataset_WaterClusters_big/N20-T50/1300.dat    Energy -2.576242
# ../dataset_WaterClusters_big/N20-T50/0600.dat    Energy -2.377154
# ../dataset_WaterClusters_big/N20-T50/0650.dat    Energy -2.097901
# ../dataset_WaterClusters_big/N20-T50/1600.dat    Energy -2.1480989999999998
# ../dataset_WaterClusters_big/N20-T50/1050.dat    Energy -2.266808
# ../dataset_WaterClusters_big/N20-T50/0300.dat    Energy -2.652356
# ../dataset_WaterClusters_big/N20-T50/1400.dat    Energy -2.694834
# ../dataset_WaterClusters_big/N20-T50/1450.dat    Energy -2.359818
# ../dataset_WaterClusters_big/N20-T50/1200.dat    Energy -3.1763529999999998
# ../dataset_WaterClusters_big/N20-T50/0150.dat    Energy -2.098033
# ../dataset_WaterClusters_big/N20-T50/1150.dat    Energy -2.5312230000000002
# ../dataset_WaterClusters_big/N20-T50/0400.dat    Energy -1.885584
# ../dataset_WaterClusters_big/N20-T50/0050.dat    Energy -2.359588
# ../dataset_WaterClusters_big/N20-T50/0750.dat    Energy -2.443643
# ../dataset_WaterClusters_big/N20-T50/1000.dat    Energy -2.03736
# ../dataset_WaterClusters_big/N20-T50/1800.dat    Energy -2.6571919999999998
# ../dataset_WaterClusters_big/N20-T50/0200.dat    Energy -2.573067
# ../dataset_WaterClusters_big/N47-T150/0350.dat    Energy -7.147062
# ../dataset_WaterClusters_big/N47-T150/1700.dat    Energy -8.11144
# ../dataset_WaterClusters_big/N47-T150/0100.dat    Energy -8.117061
# ../dataset_WaterClusters_big/N47-T150/1550.dat    Energy -8.120394000000001
# ../dataset_WaterClusters_big/N47-T150/1850.dat    Energy -7.278619
# ../dataset_WaterClusters_big/N47-T150/1100.dat    Energy -7.138923
# ../dataset_WaterClusters_big/N47-T150/0450.dat    Energy -6.458024
# ../dataset_WaterClusters_big/N47-T150/0500.dat    Energy -7.4638919999999995
# ../dataset_WaterClusters_big/N47-T150/1350.dat    Energy -8.014090999999999
# ../dataset_WaterClusters_big/N47-T150/0850.dat    Energy -6.745094
# ../dataset_WaterClusters_big/N47-T150/1900.dat    Energy -7.979683
# ../dataset_WaterClusters_big/N47-T150/1650.dat    Energy -8.674511
# ../dataset_WaterClusters_big/N47-T150/0250.dat    Energy -6.2441379999999995
# ../dataset_WaterClusters_big/N47-T150/0950.dat    Energy -5.828977
# ../dataset_WaterClusters_big/N47-T150/2000.dat    Energy -7.197125
# ../dataset_WaterClusters_big/N47-T150/1950.dat    Energy -7.402952
# ../dataset_WaterClusters_big/N47-T150/1500.dat    Energy -7.7165
# ../dataset_WaterClusters_big/N47-T150/1250.dat    Energy -7.258249
# ../dataset_WaterClusters_big/N47-T150/0800.dat    Energy -5.863208
# ../dataset_WaterClusters_big/N47-T150/0900.dat    Energy -5.611209000000001
# ../dataset_WaterClusters_big/N47-T150/0700.dat    Energy -6.323576
# ../dataset_WaterClusters_big/N47-T150/0550.dat    Energy -5.620184999999999
# ../dataset_WaterClusters_big/N47-T150/1750.dat    Energy -8.498338
# ../dataset_WaterClusters_big/N47-T150/1300.dat    Energy -6.13274
# ../dataset_WaterClusters_big/N47-T150/0600.dat    Energy -4.747335
# ../dataset_WaterClusters_big/N47-T150/0650.dat    Energy -4.92265
# ../dataset_WaterClusters_big/N47-T150/1600.dat    Energy -6.804313
# ../dataset_WaterClusters_big/N47-T150/1050.dat    Energy -6.344702000000001
# ../dataset_WaterClusters_big/N47-T150/0300.dat    Energy -6.8817580000000005
# ../dataset_WaterClusters_big/N47-T150/1400.dat    Energy -7.776901
# ../dataset_WaterClusters_big/N47-T150/1450.dat    Energy -5.803659
# ../dataset_WaterClusters_big/N47-T150/1200.dat    Energy -8.151885
# ../dataset_WaterClusters_big/N47-T150/0150.dat    Energy -6.831052
# ../dataset_WaterClusters_big/N47-T150/1150.dat    Energy -6.413360999999999
# ../dataset_WaterClusters_big/N47-T150/0400.dat    Energy -6.930084
# ../dataset_WaterClusters_big/N47-T150/0050.dat    Energy -6.811811
# ../dataset_WaterClusters_big/N47-T150/0750.dat    Energy -6.195088
# ../dataset_WaterClusters_big/N47-T150/1000.dat    Energy -5.536631
# ../dataset_WaterClusters_big/N47-T150/1800.dat    Energy -8.249919
# ../dataset_WaterClusters_big/N47-T150/0200.dat    Energy -6.069256
# ../dataset_WaterClusters_big/N190-T100/0350.dat    Energy -11.984273
# ../dataset_WaterClusters_big/N190-T100/1700.dat    Energy -11.915451000000001
# ../dataset_WaterClusters_big/N190-T100/0100.dat    Energy -11.484437999999999
# ../dataset_WaterClusters_big/N190-T100/1550.dat    Energy -11.781128
# ../dataset_WaterClusters_big/N190-T100/1850.dat    Energy -11.382514
# ../dataset_WaterClusters_big/N190-T100/1100.dat    Energy -11.505513
# ../dataset_WaterClusters_big/N190-T100/0450.dat    Energy -11.252964
# ../dataset_WaterClusters_big/N190-T100/0500.dat    Energy -12.220232000000001
# ../dataset_WaterClusters_big/N190-T100/1350.dat    Energy -12.775196
# ../dataset_WaterClusters_big/N190-T100/0850.dat    Energy -12.455266
# ../dataset_WaterClusters_big/N190-T100/1900.dat    Energy -11.739552999999999
# ../dataset_WaterClusters_big/N190-T100/1650.dat    Energy -12.847297
# ../dataset_WaterClusters_big/N190-T100/0250.dat    Energy -12.129098
# ../dataset_WaterClusters_big/N190-T100/0950.dat    Energy -12.585664999999999
# ../dataset_WaterClusters_big/N190-T100/2000.dat    Energy -12.75973
# ../dataset_WaterClusters_big/N190-T100/1950.dat    Energy -11.402714
# ../dataset_WaterClusters_big/N190-T100/1500.dat    Energy -12.344874
# ../dataset_WaterClusters_big/N190-T100/1250.dat    Energy -12.74141
# ../dataset_WaterClusters_big/N190-T100/0800.dat    Energy -11.388511
# ../dataset_WaterClusters_big/N190-T100/0900.dat    Energy -13.066433
# ../dataset_WaterClusters_big/N190-T100/0700.dat    Energy -10.594816999999999
# ../dataset_WaterClusters_big/N190-T100/0550.dat    Energy -11.628478000000001
# ../dataset_WaterClusters_big/N190-T100/1750.dat    Energy -12.022395
# ../dataset_WaterClusters_big/N190-T100/1300.dat    Energy -11.357796
# ../dataset_WaterClusters_big/N190-T100/0600.dat    Energy -11.015298
# ../dataset_WaterClusters_big/N190-T100/0650.dat    Energy -12.685883
# ../dataset_WaterClusters_big/N190-T100/1600.dat    Energy -11.980672
# ../dataset_WaterClusters_big/N190-T100/1050.dat    Energy -11.991007
# ../dataset_WaterClusters_big/N190-T100/0300.dat    Energy -11.289681
# ../dataset_WaterClusters_big/N190-T100/1400.dat    Energy -11.609534
# ../dataset_WaterClusters_big/N190-T100/1450.dat    Energy -11.732417
# ../dataset_WaterClusters_big/N190-T100/1200.dat    Energy -11.879523
# ../dataset_WaterClusters_big/N190-T100/0150.dat    Energy -11.605205
# ../dataset_WaterClusters_big/N190-T100/1150.dat    Energy -11.776391
# ../dataset_WaterClusters_big/N190-T100/0400.dat    Energy -12.629335999999999
# ../dataset_WaterClusters_big/N190-T100/0050.dat    Energy -12.716211999999999
# ../dataset_WaterClusters_big/N190-T100/0750.dat    Energy -11.524925
# ../dataset_WaterClusters_big/N190-T100/1000.dat    Energy -11.802351
# ../dataset_WaterClusters_big/N190-T100/1800.dat    Energy -11.734081999999999
# ../dataset_WaterClusters_big/N190-T100/0200.dat    Energy -11.101055
# ../dataset_WaterClusters_big/N32-T200/0350.dat    Energy -4.265378999999999
# ../dataset_WaterClusters_big/N32-T200/1700.dat    Energy -6.93168
# ../dataset_WaterClusters_big/N32-T200/0100.dat    Energy -4.244097
# ../dataset_WaterClusters_big/N32-T200/1550.dat    Energy -4.927624
# ../dataset_WaterClusters_big/N32-T200/1850.dat    Energy -5.748093
# ../dataset_WaterClusters_big/N32-T200/1100.dat    Energy -4.866902
# ../dataset_WaterClusters_big/N32-T200/0450.dat    Energy -5.746147
# ../dataset_WaterClusters_big/N32-T200/0500.dat    Energy -4.886702
# ../dataset_WaterClusters_big/N32-T200/1350.dat    Energy -5.8165759999999995
# ../dataset_WaterClusters_big/N32-T200/0850.dat    Energy -4.657623
# ../dataset_WaterClusters_big/N32-T200/1900.dat    Energy -6.897773
# ../dataset_WaterClusters_big/N32-T200/1650.dat    Energy -5.243321
# ../dataset_WaterClusters_big/N32-T200/0250.dat    Energy -4.737637
# ../dataset_WaterClusters_big/N32-T200/0950.dat    Energy -5.260037
# ../dataset_WaterClusters_big/N32-T200/2000.dat    Energy -7.229405999999999
# ../dataset_WaterClusters_big/N32-T200/1950.dat    Energy -7.144848
# ../dataset_WaterClusters_big/N32-T200/1500.dat    Energy -4.665297
# ../dataset_WaterClusters_big/N32-T200/1250.dat    Energy -3.431285
# ../dataset_WaterClusters_big/N32-T200/0800.dat    Energy -5.269976
# ../dataset_WaterClusters_big/N32-T200/0900.dat    Energy -5.228609
# ../dataset_WaterClusters_big/N32-T200/0700.dat    Energy -4.361513
# ../dataset_WaterClusters_big/N32-T200/0550.dat    Energy -4.515526
# ../dataset_WaterClusters_big/N32-T200/1750.dat    Energy -6.285590000000001
# ../dataset_WaterClusters_big/N32-T200/1300.dat    Energy -5.04363
# ../dataset_WaterClusters_big/N32-T200/0600.dat    Energy -4.269325
# ../dataset_WaterClusters_big/N32-T200/0650.dat    Energy -5.0999669999999995
# ../dataset_WaterClusters_big/N32-T200/1600.dat    Energy -6.016087
# ../dataset_WaterClusters_big/N32-T200/1050.dat    Energy -4.437061
# ../dataset_WaterClusters_big/N32-T200/0300.dat    Energy -4.993135
# ../dataset_WaterClusters_big/N32-T200/1400.dat    Energy -6.055754
# ../dataset_WaterClusters_big/N32-T200/1450.dat    Energy -5.374287
# ../dataset_WaterClusters_big/N32-T200/1200.dat    Energy -4.493851
# ../dataset_WaterClusters_big/N32-T200/0150.dat    Energy -5.613088
# ../dataset_WaterClusters_big/N32-T200/1150.dat    Energy -4.301448
# ../dataset_WaterClusters_big/N32-T200/0400.dat    Energy -5.208837
# ../dataset_WaterClusters_big/N32-T200/0050.dat    Energy -6.192355
# ../dataset_WaterClusters_big/N32-T200/0750.dat    Energy -5.126973
# ../dataset_WaterClusters_big/N32-T200/1000.dat    Energy -5.920335000000001
# ../dataset_WaterClusters_big/N32-T200/1800.dat    Energy -6.710143
# ../dataset_WaterClusters_big/N32-T200/0200.dat    Energy -3.5978179999999997
# ../dataset_WaterClusters_big/N139-T100/0350.dat    Energy -9.504667
# ../dataset_WaterClusters_big/N139-T100/1700.dat    Energy -8.151482
# ../dataset_WaterClusters_big/N139-T100/0100.dat    Energy -8.888387999999999
# ../dataset_WaterClusters_big/N139-T100/1550.dat    Energy -7.928228
# ../dataset_WaterClusters_big/N139-T100/1850.dat    Energy -8.915649
# ../dataset_WaterClusters_big/N139-T100/1100.dat    Energy -9.101865
# ../dataset_WaterClusters_big/N139-T100/0450.dat    Energy -8.975192
# ../dataset_WaterClusters_big/N139-T100/0500.dat    Energy -9.767834
# ../dataset_WaterClusters_big/N139-T100/1350.dat    Energy -9.302547
# ../dataset_WaterClusters_big/N139-T100/0850.dat    Energy -8.188455
# ../dataset_WaterClusters_big/N139-T100/1900.dat    Energy -8.475828
# ../dataset_WaterClusters_big/N139-T100/1650.dat    Energy -8.668341
# ../dataset_WaterClusters_big/N139-T100/0250.dat    Energy -9.309792
# ../dataset_WaterClusters_big/N139-T100/0950.dat    Energy -9.351213
# ../dataset_WaterClusters_big/N139-T100/2000.dat    Energy -9.471575999999999
# ../dataset_WaterClusters_big/N139-T100/1950.dat    Energy -8.748125
# ../dataset_WaterClusters_big/N139-T100/1500.dat    Energy -9.283853
# ../dataset_WaterClusters_big/N139-T100/1250.dat    Energy -9.755085
# ../dataset_WaterClusters_big/N139-T100/0800.dat    Energy -9.010447000000001
# ../dataset_WaterClusters_big/N139-T100/0900.dat    Energy -8.537189000000001
# ../dataset_WaterClusters_big/N139-T100/0700.dat    Energy -9.339484
# ../dataset_WaterClusters_big/N139-T100/0550.dat    Energy -9.378108000000001
# ../dataset_WaterClusters_big/N139-T100/1750.dat    Energy -8.301645
# ../dataset_WaterClusters_big/N139-T100/1300.dat    Energy -8.133448
# ../dataset_WaterClusters_big/N139-T100/0600.dat    Energy -9.340015
# ../dataset_WaterClusters_big/N139-T100/0650.dat    Energy -9.218346
# ../dataset_WaterClusters_big/N139-T100/1600.dat    Energy -8.30869
# ../dataset_WaterClusters_big/N139-T100/1050.dat    Energy -9.227391
# ../dataset_WaterClusters_big/N139-T100/0300.dat    Energy -9.131625
# ../dataset_WaterClusters_big/N139-T100/1400.dat    Energy -8.982370000000001
# ../dataset_WaterClusters_big/N139-T100/1450.dat    Energy -8.498221000000001
# ../dataset_WaterClusters_big/N139-T100/1200.dat    Energy -8.784072
# ../dataset_WaterClusters_big/N139-T100/0150.dat    Energy -8.7178
# ../dataset_WaterClusters_big/N139-T100/1150.dat    Energy -8.940799
# ../dataset_WaterClusters_big/N139-T100/0400.dat    Energy -10.229322
# ../dataset_WaterClusters_big/N139-T100/0050.dat    Energy -10.014787
# ../dataset_WaterClusters_big/N139-T100/0750.dat    Energy -8.21682
# ../dataset_WaterClusters_big/N139-T100/1000.dat    Energy -9.652332
# ../dataset_WaterClusters_big/N139-T100/1800.dat    Energy -9.68724
# ../dataset_WaterClusters_big/N139-T100/0200.dat    Energy -8.675638
# ../dataset_WaterClusters_big/N139-T150/0350.dat    Energy -10.035432
# ../dataset_WaterClusters_big/N139-T150/1700.dat    Energy -9.943446999999999
# ../dataset_WaterClusters_big/N139-T150/0100.dat    Energy -9.656295
# ../dataset_WaterClusters_big/N139-T150/1550.dat    Energy -10.126971999999999
# ../dataset_WaterClusters_big/N139-T150/1850.dat    Energy -10.189427
# ../dataset_WaterClusters_big/N139-T150/1100.dat    Energy -10.185115
# ../dataset_WaterClusters_big/N139-T150/0450.dat    Energy -9.26394
# ../dataset_WaterClusters_big/N139-T150/0500.dat    Energy -8.985304
# ../dataset_WaterClusters_big/N139-T150/1350.dat    Energy -10.706147000000001
# ../dataset_WaterClusters_big/N139-T150/0850.dat    Energy -9.466573
# ../dataset_WaterClusters_big/N139-T150/1900.dat    Energy -10.107581999999999
# ../dataset_WaterClusters_big/N139-T150/1650.dat    Energy -10.542619
# ../dataset_WaterClusters_big/N139-T150/0250.dat    Energy -11.057037
# ../dataset_WaterClusters_big/N139-T150/0950.dat    Energy -10.957217
# ../dataset_WaterClusters_big/N139-T150/2000.dat    Energy -10.455465
# ../dataset_WaterClusters_big/N139-T150/1950.dat    Energy -10.008954000000001
# ../dataset_WaterClusters_big/N139-T150/1500.dat    Energy -10.528569000000001
# ../dataset_WaterClusters_big/N139-T150/1250.dat    Energy -10.939781
# ../dataset_WaterClusters_big/N139-T150/0800.dat    Energy -10.288675
# ../dataset_WaterClusters_big/N139-T150/0900.dat    Energy -10.07414
# ../dataset_WaterClusters_big/N139-T150/0700.dat    Energy -10.296542
# ../dataset_WaterClusters_big/N139-T150/0550.dat    Energy -9.077016
# ../dataset_WaterClusters_big/N139-T150/1750.dat    Energy -9.898851
# ../dataset_WaterClusters_big/N139-T150/1300.dat    Energy -9.639968
# ../dataset_WaterClusters_big/N139-T150/0600.dat    Energy -9.994636
# ../dataset_WaterClusters_big/N139-T150/0650.dat    Energy -9.936762
# ../dataset_WaterClusters_big/N139-T150/1600.dat    Energy -9.908684
# ../dataset_WaterClusters_big/N139-T150/1050.dat    Energy -9.979329
# ../dataset_WaterClusters_big/N139-T150/0300.dat    Energy -9.448438000000001
# ../dataset_WaterClusters_big/N139-T150/1400.dat    Energy -10.3254
# ../dataset_WaterClusters_big/N139-T150/1450.dat    Energy -9.843145
# ../dataset_WaterClusters_big/N139-T150/1200.dat    Energy -9.857862
# ../dataset_WaterClusters_big/N139-T150/0150.dat    Energy -8.680633
# ../dataset_WaterClusters_big/N139-T150/1150.dat    Energy -9.760443
# ../dataset_WaterClusters_big/N139-T150/0400.dat    Energy -10.814335
# ../dataset_WaterClusters_big/N139-T150/0050.dat    Energy -10.514825
# ../dataset_WaterClusters_big/N139-T150/0750.dat    Energy -10.307355
# ../dataset_WaterClusters_big/N139-T150/1000.dat    Energy -10.139809
# ../dataset_WaterClusters_big/N139-T150/1800.dat    Energy -11.092837
# ../dataset_WaterClusters_big/N139-T150/0200.dat    Energy -9.740813
# ../dataset_WaterClusters_big/N32-T50/0350.dat    Energy -4.880272
# ../dataset_WaterClusters_big/N32-T50/1700.dat    Energy -5.909482
# ../dataset_WaterClusters_big/N32-T50/0100.dat    Energy -4.310936
# ../dataset_WaterClusters_big/N32-T50/1550.dat    Energy -5.253459
# ../dataset_WaterClusters_big/N32-T50/1850.dat    Energy -5.820477
# ../dataset_WaterClusters_big/N32-T50/1100.dat    Energy -4.958434
# ../dataset_WaterClusters_big/N32-T50/0450.dat    Energy -4.632412
# ../dataset_WaterClusters_big/N32-T50/0500.dat    Energy -5.1365099999999995
# ../dataset_WaterClusters_big/N32-T50/1350.dat    Energy -5.31496
# ../dataset_WaterClusters_big/N32-T50/0850.dat    Energy -4.882848
# ../dataset_WaterClusters_big/N32-T50/1900.dat    Energy -5.376861
# ../dataset_WaterClusters_big/N32-T50/1650.dat    Energy -5.589757
# ../dataset_WaterClusters_big/N32-T50/0250.dat    Energy -4.311704000000001
# ...
# ../dataset_WaterClusters_big/N100-T200/1650.dat    Energy -10.3885
# ../dataset_WaterClusters_big/N100-T200/0250.dat    Energy -8.995256
# ../dataset_WaterClusters_big/N100-T200/0950.dat    Energy -11.819922
# ../dataset_WaterClusters_big/N100-T200/2000.dat    Energy -10.056489000000001
# ../dataset_WaterClusters_big/N100-T200/1950.dat    Energy -10.441945
# ../dataset_WaterClusters_big/N100-T200/1500.dat    Energy -10.466267
# ../dataset_WaterClusters_big/N100-T200/1250.dat    Energy -12.171043
# ../dataset_WaterClusters_big/N100-T200/0800.dat    Energy -9.796038999999999
# ../dataset_WaterClusters_big/N100-T200/0900.dat    Energy -10.053206000000001
# ../dataset_WaterClusters_big/N100-T200/0700.dat    Energy -10.736621
# ../dataset_WaterClusters_big/N100-T200/0550.dat    Energy -9.934692
# ../dataset_WaterClusters_big/N100-T200/1750.dat    Energy -10.635126
# ../dataset_WaterClusters_big/N100-T200/1300.dat    Energy -10.63379
# ../dataset_WaterClusters_big/N100-T200/0600.dat    Energy -9.874333
# ../dataset_WaterClusters_big/N100-T200/0650.dat    Energy -10.039629
# ../dataset_WaterClusters_big/N100-T200/1600.dat    Energy -9.557082999999999
# ../dataset_WaterClusters_big/N100-T200/1050.dat    Energy -10.908827
# ../dataset_WaterClusters_big/N100-T200/0300.dat    Energy -10.087613
# ../dataset_WaterClusters_big/N100-T200/1400.dat    Energy -10.242006
# ../dataset_WaterClusters_big/N100-T200/1450.dat    Energy -9.202624
# ../dataset_WaterClusters_big/N100-T200/1200.dat    Energy -10.678295
# ../dataset_WaterClusters_big/N100-T200/0150.dat    Energy -10.565655999999999
# ../dataset_WaterClusters_big/N100-T200/1150.dat    Energy -11.039229
# ../dataset_WaterClusters_big/N100-T200/0400.dat    Energy -10.831754
# ../dataset_WaterClusters_big/N100-T200/0050.dat    Energy -9.900152
# ../dataset_WaterClusters_big/N100-T200/0750.dat    Energy -9.268585999999999
# ../dataset_WaterClusters_big/N100-T200/1000.dat    Energy -10.387157
# ../dataset_WaterClusters_big/N100-T200/1800.dat    Energy -9.642878000000001
# ../dataset_WaterClusters_big/N100-T200/0200.dat    Energy -9.588148
# ../dataset_WaterClusters_big/N47-T200/0350.dat    Energy -3.805771
# ../dataset_WaterClusters_big/N47-T200/1700.dat    Energy -4.203447
# ../dataset_WaterClusters_big/N47-T200/0100.dat    Energy -3.26926
# ../dataset_WaterClusters_big/N47-T200/1550.dat    Energy -3.931918
# ../dataset_WaterClusters_big/N47-T200/1850.dat    Energy -3.812659
# ../dataset_WaterClusters_big/N47-T200/1100.dat    Energy -3.4437830000000003
# ../dataset_WaterClusters_big/N47-T200/0450.dat    Energy -3.725581
# ../dataset_WaterClusters_big/N47-T200/0500.dat    Energy -4.618698
# ../dataset_WaterClusters_big/N47-T200/1350.dat    Energy -3.639008
# ../dataset_WaterClusters_big/N47-T200/0850.dat    Energy -3.026144
# ../dataset_WaterClusters_big/N47-T200/1900.dat    Energy -4.164096
# ../dataset_WaterClusters_big/N47-T200/1650.dat    Energy -3.97602
# ../dataset_WaterClusters_big/N47-T200/0250.dat    Energy -2.856087
# ../dataset_WaterClusters_big/N47-T200/0950.dat    Energy -3.834759
# ../dataset_WaterClusters_big/N47-T200/2000.dat    Energy -4.6412830000000005
# ../dataset_WaterClusters_big/N47-T200/1950.dat    Energy -4.062296
# ../dataset_WaterClusters_big/N47-T200/1500.dat    Energy -4.589572
# ../dataset_WaterClusters_big/N47-T200/1250.dat    Energy -3.862983
# ../dataset_WaterClusters_big/N47-T200/0800.dat    Energy -3.622931
# ../dataset_WaterClusters_big/N47-T200/0900.dat    Energy -3.3971229999999997
# ../dataset_WaterClusters_big/N47-T200/0700.dat    Energy -3.116199
# ../dataset_WaterClusters_big/N47-T200/0550.dat    Energy -3.9565580000000002
# ../dataset_WaterClusters_big/N47-T200/1750.dat    Energy -4.612528
# ../dataset_WaterClusters_big/N47-T200/1300.dat    Energy -4.224068
# ../dataset_WaterClusters_big/N47-T200/0600.dat    Energy -3.9016629999999997
# ../dataset_WaterClusters_big/N47-T200/0650.dat    Energy -3.83917
# ../dataset_WaterClusters_big/N47-T200/1600.dat    Energy -3.5735669999999997
# ../dataset_WaterClusters_big/N47-T200/1050.dat    Energy -3.577897
# ../dataset_WaterClusters_big/N47-T200/0300.dat    Energy -3.899048
# ../dataset_WaterClusters_big/N47-T200/1400.dat    Energy -4.630099
# ../dataset_WaterClusters_big/N47-T200/1450.dat    Energy -3.816929
# ../dataset_WaterClusters_big/N47-T200/1200.dat    Energy -3.545088
# ../dataset_WaterClusters_big/N47-T200/0150.dat    Energy -4.027602
# ../dataset_WaterClusters_big/N47-T200/1150.dat    Energy -3.773229
# ../dataset_WaterClusters_big/N47-T200/0400.dat    Energy -3.9627280000000003
# ../dataset_WaterClusters_big/N47-T200/0050.dat    Energy -4.0159899999999995
# ../dataset_WaterClusters_big/N47-T200/0750.dat    Energy -3.1689879999999997
# ../dataset_WaterClusters_big/N47-T200/1000.dat    Energy -3.6112409999999997
# ../dataset_WaterClusters_big/N47-T200/1800.dat    Energy -4.358669
# ../dataset_WaterClusters_big/N47-T200/0200.dat    Energy -4.227732
# ../dataset_WaterClusters_big/N237-T100/0350.dat    Energy -11.93639
# ../dataset_WaterClusters_big/N237-T100/1700.dat    Energy -11.952963
# ../dataset_WaterClusters_big/N237-T100/0100.dat    Energy -10.759507
# ../dataset_WaterClusters_big/N237-T100/1550.dat    Energy -12.099289
# ../dataset_WaterClusters_big/N237-T100/1850.dat    Energy -11.243814
# ../dataset_WaterClusters_big/N237-T100/1100.dat    Energy -11.179566000000001
# ../dataset_WaterClusters_big/N237-T100/0450.dat    Energy -11.154949
# ../dataset_WaterClusters_big/N237-T100/0500.dat    Energy -10.961672
# ../dataset_WaterClusters_big/N237-T100/1350.dat    Energy -11.166599000000001
# ../dataset_WaterClusters_big/N237-T100/0850.dat    Energy -11.600527
# ../dataset_WaterClusters_big/N237-T100/1900.dat    Energy -11.296531
# ../dataset_WaterClusters_big/N237-T100/1650.dat    Energy -11.235578
# ../dataset_WaterClusters_big/N237-T100/0250.dat    Energy -11.098785
# ../dataset_WaterClusters_big/N237-T100/0950.dat    Energy -11.739958999999999
# ../dataset_WaterClusters_big/N237-T100/2000.dat    Energy -12.554002
# ../dataset_WaterClusters_big/N237-T100/1950.dat    Energy -12.01154
# ../dataset_WaterClusters_big/N237-T100/1500.dat    Energy -11.970657
# ../dataset_WaterClusters_big/N237-T100/1250.dat    Energy -10.351142000000001
# ../dataset_WaterClusters_big/N237-T100/0800.dat    Energy -12.784249
# ../dataset_WaterClusters_big/N237-T100/0900.dat    Energy -11.394034
# ../dataset_WaterClusters_big/N237-T100/0700.dat    Energy -11.216220999999999
# ../dataset_WaterClusters_big/N237-T100/0550.dat    Energy -11.068598999999999
# ../dataset_WaterClusters_big/N237-T100/1750.dat    Energy -11.192986000000001
# ../dataset_WaterClusters_big/N237-T100/1300.dat    Energy -10.530258
# ../dataset_WaterClusters_big/N237-T100/0600.dat    Energy -10.419914
# ../dataset_WaterClusters_big/N237-T100/0650.dat    Energy -11.131797
# ../dataset_WaterClusters_big/N237-T100/1600.dat    Energy -12.493474
# ../dataset_WaterClusters_big/N237-T100/1050.dat    Energy -11.248932
# ../dataset_WaterClusters_big/N237-T100/0300.dat    Energy -10.707237
# ../dataset_WaterClusters_big/N237-T100/1400.dat    Energy -11.451781
# ../dataset_WaterClusters_big/N237-T100/1450.dat    Energy -11.786765
# ../dataset_WaterClusters_big/N237-T100/1200.dat    Energy -11.301169
# ../dataset_WaterClusters_big/N237-T100/0150.dat    Energy -11.100919
# ../dataset_WaterClusters_big/N237-T100/1150.dat    Energy -11.38472
# ../dataset_WaterClusters_big/N237-T100/0400.dat    Energy -11.920596999999999
# ../dataset_WaterClusters_big/N237-T100/0050.dat    Energy -10.409547
# ../dataset_WaterClusters_big/N237-T100/0750.dat    Energy -10.397005
# ../dataset_WaterClusters_big/N237-T100/1000.dat    Energy -12.332994999999999
# ../dataset_WaterClusters_big/N237-T100/1800.dat    Energy -11.681707
# ../dataset_WaterClusters_big/N237-T100/0200.dat    Energy -10.488183
# ../dataset_WaterClusters_big/N76-T150/0350.dat    Energy -9.054172000000001
# ../dataset_WaterClusters_big/N76-T150/1700.dat    Energy -9.962783
# ../dataset_WaterClusters_big/N76-T150/0100.dat    Energy -7.637572
# ../dataset_WaterClusters_big/N76-T150/1550.dat    Energy -10.167566
# ../dataset_WaterClusters_big/N76-T150/1850.dat    Energy -9.079785999999999
# ../dataset_WaterClusters_big/N76-T150/1100.dat    Energy -7.770460999999999
# ../dataset_WaterClusters_big/N76-T150/0450.dat    Energy -6.807106999999999
# ../dataset_WaterClusters_big/N76-T150/0500.dat    Energy -7.9647239999999995
# ../dataset_WaterClusters_big/N76-T150/1350.dat    Energy -7.489679000000001
# ../dataset_WaterClusters_big/N76-T150/0850.dat    Energy -7.0502910000000005
# ../dataset_WaterClusters_big/N76-T150/1900.dat    Energy -8.332761
# ../dataset_WaterClusters_big/N76-T150/1650.dat    Energy -10.369168
# ../dataset_WaterClusters_big/N76-T150/0250.dat    Energy -8.970495
# ../dataset_WaterClusters_big/N76-T150/0950.dat    Energy -6.69348
# ../dataset_WaterClusters_big/N76-T150/2000.dat    Energy -10.431362
# ../dataset_WaterClusters_big/N76-T150/1950.dat    Energy -8.901213
# ../dataset_WaterClusters_big/N76-T150/1500.dat    Energy -9.325202
# ../dataset_WaterClusters_big/N76-T150/1250.dat    Energy -8.263511
# ../dataset_WaterClusters_big/N76-T150/0800.dat    Energy -7.565252
# ../dataset_WaterClusters_big/N76-T150/0900.dat    Energy -7.758138000000001
# ../dataset_WaterClusters_big/N76-T150/0700.dat    Energy -7.254645
# ../dataset_WaterClusters_big/N76-T150/0550.dat    Energy -8.673701000000001
# ../dataset_WaterClusters_big/N76-T150/1750.dat    Energy -8.892985000000001
# ../dataset_WaterClusters_big/N76-T150/1300.dat    Energy -8.215783
# ../dataset_WaterClusters_big/N76-T150/0600.dat    Energy -8.262322
# ../dataset_WaterClusters_big/N76-T150/0650.dat    Energy -7.4211849999999995
# ../dataset_WaterClusters_big/N76-T150/1600.dat    Energy -10.165792
# ../dataset_WaterClusters_big/N76-T150/1050.dat    Energy -7.586055
# ../dataset_WaterClusters_big/N76-T150/0300.dat    Energy -9.206967
# ../dataset_WaterClusters_big/N76-T150/1400.dat    Energy -7.348388
# ../dataset_WaterClusters_big/N76-T150/1450.dat    Energy -9.328627000000001
# ../dataset_WaterClusters_big/N76-T150/1200.dat    Energy -7.947403
# ../dataset_WaterClusters_big/N76-T150/0150.dat    Energy -8.525149
# ../dataset_WaterClusters_big/N76-T150/1150.dat    Energy -6.834113
# ../dataset_WaterClusters_big/N76-T150/0400.dat    Energy -8.848823
# ../dataset_WaterClusters_big/N76-T150/0050.dat    Energy -7.796819000000001
# ../dataset_WaterClusters_big/N76-T150/0750.dat    Energy -6.636913
# ../dataset_WaterClusters_big/N76-T150/1000.dat    Energy -7.059366000000001
# ../dataset_WaterClusters_big/N76-T150/1800.dat    Energy -9.057442
# ../dataset_WaterClusters_big/N76-T150/0200.dat    Energy -8.941799
# ../dataset_WaterClusters_big/N190-T50/0350.dat    Energy -10.879492
# ../dataset_WaterClusters_big/N190-T50/1700.dat    Energy -10.460655000000001
# ../dataset_WaterClusters_big/N190-T50/0100.dat    Energy -9.992483
# ../dataset_WaterClusters_big/N190-T50/1550.dat    Energy -10.48511
# ../dataset_WaterClusters_big/N190-T50/1850.dat    Energy -10.030567
# ../dataset_WaterClusters_big/N190-T50/1100.dat    Energy -10.176564
# ../dataset_WaterClusters_big/N190-T50/0450.dat    Energy -10.733864
# ../dataset_WaterClusters_big/N190-T50/0500.dat    Energy -10.990537999999999
# ../dataset_WaterClusters_big/N190-T50/1350.dat    Energy -11.354627
# ../dataset_WaterClusters_big/N190-T50/0850.dat    Energy -11.195806
# ../dataset_WaterClusters_big/N190-T50/1900.dat    Energy -9.797667
# ../dataset_WaterClusters_big/N190-T50/1650.dat    Energy -10.917333
# ../dataset_WaterClusters_big/N190-T50/0250.dat    Energy -11.051498
# ../dataset_WaterClusters_big/N190-T50/0950.dat    Energy -11.289119
# ../dataset_WaterClusters_big/N190-T50/2000.dat    Energy -10.89001
# ../dataset_WaterClusters_big/N190-T50/1950.dat    Energy -10.496780999999999
# ../dataset_WaterClusters_big/N190-T50/1500.dat    Energy -10.473965999999999
# ../dataset_WaterClusters_big/N190-T50/1250.dat    Energy -11.297853
# ../dataset_WaterClusters_big/N190-T50/0800.dat    Energy -10.31603
# ../dataset_WaterClusters_big/N190-T50/0900.dat    Energy -10.930842
# ../dataset_WaterClusters_big/N190-T50/0700.dat    Energy -9.916259
# ../dataset_WaterClusters_big/N190-T50/0550.dat    Energy -10.021061000000001
# ../dataset_WaterClusters_big/N190-T50/1750.dat    Energy -10.653339
# ../dataset_WaterClusters_big/N190-T50/1300.dat    Energy -9.962818
# ../dataset_WaterClusters_big/N190-T50/0600.dat    Energy -10.392061
# ../dataset_WaterClusters_big/N190-T50/0650.dat    Energy -11.124680000000001
# ../dataset_WaterClusters_big/N190-T50/1600.dat    Energy -10.596378
# ../dataset_WaterClusters_big/N190-T50/1050.dat    Energy -9.834534
# ../dataset_WaterClusters_big/N190-T50/0300.dat    Energy -10.500076
# ../dataset_WaterClusters_big/N190-T50/1400.dat    Energy -10.228516
# ../dataset_WaterClusters_big/N190-T50/1450.dat    Energy -10.10683
# ../dataset_WaterClusters_big/N190-T50/1200.dat    Energy -10.227955
# ../dataset_WaterClusters_big/N190-T50/0150.dat    Energy -10.085714
# ../dataset_WaterClusters_big/N190-T50/1150.dat    Energy -10.146108
# ../dataset_WaterClusters_big/N190-T50/0400.dat    Energy -10.945086
# ../dataset_WaterClusters_big/N190-T50/0050.dat    Energy -10.718651999999999
# ../dataset_WaterClusters_big/N190-T50/0750.dat    Energy -10.495698
# ../dataset_WaterClusters_big/N190-T50/1000.dat    Energy -10.485621
# ../dataset_WaterClusters_big/N190-T50/1800.dat    Energy -10.715663000000001
# ../dataset_WaterClusters_big/N190-T50/0200.dat    Energy -10.342863
# ../dataset_WaterClusters_big/N76-T200/0350.dat    Energy -9.407459
# ../dataset_WaterClusters_big/N76-T200/1700.dat    Energy -8.177313
# ../dataset_WaterClusters_big/N76-T200/0100.dat    Energy -9.872622
# ../dataset_WaterClusters_big/N76-T200/1550.dat    Energy -10.927731
# ../dataset_WaterClusters_big/N76-T200/1850.dat    Energy -9.405904
# ../dataset_WaterClusters_big/N76-T200/1100.dat    Energy -9.520426
# ../dataset_WaterClusters_big/N76-T200/0450.dat    Energy -10.147518
# ../dataset_WaterClusters_big/N76-T200/0500.dat    Energy -8.771732
# ../dataset_WaterClusters_big/N76-T200/1350.dat    Energy -8.250409
# ../dataset_WaterClusters_big/N76-T200/0850.dat    Energy -11.243525
# ../dataset_WaterClusters_big/N76-T200/1900.dat    Energy -9.412437
# ../dataset_WaterClusters_big/N76-T200/1650.dat    Energy -9.684618
# ../dataset_WaterClusters_big/N76-T200/0250.dat    Energy -9.500018
# ../dataset_WaterClusters_big/N76-T200/0950.dat    Energy -8.395723
# ../dataset_WaterClusters_big/N76-T200/2000.dat    Energy -10.932095
# ../dataset_WaterClusters_big/N76-T200/1950.dat    Energy -8.296353
# ../dataset_WaterClusters_big/N76-T200/1500.dat    Energy -9.930306999999999
# ../dataset_WaterClusters_big/N76-T200/1250.dat    Energy -8.331138000000001
# ../dataset_WaterClusters_big/N76-T200/0800.dat    Energy -10.693558
# ../dataset_WaterClusters_big/N76-T200/0900.dat    Energy -8.633359
# ../dataset_WaterClusters_big/N76-T200/0700.dat    Energy -10.362758
# ../dataset_WaterClusters_big/N76-T200/0550.dat    Energy -9.884742000000001
# ../dataset_WaterClusters_big/N76-T200/1750.dat    Energy -8.726395
# ../dataset_WaterClusters_big/N76-T200/1300.dat    Energy -9.328465
# ../dataset_WaterClusters_big/N76-T200/0600.dat    Energy -10.229402
# ../dataset_WaterClusters_big/N76-T200/0650.dat    Energy -10.079884
# ../dataset_WaterClusters_big/N76-T200/1600.dat    Energy -8.970034
# ../dataset_WaterClusters_big/N76-T200/1050.dat    Energy -9.016903
# ../dataset_WaterClusters_big/N76-T200/0300.dat    Energy -10.053328
# ../dataset_WaterClusters_big/N76-T200/1400.dat    Energy -9.157938
# ../dataset_WaterClusters_big/N76-T200/1450.dat    Energy -8.744976
# ../dataset_WaterClusters_big/N76-T200/1200.dat    Energy -9.474029999999999
# ../dataset_WaterClusters_big/N76-T200/0150.dat    Energy -11.334985
# ../dataset_WaterClusters_big/N76-T200/1150.dat    Energy -9.216746
# ../dataset_WaterClusters_big/N76-T200/0400.dat    Energy -10.506889
# ../dataset_WaterClusters_big/N76-T200/0050.dat    Energy -9.419894
# ../dataset_WaterClusters_big/N76-T200/0750.dat    Energy -10.519409
# ../dataset_WaterClusters_big/N76-T200/1000.dat    Energy -8.986178
# ../dataset_WaterClusters_big/N76-T200/1800.dat    Energy -8.574932
# ../dataset_WaterClusters_big/N76-T200/0200.dat    Energy -10.520845

# %%
################################################################################
# Build model
################################################################################
class Net(Model):
    def __init__(self):
        super().__init__()
        #self.conv1 = ECCConv(32, activation="relu")
        #self.conv2 = ECCConv(32, activation="relu")
        #self.conv1 = GCSConv(32, activation="relu")
        #self.conv2 = GCSConv(32, activation="relu")
        #self.conv1 = GCSConv(64, activation="tanh")
        #self.conv2 = GCSConv(64, activation="tanh")
        #self.conv3 = GCSConv(64, activation="tanh")
        self.conv1 = CrystalConv(aggregate="sum",activation="sigmoid")
        self.conv2 = CrystalConv(aggregate="sum",activation="sigmoid")
        #self.conv1 = GATConv(8,attn_heads=7,dropout_rate=0)
        #self.conv2 = GATConv(8,attn_heads=7,dropout_rate=0)
        self.global_pool = GlobalSumPool()
        self.dense1 = Dense(128)
        self.dense2 = Dense(128)
        #self.dense3 = Dense(128)
        self.dense = Dense(n_out)

    def call(self, inputs):
        x, a, e, i = inputs
        x = self.conv1([x, a, e])
        x = self.conv2([x, a, e])
        #x, a, i = inputs
        #x = self.conv1([x, a])
        #x = self.conv2([x, a])
        #x = self.conv3([x, a])
        output = self.global_pool([x, i])
        output = self.dense1(output)
        output = self.dense2(output)
        #output = self.dense3(output)
        output = self.dense(output)

        return output

model = Net()
optimizer = Adam(learning_rate)
loss_fn = MeanSquaredError()
#loss_fn = MeanAbsoluteError()
#loss_fn = MeanAbsolutePercentageError()

# %%
################################################################################
# Fit model
################################################################################
@tf.function(input_signature=loader_tr.tf_signature(), experimental_relax_shapes=True)
def train_step(inputs, target):
    with tf.GradientTape() as tape:
        predictions = model(inputs, training=True)
        loss = loss_fn(target, predictions) + sum(model.losses)
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    return loss

outfile = open("loss.dat",'w')
nepoch = 1
step = loss = 0
loss_train = []
#loss_test = []
#loss_te = 0
for batch in loader_tr:
    step += 1
    loss += train_step(*batch)
    if step == loader_tr.steps_per_epoch:
        step = 0
        print(str(nepoch)+" Loss: {}".format(loss / loader_tr.steps_per_epoch))
        outfile.write(str(nepoch)+" {}".format(loss / loader_tr.steps_per_epoch)+" \n")
        loss_train.append(loss / loader_tr.steps_per_epoch)
        nepoch = nepoch + 1

        # log the loss into wandb
        #wandb.log({"loss": loss / loader_tr.steps_per_epoch})
        
        loss = 0

        """
        # Loss on test set
        batch_te = next(iter(loader_te))
        inputs, target = batch_te
        predictions = model(inputs, training=False)
        #loss_te += loss_fn(target, predictions)
        loss_te = loss_fn(target, predictions)
        #loss_te /= loader_te.steps_per_epoch
        loss_test.append(loss_te)
        #loss_te = 0
        """

outfile.close()

# Plot Loss Function on Training Set
plt.figure(figsize=(6,4))
plt.scatter(range(1,epochs+1),loss_train)
plt.plot(range(1,epochs+1),loss_train,ls="--")
plt.xlabel("Epochs")
plt.ylabel("Loss (MSE)")
plt.show()

"""
# Plot Loss Function on Test Set
plt.figure(figsize=(6,4))
plt.scatter(range(1,epochs+1),loss_test)
plt.plot(range(1,epochs+1),loss_test,ls="--")
plt.xlabel("Epochs")
plt.ylabel("Loss (MSE)")
plt.show()
"""
# Out:
# /home/alfonso/Work/UGR/Calculations/WaterClusters_GNNs/GNNs_WaterClusters_venv/lib/python3.10/site-packages/spektral/data/utils.py:221: UserWarning: you are shuffling a 'MyDataset' object which is not a subclass of 'Sequence'; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   np.random.shuffle(a)
# /home/alfonso/Work/UGR/Calculations/WaterClusters_GNNs/GNNs_WaterClusters_venv/lib/python3.10/site-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer GlorotUniform is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# 1 Loss: 211.2000274658203
# 2 Loss: 10.425651550292969
# 3 Loss: 10.425642013549805
# 4 Loss: 10.425639152526855
# 5 Loss: 10.425649642944336
# 6 Loss: 10.425651550292969
# 7 Loss: 10.425651550292969
# 8 Loss: 10.425641059875488
# 9 Loss: 10.425646781921387
# 10 Loss: 10.425640106201172
# 11 Loss: 10.42565631866455
# 12 Loss: 10.425647735595703
# 13 Loss: 10.42564582824707
# 14 Loss: 10.425639152526855
# 15 Loss: 10.425642967224121
# 16 Loss: 10.42564868927002
# 17 Loss: 10.425644874572754
# 18 Loss: 10.425642013549805
# 19 Loss: 10.425633430480957
# 20 Loss: 10.425640106201172
# 21 Loss: 10.425651550292969
# 22 Loss: 10.425642967224121
# 23 Loss: 10.425640106201172
# 24 Loss: 10.425643920898438
# 25 Loss: 10.425641059875488
# 26 Loss: 10.425644874572754
# 27 Loss: 10.425641059875488
# 28 Loss: 10.42564868927002
# 29 Loss: 10.425642967224121
# 30 Loss: 10.425646781921387
# 31 Loss: 10.425660133361816
# 32 Loss: 10.425642967224121
# 33 Loss: 10.425647735595703
# 34 Loss: 10.42564868927002
# 35 Loss: 10.425647735595703
# 36 Loss: 10.425646781921387
# 37 Loss: 10.425649642944336
# 38 Loss: 10.425651550292969
# 39 Loss: 10.425637245178223
# 40 Loss: 10.425650596618652
# 41 Loss: 10.425637245178223
# 42 Loss: 10.42564868927002
# 43 Loss: 10.425644874572754
# 44 Loss: 10.425642013549805
# 45 Loss: 10.425644874572754
# 46 Loss: 10.425642013549805
# 47 Loss: 10.42564582824707
# 48 Loss: 10.42564868927002
# 49 Loss: 10.425639152526855
# 50 Loss: 10.425649642944336
# 51 Loss: 10.425642967224121
# 52 Loss: 10.425638198852539
# 53 Loss: 10.425643920898438
# 54 Loss: 10.425637245178223
# 55 Loss: 10.42564582824707
# 56 Loss: 10.425652503967285
# 57 Loss: 10.425642013549805
# 58 Loss: 10.425649642944336
# 59 Loss: 10.425644874572754
# 60 Loss: 10.425639152526855
# 61 Loss: 10.425642967224121
# 62 Loss: 10.425647735595703
# 63 Loss: 10.425640106201172
# 64 Loss: 10.425639152526855
# 65 Loss: 10.425639152526855
# 66 Loss: 10.425641059875488
# 67 Loss: 10.425644874572754
# 68 Loss: 10.425646781921387
# 69 Loss: 10.425653457641602
# 70 Loss: 10.42563533782959
# 71 Loss: 10.425646781921387
# 72 Loss: 10.425638198852539
# 73 Loss: 10.425639152526855
# 74 Loss: 10.425640106201172
# 75 Loss: 10.425641059875488
# 76 Loss: 10.425644874572754
# 77 Loss: 10.42564582824707
# 78 Loss: 10.425637245178223
# 79 Loss: 10.42564582824707
# 80 Loss: 10.42564582824707
# 81 Loss: 10.425641059875488
# 82 Loss: 10.425644874572754
# 83 Loss: 10.425640106201172
# 84 Loss: 10.425650596618652
# 85 Loss: 10.42564582824707
# 86 Loss: 10.425642013549805
# 87 Loss: 10.425646781921387
# 88 Loss: 10.425646781921387
# 89 Loss: 10.425637245178223
# 90 Loss: 10.425642967224121
# 91 Loss: 10.42563533782959
# 92 Loss: 10.425636291503906
# 93 Loss: 10.425643920898438
# 94 Loss: 10.425642013549805
# 95 Loss: 10.425646781921387
# 96 Loss: 10.425643920898438
# 97 Loss: 10.42564582824707
# 98 Loss: 10.425646781921387
# 99 Loss: 10.42564868927002
# 100 Loss: 10.425639152526855
# 101 Loss: 10.425644874572754
# 102 Loss: 10.42564868927002
# 103 Loss: 10.425650596618652
# 104 Loss: 10.425642967224121
# 105 Loss: 10.42564582824707
# 106 Loss: 10.425649642944336
# 107 Loss: 10.425644874572754
# 108 Loss: 10.425637245178223
# 109 Loss: 10.425644874572754
# 110 Loss: 10.425649642944336
# 111 Loss: 10.425643920898438
# 112 Loss: 10.425651550292969
# 113 Loss: 10.42564868927002
# 114 Loss: 10.425647735595703
# 115 Loss: 10.425650596618652
# 116 Loss: 10.42564582824707
# 117 Loss: 10.425649642944336
# 118 Loss: 10.425644874572754
# 119 Loss: 10.42564868927002
# 120 Loss: 10.42564582824707
# 121 Loss: 10.425653457641602
# 122 Loss: 10.425653457641602
# 123 Loss: 10.425639152526855
# 124 Loss: 10.425644874572754
# 125 Loss: 10.425642013549805
# 126 Loss: 10.425641059875488
# 127 Loss: 10.425650596618652
# 128 Loss: 10.42564582824707
# 129 Loss: 10.425641059875488
# 130 Loss: 10.425643920898438
# 131 Loss: 10.42564868927002
# 132 Loss: 10.425650596618652
# 133 Loss: 10.42564582824707
# 134 Loss: 10.425639152526855
# 135 Loss: 10.425642013549805
# 136 Loss: 10.425639152526855
# 137 Loss: 10.42564582824707
# 138 Loss: 10.425642013549805
# 139 Loss: 10.425639152526855
# 140 Loss: 10.425647735595703
# 141 Loss: 10.425642967224121
# 142 Loss: 10.425646781921387
# 143 Loss: 10.425643920898438
# 144 Loss: 10.425642967224121
# 145 Loss: 10.42563247680664
# 146 Loss: 10.425642967224121
# 147 Loss: 10.42565631866455
# 148 Loss: 10.425649642944336
# 149 Loss: 10.425646781921387
# 150 Loss: 10.425643920898438
# 151 Loss: 10.42565631866455
# 152 Loss: 10.425643920898438
# 153 Loss: 10.425642967224121
# 154 Loss: 10.425642967224121
# 155 Loss: 10.425642967224121
# 156 Loss: 10.425643920898438
# 157 Loss: 10.42564868927002
# 158 Loss: 10.425639152526855
# 159 Loss: 10.425642013549805
# 160 Loss: 10.425652503967285
# 161 Loss: 10.425642013549805
# 162 Loss: 10.425650596618652
# 163 Loss: 10.425650596618652
# 164 Loss: 10.425653457641602
# 165 Loss: 10.425653457641602
# 166 Loss: 10.425642967224121
# 167 Loss: 10.42564868927002
# 168 Loss: 10.425644874572754
# 169 Loss: 10.425652503967285
# 170 Loss: 10.425650596618652
# 171 Loss: 10.425651550292969
# 172 Loss: 10.425642013549805
# 173 Loss: 10.425642013549805
# 174 Loss: 10.425644874572754
# 175 Loss: 10.425647735595703
# 176 Loss: 10.425641059875488
# 177 Loss: 10.425637245178223
# 178 Loss: 10.425644874572754
# 179 Loss: 10.425642013549805
# 180 Loss: 10.425640106201172
# 181 Loss: 10.425650596618652
# 182 Loss: 10.425640106201172
# 183 Loss: 10.425639152526855
# 184 Loss: 10.425643920898438
# 185 Loss: 10.425634384155273
# 186 Loss: 10.425651550292969
# 187 Loss: 10.425642013549805
# 188 Loss: 10.42564868927002
# 189 Loss: 10.425634384155273
# 190 Loss: 10.425642967224121
# 191 Loss: 10.425642013549805
# 192 Loss: 10.425646781921387
# 193 Loss: 10.425642013549805
# 194 Loss: 10.425647735595703
# 195 Loss: 10.425641059875488
# 196 Loss: 10.42564868927002
# 197 Loss: 10.425643920898438
# 198 Loss: 10.425655364990234
# 199 Loss: 10.42564582824707
# 200 Loss: 10.425640106201172
# '\n# Plot Loss Function on Test Set\nplt.figure(figsize=(6,4))\nplt.scatter(range(1,epochs+1),loss_test)\nplt.plot(range(1,epochs+1),loss_test,ls="--")\nplt.xlabel("Epochs")\nplt.ylabel("Loss (MSE)")\nplt.show()\n'

# %%
# Plot Loss Function on Training Set
plt.figure(figsize=(6,4))
plt.scatter(range(1,epochs+1),loss_train)
plt.plot(range(1,epochs+1),loss_train,ls="--")
plt.xlabel("Epochs")
plt.ylabel("Loss (MSE)")
ymedian = np.median(loss_train)
#plt.xlim(0,200)
plt.ylim(0,ymedian*5)
plt.show()

# %%
################################################################################
# Evaluate model
################################################################################

# Loss on Test Set. Predicted vs Real energies
print("Testing model")
loss = 0
ypred = []
ytrue = []
for batch in loader_te:
    inputs, target = batch
    predictions = model(inputs, training=False)
    loss += loss_fn(target, predictions)
    ypred.append(predictions)
    ytrue.append(target)
loss /= loader_te.steps_per_epoch
print("Done. Test loss: {}".format(loss))
# Out:
# Testing model
# Done. Test loss: 10.48144245147705

# %%
# Plot Predicted vs Real on Test Set

y_pred = np.array(ypred).ravel()
y_true = np.array(ytrue).ravel()

# Convert to original units
#y_pred = np.array(ypred).ravel()#/100
#y_true = np.array(ytrue).ravel()#/100

#E_avrg = -0.025591339035879856
#E_dev = 2.0321151163332116
#y_pred = np.array(ypred).ravel()*E_dev + E_avrg
#y_true = np.array(ytrue).ravel()*E_dev + E_avrg

plt.figure(figsize=(6,4))
plt.scatter(y_true,y_pred,label = "GNN model",color="red")
p1 = max(max(y_pred), max(y_true))
p2 = min(min(y_pred), min(y_true))
plt.plot([p1, p2], [p1, p2], 'b-')
#plt.plot(np.linspace(-0.2,0.1,50),np.linspace(-0.2,0.1,50))
plt.xlabel("True Electronic Energy")
plt.ylabel("Pred Electronic Energy")
#plt.xlim(-5,0)
#plt.ylim(-5,0)
plt.title("Test Set")
plt.show()

# mean absolute percentage error (MAPE)
def mape(ytrue, ypred):
    ytrue, ypred = np.array(ytrue), np.array(ypred)
    
    mape_i = np.zeros(len(ytrue))
    mape_i = np.abs((ypred-ytrue)/ytrue)*100
    mape_i = mape_i[ mape_i < 1e6]

    return np.mean(mape_i)

# Compute metrics (MAPE, MAE, MSE)
print("Test MAE:", mean_absolute_error(y_true,y_pred))
print("Test MSE:", mean_squared_error(y_true,y_pred))
print("Test MAPE:", mape(y_true,y_pred))
# Out:
# Test MAE: 2.8194946474278866
# Test MSE: 10.481442448476027
# Test MAPE: 35.13741157735678
