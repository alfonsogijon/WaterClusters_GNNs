# %%
"""
This example shows how to perform regression of molecular properties with a
database of the atomic geometry of water clusters with an associated energy, 
using a simple GNN in disjoint mode.
"""

import numpy as np
import scipy.sparse as sp
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.losses import MeanAbsoluteError
from tensorflow.keras.losses import MeanAbsolutePercentageError
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Install matplotlib inside the virtual env
#import pip
#pip.main(["install","matplotlib"])
import matplotlib.pyplot as plt

from spektral.data import Dataset, DisjointLoader, Graph
from spektral.datasets import QM9
from spektral.layers import GCSConv, ECCConv, GlobalSumPool, MessagePassing, GATConv, CrystalConv

#from spektral.utils import normalized_adjacency

# %%
################################################################################
# Config
################################################################################
learning_rate = 1e-3  # Learning rate
#learning_rate = 1e-4  # Learning rate
epochs = 200  # Number of training epochs
batch_size = 1  # Batch size

#initial_learning_rate = 1e-3
#learning_rate = tf.keras.optimizers.schedules.InverseTimeDecay(initial_learning_rate=initial_learning_rate, decay_steps=epochs/10, decay_rate=0.8)
#learning_rate = tf.keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=initial_learning_rate,
#                decay_steps=epochs/10, decay_rate=0.8)

"""
learning_rate = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=learning_rate_initial,
    decay_steps=epochs,
    decay_rate=0.98)
"""
# Out:
# '\nlearning_rate = tf.keras.optimizers.schedules.ExponentialDecay(\n    initial_learning_rate=learning_rate_initial,\n    decay_steps=epochs,\n    decay_rate=0.98)\n'

# %%
################################################################################
# Load data and make graphs
################################################################################
class MyDataset(Dataset):
    """
    A dataset of graphs obtained from the atomic positions of water
    clusters with size between 20 and 237 water molecules, each of them
    associated to an energy value.
    """

    def __init__(self, r2_cutoff, n_dim = 3, **kwargs):

        self.r2_cutoff = r2_cutoff
        self.n_dim = n_dim

        # path of the atomic geometry files
        self.geometry_paths = []
        data_dir = "../dataset_WaterClusters_big/"
        #data_dir = "../dataset_WaterClusters/"
        #for N in [20,32,47,76,100,139,190,237]:
            #for temp in [100,150,200]:
                #for MDstep in ["0500.dat","1000.dat","1500.dat","2000.dat"]:
                    #geometry_path = data_dir+"N"+str(N)+"-T"+str(temp)+"/"+str(MDstep)
                    #self.geometry_paths.append(geometry_path)
        for folder in os.listdir(data_dir): 
            dir_name = os.path.join(data_dir,folder)
            for file_name in os.listdir(dir_name):
                geometry_path = os.path.join(dir_name,file_name)
                self.geometry_paths.append(geometry_path)

        self.n_samples = len(self.geometry_paths)

        self.Epm_avrg = 0.0
        self.Epm_dev = 0.0
        self.E_avrg = 0.0
        self.E_dev = 0.0
        self.xmax = 22.0

        self.num_node_features = 0
        self.num_edge_features = 0
        self.num_labels = 0
        
        super().__init__(**kwargs)

    def read(self):

        def compute_Eavrg():

            # Compute the average energy per molecule among all the clusters

            Epm_avrg = 0.0
            E_avrg = 0.0
            
            for ii in range(self.n_samples):
            
                geom_path = self.geometry_paths[ii]
                gfile = open(geom_path,'r')
                line = gfile.readline()
                n_molecules = int(gfile.readline())
                line = gfile.readline()
                line = gfile.readline()
                line = gfile.readline()
                columns = line.split()
                energy = float(columns[0])
                gfile.close()

                Epm_avrg = Epm_avrg + energy / float(n_molecules)
                E_avrg = E_avrg + energy

            Epm_avrg = Epm_avrg / float(self.n_samples)
            E_avrg = E_avrg / float(self.n_samples)

            self.Epm_avrg = Epm_avrg
            self.E_avrg = E_avrg

            print("E_avrg: "+str(E_avrg))

        def compute_Edev():

            # Compute standard deviation from Epm_avrg

            Epm_dev = 0.0
            E_dev = 0.0

            for ii in range(self.n_samples):
            
                geom_path = self.geometry_paths[ii]
                gfile = open(geom_path,'r')
                line = gfile.readline()
                n_molecules = int(gfile.readline())
                line = gfile.readline()
                line = gfile.readline()
                line = gfile.readline()
                columns = line.split()
                energy = float(columns[0])
                gfile.close()

                Epm_dev = Epm_dev + ( energy / float(n_molecules) - self.Epm_avrg )**2
                E_dev = E_dev + ( energy - self.E_avrg )**2

            Epm_dev = np.sqrt( Epm_dev / float(self.n_samples) )
            E_dev = np.sqrt( E_dev / float(self.n_samples) )

            self.Epm_dev = Epm_dev
            self.E_dev = E_dev

            print("E_dev: "+str(E_dev))
            
        def make_graph(isample):

            # Process the header of the geometry file
            geom_path = self.geometry_paths[isample]
            gfile = open(geom_path,'r')
            line = gfile.readline()
            n_molecules = int(gfile.readline())
            line = gfile.readline()
            line = gfile.readline()
            line = gfile.readline()
            columns = line.split()
            energy = float(columns[0])
            line = gfile.readline()
            line = gfile.readline()            

            # Node features (atom type and position [x,y,z])            
            n_nodes = 3*n_molecules
            #num_node_features = 1 + self.n_dim
            num_abstract_features = 0
            num_node_features = 1 + num_abstract_features
            self.num_node_features = num_node_features
            x = np.zeros((n_nodes, num_node_features))
            pos = np.zeros((n_nodes, 3))
            for inode in range(n_nodes):
                line = gfile.readline()
                columns = line.split()
                if (inode%3==0):
                    x[inode,0] = 1.0    # oxygen atom
                else:
                    x[inode,0] = 0.0    # hydrogen atom
                pos[inode,0:] = columns[1:]
                #x[inode,1:] = pos[inode,0:]
                #x[inode,1:] = x[inode,1:] / float(self.xmax)
                #x[inode,1:] = np.random.random(num_abstract_features)
            gfile.close()                

            # Binary Adjacency matrix (two nodes/atoms are connected if rij2 < r2_cutoff)
            a = np.zeros((n_nodes,n_nodes))
            n_edges = 0
            for iatom in range(3*n_molecules):
                for jatom in range(iatom+1,3*n_molecules):
                    rij = pos[iatom,0:] - pos[jatom,0:]
                    r2 = np.dot(rij,rij)
                    if (r2 <= self.r2_cutoff):
                        #print(iatom,jatom,r2)                        
                        #a[iatom,jatom] = np.sqrt(r2)
                        a[iatom,jatom] = 1
                        n_edges = n_edges + 1            
            a = np.maximum(a, a.T)#.astype(int) # Adjacency matrix is symetric in this case
            a = sp.csr_matrix(a)
            #a = normalized_adjacency(a, symmetric=True)

            # Edge features (type of bonding: O-O, H-O, H-H)
            n_edges = n_edges*2
            num_abstract_features = 0
            num_edge_features = 1 + num_abstract_features
            self.num_edge_features = num_edge_features
            e = np.zeros((n_edges,num_edge_features))
            id_edge = 0
            for iatom in range(3*n_molecules):
                for jatom in range(3*n_molecules):
                    if(iatom!=jatom):
                        rij = pos[iatom,0:] - pos[jatom,0:]
                        r2 = np.dot(rij,rij)
                        if (r2 <= self.r2_cutoff):
                            #print(iatom,jatom,r2)                        
                            e[id_edge,0] = np.sqrt(r2)
                            #e[id_edge,1:] = np.random.random(num_abstract_features)
                            id_edge = id_edge + 1
            
            # Labels
            num_labels = 1
            self.num_labels = num_labels
            y = np.zeros(num_labels,)
            y[0,] = energy
            #y[0,] = ( energy / float(n_molecules) - self.Epm_avrg ) / self.Epm_avrg
            #y[0,] = ( energy / float(n_molecules) - self.Epm_avrg ) / self.Epm_dev
            #y[0,] = ( energy - self.E_avrg ) / self.E_dev
            #y[0,] = energy - self.E_avrg
            #y[0,] = ( energy - self.E_avrg ) / self.E_dev * 100
            #y[0,] = energy * 100

            print(str(geom_path)+"    Energy "+str(y[0,]))
            
            return Graph(x=x, a=a, e=e, y=y)

        # Compute average of the energy per molecule
        compute_Eavrg()
        compute_Edev()
        # We must return a list of Graph objects
        return [make_graph(isample) for isample in range(self.n_samples)]        

# Generate dataset from atomic geometry files
#d2_cutoff = 20.0
d2_cutoff = 10.0            
dataset = MyDataset( d2_cutoff )

# Parameters

F = dataset.num_node_features  # Dimension of node features
S = dataset.num_edge_features  # Dimension of edge features
n_out = dataset.num_labels  # Dimension of the target

# Train/test split
idxs = np.random.permutation(len(dataset))
split = int(0.8 * len(dataset))
idx_tr, idx_te = np.split(idxs, [split])
dataset_tr, dataset_te = dataset[idx_tr], dataset[idx_te]

loader_tr = DisjointLoader(dataset_tr, batch_size=batch_size, epochs=epochs)
loader_te = DisjointLoader(dataset_te, batch_size=batch_size, epochs=1)
# we set epochs=epochs within loader_te to check loss on test set
#loader_te = DisjointLoader(dataset_te, batch_size=batch_size, epochs=epochs+1)
# Out:
# E_avrg: -1.678857124507812
# E_dev: 1.2688447356520496
# ../dataset_WaterClusters_big/N20-T150/0350.dat    Energy -0.24305615
# ../dataset_WaterClusters_big/N20-T150/1700.dat    Energy -0.25697191
# ../dataset_WaterClusters_big/N20-T150/0100.dat    Energy -0.2451
# ../dataset_WaterClusters_big/N20-T150/1550.dat    Energy -0.25697741
# ../dataset_WaterClusters_big/N20-T150/1850.dat    Energy -0.2676109
# ../dataset_WaterClusters_big/N20-T150/1100.dat    Energy -0.24883782
# ../dataset_WaterClusters_big/N20-T150/0450.dat    Energy -0.25257631
# ../dataset_WaterClusters_big/N20-T150/0500.dat    Energy -0.25955347
# ../dataset_WaterClusters_big/N20-T150/1350.dat    Energy -0.24205364
# ../dataset_WaterClusters_big/N20-T150/0850.dat    Energy -0.26418391
# ../dataset_WaterClusters_big/N20-T150/1900.dat    Energy -0.25505501
# ../dataset_WaterClusters_big/N20-T150/1650.dat    Energy -0.25008463
# ../dataset_WaterClusters_big/N20-T150/0250.dat    Energy -0.25938082
# ../dataset_WaterClusters_big/N20-T150/0950.dat    Energy -0.25628299
# ../dataset_WaterClusters_big/N20-T150/2000.dat    Energy -0.25603255
# ../dataset_WaterClusters_big/N20-T150/1950.dat    Energy -0.2597252
# ../dataset_WaterClusters_big/N20-T150/1500.dat    Energy -0.25106678
# ../dataset_WaterClusters_big/N20-T150/1250.dat    Energy -0.24843536
# ../dataset_WaterClusters_big/N20-T150/0800.dat    Energy -0.25251794
# ../dataset_WaterClusters_big/N20-T150/0900.dat    Energy -0.2603775
# ../dataset_WaterClusters_big/N20-T150/0700.dat    Energy -0.24150352
# ../dataset_WaterClusters_big/N20-T150/0550.dat    Energy -0.25679607
# ../dataset_WaterClusters_big/N20-T150/1750.dat    Energy -0.24581296
# ../dataset_WaterClusters_big/N20-T150/1300.dat    Energy -0.25269523
# ../dataset_WaterClusters_big/N20-T150/0600.dat    Energy -0.25965089
# ../dataset_WaterClusters_big/N20-T150/0650.dat    Energy -0.24904017
# ../dataset_WaterClusters_big/N20-T150/1600.dat    Energy -0.24904696
# ../dataset_WaterClusters_big/N20-T150/1050.dat    Energy -0.24719667
# ../dataset_WaterClusters_big/N20-T150/0300.dat    Energy -0.25094623
# ../dataset_WaterClusters_big/N20-T150/1400.dat    Energy -0.25812757
# ../dataset_WaterClusters_big/N20-T150/1450.dat    Energy -0.25009167
# ../dataset_WaterClusters_big/N20-T150/1200.dat    Energy -0.24777648
# ../dataset_WaterClusters_big/N20-T150/0150.dat    Energy -0.25063647
# ../dataset_WaterClusters_big/N20-T150/1150.dat    Energy -0.2497198
# ../dataset_WaterClusters_big/N20-T150/0400.dat    Energy -0.25993693
# ../dataset_WaterClusters_big/N20-T150/0050.dat    Energy -0.24732996
# ../dataset_WaterClusters_big/N20-T150/0750.dat    Energy -0.26116447
# ../dataset_WaterClusters_big/N20-T150/1000.dat    Energy -0.24915115
# ../dataset_WaterClusters_big/N20-T150/1800.dat    Energy -0.25376377
# ../dataset_WaterClusters_big/N20-T150/0200.dat    Energy -0.25143999
# ../dataset_WaterClusters_big/N32-T150/0350.dat    Energy -0.4065278
# ../dataset_WaterClusters_big/N32-T150/1700.dat    Energy -0.38752475
# ../dataset_WaterClusters_big/N32-T150/0100.dat    Energy -0.39503817
# ../dataset_WaterClusters_big/N32-T150/1550.dat    Energy -0.41008177
# ../dataset_WaterClusters_big/N32-T150/1850.dat    Energy -0.38673513
# ../dataset_WaterClusters_big/N32-T150/1100.dat    Energy -0.4026688
# ../dataset_WaterClusters_big/N32-T150/0450.dat    Energy -0.40816788
# ../dataset_WaterClusters_big/N32-T150/0500.dat    Energy -0.40419989
# ../dataset_WaterClusters_big/N32-T150/1350.dat    Energy -0.39905179
# ../dataset_WaterClusters_big/N32-T150/0850.dat    Energy -0.38583161
# ../dataset_WaterClusters_big/N32-T150/1900.dat    Energy -0.39810479
# ../dataset_WaterClusters_big/N32-T150/1650.dat    Energy -0.39387813
# ../dataset_WaterClusters_big/N32-T150/0250.dat    Energy -0.38731454
# ../dataset_WaterClusters_big/N32-T150/0950.dat    Energy -0.39903241
# ../dataset_WaterClusters_big/N32-T150/2000.dat    Energy -0.38739953
# ../dataset_WaterClusters_big/N32-T150/1950.dat    Energy -0.39439704
# ../dataset_WaterClusters_big/N32-T150/1500.dat    Energy -0.41271231
# ../dataset_WaterClusters_big/N32-T150/1250.dat    Energy -0.42354643
# ../dataset_WaterClusters_big/N32-T150/0800.dat    Energy -0.37805349
# ../dataset_WaterClusters_big/N32-T150/0900.dat    Energy -0.39075818
# ../dataset_WaterClusters_big/N32-T150/0700.dat    Energy -0.40816523
# ../dataset_WaterClusters_big/N32-T150/0550.dat    Energy -0.40664633
# ../dataset_WaterClusters_big/N32-T150/1750.dat    Energy -0.40173972
# ../dataset_WaterClusters_big/N32-T150/1300.dat    Energy -0.39584135
# ../dataset_WaterClusters_big/N32-T150/0600.dat    Energy -0.38042551
# ../dataset_WaterClusters_big/N32-T150/0650.dat    Energy -0.39295296
# ../dataset_WaterClusters_big/N32-T150/1600.dat    Energy -0.397362
# ../dataset_WaterClusters_big/N32-T150/1050.dat    Energy -0.40597503
# ../dataset_WaterClusters_big/N32-T150/0300.dat    Energy -0.39425152
# ../dataset_WaterClusters_big/N32-T150/1400.dat    Energy -0.39424768
# ../dataset_WaterClusters_big/N32-T150/1450.dat    Energy -0.40216228
# ../dataset_WaterClusters_big/N32-T150/1200.dat    Energy -0.3976752
# ../dataset_WaterClusters_big/N32-T150/0150.dat    Energy -0.39320954
# ../dataset_WaterClusters_big/N32-T150/1150.dat    Energy -0.39407237
# ../dataset_WaterClusters_big/N32-T150/0400.dat    Energy -0.39538249
# ../dataset_WaterClusters_big/N32-T150/0050.dat    Energy -0.37564936
# ../dataset_WaterClusters_big/N32-T150/0750.dat    Energy -0.39711093
# ../dataset_WaterClusters_big/N32-T150/1000.dat    Energy -0.37491919
# ../dataset_WaterClusters_big/N32-T150/1800.dat    Energy -0.40063482
# ../dataset_WaterClusters_big/N32-T150/0200.dat    Energy -0.38814777
# ../dataset_WaterClusters_big/N100-T150/0350.dat    Energy -1.46896217
# ../dataset_WaterClusters_big/N100-T150/1700.dat    Energy -1.53137894
# ../dataset_WaterClusters_big/N100-T150/0100.dat    Energy -1.49632618
# ../dataset_WaterClusters_big/N100-T150/1550.dat    Energy -1.5438014
# ../dataset_WaterClusters_big/N100-T150/1850.dat    Energy -1.5283718
# ../dataset_WaterClusters_big/N100-T150/1100.dat    Energy -1.5252109
# ../dataset_WaterClusters_big/N100-T150/0450.dat    Energy -1.49349397
# ../dataset_WaterClusters_big/N100-T150/0500.dat    Energy -1.53129312
# ../dataset_WaterClusters_big/N100-T150/1350.dat    Energy -1.54356639
# ../dataset_WaterClusters_big/N100-T150/0850.dat    Energy -1.53909059
# ../dataset_WaterClusters_big/N100-T150/1900.dat    Energy -1.50287105
# ../dataset_WaterClusters_big/N100-T150/1650.dat    Energy -1.53074217
# ../dataset_WaterClusters_big/N100-T150/0250.dat    Energy -1.49936975
# ../dataset_WaterClusters_big/N100-T150/0950.dat    Energy -1.52132677
# ../dataset_WaterClusters_big/N100-T150/2000.dat    Energy -1.54345203
# ../dataset_WaterClusters_big/N100-T150/1950.dat    Energy -1.55110027
# ../dataset_WaterClusters_big/N100-T150/1500.dat    Energy -1.53537838
# ../dataset_WaterClusters_big/N100-T150/1250.dat    Energy -1.5208905
# ../dataset_WaterClusters_big/N100-T150/0800.dat    Energy -1.52304851
# ../dataset_WaterClusters_big/N100-T150/0900.dat    Energy -1.52975913
# ../dataset_WaterClusters_big/N100-T150/0700.dat    Energy -1.50565147
# ../dataset_WaterClusters_big/N100-T150/0550.dat    Energy -1.52121736
# ../dataset_WaterClusters_big/N100-T150/1750.dat    Energy -1.51589626
# ../dataset_WaterClusters_big/N100-T150/1300.dat    Energy -1.51508254
# ../dataset_WaterClusters_big/N100-T150/0600.dat    Energy -1.52194284
# ../dataset_WaterClusters_big/N100-T150/0650.dat    Energy -1.53261561
# ../dataset_WaterClusters_big/N100-T150/1600.dat    Energy -1.52069779
# ../dataset_WaterClusters_big/N100-T150/1050.dat    Energy -1.52145245
# ../dataset_WaterClusters_big/N100-T150/0300.dat    Energy -1.4948151
# ../dataset_WaterClusters_big/N100-T150/1400.dat    Energy -1.51583064
# ../dataset_WaterClusters_big/N100-T150/1450.dat    Energy -1.55641844
# ../dataset_WaterClusters_big/N100-T150/1200.dat    Energy -1.52839659
# ../dataset_WaterClusters_big/N100-T150/0150.dat    Energy -1.4680952
# ../dataset_WaterClusters_big/N100-T150/1150.dat    Energy -1.52313316
# ../dataset_WaterClusters_big/N100-T150/0400.dat    Energy -1.48926349
# ../dataset_WaterClusters_big/N100-T150/0050.dat    Energy -1.49133861
# ../dataset_WaterClusters_big/N100-T150/0750.dat    Energy -1.52795578
# ../dataset_WaterClusters_big/N100-T150/1000.dat    Energy -1.52608644
# ../dataset_WaterClusters_big/N100-T150/1800.dat    Energy -1.55017854
# ../dataset_WaterClusters_big/N100-T150/0200.dat    Energy -1.48169803
# ../dataset_WaterClusters_big/N139-T50/0350.dat    Energy -2.43013467
# ../dataset_WaterClusters_big/N139-T50/1700.dat    Energy -2.45266418
# ../dataset_WaterClusters_big/N139-T50/0100.dat    Energy -2.44393605
# ../dataset_WaterClusters_big/N139-T50/1550.dat    Energy -2.4482588
# ../dataset_WaterClusters_big/N139-T50/1850.dat    Energy -2.44786171
# ../dataset_WaterClusters_big/N139-T50/1100.dat    Energy -2.44563842
# ../dataset_WaterClusters_big/N139-T50/0450.dat    Energy -2.43896683
# ../dataset_WaterClusters_big/N139-T50/0500.dat    Energy -2.44179118
# ../dataset_WaterClusters_big/N139-T50/1350.dat    Energy -2.45472293
# ../dataset_WaterClusters_big/N139-T50/0850.dat    Energy -2.4504698
# ../dataset_WaterClusters_big/N139-T50/1900.dat    Energy -2.45290913
# ../dataset_WaterClusters_big/N139-T50/1650.dat    Energy -2.44751501
# ../dataset_WaterClusters_big/N139-T50/0250.dat    Energy -2.43248707
# ../dataset_WaterClusters_big/N139-T50/0950.dat    Energy -2.4427487
# ../dataset_WaterClusters_big/N139-T50/2000.dat    Energy -2.45260305
# ../dataset_WaterClusters_big/N139-T50/1950.dat    Energy -2.45151145
# ../dataset_WaterClusters_big/N139-T50/1500.dat    Energy -2.44606227
# ../dataset_WaterClusters_big/N139-T50/1250.dat    Energy -2.46186633
# ../dataset_WaterClusters_big/N139-T50/0800.dat    Energy -2.44541768
# ../dataset_WaterClusters_big/N139-T50/0900.dat    Energy -2.44051034
# ../dataset_WaterClusters_big/N139-T50/0700.dat    Energy -2.44780976
# ../dataset_WaterClusters_big/N139-T50/0550.dat    Energy -2.44294212
# ../dataset_WaterClusters_big/N139-T50/1750.dat    Energy -2.45210473
# ../dataset_WaterClusters_big/N139-T50/1300.dat    Energy -2.45609085
# ../dataset_WaterClusters_big/N139-T50/0600.dat    Energy -2.43896853
# ../dataset_WaterClusters_big/N139-T50/0650.dat    Energy -2.43929711
# ../dataset_WaterClusters_big/N139-T50/1600.dat    Energy -2.44592448
# ../dataset_WaterClusters_big/N139-T50/1050.dat    Energy -2.4463057
# ../dataset_WaterClusters_big/N139-T50/0300.dat    Energy -2.44179405
# ../dataset_WaterClusters_big/N139-T50/1400.dat    Energy -2.4471701
# ../dataset_WaterClusters_big/N139-T50/1450.dat    Energy -2.45030676
# ../dataset_WaterClusters_big/N139-T50/1200.dat    Energy -2.45024299
# ../dataset_WaterClusters_big/N139-T50/0150.dat    Energy -2.44735604
# ../dataset_WaterClusters_big/N139-T50/1150.dat    Energy -2.44825022
# ../dataset_WaterClusters_big/N139-T50/0400.dat    Energy -2.42117298
# ../dataset_WaterClusters_big/N139-T50/0050.dat    Energy -2.43361629
# ../dataset_WaterClusters_big/N139-T50/0750.dat    Energy -2.4521801
# ../dataset_WaterClusters_big/N139-T50/1000.dat    Energy -2.4541609
# ../dataset_WaterClusters_big/N139-T50/1800.dat    Energy -2.4528889
# ../dataset_WaterClusters_big/N139-T50/0200.dat    Energy -2.44419352
# ../dataset_WaterClusters_big/N237-T200/0350.dat    Energy -3.66551961
# ../dataset_WaterClusters_big/N237-T200/1700.dat    Energy -3.7267578
# ../dataset_WaterClusters_big/N237-T200/0100.dat    Energy -3.69401303
# ../dataset_WaterClusters_big/N237-T200/1550.dat    Energy -3.67120492
# ../dataset_WaterClusters_big/N237-T200/1850.dat    Energy -3.69825787
# ../dataset_WaterClusters_big/N237-T200/1100.dat    Energy -3.65829917
# ../dataset_WaterClusters_big/N237-T200/0450.dat    Energy -3.68923925
# ../dataset_WaterClusters_big/N237-T200/0500.dat    Energy -3.70336594
# ../dataset_WaterClusters_big/N237-T200/1350.dat    Energy -3.70834378
# ../dataset_WaterClusters_big/N237-T200/0850.dat    Energy -3.68464474
# ../dataset_WaterClusters_big/N237-T200/1900.dat    Energy -3.72456542
# ../dataset_WaterClusters_big/N237-T200/1650.dat    Energy -3.73083536
# ../dataset_WaterClusters_big/N237-T200/0250.dat    Energy -3.67917208
# ../dataset_WaterClusters_big/N237-T200/0950.dat    Energy -3.65698535
# ../dataset_WaterClusters_big/N237-T200/2000.dat    Energy -3.70337252
# ../dataset_WaterClusters_big/N237-T200/1950.dat    Energy -3.7110707
# ../dataset_WaterClusters_big/N237-T200/1500.dat    Energy -3.69015687
# ../dataset_WaterClusters_big/N237-T200/1250.dat    Energy -3.66710132
# ../dataset_WaterClusters_big/N237-T200/0800.dat    Energy -3.68026062
# ../dataset_WaterClusters_big/N237-T200/0900.dat    Energy -3.61845554
# ../dataset_WaterClusters_big/N237-T200/0700.dat    Energy -3.6644573
# ../dataset_WaterClusters_big/N237-T200/0550.dat    Energy -3.64947149
# ../dataset_WaterClusters_big/N237-T200/1750.dat    Energy -3.73506311
# ../dataset_WaterClusters_big/N237-T200/1300.dat    Energy -3.73407704
# ../dataset_WaterClusters_big/N237-T200/0600.dat    Energy -3.63417033
# ../dataset_WaterClusters_big/N237-T200/0650.dat    Energy -3.67122709
# ../dataset_WaterClusters_big/N237-T200/1600.dat    Energy -3.6991074
# ../dataset_WaterClusters_big/N237-T200/1050.dat    Energy -3.7143634
# ../dataset_WaterClusters_big/N237-T200/0300.dat    Energy -3.67106413
# ../dataset_WaterClusters_big/N237-T200/1400.dat    Energy -3.74079773
# ../dataset_WaterClusters_big/N237-T200/1450.dat    Energy -3.69705045
# ../dataset_WaterClusters_big/N237-T200/1200.dat    Energy -3.69150406
# ../dataset_WaterClusters_big/N237-T200/0150.dat    Energy -3.66676208
# ../dataset_WaterClusters_big/N237-T200/1150.dat    Energy -3.64876301
# ../dataset_WaterClusters_big/N237-T200/0400.dat    Energy -3.6586602
# ../dataset_WaterClusters_big/N237-T200/0050.dat    Energy -3.64587353
# ../dataset_WaterClusters_big/N237-T200/0750.dat    Energy -3.69086859
# ../dataset_WaterClusters_big/N237-T200/1000.dat    Energy -3.68900093
# ../dataset_WaterClusters_big/N237-T200/1800.dat    Energy -3.68628481
# ../dataset_WaterClusters_big/N237-T200/0200.dat    Energy -3.66773852
# ../dataset_WaterClusters_big/N237-T150/0350.dat    Energy -3.84884936
# ../dataset_WaterClusters_big/N237-T150/1700.dat    Energy -3.90364722
# ../dataset_WaterClusters_big/N237-T150/0100.dat    Energy -3.88141095
# ../dataset_WaterClusters_big/N237-T150/1550.dat    Energy -3.89117425
# ../dataset_WaterClusters_big/N237-T150/1850.dat    Energy -3.8902009
# ../dataset_WaterClusters_big/N237-T150/1100.dat    Energy -3.83332062
# ../dataset_WaterClusters_big/N237-T150/0450.dat    Energy -3.88849285
# ../dataset_WaterClusters_big/N237-T150/0500.dat    Energy -3.90463683
# ../dataset_WaterClusters_big/N237-T150/1350.dat    Energy -3.88069021
# ../dataset_WaterClusters_big/N237-T150/0850.dat    Energy -3.8747736
# ../dataset_WaterClusters_big/N237-T150/1900.dat    Energy -3.90867197
# ../dataset_WaterClusters_big/N237-T150/1650.dat    Energy -3.91211509
# ../dataset_WaterClusters_big/N237-T150/0250.dat    Energy -3.8814518
# ../dataset_WaterClusters_big/N237-T150/0950.dat    Energy -3.85691362
# ../dataset_WaterClusters_big/N237-T150/2000.dat    Energy -3.89265619
# ../dataset_WaterClusters_big/N237-T150/1950.dat    Energy -3.89902251
# ../dataset_WaterClusters_big/N237-T150/1500.dat    Energy -3.88839526
# ../dataset_WaterClusters_big/N237-T150/1250.dat    Energy -3.86897383
# ../dataset_WaterClusters_big/N237-T150/0800.dat    Energy -3.87272843
# ../dataset_WaterClusters_big/N237-T150/0900.dat    Energy -3.83700133
# ../dataset_WaterClusters_big/N237-T150/0700.dat    Energy -3.85474821
# ../dataset_WaterClusters_big/N237-T150/0550.dat    Energy -3.8646602
# ../dataset_WaterClusters_big/N237-T150/1750.dat    Energy -3.88932642
# ../dataset_WaterClusters_big/N237-T150/1300.dat    Energy -3.9124125
# ../dataset_WaterClusters_big/N237-T150/0600.dat    Energy -3.83070915
# ../dataset_WaterClusters_big/N237-T150/0650.dat    Energy -3.87073384
# ../dataset_WaterClusters_big/N237-T150/1600.dat    Energy -3.8916888
# ../dataset_WaterClusters_big/N237-T150/1050.dat    Energy -3.88832835
# ../dataset_WaterClusters_big/N237-T150/0300.dat    Energy -3.86282028
# ../dataset_WaterClusters_big/N237-T150/1400.dat    Energy -3.89053096
# ../dataset_WaterClusters_big/N237-T150/1450.dat    Energy -3.89620838
# ../dataset_WaterClusters_big/N237-T150/1200.dat    Energy -3.87901892
# ../dataset_WaterClusters_big/N237-T150/0150.dat    Energy -3.87196249
# ../dataset_WaterClusters_big/N237-T150/1150.dat    Energy -3.85414459
# ../dataset_WaterClusters_big/N237-T150/0400.dat    Energy -3.85738915
# ../dataset_WaterClusters_big/N237-T150/0050.dat    Energy -3.8667349
# ../dataset_WaterClusters_big/N237-T150/0750.dat    Energy -3.8863271
# ../dataset_WaterClusters_big/N237-T150/1000.dat    Energy -3.88364082
# ../dataset_WaterClusters_big/N237-T150/1800.dat    Energy -3.87287869
# ../dataset_WaterClusters_big/N237-T150/0200.dat    Energy -3.85848234
# ../dataset_WaterClusters_big/N76-T50/0350.dat    Energy -1.22155793
# ../dataset_WaterClusters_big/N76-T50/1700.dat    Energy -1.23445106
# ../dataset_WaterClusters_big/N76-T50/0100.dat    Energy -1.21857355
# ../dataset_WaterClusters_big/N76-T50/1550.dat    Energy -1.23147267
# ../dataset_WaterClusters_big/N76-T50/1850.dat    Energy -1.24196756
# ../dataset_WaterClusters_big/N76-T50/1100.dat    Energy -1.23474684
# ../dataset_WaterClusters_big/N76-T50/0450.dat    Energy -1.24171502
# ../dataset_WaterClusters_big/N76-T50/0500.dat    Energy -1.22900676
# ../dataset_WaterClusters_big/N76-T50/1350.dat    Energy -1.24222567
# ../dataset_WaterClusters_big/N76-T50/0850.dat    Energy -1.24172105
# ../dataset_WaterClusters_big/N76-T50/1900.dat    Energy -1.23728263
# ../dataset_WaterClusters_big/N76-T50/1650.dat    Energy -1.22838235
# ../dataset_WaterClusters_big/N76-T50/0250.dat    Energy -1.22121656
# ../dataset_WaterClusters_big/N76-T50/0950.dat    Energy -1.24291475
# ../dataset_WaterClusters_big/N76-T50/2000.dat    Energy -1.22864555
# ../dataset_WaterClusters_big/N76-T50/1950.dat    Energy -1.23913622
# ../dataset_WaterClusters_big/N76-T50/1500.dat    Energy -1.22789862
# ../dataset_WaterClusters_big/N76-T50/1250.dat    Energy -1.23643515
# ../dataset_WaterClusters_big/N76-T50/0800.dat    Energy -1.23260311
# ../dataset_WaterClusters_big/N76-T50/0900.dat    Energy -1.23606156
# ../dataset_WaterClusters_big/N76-T50/0700.dat    Energy -1.23994681
# ../dataset_WaterClusters_big/N76-T50/0550.dat    Energy -1.23445451
# ../dataset_WaterClusters_big/N76-T50/1750.dat    Energy -1.24130858
# ../dataset_WaterClusters_big/N76-T50/1300.dat    Energy -1.23292865
# ../dataset_WaterClusters_big/N76-T50/0600.dat    Energy -1.2400149
# ../dataset_WaterClusters_big/N76-T50/0650.dat    Energy -1.22968825
# ../dataset_WaterClusters_big/N76-T50/1600.dat    Energy -1.2325949
# ../dataset_WaterClusters_big/N76-T50/1050.dat    Energy -1.2416058
# ../dataset_WaterClusters_big/N76-T50/0300.dat    Energy -1.21339099
# ../dataset_WaterClusters_big/N76-T50/1400.dat    Energy -1.24638556
# ../dataset_WaterClusters_big/N76-T50/1450.dat    Energy -1.23333139
# ../dataset_WaterClusters_big/N76-T50/1200.dat    Energy -1.23830962
# ../dataset_WaterClusters_big/N76-T50/0150.dat    Energy -1.21832137
# ../dataset_WaterClusters_big/N76-T50/1150.dat    Energy -1.23579535
# ../dataset_WaterClusters_big/N76-T50/0400.dat    Energy -1.22286948
# ../dataset_WaterClusters_big/N76-T50/0050.dat    Energy -1.21463725
# ../dataset_WaterClusters_big/N76-T50/0750.dat    Energy -1.24337549
# ../dataset_WaterClusters_big/N76-T50/1000.dat    Energy -1.24127691
# ../dataset_WaterClusters_big/N76-T50/1800.dat    Energy -1.24580563
# ../dataset_WaterClusters_big/N76-T50/0200.dat    Energy -1.22346226
# ../dataset_WaterClusters_big/N100-T50/0350.dat    Energy -1.64488169
# ../dataset_WaterClusters_big/N100-T50/1700.dat    Energy -1.68227232
# ../dataset_WaterClusters_big/N100-T50/0100.dat    Energy -1.64844547
# ../dataset_WaterClusters_big/N100-T50/1550.dat    Energy -1.68269713
# ../dataset_WaterClusters_big/N100-T50/1850.dat    Energy -1.67235085
# ../dataset_WaterClusters_big/N100-T50/1100.dat    Energy -1.67823427
# ../dataset_WaterClusters_big/N100-T50/0450.dat    Energy -1.65542334
# ../dataset_WaterClusters_big/N100-T50/0500.dat    Energy -1.66757644
# ../dataset_WaterClusters_big/N100-T50/1350.dat    Energy -1.67330071
# ../dataset_WaterClusters_big/N100-T50/0850.dat    Energy -1.66807435
# ../dataset_WaterClusters_big/N100-T50/1900.dat    Energy -1.65143179
# ../dataset_WaterClusters_big/N100-T50/1650.dat    Energy -1.67385994
# ../dataset_WaterClusters_big/N100-T50/0250.dat    Energy -1.64747489
# ../dataset_WaterClusters_big/N100-T50/0950.dat    Energy -1.66310306
# ../dataset_WaterClusters_big/N100-T50/2000.dat    Energy -1.67494139
# ../dataset_WaterClusters_big/N100-T50/1950.dat    Energy -1.68225901
# ../dataset_WaterClusters_big/N100-T50/1500.dat    Energy -1.67776863
# ../dataset_WaterClusters_big/N100-T50/1250.dat    Energy -1.66567606
# ../dataset_WaterClusters_big/N100-T50/0800.dat    Energy -1.66715754
# ../dataset_WaterClusters_big/N100-T50/0900.dat    Energy -1.67754141
# ../dataset_WaterClusters_big/N100-T50/0700.dat    Energy -1.66023826
# ../dataset_WaterClusters_big/N100-T50/0550.dat    Energy -1.66230707
# ../dataset_WaterClusters_big/N100-T50/1750.dat    Energy -1.67212005
# ../dataset_WaterClusters_big/N100-T50/1300.dat    Energy -1.67011302
# ../dataset_WaterClusters_big/N100-T50/0600.dat    Energy -1.66258899
# ../dataset_WaterClusters_big/N100-T50/0650.dat    Energy -1.66567158
# ../dataset_WaterClusters_big/N100-T50/1600.dat    Energy -1.67218372
# ../dataset_WaterClusters_big/N100-T50/1050.dat    Energy -1.67356563
# ../dataset_WaterClusters_big/N100-T50/0300.dat    Energy -1.65331935
# ../dataset_WaterClusters_big/N100-T50/1400.dat    Energy -1.67738574
# ../dataset_WaterClusters_big/N100-T50/1450.dat    Energy -1.68682083
# ../dataset_WaterClusters_big/N100-T50/1200.dat    Energy -1.67705543
# ../dataset_WaterClusters_big/N100-T50/0150.dat    Energy -1.63833853
# ../dataset_WaterClusters_big/N100-T50/1150.dat    Energy -1.67757426
# ../dataset_WaterClusters_big/N100-T50/0400.dat    Energy -1.64474553
# ../dataset_WaterClusters_big/N100-T50/0050.dat    Energy -1.64130956
# ../dataset_WaterClusters_big/N100-T50/0750.dat    Energy -1.67038816
# ../dataset_WaterClusters_big/N100-T50/1000.dat    Energy -1.67508952
# ../dataset_WaterClusters_big/N100-T50/1800.dat    Energy -1.67435618
# ../dataset_WaterClusters_big/N100-T50/0200.dat    Energy -1.64611378
# ../dataset_WaterClusters_big/N32-T100/0350.dat    Energy -0.43210929
# ../dataset_WaterClusters_big/N32-T100/1700.dat    Energy -0.41872069
# ../dataset_WaterClusters_big/N32-T100/0100.dat    Energy -0.42998735
# ../dataset_WaterClusters_big/N32-T100/1550.dat    Energy -0.42483175
# ../dataset_WaterClusters_big/N32-T100/1850.dat    Energy -0.42262162
# ../dataset_WaterClusters_big/N32-T100/1100.dat    Energy -0.43664524
# ../dataset_WaterClusters_big/N32-T100/0450.dat    Energy -0.43073433
# ../dataset_WaterClusters_big/N32-T100/0500.dat    Energy -0.42988907
# ../dataset_WaterClusters_big/N32-T100/1350.dat    Energy -0.43919717
# ../dataset_WaterClusters_big/N32-T100/0850.dat    Energy -0.43039012
# ../dataset_WaterClusters_big/N32-T100/1900.dat    Energy -0.42351261
# ../dataset_WaterClusters_big/N32-T100/1650.dat    Energy -0.43305195
# ../dataset_WaterClusters_big/N32-T100/0250.dat    Energy -0.42668668
# ../dataset_WaterClusters_big/N32-T100/0950.dat    Energy -0.42771105
# ../dataset_WaterClusters_big/N32-T100/2000.dat    Energy -0.42137845
# ../dataset_WaterClusters_big/N32-T100/1950.dat    Energy -0.4204465
# ../dataset_WaterClusters_big/N32-T100/1500.dat    Energy -0.42679292
# ../dataset_WaterClusters_big/N32-T100/1250.dat    Energy -0.44326112
# ../dataset_WaterClusters_big/N32-T100/0800.dat    Energy -0.42614142
# ../dataset_WaterClusters_big/N32-T100/0900.dat    Energy -0.42375162
# ../dataset_WaterClusters_big/N32-T100/0700.dat    Energy -0.42985776
# ../dataset_WaterClusters_big/N32-T100/0550.dat    Energy -0.43064022
# ../dataset_WaterClusters_big/N32-T100/1750.dat    Energy -0.43294386
# ../dataset_WaterClusters_big/N32-T100/1300.dat    Energy -0.43784321
# ../dataset_WaterClusters_big/N32-T100/0600.dat    Energy -0.41758847
# ../dataset_WaterClusters_big/N32-T100/0650.dat    Energy -0.42611953
# ../dataset_WaterClusters_big/N32-T100/1600.dat    Energy -0.42830395
# ../dataset_WaterClusters_big/N32-T100/1050.dat    Energy -0.43332745
# ../dataset_WaterClusters_big/N32-T100/0300.dat    Energy -0.4253742
# ../dataset_WaterClusters_big/N32-T100/1400.dat    Energy -0.42465972
# ../dataset_WaterClusters_big/N32-T100/1450.dat    Energy -0.42270195
# ../dataset_WaterClusters_big/N32-T100/1200.dat    Energy -0.43698147
# ../dataset_WaterClusters_big/N32-T100/0150.dat    Energy -0.42429631
# ../dataset_WaterClusters_big/N32-T100/1150.dat    Energy -0.4398966
# ../dataset_WaterClusters_big/N32-T100/0400.dat    Energy -0.42454683
# ../dataset_WaterClusters_big/N32-T100/0050.dat    Energy -0.4113175
# ../dataset_WaterClusters_big/N32-T100/0750.dat    Energy -0.42985912
# ../dataset_WaterClusters_big/N32-T100/1000.dat    Energy -0.41267015
# ../dataset_WaterClusters_big/N32-T100/1800.dat    Energy -0.4359291
# ../dataset_WaterClusters_big/N32-T100/0200.dat    Energy -0.41651019
# ../dataset_WaterClusters_big/N237-T50/0350.dat    Energy -4.26285038
# ../dataset_WaterClusters_big/N237-T50/1700.dat    Energy -4.29671897
# ../dataset_WaterClusters_big/N237-T50/0100.dat    Energy -4.26877881
# ../dataset_WaterClusters_big/N237-T50/1550.dat    Energy -4.28942764
# ../dataset_WaterClusters_big/N237-T50/1850.dat    Energy -4.29979475
# ../dataset_WaterClusters_big/N237-T50/1100.dat    Energy -4.26565009
# ../dataset_WaterClusters_big/N237-T50/0450.dat    Energy -4.27945368
# ../dataset_WaterClusters_big/N237-T50/0500.dat    Energy -4.27917469
# ../dataset_WaterClusters_big/N237-T50/1350.dat    Energy -4.28455137
# ../dataset_WaterClusters_big/N237-T50/0850.dat    Energy -4.26893976
# ../dataset_WaterClusters_big/N237-T50/1900.dat    Energy -4.29615242
# ../dataset_WaterClusters_big/N237-T50/1650.dat    Energy -4.3027304
# ../dataset_WaterClusters_big/N237-T50/0250.dat    Energy -4.26167279
# ../dataset_WaterClusters_big/N237-T50/0950.dat    Energy -4.26286591
# ../dataset_WaterClusters_big/N237-T50/2000.dat    Energy -4.29192672
# ../dataset_WaterClusters_big/N237-T50/1950.dat    Energy -4.29830288
# ../dataset_WaterClusters_big/N237-T50/1500.dat    Energy -4.28991188
# ../dataset_WaterClusters_big/N237-T50/1250.dat    Energy -4.28259644
# ../dataset_WaterClusters_big/N237-T50/0800.dat    Energy -4.2666585
# ../dataset_WaterClusters_big/N237-T50/0900.dat    Energy -4.25362362
# ../dataset_WaterClusters_big/N237-T50/0700.dat    Energy -4.26286279
# ../dataset_WaterClusters_big/N237-T50/0550.dat    Energy -4.26688996
# ../dataset_WaterClusters_big/N237-T50/1750.dat    Energy -4.2963787
# ../dataset_WaterClusters_big/N237-T50/1300.dat    Energy -4.29410582
# ../dataset_WaterClusters_big/N237-T50/0600.dat    Energy -4.26362989
# ../dataset_WaterClusters_big/N237-T50/0650.dat    Energy -4.26579125
# ../dataset_WaterClusters_big/N237-T50/1600.dat    Energy -4.28438271
# ../dataset_WaterClusters_big/N237-T50/1050.dat    Energy -4.27894787
# ../dataset_WaterClusters_big/N237-T50/0300.dat    Energy -4.27025329
# ../dataset_WaterClusters_big/N237-T50/1400.dat    Energy -4.28892598
# ../dataset_WaterClusters_big/N237-T50/1450.dat    Energy -4.29231031
# ../dataset_WaterClusters_big/N237-T50/1200.dat    Energy -4.27643962
# ../dataset_WaterClusters_big/N237-T50/0150.dat    Energy -4.26794448
# ../dataset_WaterClusters_big/N237-T50/1150.dat    Energy -4.26114144
# ../dataset_WaterClusters_big/N237-T50/0400.dat    Energy -4.26755729
# ../dataset_WaterClusters_big/N237-T50/0050.dat    Energy -4.26852913
# ../dataset_WaterClusters_big/N237-T50/0750.dat    Energy -4.27547637
# ../dataset_WaterClusters_big/N237-T50/1000.dat    Energy -4.26463716
# ../dataset_WaterClusters_big/N237-T50/1800.dat    Energy -4.28529171
# ../dataset_WaterClusters_big/N237-T50/0200.dat    Energy -4.26737587
# ../dataset_WaterClusters_big/N47-T50/0350.dat    Energy -0.69668334
# ../dataset_WaterClusters_big/N47-T50/1700.dat    Energy -0.70071984
# ../dataset_WaterClusters_big/N47-T50/0100.dat    Energy -0.68355344
# ../dataset_WaterClusters_big/N47-T50/1550.dat    Energy -0.69463549
# ../dataset_WaterClusters_big/N47-T50/1850.dat    Energy -0.69612362
# ../dataset_WaterClusters_big/N47-T50/1100.dat    Energy -0.69442886
# ../dataset_WaterClusters_big/N47-T50/0450.dat    Energy -0.69509477
# ../dataset_WaterClusters_big/N47-T50/0500.dat    Energy -0.69367723
# ../dataset_WaterClusters_big/N47-T50/1350.dat    Energy -0.69015861
# ../dataset_WaterClusters_big/N47-T50/0850.dat    Energy -0.70303994
# ../dataset_WaterClusters_big/N47-T50/1900.dat    Energy -0.69575463
# ../dataset_WaterClusters_big/N47-T50/1650.dat    Energy -0.69064166
# ../dataset_WaterClusters_big/N47-T50/0250.dat    Energy -0.6940553
# ../dataset_WaterClusters_big/N47-T50/0950.dat    Energy -0.69515536
# ../dataset_WaterClusters_big/N47-T50/2000.dat    Energy -0.69631281
# ../dataset_WaterClusters_big/N47-T50/1950.dat    Energy -0.69686879
# ../dataset_WaterClusters_big/N47-T50/1500.dat    Energy -0.69191156
# ../dataset_WaterClusters_big/N47-T50/1250.dat    Energy -0.69984649
# ../dataset_WaterClusters_big/N47-T50/0800.dat    Energy -0.69813469
# ../dataset_WaterClusters_big/N47-T50/0900.dat    Energy -0.69985078
# ../dataset_WaterClusters_big/N47-T50/0700.dat    Energy -0.69623285
# ../dataset_WaterClusters_big/N47-T50/0550.dat    Energy -0.69699965
# ../dataset_WaterClusters_big/N47-T50/1750.dat    Energy -0.69233791
# ../dataset_WaterClusters_big/N47-T50/1300.dat    Energy -0.70174388
# ../dataset_WaterClusters_big/N47-T50/0600.dat    Energy -0.70008588
# ../dataset_WaterClusters_big/N47-T50/0650.dat    Energy -0.70481717
# ../dataset_WaterClusters_big/N47-T50/1600.dat    Energy -0.70020427
# ../dataset_WaterClusters_big/N47-T50/1050.dat    Energy -0.69375136
# ../dataset_WaterClusters_big/N47-T50/0300.dat    Energy -0.69144671
# ../dataset_WaterClusters_big/N47-T50/1400.dat    Energy -0.69843697
# ../dataset_WaterClusters_big/N47-T50/1450.dat    Energy -0.70307439
# ../dataset_WaterClusters_big/N47-T50/1200.dat    Energy -0.68960914
# ../dataset_WaterClusters_big/N47-T50/0150.dat    Energy -0.68869057
# ../dataset_WaterClusters_big/N47-T50/1150.dat    Energy -0.6965546
# ../dataset_WaterClusters_big/N47-T50/0400.dat    Energy -0.69155668
# ../dataset_WaterClusters_big/N47-T50/0050.dat    Energy -0.69088019
# ../dataset_WaterClusters_big/N47-T50/0750.dat    Energy -0.69653228
# ../dataset_WaterClusters_big/N47-T50/1000.dat    Energy -0.70127102
# ../dataset_WaterClusters_big/N47-T50/1800.dat    Energy -0.6951374
# ../dataset_WaterClusters_big/N47-T50/0200.dat    Energy -0.69764954
# ../dataset_WaterClusters_big/N20-T50/0350.dat    Energy -0.27972537
# ../dataset_WaterClusters_big/N20-T50/1700.dat    Energy -0.28747328
# ../dataset_WaterClusters_big/N20-T50/0100.dat    Energy -0.27486326
# ../dataset_WaterClusters_big/N20-T50/1550.dat    Energy -0.2900221
# ../dataset_WaterClusters_big/N20-T50/1850.dat    Energy -0.2866409
# ../dataset_WaterClusters_big/N20-T50/1100.dat    Energy -0.28717328
# ../dataset_WaterClusters_big/N20-T50/0450.dat    Energy -0.28466291
# ../dataset_WaterClusters_big/N20-T50/0500.dat    Energy -0.2833184
# ../dataset_WaterClusters_big/N20-T50/1350.dat    Energy -0.28430037
# ../dataset_WaterClusters_big/N20-T50/0850.dat    Energy -0.28831328
# ../dataset_WaterClusters_big/N20-T50/1900.dat    Energy -0.28731566
# ../dataset_WaterClusters_big/N20-T50/1650.dat    Energy -0.28412734
# ../dataset_WaterClusters_big/N20-T50/0250.dat    Energy -0.27421821
# ../dataset_WaterClusters_big/N20-T50/0950.dat    Energy -0.28474053
# ../dataset_WaterClusters_big/N20-T50/2000.dat    Energy -0.28586672
# ../dataset_WaterClusters_big/N20-T50/1950.dat    Energy -0.28694333
# ../dataset_WaterClusters_big/N20-T50/1500.dat    Energy -0.27892862
# ../dataset_WaterClusters_big/N20-T50/1250.dat    Energy -0.27918052
# ../dataset_WaterClusters_big/N20-T50/0800.dat    Energy -0.28012098
# ../dataset_WaterClusters_big/N20-T50/0900.dat    Energy -0.28435223
# ../dataset_WaterClusters_big/N20-T50/0700.dat    Energy -0.28263455
# ../dataset_WaterClusters_big/N20-T50/0550.dat    Energy -0.28181001
# ../dataset_WaterClusters_big/N20-T50/1750.dat    Energy -0.28257171
# ../dataset_WaterClusters_big/N20-T50/1300.dat    Energy -0.28482425
# ../dataset_WaterClusters_big/N20-T50/0600.dat    Energy -0.28220751
# ../dataset_WaterClusters_big/N20-T50/0650.dat    Energy -0.28573107
# ../dataset_WaterClusters_big/N20-T50/1600.dat    Energy -0.28991333
# ../dataset_WaterClusters_big/N20-T50/1050.dat    Energy -0.28558521
# ../dataset_WaterClusters_big/N20-T50/0300.dat    Energy -0.28050088
# ../dataset_WaterClusters_big/N20-T50/1400.dat    Energy -0.28666516
# ../dataset_WaterClusters_big/N20-T50/1450.dat    Energy -0.28809637
# ../dataset_WaterClusters_big/N20-T50/1200.dat    Energy -0.27739145
# ../dataset_WaterClusters_big/N20-T50/0150.dat    Energy -0.28044104
# ../dataset_WaterClusters_big/N20-T50/1150.dat    Energy -0.2824699
# ../dataset_WaterClusters_big/N20-T50/0400.dat    Energy -0.28816101
# ../dataset_WaterClusters_big/N20-T50/0050.dat    Energy -0.27976887
# ../dataset_WaterClusters_big/N20-T50/0750.dat    Energy -0.28339062
# ../dataset_WaterClusters_big/N20-T50/1000.dat    Energy -0.28749815
# ../dataset_WaterClusters_big/N20-T50/1800.dat    Energy -0.28514404
# ../dataset_WaterClusters_big/N20-T50/0200.dat    Energy -0.27804126
# ../dataset_WaterClusters_big/N47-T150/0350.dat    Energy -0.63295112
# ../dataset_WaterClusters_big/N47-T150/1700.dat    Energy -0.62828033
# ../dataset_WaterClusters_big/N47-T150/0100.dat    Energy -0.61776704
# ../dataset_WaterClusters_big/N47-T150/1550.dat    Energy -0.6276513
# ../dataset_WaterClusters_big/N47-T150/1850.dat    Energy -0.6335169
# ../dataset_WaterClusters_big/N47-T150/1100.dat    Energy -0.63175465
# ../dataset_WaterClusters_big/N47-T150/0450.dat    Energy -0.64134951
# ../dataset_WaterClusters_big/N47-T150/0500.dat    Energy -0.62538904
# ../dataset_WaterClusters_big/N47-T150/1350.dat    Energy -0.61896745
# ../dataset_WaterClusters_big/N47-T150/0850.dat    Energy -0.63611861
# ../dataset_WaterClusters_big/N47-T150/1900.dat    Energy -0.63705853
# ../dataset_WaterClusters_big/N47-T150/1650.dat    Energy -0.6197398
# ../dataset_WaterClusters_big/N47-T150/0250.dat    Energy -0.64188181
# ../dataset_WaterClusters_big/N47-T150/0950.dat    Energy -0.64428131
# ../dataset_WaterClusters_big/N47-T150/2000.dat    Energy -0.63180214
# ../dataset_WaterClusters_big/N47-T150/1950.dat    Energy -0.64222957
# ../dataset_WaterClusters_big/N47-T150/1500.dat    Energy -0.63096763
# ../dataset_WaterClusters_big/N47-T150/1250.dat    Energy -0.62559473
# ../dataset_WaterClusters_big/N47-T150/0800.dat    Energy -0.63778767
# ../dataset_WaterClusters_big/N47-T150/0900.dat    Energy -0.62884548
# ../dataset_WaterClusters_big/N47-T150/0700.dat    Energy -0.63715902
# ../dataset_WaterClusters_big/N47-T150/0550.dat    Energy -0.63921723
# ../dataset_WaterClusters_big/N47-T150/1750.dat    Energy -0.6198978
# ../dataset_WaterClusters_big/N47-T150/1300.dat    Energy -0.64139439
# ../dataset_WaterClusters_big/N47-T150/0600.dat    Energy -0.65833656
# ../dataset_WaterClusters_big/N47-T150/0650.dat    Energy -0.66654651
# ../dataset_WaterClusters_big/N47-T150/1600.dat    Energy -0.63724238
# ../dataset_WaterClusters_big/N47-T150/1050.dat    Energy -0.63783205
# ../dataset_WaterClusters_big/N47-T150/0300.dat    Energy -0.63286083
# ../dataset_WaterClusters_big/N47-T150/1400.dat    Energy -0.63794701
# ../dataset_WaterClusters_big/N47-T150/1450.dat    Energy -0.64830756
# ../dataset_WaterClusters_big/N47-T150/1200.dat    Energy -0.62363622
# ../dataset_WaterClusters_big/N47-T150/0150.dat    Energy -0.63198411
# ../dataset_WaterClusters_big/N47-T150/1150.dat    Energy -0.62756515
# ../dataset_WaterClusters_big/N47-T150/0400.dat    Energy -0.64079128
# ../dataset_WaterClusters_big/N47-T150/0050.dat    Energy -0.62932449
# ../dataset_WaterClusters_big/N47-T150/0750.dat    Energy -0.62914168
# ../dataset_WaterClusters_big/N47-T150/1000.dat    Energy -0.64739728
# ../dataset_WaterClusters_big/N47-T150/1800.dat    Energy -0.62789696
# ../dataset_WaterClusters_big/N47-T150/0200.dat    Energy -0.64784361
# ../dataset_WaterClusters_big/N190-T100/0350.dat    Energy -3.21972472
# ../dataset_WaterClusters_big/N190-T100/1700.dat    Energy -3.22894047
# ../dataset_WaterClusters_big/N190-T100/0100.dat    Energy -3.21848408
# ../dataset_WaterClusters_big/N190-T100/1550.dat    Energy -3.22948945
# ../dataset_WaterClusters_big/N190-T100/1850.dat    Energy -3.2387858
# ../dataset_WaterClusters_big/N190-T100/1100.dat    Energy -3.22411985
# ../dataset_WaterClusters_big/N190-T100/0450.dat    Energy -3.222257
# ../dataset_WaterClusters_big/N190-T100/0500.dat    Energy -3.20312133
# ../dataset_WaterClusters_big/N190-T100/1350.dat    Energy -3.23470921
# ../dataset_WaterClusters_big/N190-T100/0850.dat    Energy -3.21901788
# ../dataset_WaterClusters_big/N190-T100/1900.dat    Energy -3.23641024
# ../dataset_WaterClusters_big/N190-T100/1650.dat    Energy -3.22735156
# ../dataset_WaterClusters_big/N190-T100/0250.dat    Energy -3.20968214
# ../dataset_WaterClusters_big/N190-T100/0950.dat    Energy -3.21542385
# ../dataset_WaterClusters_big/N190-T100/2000.dat    Energy -3.2006837
# ../dataset_WaterClusters_big/N190-T100/1950.dat    Energy -3.24109396
# ../dataset_WaterClusters_big/N190-T100/1500.dat    Energy -3.21640527
# ../dataset_WaterClusters_big/N190-T100/1250.dat    Energy -3.22008723
# ../dataset_WaterClusters_big/N190-T100/0800.dat    Energy -3.22878201
# ../dataset_WaterClusters_big/N190-T100/0900.dat    Energy -3.22544201
# ../dataset_WaterClusters_big/N190-T100/0700.dat    Energy -3.25520204
# ../dataset_WaterClusters_big/N190-T100/0550.dat    Energy -3.21461416
# ../dataset_WaterClusters_big/N190-T100/1750.dat    Energy -3.24318418
# ../dataset_WaterClusters_big/N190-T100/1300.dat    Energy -3.24290204
# ../dataset_WaterClusters_big/N190-T100/0600.dat    Energy -3.22788351
# ../dataset_WaterClusters_big/N190-T100/0650.dat    Energy -3.20609802
# ../dataset_WaterClusters_big/N190-T100/1600.dat    Energy -3.22063093
# ../dataset_WaterClusters_big/N190-T100/1050.dat    Energy -3.21451948
# ../dataset_WaterClusters_big/N190-T100/0300.dat    Energy -3.23980629
# ../dataset_WaterClusters_big/N190-T100/1400.dat    Energy -3.24140954
# ../dataset_WaterClusters_big/N190-T100/1450.dat    Energy -3.24487308
# ../dataset_WaterClusters_big/N190-T100/1200.dat    Energy -3.24265155
# ../dataset_WaterClusters_big/N190-T100/0150.dat    Energy -3.23482352
# ../dataset_WaterClusters_big/N190-T100/1150.dat    Energy -3.2309828
# ../dataset_WaterClusters_big/N190-T100/0400.dat    Energy -3.21153355
# ../dataset_WaterClusters_big/N190-T100/0050.dat    Energy -3.19008097
# ../dataset_WaterClusters_big/N190-T100/0750.dat    Energy -3.23747184
# ../dataset_WaterClusters_big/N190-T100/1000.dat    Energy -3.22619544
# ../dataset_WaterClusters_big/N190-T100/1800.dat    Energy -3.23088064
# ../dataset_WaterClusters_big/N190-T100/0200.dat    Energy -3.23205635
# ../dataset_WaterClusters_big/N32-T200/0350.dat    Energy -0.39487995
# ../dataset_WaterClusters_big/N32-T200/1700.dat    Energy -0.35466252
# ../dataset_WaterClusters_big/N32-T200/0100.dat    Energy -0.37231802
# ../dataset_WaterClusters_big/N32-T200/1550.dat    Energy -0.38203702
# ../dataset_WaterClusters_big/N32-T200/1850.dat    Energy -0.35370754
# ../dataset_WaterClusters_big/N32-T200/1100.dat    Energy -0.37823052
# ../dataset_WaterClusters_big/N32-T200/0450.dat    Energy -0.37657688
# ../dataset_WaterClusters_big/N32-T200/0500.dat    Energy -0.37661371
# ../dataset_WaterClusters_big/N32-T200/1350.dat    Energy -0.37277138
# ../dataset_WaterClusters_big/N32-T200/0850.dat    Energy -0.35717238
# ../dataset_WaterClusters_big/N32-T200/1900.dat    Energy -0.35174607
# ../dataset_WaterClusters_big/N32-T200/1650.dat    Energy -0.38132859
# ../dataset_WaterClusters_big/N32-T200/0250.dat    Energy -0.35616586
# ../dataset_WaterClusters_big/N32-T200/0950.dat    Energy -0.37154759
# ../dataset_WaterClusters_big/N32-T200/2000.dat    Energy -0.34472047
# ../dataset_WaterClusters_big/N32-T200/1950.dat    Energy -0.34480871
# ../dataset_WaterClusters_big/N32-T200/1500.dat    Energy -0.38333578
# ../dataset_WaterClusters_big/N32-T200/1250.dat    Energy -0.39921433
# ../dataset_WaterClusters_big/N32-T200/0800.dat    Energy -0.34829064
# ../dataset_WaterClusters_big/N32-T200/0900.dat    Energy -0.3565953
# ../dataset_WaterClusters_big/N32-T200/0700.dat    Energy -0.38445663
# ../dataset_WaterClusters_big/N32-T200/0550.dat    Energy -0.38154525
# ../dataset_WaterClusters_big/N32-T200/1750.dat    Energy -0.36931549
# ../dataset_WaterClusters_big/N32-T200/1300.dat    Energy -0.37874388
# ../dataset_WaterClusters_big/N32-T200/0600.dat    Energy -0.36319175
# ../dataset_WaterClusters_big/N32-T200/0650.dat    Energy -0.37094626
# ../dataset_WaterClusters_big/N32-T200/1600.dat    Energy -0.36618304
# ../dataset_WaterClusters_big/N32-T200/1050.dat    Energy -0.38961826
# ../dataset_WaterClusters_big/N32-T200/0300.dat    Energy -0.37894748
# ../dataset_WaterClusters_big/N32-T200/1400.dat    Energy -0.35393081
# ../dataset_WaterClusters_big/N32-T200/1450.dat    Energy -0.37578087
# ../dataset_WaterClusters_big/N32-T200/1200.dat    Energy -0.37419178
# ../dataset_WaterClusters_big/N32-T200/0150.dat    Energy -0.35680671
# ../dataset_WaterClusters_big/N32-T200/1150.dat    Energy -0.36574833
# ../dataset_WaterClusters_big/N32-T200/0400.dat    Energy -0.37155815
# ../dataset_WaterClusters_big/N32-T200/0050.dat    Energy -0.34215729
# ../dataset_WaterClusters_big/N32-T200/0750.dat    Energy -0.37090956
# ../dataset_WaterClusters_big/N32-T200/1000.dat    Energy -0.35112485
# ../dataset_WaterClusters_big/N32-T200/1800.dat    Energy -0.36217946
# ../dataset_WaterClusters_big/N32-T200/0200.dat    Energy -0.37215014
# ../dataset_WaterClusters_big/N139-T100/0350.dat    Energy -2.32230442
# ../dataset_WaterClusters_big/N139-T100/1700.dat    Energy -2.36179765
# ../dataset_WaterClusters_big/N139-T100/0100.dat    Energy -2.32988305
# ../dataset_WaterClusters_big/N139-T100/1550.dat    Energy -2.36001638
# ../dataset_WaterClusters_big/N139-T100/1850.dat    Energy -2.34939342
# ../dataset_WaterClusters_big/N139-T100/1100.dat    Energy -2.34218684
# ../dataset_WaterClusters_big/N139-T100/0450.dat    Energy -2.33316833
# ../dataset_WaterClusters_big/N139-T100/0500.dat    Energy -2.32848073
# ../dataset_WaterClusters_big/N139-T100/1350.dat    Energy -2.37358267
# ../dataset_WaterClusters_big/N139-T100/0850.dat    Energy -2.3339579
# ../dataset_WaterClusters_big/N139-T100/1900.dat    Energy -2.35718204
# ../dataset_WaterClusters_big/N139-T100/1650.dat    Energy -2.3620373
# ../dataset_WaterClusters_big/N139-T100/0250.dat    Energy -2.32453868
# ../dataset_WaterClusters_big/N139-T100/0950.dat    Energy -2.33016822
# ../dataset_WaterClusters_big/N139-T100/2000.dat    Energy -2.35974026
# ../dataset_WaterClusters_big/N139-T100/1950.dat    Energy -2.37032944
# ../dataset_WaterClusters_big/N139-T100/1500.dat    Energy -2.34811643
# ../dataset_WaterClusters_big/N139-T100/1250.dat    Energy -2.36472232
# ../dataset_WaterClusters_big/N139-T100/0800.dat    Energy -2.32901799
# ../dataset_WaterClusters_big/N139-T100/0900.dat    Energy -2.34536421
# ../dataset_WaterClusters_big/N139-T100/0700.dat    Energy -2.33058079
# ../dataset_WaterClusters_big/N139-T100/0550.dat    Energy -2.31989078
# ../dataset_WaterClusters_big/N139-T100/1750.dat    Energy -2.37106405
# ../dataset_WaterClusters_big/N139-T100/1300.dat    Energy -2.36774927
# ../dataset_WaterClusters_big/N139-T100/0600.dat    Energy -2.31805923
# ../dataset_WaterClusters_big/N139-T100/0650.dat    Energy -2.3215908
# ../dataset_WaterClusters_big/N139-T100/1600.dat    Energy -2.36227268
# ../dataset_WaterClusters_big/N139-T100/1050.dat    Energy -2.33857868
# ../dataset_WaterClusters_big/N139-T100/0300.dat    Energy -2.3185002
# ../dataset_WaterClusters_big/N139-T100/1400.dat    Energy -2.36046492
# ../dataset_WaterClusters_big/N139-T100/1450.dat    Energy -2.35969504
# ../dataset_WaterClusters_big/N139-T100/1200.dat    Energy -2.35756011
# ../dataset_WaterClusters_big/N139-T100/0150.dat    Energy -2.32939141
# ../dataset_WaterClusters_big/N139-T100/1150.dat    Energy -2.34497095
# ../dataset_WaterClusters_big/N139-T100/0400.dat    Energy -2.31009598
# ../dataset_WaterClusters_big/N139-T100/0050.dat    Energy -2.30806327
# ../dataset_WaterClusters_big/N139-T100/0750.dat    Energy -2.34640893
# ../dataset_WaterClusters_big/N139-T100/1000.dat    Energy -2.33196448
# ../dataset_WaterClusters_big/N139-T100/1800.dat    Energy -2.36059423
# ../dataset_WaterClusters_big/N139-T100/0200.dat    Energy -2.32112811
# ../dataset_WaterClusters_big/N139-T150/0350.dat    Energy -2.2037802
# ../dataset_WaterClusters_big/N139-T150/1700.dat    Energy -2.235837
# ../dataset_WaterClusters_big/N139-T150/0100.dat    Energy -2.2297936
# ../dataset_WaterClusters_big/N139-T150/1550.dat    Energy -2.23141561
# ../dataset_WaterClusters_big/N139-T150/1850.dat    Energy -2.22879064
# ../dataset_WaterClusters_big/N139-T150/1100.dat    Energy -2.21034087
# ../dataset_WaterClusters_big/N139-T150/0450.dat    Energy -2.21402727
# ../dataset_WaterClusters_big/N139-T150/0500.dat    Energy -2.22403902
# ../dataset_WaterClusters_big/N139-T150/1350.dat    Energy -2.25308253
# ../dataset_WaterClusters_big/N139-T150/0850.dat    Energy -2.21829602
# ../dataset_WaterClusters_big/N139-T150/1900.dat    Energy -2.21590034
# ../dataset_WaterClusters_big/N139-T150/1650.dat    Energy -2.22388525
# ../dataset_WaterClusters_big/N139-T150/0250.dat    Energy -2.19789318
# ../dataset_WaterClusters_big/N139-T150/0950.dat    Energy -2.21935103
# ../dataset_WaterClusters_big/N139-T150/2000.dat    Energy -2.22553594
# ../dataset_WaterClusters_big/N139-T150/1950.dat    Energy -2.22885313
# ../dataset_WaterClusters_big/N139-T150/1500.dat    Energy -2.2276131
# ../dataset_WaterClusters_big/N139-T150/1250.dat    Energy -2.24751736
# ../dataset_WaterClusters_big/N139-T150/0800.dat    Energy -2.20332591
# ../dataset_WaterClusters_big/N139-T150/0900.dat    Energy -2.23493439
# ../dataset_WaterClusters_big/N139-T150/0700.dat    Energy -2.21523461
# ../dataset_WaterClusters_big/N139-T150/0550.dat    Energy -2.21316894
# ../dataset_WaterClusters_big/N139-T150/1750.dat    Energy -2.22530924
# ../dataset_WaterClusters_big/N139-T150/1300.dat    Energy -2.22826026
# ../dataset_WaterClusters_big/N139-T150/0600.dat    Energy -2.19604972
# ../dataset_WaterClusters_big/N139-T150/0650.dat    Energy -2.21185511
# ../dataset_WaterClusters_big/N139-T150/1600.dat    Energy -2.23326045
# ../dataset_WaterClusters_big/N139-T150/1050.dat    Energy -2.20901397
# ../dataset_WaterClusters_big/N139-T150/0300.dat    Energy -2.20513082
# ../dataset_WaterClusters_big/N139-T150/1400.dat    Energy -2.21175939
# ../dataset_WaterClusters_big/N139-T150/1450.dat    Energy -2.22593371
# ../dataset_WaterClusters_big/N139-T150/1200.dat    Energy -2.24430381
# ../dataset_WaterClusters_big/N139-T150/0150.dat    Energy -2.22172455
# ../dataset_WaterClusters_big/N139-T150/1150.dat    Energy -2.21050382
# ../dataset_WaterClusters_big/N139-T150/0400.dat    Energy -2.19055069
# ../dataset_WaterClusters_big/N139-T150/0050.dat    Energy -2.18528189
# ../dataset_WaterClusters_big/N139-T150/0750.dat    Energy -2.22669831
# ../dataset_WaterClusters_big/N139-T150/1000.dat    Energy -2.23117976
# ../dataset_WaterClusters_big/N139-T150/1800.dat    Energy -2.21870137
# ../dataset_WaterClusters_big/N139-T150/0200.dat    Energy -2.21552278
# ../dataset_WaterClusters_big/N32-T50/0350.dat    Energy -0.46209072
# ../dataset_WaterClusters_big/N32-T50/1700.dat    Energy -0.45828277
# ../dataset_WaterClusters_big/N32-T50/0100.dat    Energy -0.46103404
# ../dataset_WaterClusters_big/N32-T50/1550.dat    Energy -0.46632491
# ../dataset_WaterClusters_big/N32-T50/1850.dat    Energy -0.45545124
# ../dataset_WaterClusters_big/N32-T50/1100.dat    Energy -0.46395646
# ../dataset_WaterClusters_big/N32-T50/0450.dat    Energy -0.46277464
# ../dataset_WaterClusters_big/N32-T50/0500.dat    Energy -0.45744711
# ../dataset_WaterClusters_big/N32-T50/1350.dat    Energy -0.4652916
# ../dataset_WaterClusters_big/N32-T50/0850.dat    Energy -0.46192902
# ../dataset_WaterClusters_big/N32-T50/1900.dat    Energy -0.45995966
# ../dataset_WaterClusters_big/N32-T50/1650.dat    Energy -0.45948353
# ../dataset_WaterClusters_big/N32-T50/0250.dat    Energy -0.45842046
# ../dataset_WaterClusters_big/N32-T50/0950.dat    Energy -0.46199582
# ...
# ../dataset_WaterClusters_big/N100-T200/0850.dat    Energy -1.46149537
# ../dataset_WaterClusters_big/N100-T200/1900.dat    Energy -1.42666695
# ../dataset_WaterClusters_big/N100-T200/1650.dat    Energy -1.45907433
# ../dataset_WaterClusters_big/N100-T200/0250.dat    Energy -1.42861496
# ../dataset_WaterClusters_big/N100-T200/0950.dat    Energy -1.42986328
# ../dataset_WaterClusters_big/N100-T200/2000.dat    Energy -1.46138544
# ../dataset_WaterClusters_big/N100-T200/1950.dat    Energy -1.46763168
# ../dataset_WaterClusters_big/N100-T200/1500.dat    Energy -1.45458232
# ../dataset_WaterClusters_big/N100-T200/1250.dat    Energy -1.43509758
# ../dataset_WaterClusters_big/N100-T200/0800.dat    Energy -1.4555836
# ../dataset_WaterClusters_big/N100-T200/0900.dat    Energy -1.46429942
# ../dataset_WaterClusters_big/N100-T200/0700.dat    Energy -1.43358414
# ../dataset_WaterClusters_big/N100-T200/0550.dat    Energy -1.45105843
# ../dataset_WaterClusters_big/N100-T200/1750.dat    Energy -1.44802653
# ../dataset_WaterClusters_big/N100-T200/1300.dat    Energy -1.41930275
# ../dataset_WaterClusters_big/N100-T200/0600.dat    Energy -1.46203661
# ../dataset_WaterClusters_big/N100-T200/0650.dat    Energy -1.46954693
# ../dataset_WaterClusters_big/N100-T200/1600.dat    Energy -1.45529432
# ../dataset_WaterClusters_big/N100-T200/1050.dat    Energy -1.44427644
# ../dataset_WaterClusters_big/N100-T200/0300.dat    Energy -1.42088805
# ../dataset_WaterClusters_big/N100-T200/1400.dat    Energy -1.42334579
# ../dataset_WaterClusters_big/N100-T200/1450.dat    Energy -1.46730068
# ../dataset_WaterClusters_big/N100-T200/1200.dat    Energy -1.43877363
# ../dataset_WaterClusters_big/N100-T200/0150.dat    Energy -1.40187126
# ../dataset_WaterClusters_big/N100-T200/1150.dat    Energy -1.42679608
# ../dataset_WaterClusters_big/N100-T200/0400.dat    Energy -1.41466248
# ../dataset_WaterClusters_big/N100-T200/0050.dat    Energy -1.38673542
# ../dataset_WaterClusters_big/N100-T200/0750.dat    Energy -1.48650612
# ../dataset_WaterClusters_big/N100-T200/1000.dat    Energy -1.45363345
# ../dataset_WaterClusters_big/N100-T200/1800.dat    Energy -1.48074798
# ../dataset_WaterClusters_big/N100-T200/0200.dat    Energy -1.40284117
# ../dataset_WaterClusters_big/N47-T200/0350.dat    Energy -0.64368566
# ../dataset_WaterClusters_big/N47-T200/1700.dat    Energy -0.64254107
# ../dataset_WaterClusters_big/N47-T200/0100.dat    Energy -0.63915792
# ../dataset_WaterClusters_big/N47-T200/1550.dat    Energy -0.65003474
# ../dataset_WaterClusters_big/N47-T200/1850.dat    Energy -0.64149848
# ../dataset_WaterClusters_big/N47-T200/1100.dat    Energy -0.6287667
# ../dataset_WaterClusters_big/N47-T200/0450.dat    Energy -0.63962248
# ../dataset_WaterClusters_big/N47-T200/0500.dat    Energy -0.62599931
# ../dataset_WaterClusters_big/N47-T200/1350.dat    Energy -0.64017183
# ../dataset_WaterClusters_big/N47-T200/0850.dat    Energy -0.6223952
# ../dataset_WaterClusters_big/N47-T200/1900.dat    Energy -0.65179162
# ../dataset_WaterClusters_big/N47-T200/1650.dat    Energy -0.64620913
# ../dataset_WaterClusters_big/N47-T200/0250.dat    Energy -0.64483193
# ../dataset_WaterClusters_big/N47-T200/0950.dat    Energy -0.6239085
# ../dataset_WaterClusters_big/N47-T200/2000.dat    Energy -0.63888085
# ../dataset_WaterClusters_big/N47-T200/1950.dat    Energy -0.65162045
# ../dataset_WaterClusters_big/N47-T200/1500.dat    Energy -0.62925937
# ../dataset_WaterClusters_big/N47-T200/1250.dat    Energy -0.62354713
# ../dataset_WaterClusters_big/N47-T200/0800.dat    Energy -0.64048638
# ../dataset_WaterClusters_big/N47-T200/0900.dat    Energy -0.6200018
# ../dataset_WaterClusters_big/N47-T200/0700.dat    Energy -0.63993068
# ../dataset_WaterClusters_big/N47-T200/0550.dat    Energy -0.63370651
# ../dataset_WaterClusters_big/N47-T200/1750.dat    Energy -0.64878859
# ../dataset_WaterClusters_big/N47-T200/1300.dat    Energy -0.63792755
# ../dataset_WaterClusters_big/N47-T200/0600.dat    Energy -0.64766758
# ../dataset_WaterClusters_big/N47-T200/0650.dat    Energy -0.65348753
# ../dataset_WaterClusters_big/N47-T200/1600.dat    Energy -0.6469605
# ../dataset_WaterClusters_big/N47-T200/1050.dat    Energy -0.62106433
# ../dataset_WaterClusters_big/N47-T200/0300.dat    Energy -0.62971094
# ../dataset_WaterClusters_big/N47-T200/1400.dat    Energy -0.62499669
# ../dataset_WaterClusters_big/N47-T200/1450.dat    Energy -0.64773981
# ../dataset_WaterClusters_big/N47-T200/1200.dat    Energy -0.63708543
# ../dataset_WaterClusters_big/N47-T200/0150.dat    Energy -0.63924489
# ../dataset_WaterClusters_big/N47-T200/1150.dat    Energy -0.62852781
# ../dataset_WaterClusters_big/N47-T200/0400.dat    Energy -0.63021047
# ../dataset_WaterClusters_big/N47-T200/0050.dat    Energy -0.62172206
# ../dataset_WaterClusters_big/N47-T200/0750.dat    Energy -0.62950499
# ../dataset_WaterClusters_big/N47-T200/1000.dat    Energy -0.62755336
# ../dataset_WaterClusters_big/N47-T200/1800.dat    Energy -0.6462361
# ../dataset_WaterClusters_big/N47-T200/0200.dat    Energy -0.6280205
# ../dataset_WaterClusters_big/N237-T100/0350.dat    Energy -4.08505679
# ../dataset_WaterClusters_big/N237-T100/1700.dat    Energy -4.1247424
# ../dataset_WaterClusters_big/N237-T100/0100.dat    Energy -4.08412843
# ../dataset_WaterClusters_big/N237-T100/1550.dat    Energy -4.10478417
# ../dataset_WaterClusters_big/N237-T100/1850.dat    Energy -4.12024696
# ../dataset_WaterClusters_big/N237-T100/1100.dat    Energy -4.0868835
# ../dataset_WaterClusters_big/N237-T100/0450.dat    Energy -4.10852564
# ../dataset_WaterClusters_big/N237-T100/0500.dat    Energy -4.12018061
# ../dataset_WaterClusters_big/N237-T100/1350.dat    Energy -4.10828808
# ../dataset_WaterClusters_big/N237-T100/0850.dat    Energy -4.09804567
# ../dataset_WaterClusters_big/N237-T100/1900.dat    Energy -4.11344446
# ../dataset_WaterClusters_big/N237-T100/1650.dat    Energy -4.12418848
# ../dataset_WaterClusters_big/N237-T100/0250.dat    Energy -4.08107745
# ../dataset_WaterClusters_big/N237-T100/0950.dat    Energy -4.0870274
# ../dataset_WaterClusters_big/N237-T100/2000.dat    Energy -4.10904897
# ../dataset_WaterClusters_big/N237-T100/1950.dat    Energy -4.10996423
# ../dataset_WaterClusters_big/N237-T100/1500.dat    Energy -4.10671878
# ../dataset_WaterClusters_big/N237-T100/1250.dat    Energy -4.10024964
# ../dataset_WaterClusters_big/N237-T100/0800.dat    Energy -4.09399699
# ../dataset_WaterClusters_big/N237-T100/0900.dat    Energy -4.07299877
# ../dataset_WaterClusters_big/N237-T100/0700.dat    Energy -4.07976092
# ../dataset_WaterClusters_big/N237-T100/0550.dat    Energy -4.07713016
# ../dataset_WaterClusters_big/N237-T100/1750.dat    Energy -4.1212429
# ../dataset_WaterClusters_big/N237-T100/1300.dat    Energy -4.1241968
# ../dataset_WaterClusters_big/N237-T100/0600.dat    Energy -4.05899336
# ../dataset_WaterClusters_big/N237-T100/0650.dat    Energy -4.09213984
# ../dataset_WaterClusters_big/N237-T100/1600.dat    Energy -4.09320041
# ../dataset_WaterClusters_big/N237-T100/1050.dat    Energy -4.10885448
# ../dataset_WaterClusters_big/N237-T100/0300.dat    Energy -4.09657688
# ../dataset_WaterClusters_big/N237-T100/1400.dat    Energy -4.11044888
# ../dataset_WaterClusters_big/N237-T100/1450.dat    Energy -4.10498212
# ../dataset_WaterClusters_big/N237-T100/1200.dat    Energy -4.10786169
# ../dataset_WaterClusters_big/N237-T100/0150.dat    Energy -4.0868406
# ../dataset_WaterClusters_big/N237-T100/1150.dat    Energy -4.08428947
# ../dataset_WaterClusters_big/N237-T100/0400.dat    Energy -4.08266151
# ../dataset_WaterClusters_big/N237-T100/0050.dat    Energy -4.08307876
# ../dataset_WaterClusters_big/N237-T100/0750.dat    Energy -4.10088651
# ../dataset_WaterClusters_big/N237-T100/1000.dat    Energy -4.10263458
# ../dataset_WaterClusters_big/N237-T100/1800.dat    Energy -4.1099904
# ../dataset_WaterClusters_big/N237-T100/0200.dat    Energy -4.07942065
# ../dataset_WaterClusters_big/N76-T150/0350.dat    Energy -1.08956754
# ../dataset_WaterClusters_big/N76-T150/1700.dat    Energy -1.10033262
# ../dataset_WaterClusters_big/N76-T150/0100.dat    Energy -1.1005563
# ../dataset_WaterClusters_big/N76-T150/1550.dat    Energy -1.08174377
# ../dataset_WaterClusters_big/N76-T150/1850.dat    Energy -1.1099408
# ../dataset_WaterClusters_big/N76-T150/1100.dat    Energy -1.10285215
# ../dataset_WaterClusters_big/N76-T150/0450.dat    Energy -1.12675692
# ../dataset_WaterClusters_big/N76-T150/0500.dat    Energy -1.10143895
# ../dataset_WaterClusters_big/N76-T150/1350.dat    Energy -1.12166663
# ../dataset_WaterClusters_big/N76-T150/0850.dat    Energy -1.11732276
# ../dataset_WaterClusters_big/N76-T150/1900.dat    Energy -1.10014011
# ../dataset_WaterClusters_big/N76-T150/1650.dat    Energy -1.0863389
# ../dataset_WaterClusters_big/N76-T150/0250.dat    Energy -1.0819425
# ../dataset_WaterClusters_big/N76-T150/0950.dat    Energy -1.1271641
# ../dataset_WaterClusters_big/N76-T150/2000.dat    Energy -1.09222887
# ../dataset_WaterClusters_big/N76-T150/1950.dat    Energy -1.1079004
# ../dataset_WaterClusters_big/N76-T150/1500.dat    Energy -1.0927221
# ../dataset_WaterClusters_big/N76-T150/1250.dat    Energy -1.11620651
# ../dataset_WaterClusters_big/N76-T150/0800.dat    Energy -1.11510317
# ../dataset_WaterClusters_big/N76-T150/0900.dat    Energy -1.09483344
# ../dataset_WaterClusters_big/N76-T150/0700.dat    Energy -1.13603934
# ../dataset_WaterClusters_big/N76-T150/0550.dat    Energy -1.11891579
# ../dataset_WaterClusters_big/N76-T150/1750.dat    Energy -1.1051659
# ../dataset_WaterClusters_big/N76-T150/1300.dat    Energy -1.11177507
# ../dataset_WaterClusters_big/N76-T150/0600.dat    Energy -1.12375546
# ../dataset_WaterClusters_big/N76-T150/0650.dat    Energy -1.10240424
# ../dataset_WaterClusters_big/N76-T150/1600.dat    Energy -1.0845236
# ../dataset_WaterClusters_big/N76-T150/1050.dat    Energy -1.10774454
# ../dataset_WaterClusters_big/N76-T150/0300.dat    Energy -1.06853096
# ../dataset_WaterClusters_big/N76-T150/1400.dat    Energy -1.12108965
# ../dataset_WaterClusters_big/N76-T150/1450.dat    Energy -1.08592129
# ../dataset_WaterClusters_big/N76-T150/1200.dat    Energy -1.1109494
# ../dataset_WaterClusters_big/N76-T150/0150.dat    Energy -1.09431681
# ../dataset_WaterClusters_big/N76-T150/1150.dat    Energy -1.11121998
# ../dataset_WaterClusters_big/N76-T150/0400.dat    Energy -1.0989194
# ../dataset_WaterClusters_big/N76-T150/0050.dat    Energy -1.09734083
# ../dataset_WaterClusters_big/N76-T150/0750.dat    Energy -1.12633732
# ../dataset_WaterClusters_big/N76-T150/1000.dat    Energy -1.12905041
# ../dataset_WaterClusters_big/N76-T150/1800.dat    Energy -1.12529989
# ../dataset_WaterClusters_big/N76-T150/0200.dat    Energy -1.09843568
# ../dataset_WaterClusters_big/N190-T50/0350.dat    Energy -3.37171574
# ../dataset_WaterClusters_big/N190-T50/1700.dat    Energy -3.40250657
# ../dataset_WaterClusters_big/N190-T50/0100.dat    Energy -3.37522186
# ../dataset_WaterClusters_big/N190-T50/1550.dat    Energy -3.39509177
# ../dataset_WaterClusters_big/N190-T50/1850.dat    Energy -3.40460293
# ../dataset_WaterClusters_big/N190-T50/1100.dat    Energy -3.38853079
# ../dataset_WaterClusters_big/N190-T50/0450.dat    Energy -3.36829523
# ../dataset_WaterClusters_big/N190-T50/0500.dat    Energy -3.37025378
# ../dataset_WaterClusters_big/N190-T50/1350.dat    Energy -3.38441631
# ../dataset_WaterClusters_big/N190-T50/0850.dat    Energy -3.37304753
# ../dataset_WaterClusters_big/N190-T50/1900.dat    Energy -3.40509125
# ../dataset_WaterClusters_big/N190-T50/1650.dat    Energy -3.39864357
# ../dataset_WaterClusters_big/N190-T50/0250.dat    Energy -3.36551763
# ../dataset_WaterClusters_big/N190-T50/0950.dat    Energy -3.37184251
# ../dataset_WaterClusters_big/N190-T50/2000.dat    Energy -3.38030729
# ../dataset_WaterClusters_big/N190-T50/1950.dat    Energy -3.39887852
# ../dataset_WaterClusters_big/N190-T50/1500.dat    Energy -3.40015503
# ../dataset_WaterClusters_big/N190-T50/1250.dat    Energy -3.37846891
# ../dataset_WaterClusters_big/N190-T50/0800.dat    Energy -3.38046169
# ../dataset_WaterClusters_big/N190-T50/0900.dat    Energy -3.37875454
# ../dataset_WaterClusters_big/N190-T50/0700.dat    Energy -3.38985352
# ../dataset_WaterClusters_big/N190-T50/0550.dat    Energy -3.38094555
# ../dataset_WaterClusters_big/N190-T50/1750.dat    Energy -3.40090305
# ../dataset_WaterClusters_big/N190-T50/1300.dat    Energy -3.40105958
# ../dataset_WaterClusters_big/N190-T50/0600.dat    Energy -3.37447877
# ../dataset_WaterClusters_big/N190-T50/0650.dat    Energy -3.36524733
# ../dataset_WaterClusters_big/N190-T50/1600.dat    Energy -3.39191502
# ../dataset_WaterClusters_big/N190-T50/1050.dat    Energy -3.3853021
# ../dataset_WaterClusters_big/N190-T50/0300.dat    Energy -3.37697487
# ../dataset_WaterClusters_big/N190-T50/1400.dat    Energy -3.39847499
# ../dataset_WaterClusters_big/N190-T50/1450.dat    Energy -3.40259179
# ../dataset_WaterClusters_big/N190-T50/1200.dat    Energy -3.40001831
# ../dataset_WaterClusters_big/N190-T50/0150.dat    Energy -3.38214847
# ../dataset_WaterClusters_big/N190-T50/1150.dat    Energy -3.39233438
# ../dataset_WaterClusters_big/N190-T50/0400.dat    Energy -3.37266539
# ../dataset_WaterClusters_big/N190-T50/0050.dat    Energy -3.35913103
# ../dataset_WaterClusters_big/N190-T50/0750.dat    Energy -3.37733589
# ../dataset_WaterClusters_big/N190-T50/1000.dat    Energy -3.38513376
# ../dataset_WaterClusters_big/N190-T50/1800.dat    Energy -3.39458695
# ../dataset_WaterClusters_big/N190-T50/0200.dat    Energy -3.37627136
# ../dataset_WaterClusters_big/N76-T200/0350.dat    Energy -1.00336798
# ../dataset_WaterClusters_big/N76-T200/1700.dat    Energy -1.05448736
# ../dataset_WaterClusters_big/N76-T200/0100.dat    Energy -0.99844911
# ../dataset_WaterClusters_big/N76-T200/1550.dat    Energy -1.01639992
# ../dataset_WaterClusters_big/N76-T200/1850.dat    Energy -1.06017125
# ../dataset_WaterClusters_big/N76-T200/1100.dat    Energy -1.01698033
# ../dataset_WaterClusters_big/N76-T200/0450.dat    Energy -1.01742036
# ../dataset_WaterClusters_big/N76-T200/0500.dat    Energy -1.01955856
# ../dataset_WaterClusters_big/N76-T200/1350.dat    Energy -1.04985906
# ../dataset_WaterClusters_big/N76-T200/0850.dat    Energy -0.99817336
# ../dataset_WaterClusters_big/N76-T200/1900.dat    Energy -1.04260542
# ../dataset_WaterClusters_big/N76-T200/1650.dat    Energy -1.04128211
# ../dataset_WaterClusters_big/N76-T200/0250.dat    Energy -1.00463233
# ../dataset_WaterClusters_big/N76-T200/0950.dat    Energy -1.05553181
# ../dataset_WaterClusters_big/N76-T200/2000.dat    Energy -1.02886084
# ../dataset_WaterClusters_big/N76-T200/1950.dat    Energy -1.04866794
# ../dataset_WaterClusters_big/N76-T200/1500.dat    Energy -1.02092776
# ../dataset_WaterClusters_big/N76-T200/1250.dat    Energy -1.03722054
# ../dataset_WaterClusters_big/N76-T200/0800.dat    Energy -1.00823441
# ../dataset_WaterClusters_big/N76-T200/0900.dat    Energy -1.03319457
# ../dataset_WaterClusters_big/N76-T200/0700.dat    Energy -1.03944926
# ../dataset_WaterClusters_big/N76-T200/0550.dat    Energy -1.04564257
# ../dataset_WaterClusters_big/N76-T200/1750.dat    Energy -1.06011245
# ../dataset_WaterClusters_big/N76-T200/1300.dat    Energy -1.02061449
# ../dataset_WaterClusters_big/N76-T200/0600.dat    Energy -1.03823121
# ../dataset_WaterClusters_big/N76-T200/0650.dat    Energy -0.98695323
# ../dataset_WaterClusters_big/N76-T200/1600.dat    Energy -1.02975049
# ../dataset_WaterClusters_big/N76-T200/1050.dat    Energy -1.0309569
# ../dataset_WaterClusters_big/N76-T200/0300.dat    Energy -0.98832581
# ../dataset_WaterClusters_big/N76-T200/1400.dat    Energy -1.05146429
# ../dataset_WaterClusters_big/N76-T200/1450.dat    Energy -1.04100247
# ../dataset_WaterClusters_big/N76-T200/1200.dat    Energy -1.02696801
# ../dataset_WaterClusters_big/N76-T200/0150.dat    Energy -0.98242663
# ../dataset_WaterClusters_big/N76-T200/1150.dat    Energy -1.04116492
# ../dataset_WaterClusters_big/N76-T200/0400.dat    Energy -1.00611981
# ../dataset_WaterClusters_big/N76-T200/0050.dat    Energy -1.01278391
# ../dataset_WaterClusters_big/N76-T200/0750.dat    Energy -1.03259634
# ../dataset_WaterClusters_big/N76-T200/1000.dat    Energy -1.04861342
# ../dataset_WaterClusters_big/N76-T200/1800.dat    Energy -1.07468826
# ../dataset_WaterClusters_big/N76-T200/0200.dat    Energy -1.00995792

# %%
################################################################################
# Build model
################################################################################
class Net(Model):
    def __init__(self):
        super().__init__()
        #self.conv1 = ECCConv(32, activation="relu")
        #self.conv2 = ECCConv(32, activation="relu")
        #self.conv1 = GCSConv(32, activation="relu")
        #self.conv2 = GCSConv(32, activation="relu")
        #self.conv1 = GCSConv(64, activation="tanh")
        #self.conv2 = GCSConv(64, activation="tanh")
        #self.conv3 = GCSConv(64, activation="tanh")
        self.conv1 = CrystalConv(aggregate="sum",activation="sigmoid")
        self.conv2 = CrystalConv(aggregate="sum",activation="sigmoid")
        #self.conv1 = GATConv(8,attn_heads=7,dropout_rate=0)
        #self.conv2 = GATConv(8,attn_heads=7,dropout_rate=0)
        #self.global_pool = GlobalSumPool()
        self.dense1 = Dense(128)
        self.dense2 = Dense(128)
        self.dense3 = Dense(F)
        #self.dense3 = Dense(dataset.num_node_features)
        self.global_pool = GlobalSumPool()
        #self.dense = Dense(n_out)

    def call(self, inputs):
        x, a, e, i = inputs
        x = self.conv1([x, a, e])
        x = self.conv2([x, a, e])
        #x, a, i = inputs
        #x = self.conv1([x, a])
        #x = self.conv2([x, a])
        #x = self.conv3([x, a])
        #output = self.global_pool([x, i])
        output = self.dense1(x)
        output = self.dense2(output)
        output = self.dense3(output)
        output = self.global_pool([output, i])
        #output = self.dense(output)

        return output

model = Net()
optimizer = Adam(learning_rate)
loss_fn = MeanSquaredError()
#loss_fn = MeanAbsoluteError()
#loss_fn = MeanAbsolutePercentageError()

# %%
################################################################################
# Fit model
################################################################################
@tf.function(input_signature=loader_tr.tf_signature(), experimental_relax_shapes=True)
def train_step(inputs, target):
    with tf.GradientTape() as tape:
        predictions = model(inputs, training=True)
        loss = loss_fn(target, predictions) + sum(model.losses)
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    return loss

outfile = open("loss.dat",'w')
nepoch = 1
step = loss = 0
loss_train = []
#loss_test = []
#loss_te = 0
for batch in loader_tr:
    step += 1
    loss += train_step(*batch)
    if step == loader_tr.steps_per_epoch:
        step = 0
        print(str(nepoch)+" Loss: {}".format(loss / loader_tr.steps_per_epoch))
        outfile.write(str(nepoch)+" {}".format(loss / loader_tr.steps_per_epoch)+" \n")
        loss_train.append(loss / loader_tr.steps_per_epoch)
        nepoch = nepoch + 1

        # log the loss into wandb
        #wandb.log({"loss": loss / loader_tr.steps_per_epoch})
        
        loss = 0

        """
        # Loss on test set
        batch_te = next(iter(loader_te))
        inputs, target = batch_te
        predictions = model(inputs, training=False)
        #loss_te += loss_fn(target, predictions)
        loss_te = loss_fn(target, predictions)
        #loss_te /= loader_te.steps_per_epoch
        loss_test.append(loss_te)
        #loss_te = 0
        """

outfile.close()

# Plot Loss Function on Training Set
plt.figure(figsize=(6,4))
plt.scatter(range(1,epochs+1),loss_train)
plt.plot(range(1,epochs+1),loss_train,ls="--")
plt.xlabel("Epochs")
plt.ylabel("Loss (MSE)")
plt.show()

"""
# Plot Loss Function on Test Set
plt.figure(figsize=(6,4))
plt.scatter(range(1,epochs+1),loss_test)
plt.plot(range(1,epochs+1),loss_test,ls="--")
plt.xlabel("Epochs")
plt.ylabel("Loss (MSE)")
plt.show()
"""
# Out:
# /home/alfonso/Work/UGR/Calculations/WaterClusters_GNNs/GNNs_WaterClusters_venv/lib/python3.10/site-packages/spektral/data/utils.py:221: UserWarning: you are shuffling a 'MyDataset' object which is not a subclass of 'Sequence'; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   np.random.shuffle(a)
# /home/alfonso/Work/UGR/Calculations/WaterClusters_GNNs/GNNs_WaterClusters_venv/lib/python3.10/site-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer GlorotUniform is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# 1 Loss: 63.71033477783203
# 2 Loss: 14.836661338806152
# 3 Loss: 5.335364818572998
# 4 Loss: 2.013763189315796
# 5 Loss: 5.993358135223389
# 6 Loss: 0.06157761439681053
# 7 Loss: 0.10546360164880753
# 8 Loss: 0.5376761555671692
# 9 Loss: 0.6430760025978088
# 10 Loss: 0.2041700780391693
# 11 Loss: 0.21692076325416565
# 12 Loss: 0.09382591396570206
# 13 Loss: 0.2256070077419281
# 14 Loss: 0.05364653095602989
# 15 Loss: 0.08586466312408447
# 16 Loss: 0.05716707929968834
# 17 Loss: 0.20431073009967804
# 18 Loss: 0.0700448751449585
# 19 Loss: 0.9559672474861145
# 20 Loss: 0.04256458953022957
# 21 Loss: 0.05707749351859093
# 22 Loss: 0.07410594820976257
# 23 Loss: 0.05582531541585922
# 24 Loss: 0.09148968011140823
# 25 Loss: 0.07800564914941788
# 26 Loss: 0.08794480562210083
# 27 Loss: 0.15966029465198517
# 28 Loss: 0.046563759446144104
# 29 Loss: 0.4524250030517578
# 30 Loss: 0.039791449904441833
# 31 Loss: 0.04462355747818947
# 32 Loss: 0.06814487278461456
# 33 Loss: 0.07712192833423615
# 34 Loss: 0.12929558753967285
# 35 Loss: 0.06078282743692398
# 36 Loss: 0.09922970831394196
# 37 Loss: 0.15250729024410248
# 38 Loss: 0.04815569892525673
# 39 Loss: 0.08082916587591171
# 40 Loss: 0.9440462589263916
# 41 Loss: 0.047364212572574615
# 42 Loss: 0.043858762830495834
# 43 Loss: 0.046072717756032944
# 44 Loss: 0.06204883009195328
# 45 Loss: 0.06734007596969604
# 46 Loss: 0.15478599071502686
# 47 Loss: 0.06688783317804337
# 48 Loss: 0.0808403342962265
# 49 Loss: 0.05811205878853798
# 50 Loss: 0.2133803516626358
# 51 Loss: 0.03813931718468666
# 52 Loss: 0.05957091599702835
# 53 Loss: 0.06435228139162064
# 54 Loss: 0.23218566179275513
# 55 Loss: 0.040986254811286926
# 56 Loss: 0.057802021503448486
# 57 Loss: 0.09126833081245422
# 58 Loss: 0.06436865031719208
# 59 Loss: 0.5642849206924438
# 60 Loss: 0.04540819302201271
# 61 Loss: 0.06020987406373024
# 62 Loss: 0.046851739287376404
# 63 Loss: 0.07020401209592819
# 64 Loss: 0.08082892745733261
# 65 Loss: 0.17261064052581787
# 66 Loss: 0.07529637962579727
# 67 Loss: 0.12958520650863647
# 68 Loss: 0.283406525850296
# 69 Loss: 0.06189412623643875
# 70 Loss: 0.07240713387727737
# 71 Loss: 0.258150577545166
# 72 Loss: 0.04544055089354515
# 73 Loss: 0.05024148151278496
# 74 Loss: 0.11531993001699448
# 75 Loss: 0.0573713481426239
# 76 Loss: 1.0757293701171875
# 77 Loss: 0.03635512664914131
# 78 Loss: 0.04310784488916397
# 79 Loss: 0.06662361323833466
# 80 Loss: 0.0723438486456871
# 81 Loss: 0.05992528051137924
# 82 Loss: 0.2521246671676636
# 83 Loss: 0.04582249000668526
# 84 Loss: 0.08500707149505615
# 85 Loss: 0.07737497240304947
# 86 Loss: 0.6590723395347595
# 87 Loss: 0.04848816245794296
# 88 Loss: 0.048306580632925034
# 89 Loss: 0.06366655975580215
# 90 Loss: 0.06731583923101425
# 91 Loss: 0.062267955392599106
# 92 Loss: 1.2559820413589478
# 93 Loss: 0.09732091426849365
# 94 Loss: 0.04946113005280495
# 95 Loss: 0.051916174590587616
# 96 Loss: 0.06616264581680298
# 97 Loss: 0.05841595679521561
# 98 Loss: 0.11145759373903275
# 99 Loss: 0.07639812678098679
# 100 Loss: 0.1111643835902214
# 101 Loss: 0.08049066364765167
# 102 Loss: 1.3740975856781006
# 103 Loss: 0.03459378331899643
# 104 Loss: 0.039645273238420486
# 105 Loss: 0.07678733021020889
# 106 Loss: 0.07198436558246613
# 107 Loss: 0.056696679443120956
# 108 Loss: 0.06802042573690414
# 109 Loss: 0.6554521322250366
# 110 Loss: 0.04757555201649666
# 111 Loss: 0.05025344341993332
# 112 Loss: 0.09278172254562378
# 113 Loss: 0.06789878010749817
# 114 Loss: 0.3800811171531677
# 115 Loss: 0.05290825292468071
# 116 Loss: 0.077830471098423
# 117 Loss: 0.26729440689086914
# 118 Loss: 0.053812142461538315
# 119 Loss: 0.07408178597688675
# 120 Loss: 0.12744152545928955
# 121 Loss: 0.20696291327476501
# 122 Loss: 0.05286822468042374
# 123 Loss: 0.06692668795585632
# 124 Loss: 0.4098215699195862
# 125 Loss: 0.04294336587190628
# 126 Loss: 0.04700430482625961
# 127 Loss: 0.07654711604118347
# 128 Loss: 0.6598042249679565
# 129 Loss: 0.03737126290798187
# 130 Loss: 0.06255827844142914
# 131 Loss: 0.05197412520647049
# 132 Loss: 0.0646749958395958
# 133 Loss: 0.06564036756753922
# 134 Loss: 0.7776367664337158
# 135 Loss: 0.05082113668322563
# 136 Loss: 0.05239921435713768
# 137 Loss: 0.07865529507398605
# 138 Loss: 1.1694122552871704
# 139 Loss: 0.06295838952064514
# 140 Loss: 0.06155189871788025
# 141 Loss: 0.04624391719698906
# 142 Loss: 0.06855415552854538
# 143 Loss: 0.056165993213653564
# 144 Loss: 1.3640540838241577
# 145 Loss: 0.03249392285943031
# 146 Loss: 0.044219743460416794
# 147 Loss: 0.050326280295848846
# 148 Loss: 0.052829254418611526
# 149 Loss: 0.14522600173950195
# 150 Loss: 0.06614221632480621
# 151 Loss: 1.2749048471450806
# 152 Loss: 0.08164559304714203
# 153 Loss: 0.04037501662969589
# 154 Loss: 0.054922208189964294
# 155 Loss: 0.08537401258945465
# 156 Loss: 0.06349876523017883
# 157 Loss: 0.3126615881919861
# 158 Loss: 0.06642366200685501
# 159 Loss: 0.062268950045108795
# 160 Loss: 0.05407929793000221
# 161 Loss: 0.38959401845932007
# 162 Loss: 0.04291345924139023
# 163 Loss: 0.06816480308771133
# 164 Loss: 0.08388175070285797
# 165 Loss: 0.05310916528105736
# 166 Loss: 1.1982322931289673
# 167 Loss: 0.03339849412441254
# 168 Loss: 0.04201335087418556
# 169 Loss: 0.053014613687992096
# 170 Loss: 0.08160896599292755
# 171 Loss: 0.41271549463272095
# 172 Loss: 0.14667385816574097
# 173 Loss: 0.049820732325315475
# 174 Loss: 0.05036650970578194
# 175 Loss: 0.06442655622959137
# 176 Loss: 0.06860113888978958
# 177 Loss: 0.2356691211462021
# 178 Loss: 0.04930450767278671
# 179 Loss: 0.17081308364868164
# 180 Loss: 0.07260049134492874
# 181 Loss: 0.08848042041063309
# 182 Loss: 0.06118176504969597
# 183 Loss: 0.42779549956321716
# 184 Loss: 0.04422904923558235
# 185 Loss: 0.06691807508468628
# 186 Loss: 0.04991297423839569
# 187 Loss: 0.13180460035800934
# 188 Loss: 0.04855437949299812
# 189 Loss: 0.08690452575683594
# 190 Loss: 0.11389687657356262
# 191 Loss: 0.05486688390374184
# 192 Loss: 0.106757253408432
# 193 Loss: 0.06240874528884888
# 194 Loss: 0.2134486436843872
# 195 Loss: 0.05968276783823967
# 196 Loss: 0.06453640758991241
# 197 Loss: 0.060536470264196396
# 198 Loss: 0.13410191237926483
# 199 Loss: 0.05266793072223663
# 200 Loss: 0.07205182313919067
# '\n# Plot Loss Function on Test Set\nplt.figure(figsize=(6,4))\nplt.scatter(range(1,epochs+1),loss_test)\nplt.plot(range(1,epochs+1),loss_test,ls="--")\nplt.xlabel("Epochs")\nplt.ylabel("Loss (MSE)")\nplt.show()\n'

# %%
# Plot Loss Function on Training Set
plt.figure(figsize=(6,4))
plt.scatter(range(1,epochs+1),loss_train)
plt.plot(range(1,epochs+1),loss_train,ls="--")
plt.xlabel("Epochs")
plt.ylabel("Loss (MSE)")
ymedian = np.median(loss_train)
#plt.xlim(0,200)
plt.ylim(0,ymedian*2)
plt.show()

# %%
################################################################################
# Evaluate model
################################################################################

# Loss on Test Set. Predicted vs Real energies
print("Testing model")
loss = 0
ypred = []
ytrue = []
for batch in loader_te:
    inputs, target = batch
    predictions = model(inputs, training=False)
    loss += loss_fn(target, predictions)
    ypred.append(predictions)
    ytrue.append(target)
loss /= loader_te.steps_per_epoch
print("Done. Test loss: {}".format(loss))
# Out:
# Testing model
# Done. Test loss: 0.06751308590173721

# %%
# Plot Predicted vs Real on Test Set

y_pred = np.array(ypred).ravel()
y_true = np.array(ytrue).ravel()

# Convert to original units
#y_pred = np.array(ypred).ravel()#/100
#y_true = np.array(ytrue).ravel()#/100

#E_avrg = -0.025591339035879856
#E_dev = 2.0321151163332116
#y_pred = np.array(ypred).ravel()*E_dev + E_avrg
#y_true = np.array(ytrue).ravel()*E_dev + E_avrg

plt.figure(figsize=(6,4))
plt.scatter(y_true,y_pred,label = "GNN model",color="red")
p1 = max(max(y_pred), max(y_true))
p2 = min(min(y_pred), min(y_true))
plt.plot([p1, p2], [p1, p2], 'b-')
#plt.plot(np.linspace(-0.2,0.1,50),np.linspace(-0.2,0.1,50))
plt.xlabel("True Atomic Energy")
plt.ylabel("Pred Atomic Energy")
#plt.xlim(-5,0)
#plt.ylim(-5,0)
plt.title("Test Set")
plt.show()

# mean absolute percentage error (MAPE)
def mape(ytrue, ypred):
    ytrue, ypred = np.array(ytrue), np.array(ypred)
    
    mape_i = np.zeros(len(ytrue))
    mape_i = np.abs((ypred-ytrue)/ytrue)*100
    mape_i = mape_i[ mape_i < 1e6]

    return np.mean(mape_i)

# Compute metrics (MAPE, MAE, MSE)
print("Test MAE:", mean_absolute_error(y_true,y_pred))
print("Test MSE:", mean_squared_error(y_true,y_pred))
print("Test MAPE:", mape(y_true,y_pred))
# Out:
# Test MAE: 0.20820651461779832
# Test MSE: 0.06751311221449577
# Test MAPE: 17.79871967095781
